# %% [raw]
# ---
# output-file: 052-family_history.html
# title: Family History
# ---

# %% [markdown]
# ### Description
#
# Family history information in medical research involves collecting data on genetic and hereditary conditions passed down through generations. This includes predispositions to diseases such as cancer, cardiovascular conditions, diabetes, and mental health disorders, helping identify potential health risks based on familial patterns.
#
# ### Introduction
#
# The Human Phenotype Project conducts comprehensive data collection through online surveys, where participants voluntarily provide information on various aspects influencing their health. This includes information about a participant's family history, captured through two lifestyle surveys and the Initial Medical Survey.
#
# ### Measurement protocol
# <!-- long measurment protocol for the data browser -->
# These lifestyle surveys are modeled after the UK Biobank's touch screen questionnaire. Participants receive the full version via email to complete on the Zoho platform, either before or after their baseline visit. A shorter, follow-up version of the questionnaire is then filled out by participants during subsequent visits.
#
# ### Data availability
# <!-- for the example notebooks -->
# The information is stored in 2 parquet files:  `initial_medical.parquet` and `ukbb.parquet`. The ukbb.parquet contains questions asked in our lifestyle surveys at the baseline and follow up stages.
#
# ### Summary of available data
# <!-- for the data browser -->
# 1. Initial Medical Survey: A DataFrame containing tabular features representing responses related to family medical history from the initial medical survey.
# 2. Lifestyle Survey: A DataFrame containing tabular features representing responses related to family medical history from the lifestyle survey.
#
# ### Relevant links
#
# * [Pheno Knowledgebase](https://knowledgebase.pheno.ai/datasets/052-family_history.html)
# * [Pheno Data Browser](https://pheno-demo-app.vercel.app/folder/52)

# %%
#| echo: false
import pandas as pd
pd.set_option("display.max_rows", 500)

# %%
from pheno_utils import PhenoLoader

# %%
pl = PhenoLoader('family_history')
pl
# Out:
# PhenoLoader for family_history with
# 60 fields
# 3 tables: ['initial_medical', 'ukbb', 'age_sex']

# %% [markdown]
# # Data dictionary

# %%
pl.dict
# Out:
#                                                 folder_id      feature_set  \
# tabular_field_name
# sudden_death_family                                    52  initial_medical
# family_history                                         52  initial_medical
# hypertension_family_number                             52  initial_medical
# hyperlipidemia_family_number                           52  initial_medical
# type_1_diabetes_family_number                          52  initial_medical
# type_2_diabetes_family_number                          52  initial_medical
# stroke_family_number                                   52  initial_medical
# kidney_disease_dialysis_family_number                  52  initial_medical
# autoimmune_diseases_family_number                      52  initial_medical
# hypercoagulation_family_number                         52  initial_medical
# clotting_family_number                                 52  initial_medical
# crohn_family_number                                    52  initial_medical
# celiac_family_number                                   52  initial_medical
# dementia_under_60_family_number                        52  initial_medical
# parkinson_family_number                                52  initial_medical
# asthma_family_number                                   52  initial_medical
# cancer_type_family                                     52  initial_medical
# collection_timestamp                                   52  initial_medical
# collection_date                                        52  initial_medical
# timezone                                               52  initial_medical
# early_life_breastfeeding                               52             ukbb
# early_life_comparative_body_weight                     52             ukbb
# early_life_comparative_body_height                     52             ukbb
# early_life_handedness                                  52             ukbb
# early_life_adopted                                     52             ukbb
# early_life_multiple_birth                              52             ukbb
# early_life_mother_smoking                              52             ukbb
# family_history_father_alive                            52             ukbb
# family_history_adopted_father_alive                    52             ukbb
# family_history_current_father_age                      52             ukbb
# family_history_current_adopted_father_age              52             ukbb
# family_history_father_age_passing                      52             ukbb
# family_history_adopted_father_age_passing              52             ukbb
# family_history_past_father_illness_1                   52             ukbb
# family_history_past_adopted_father_illness_1           52             ukbb
# family_history_past_father_illness_2                   52             ukbb
# family_history_past_adopted_father_illness_2           52             ukbb
# family_history_mother_alive                            52             ukbb
# family_history_adopted_mother_alive                    52             ukbb
# family_history_current_mother_age                      52             ukbb
# family_history_current_adopted_mother_age              52             ukbb
# family_history_mother_age_passing                      52             ukbb
# family_history_adopted_mother_age_passing              52             ukbb
# family_history_past_mother_illness_1                   52             ukbb
# family_history_past_adopted_mother_illness_1           52             ukbb
# family_history_past_mother_illness_2                   52             ukbb
# family_history_past_adopted_mother_illness_2           52             ukbb
# family_history_number_full_brothers                    52             ukbb
# family_history_number_adopted_brothers                 52             ukbb
# family_history_number_full_sisters                     52             ukbb
# family_history_number_adopted_sisters                  52             ukbb
# family_history_past_siblings_illness_1                 52             ukbb
# family_history_past_adopted_siblings_illness_1         52             ukbb
# family_history_past_siblings_illness_2                 52             ukbb
# family_history_past_adopted_siblings_illness_2         52             ukbb
# family_history_number_older_siblings                   52             ukbb
# family_history_non_accidental_death                    52             ukbb
# data_source                                            52             ukbb
# collection_timestamp                                   52             ukbb
# collection_date                                        52             ukbb
# timezone                                               52             ukbb
#
#                                                                                 field_string  \
# tabular_field_name
# sudden_death_family                                                      Sudden death family
# family_history                                                                Family history
# hypertension_family_number                                        Hypertension family number
# hyperlipidemia_family_number                                    Hyperlipidemia family number
# type_1_diabetes_family_number                                  Type 1 diabetes family number
# type_2_diabetes_family_number                                  Type 2 diabetes family number
# stroke_family_number                                                    Stroke family number
# kidney_disease_dialysis_family_number                  Kidney disease dialysis family number
# autoimmune_diseases_family_number                          Autoimmune diseases family number
# hypercoagulation_family_number                                Hypercoagulation family number
# clotting_family_number                                                Clotting family number
# crohn_family_number                                                      Crohn family number
# celiac_family_number                                                    Celiac family number
# dementia_under_60_family_number                              Dementia under 60 family number
# parkinson_family_number                                              Parkinson family number
# asthma_family_number                                                    Asthma family number
# cancer_type_family                                                        Cancer type family
# collection_timestamp                                                         Collection time
# collection_date                                                              Collection date
# timezone                                                                            Timezone
# early_life_breastfeeding                                                 Breastfed as a baby
# early_life_comparative_body_weight                           Comparative body size at age 10
# early_life_comparative_body_height                         Comparative height size at age 10
# early_life_handedness                                      Handedness (chirality/laterality)
# early_life_adopted                                                        Adopted as a child
# early_life_multiple_birth                                           Part of a multiple birth
# early_life_mother_smoking                                      Maternal smoking around birth
# family_history_father_alive                                               Father still alive
# family_history_adopted_father_alive                               Adopted father still alive
# family_history_current_father_age                                               Father's age
# family_history_current_adopted_father_age                                       Father's age
# family_history_father_age_passing                                      Father's age at death
# family_history_adopted_father_age_passing                              Father's age at death
# family_history_past_father_illness_1                                     Illnesses of father
# family_history_past_adopted_father_illness_1                     Illnesses of adopted father
# family_history_past_father_illness_2                                     Illnesses of father
# family_history_past_adopted_father_illness_2                     Illnesses of adopted father
# family_history_mother_alive                                               Mother still alive
# family_history_adopted_mother_alive                               Adopted mother still alive
# family_history_current_mother_age                                               Mother's age
# family_history_current_adopted_mother_age                                       Mother's age
# family_history_mother_age_passing                                      Mother's age at death
# family_history_adopted_mother_age_passing                              Mother's age at death
# family_history_past_mother_illness_1                                     Illnesses of mother
# family_history_past_adopted_mother_illness_1                     Illnesses of adopted mother
# family_history_past_mother_illness_2                                     Illnesses of mother
# family_history_past_adopted_mother_illness_2                     Illnesses of adopted mother
# family_history_number_full_brothers                                  Number of full brothers
# family_history_number_adopted_brothers                            Number of adopted brothers
# family_history_number_full_sisters                                    Number of full sisters
# family_history_number_adopted_sisters                              Number of adopted sisters
# family_history_past_siblings_illness_1                                 Illnesses of siblings
# family_history_past_adopted_siblings_illness_1                 Illnesses of adopted siblings
# family_history_past_siblings_illness_2                                 Illnesses of siblings
# family_history_past_adopted_siblings_illness_2                 Illnesses of adopted siblings
# family_history_number_older_siblings                                Number of older siblings
# family_history_non_accidental_death             Non-accidental death in close genetic family
# data_source                                                                      Data source
# collection_timestamp                                                         Collection time
# collection_date                                                              Collection date
# timezone                                                                            Timezone
#
#                                                                      relative_location  \
# tabular_field_name
# sudden_death_family                             family_history/initial_medical.parquet
# family_history                                  family_history/initial_medical.parquet
# hypertension_family_number                      family_history/initial_medical.parquet
# hyperlipidemia_family_number                    family_history/initial_medical.parquet
# type_1_diabetes_family_number                   family_history/initial_medical.parquet
# type_2_diabetes_family_number                   family_history/initial_medical.parquet
# stroke_family_number                            family_history/initial_medical.parquet
# kidney_disease_dialysis_family_number           family_history/initial_medical.parquet
# autoimmune_diseases_family_number               family_history/initial_medical.parquet
# hypercoagulation_family_number                  family_history/initial_medical.parquet
# clotting_family_number                          family_history/initial_medical.parquet
# crohn_family_number                             family_history/initial_medical.parquet
# celiac_family_number                            family_history/initial_medical.parquet
# dementia_under_60_family_number                 family_history/initial_medical.parquet
# parkinson_family_number                         family_history/initial_medical.parquet
# asthma_family_number                            family_history/initial_medical.parquet
# cancer_type_family                              family_history/initial_medical.parquet
# collection_timestamp                            family_history/initial_medical.parquet
# collection_date                                 family_history/initial_medical.parquet
# timezone                                        family_history/initial_medical.parquet
# early_life_breastfeeding                                   family_history/ukbb.parquet
# early_life_comparative_body_weight                         family_history/ukbb.parquet
# early_life_comparative_body_height                         family_history/ukbb.parquet
# early_life_handedness                                      family_history/ukbb.parquet
# early_life_adopted                                         family_history/ukbb.parquet
# early_life_multiple_birth                                  family_history/ukbb.parquet
# early_life_mother_smoking                                  family_history/ukbb.parquet
# family_history_father_alive                                family_history/ukbb.parquet
# family_history_adopted_father_alive                        family_history/ukbb.parquet
# family_history_current_father_age                          family_history/ukbb.parquet
# family_history_current_adopted_father_age                  family_history/ukbb.parquet
# family_history_father_age_passing                          family_history/ukbb.parquet
# family_history_adopted_father_age_passing                  family_history/ukbb.parquet
# family_history_past_father_illness_1                       family_history/ukbb.parquet
# family_history_past_adopted_father_illness_1               family_history/ukbb.parquet
# family_history_past_father_illness_2                       family_history/ukbb.parquet
# family_history_past_adopted_father_illness_2               family_history/ukbb.parquet
# family_history_mother_alive                                family_history/ukbb.parquet
# family_history_adopted_mother_alive                        family_history/ukbb.parquet
# family_history_current_mother_age                          family_history/ukbb.parquet
# family_history_current_adopted_mother_age                  family_history/ukbb.parquet
# family_history_mother_age_passing                          family_history/ukbb.parquet
# family_history_adopted_mother_age_passing                  family_history/ukbb.parquet
# family_history_past_mother_illness_1                       family_history/ukbb.parquet
# family_history_past_adopted_mother_illness_1               family_history/ukbb.parquet
# family_history_past_mother_illness_2                       family_history/ukbb.parquet
# family_history_past_adopted_mother_illness_2               family_history/ukbb.parquet
# family_history_number_full_brothers                        family_history/ukbb.parquet
# family_history_number_adopted_brothers                     family_history/ukbb.parquet
# family_history_number_full_sisters                         family_history/ukbb.parquet
# family_history_number_adopted_sisters                      family_history/ukbb.parquet
# family_history_past_siblings_illness_1                     family_history/ukbb.parquet
# family_history_past_adopted_siblings_illness_1             family_history/ukbb.parquet
# family_history_past_siblings_illness_2                     family_history/ukbb.parquet
# family_history_past_adopted_siblings_illness_2             family_history/ukbb.parquet
# family_history_number_older_siblings                       family_history/ukbb.parquet
# family_history_non_accidental_death                        family_history/ukbb.parquet
# data_source                                                family_history/ukbb.parquet
# collection_timestamp                                       family_history/ukbb.parquet
# collection_date                                            family_history/ukbb.parquet
# timezone                                                   family_history/ukbb.parquet
#
#                                                 bulk_file_extension  \
# tabular_field_name
# sudden_death_family                                             NaN
# family_history                                                  NaN
# hypertension_family_number                                      NaN
# hyperlipidemia_family_number                                    NaN
# type_1_diabetes_family_number                                   NaN
# type_2_diabetes_family_number                                   NaN
# stroke_family_number                                            NaN
# kidney_disease_dialysis_family_number                           NaN
# autoimmune_diseases_family_number                               NaN
# hypercoagulation_family_number                                  NaN
# clotting_family_number                                          NaN
# crohn_family_number                                             NaN
# celiac_family_number                                            NaN
# dementia_under_60_family_number                                 NaN
# parkinson_family_number                                         NaN
# asthma_family_number                                            NaN
# cancer_type_family                                              NaN
# collection_timestamp                                            NaN
# collection_date                                                 NaN
# timezone                                                        NaN
# early_life_breastfeeding                                        NaN
# early_life_comparative_body_weight                              NaN
# early_life_comparative_body_height                              NaN
# early_life_handedness                                           NaN
# early_life_adopted                                              NaN
# early_life_multiple_birth                                       NaN
# early_life_mother_smoking                                       NaN
# family_history_father_alive                                     NaN
# family_history_adopted_father_alive                             NaN
# family_history_current_father_age                               NaN
# family_history_current_adopted_father_age                       NaN
# family_history_father_age_passing                               NaN
# family_history_adopted_father_age_passing                       NaN
# family_history_past_father_illness_1                            NaN
# family_history_past_adopted_father_illness_1                    NaN
# family_history_past_father_illness_2                            NaN
# family_history_past_adopted_father_illness_2                    NaN
# family_history_mother_alive                                     NaN
# family_history_adopted_mother_alive                             NaN
# family_history_current_mother_age                               NaN
# family_history_current_adopted_mother_age                       NaN
# family_history_mother_age_passing                               NaN
# family_history_adopted_mother_age_passing                       NaN
# family_history_past_mother_illness_1                            NaN
# family_history_past_adopted_mother_illness_1                    NaN
# family_history_past_mother_illness_2                            NaN
# family_history_past_adopted_mother_illness_2                    NaN
# family_history_number_full_brothers                             NaN
# family_history_number_adopted_brothers                          NaN
# family_history_number_full_sisters                              NaN
# family_history_number_adopted_sisters                           NaN
# family_history_past_siblings_illness_1                          NaN
# family_history_past_adopted_siblings_illness_1                  NaN
# family_history_past_siblings_illness_2                          NaN
# family_history_past_adopted_siblings_illness_2                  NaN
# family_history_number_older_siblings                            NaN
# family_history_non_accidental_death                             NaN
# data_source                                                     NaN
# collection_timestamp                                            NaN
# collection_date                                                 NaN
# timezone                                                        NaN
#
#                                                 bulk_dictionary  \
# tabular_field_name
# sudden_death_family                                         NaN
# family_history                                              NaN
# hypertension_family_number                                  NaN
# hyperlipidemia_family_number                                NaN
# type_1_diabetes_family_number                               NaN
# type_2_diabetes_family_number                               NaN
# stroke_family_number                                        NaN
# kidney_disease_dialysis_family_number                       NaN
# autoimmune_diseases_family_number                           NaN
# hypercoagulation_family_number                              NaN
# clotting_family_number                                      NaN
# crohn_family_number                                         NaN
# celiac_family_number                                        NaN
# dementia_under_60_family_number                             NaN
# parkinson_family_number                                     NaN
# asthma_family_number                                        NaN
# cancer_type_family                                          NaN
# collection_timestamp                                        NaN
# collection_date                                             NaN
# timezone                                                    NaN
# early_life_breastfeeding                                    NaN
# early_life_comparative_body_weight                          NaN
# early_life_comparative_body_height                          NaN
# early_life_handedness                                       NaN
# early_life_adopted                                          NaN
# early_life_multiple_birth                                   NaN
# early_life_mother_smoking                                   NaN
# family_history_father_alive                                 NaN
# family_history_adopted_father_alive                         NaN
# family_history_current_father_age                           NaN
# family_history_current_adopted_father_age                   NaN
# family_history_father_age_passing                           NaN
# family_history_adopted_father_age_passing                   NaN
# family_history_past_father_illness_1                        NaN
# family_history_past_adopted_father_illness_1                NaN
# family_history_past_father_illness_2                        NaN
# family_history_past_adopted_father_illness_2                NaN
# family_history_mother_alive                                 NaN
# family_history_adopted_mother_alive                         NaN
# family_history_current_mother_age                           NaN
# family_history_current_adopted_mother_age                   NaN
# family_history_mother_age_passing                           NaN
# family_history_adopted_mother_age_passing                   NaN
# family_history_past_mother_illness_1                        NaN
# family_history_past_adopted_mother_illness_1                NaN
# family_history_past_mother_illness_2                        NaN
# family_history_past_adopted_mother_illness_2                NaN
# family_history_number_full_brothers                         NaN
# family_history_number_adopted_brothers                      NaN
# family_history_number_full_sisters                          NaN
# family_history_number_adopted_sisters                       NaN
# family_history_past_siblings_illness_1                      NaN
# family_history_past_adopted_siblings_illness_1              NaN
# family_history_past_siblings_illness_2                      NaN
# family_history_past_adopted_siblings_illness_2              NaN
# family_history_number_older_siblings                        NaN
# family_history_non_accidental_death                         NaN
# data_source                                                 NaN
# collection_timestamp                                        NaN
# collection_date                                             NaN
# timezone                                                    NaN
#
#                                                                                description_string  \
# tabular_field_name
# sudden_death_family                             Has one or more of your close family members d...
# family_history                                  Has one or more of your close family members s...
# hypertension_family_number                      How many of your close family members have hig...
# hyperlipidemia_family_number                    How many of your close family members have ele...
# type_1_diabetes_family_number                   How many of your close family members have typ...
# type_2_diabetes_family_number                   How many of your close family members have typ...
# stroke_family_number                            How many of your close family members have had...
# kidney_disease_dialysis_family_number           How many of your close family members have kid...
# autoimmune_diseases_family_number               How many of your close family members have art...
# hypercoagulation_family_number                  How many of your close family members have hyp...
# clotting_family_number                          How many of your close family members have a c...
# crohn_family_number                             How many of your close family members have inf...
# celiac_family_number                            How many of your close family members have cel...
# dementia_under_60_family_number                 How many of your close family members have dem...
# parkinson_family_number                         How many of your close family members have a m...
# asthma_family_number                            How many of your close family members have ast...
# cancer_type_family                                                     Specify the type of cancer
# collection_timestamp                                                              Collection time
# collection_date                                                                   Collection date
# timezone                                                                                 Timezone
# early_life_breastfeeding                                 Were you breastfed when you were a baby?
# early_life_comparative_body_weight              When you were 10 years old, compared to averag...
# early_life_comparative_body_height              When you were 10 years old, compared to averag...
# early_life_handedness                                               Are you right or left handed?
# early_life_adopted                                                   Were you adopted as a child?
# early_life_multiple_birth                        Are you a twin, triplet or other multiple birth?
# early_life_mother_smoking                       Did your mother smoke regularly around the tim...
# family_history_father_alive                                           Is your father still alive?
# family_history_adopted_father_alive                           Is your ADOPTED father still alive?
# family_history_current_father_age                                            What is his age now?
# family_history_current_adopted_father_age                                    What is his age now?
# family_history_father_age_passing                                  What was his age when he died?
# family_history_adopted_father_age_passing                          What was his age when he died?
# family_history_past_father_illness_1            Has/did your father ever suffer from? (You can...
# family_history_past_adopted_father_illness_1    Has/did your ADOPTED father ever suffer from? ...
# family_history_past_father_illness_2            Has/did your father ever suffer from? (You can...
# family_history_past_adopted_father_illness_2    Has/did your ADOPTED father ever suffer from? ...
# family_history_mother_alive                                           Is your mother still alive?
# family_history_adopted_mother_alive                           Is your ADOPTED mother still alive?
# family_history_current_mother_age                                            What is her age now?
# family_history_current_adopted_mother_age                                    What is her age now?
# family_history_mother_age_passing                                 What was her age when she died?
# family_history_adopted_mother_age_passing                         What was her age when she died?
# family_history_past_mother_illness_1            Has/did your mother ever suffer from? (You can...
# family_history_past_adopted_mother_illness_1    Has/did your ADOPTED mother ever suffer from? ...
# family_history_past_mother_illness_2            Has/did your mother ever suffer from? (You can...
# family_history_past_adopted_mother_illness_2    Has/did your ADOPTED mother ever suffer from? ...
# family_history_number_full_brothers             How many brothers do you have? (Please include...
# family_history_number_adopted_brothers          How many ADOPTED brothers do you have? (Please...
# family_history_number_full_sisters              How many sisters do you have? (Please include ...
# family_history_number_adopted_sisters           How many ADOPTED sisters do you have? (Please ...
# family_history_past_siblings_illness_1          Have any of your brothers or sisters suffered ...
# family_history_past_adopted_siblings_illness_1  Have any of your ADOPTED brothers or sisters s...
# family_history_past_siblings_illness_2          Have any or your brothers or sisters suffered ...
# family_history_past_adopted_siblings_illness_2  Have any or your ADOPTED brothers or sisters s...
# family_history_number_older_siblings            How many OLDER brothers/sisters do you have? (...
# family_history_non_accidental_death             Have any of your mother, father, brothers or s...
# data_source                                                    Source where data originates from.
# collection_timestamp                                                              Collection time
# collection_date                                                                   Collection date
# timezone                                                                                 Timezone
#
#                                                             field_type  \
# tabular_field_name
# sudden_death_family                               Categorical (single)
# family_history                                  Categorical (multiple)
# hypertension_family_number                                     Integer
# hyperlipidemia_family_number                                   Integer
# type_1_diabetes_family_number                                  Integer
# type_2_diabetes_family_number                                  Integer
# stroke_family_number                                           Integer
# kidney_disease_dialysis_family_number                          Integer
# autoimmune_diseases_family_number                              Integer
# hypercoagulation_family_number                                 Integer
# clotting_family_number                                         Integer
# crohn_family_number                                            Integer
# celiac_family_number                                           Integer
# dementia_under_60_family_number                                Integer
# parkinson_family_number                                        Integer
# asthma_family_number                                           Integer
# cancer_type_family                              Categorical (multiple)
# collection_timestamp                                          Datetime
# collection_date                                                   Date
# timezone                                          Categorical (single)
# early_life_breastfeeding                          Categorical (single)
# early_life_comparative_body_weight                Categorical (single)
# early_life_comparative_body_height                Categorical (single)
# early_life_handedness                             Categorical (single)
# early_life_adopted                                Categorical (single)
# early_life_multiple_birth                         Categorical (single)
# early_life_mother_smoking                         Categorical (single)
# family_history_father_alive                       Categorical (single)
# family_history_adopted_father_alive               Categorical (single)
# family_history_current_father_age                              Integer
# family_history_current_adopted_father_age                      Integer
# family_history_father_age_passing                              Integer
# family_history_adopted_father_age_passing                      Integer
# family_history_past_father_illness_1            Categorical (multiple)
# family_history_past_adopted_father_illness_1    Categorical (multiple)
# family_history_past_father_illness_2            Categorical (multiple)
# family_history_past_adopted_father_illness_2    Categorical (multiple)
# family_history_mother_alive                       Categorical (single)
# family_history_adopted_mother_alive               Categorical (single)
# family_history_current_mother_age                              Integer
# family_history_current_adopted_mother_age                      Integer
# family_history_mother_age_passing                              Integer
# family_history_adopted_mother_age_passing                      Integer
# family_history_past_mother_illness_1            Categorical (multiple)
# family_history_past_adopted_mother_illness_1    Categorical (multiple)
# family_history_past_mother_illness_2            Categorical (multiple)
# family_history_past_adopted_mother_illness_2    Categorical (multiple)
# family_history_number_full_brothers                            Integer
# family_history_number_adopted_brothers                         Integer
# family_history_number_full_sisters                             Integer
# family_history_number_adopted_sisters                          Integer
# family_history_past_siblings_illness_1          Categorical (multiple)
# family_history_past_adopted_siblings_illness_1  Categorical (multiple)
# family_history_past_siblings_illness_2          Categorical (multiple)
# family_history_past_adopted_siblings_illness_2  Categorical (multiple)
# family_history_number_older_siblings                           Integer
# family_history_non_accidental_death               Categorical (single)
# data_source                                                        NaN
# collection_timestamp                                          Datetime
# collection_date                                                   Date
# timezone                                          Categorical (single)
#
#                                                    array  \
# tabular_field_name
# sudden_death_family                               Single
# family_history                                  Multiple
# hypertension_family_number                        Single
# hyperlipidemia_family_number                      Single
# type_1_diabetes_family_number                     Single
# type_2_diabetes_family_number                     Single
# stroke_family_number                              Single
# kidney_disease_dialysis_family_number             Single
# autoimmune_diseases_family_number                 Single
# hypercoagulation_family_number                    Single
# clotting_family_number                            Single
# crohn_family_number                               Single
# celiac_family_number                              Single
# dementia_under_60_family_number                   Single
# parkinson_family_number                           Single
# asthma_family_number                              Single
# cancer_type_family                              Multiple
# collection_timestamp                              Single
# collection_date                                   Single
# timezone                                          Single
# early_life_breastfeeding                          Single
# early_life_comparative_body_weight                Single
# early_life_comparative_body_height                Single
# early_life_handedness                             Single
# early_life_adopted                                Single
# early_life_multiple_birth                         Single
# early_life_mother_smoking                         Single
# family_history_father_alive                       Single
# family_history_adopted_father_alive               Single
# family_history_current_father_age                 Single
# family_history_current_adopted_father_age         Single
# family_history_father_age_passing                 Single
# family_history_adopted_father_age_passing         Single
# family_history_past_father_illness_1            Multiple
# family_history_past_adopted_father_illness_1    Multiple
# family_history_past_father_illness_2            Multiple
# family_history_past_adopted_father_illness_2    Multiple
# family_history_mother_alive                       Single
# family_history_adopted_mother_alive               Single
# family_history_current_mother_age                 Single
# family_history_current_adopted_mother_age         Single
# family_history_mother_age_passing                 Single
# family_history_adopted_mother_age_passing         Single
# family_history_past_mother_illness_1            Multiple
# family_history_past_adopted_mother_illness_1    Multiple
# family_history_past_mother_illness_2            Multiple
# family_history_past_adopted_mother_illness_2    Multiple
# family_history_number_full_brothers               Single
# family_history_number_adopted_brothers            Single
# family_history_number_full_sisters                Single
# family_history_number_adopted_sisters             Single
# family_history_past_siblings_illness_1          Multiple
# family_history_past_adopted_siblings_illness_1  Multiple
# family_history_past_siblings_illness_2          Multiple
# family_history_past_adopted_siblings_illness_2  Multiple
# family_history_number_older_siblings              Single
# family_history_non_accidental_death               Single
# data_source                                       Single
# collection_timestamp                              Single
# collection_date                                   Single
# timezone                                          Single
#
#                                                                   pandas_dtype  \
# tabular_field_name
# sudden_death_family                                                        int
# family_history                                                          object
# hypertension_family_number                                                 int
# hyperlipidemia_family_number                                               int
# type_1_diabetes_family_number                                              int
# type_2_diabetes_family_number                                              int
# stroke_family_number                                                       int
# kidney_disease_dialysis_family_number                                      int
# autoimmune_diseases_family_number                                          int
# hypercoagulation_family_number                                             int
# clotting_family_number                                                     int
# crohn_family_number                                                        int
# celiac_family_number                                                       int
# dementia_under_60_family_number                                            int
# parkinson_family_number                                                    int
# asthma_family_number                                                       int
# cancer_type_family                                                      object
# collection_timestamp                            datetime64[ns, Asia/Jerusalem]
# collection_date                                                 datetime64[ns]
# timezone                                                                string
# early_life_breastfeeding                                                   int
# early_life_comparative_body_weight                                         int
# early_life_comparative_body_height                                         int
# early_life_handedness                                                      int
# early_life_adopted                                                         int
# early_life_multiple_birth                                                  int
# early_life_mother_smoking                                                  int
# family_history_father_alive                                                int
# family_history_adopted_father_alive                                        int
# family_history_current_father_age                                          int
# family_history_current_adopted_father_age                                  int
# family_history_father_age_passing                                          int
# family_history_adopted_father_age_passing                                  int
# family_history_past_father_illness_1                                    object
# family_history_past_adopted_father_illness_1                            object
# family_history_past_father_illness_2                                    object
# family_history_past_adopted_father_illness_2                            object
# family_history_mother_alive                                                int
# family_history_adopted_mother_alive                                        int
# family_history_current_mother_age                                          int
# family_history_current_adopted_mother_age                                  int
# family_history_mother_age_passing                                          int
# family_history_adopted_mother_age_passing                                  int
# family_history_past_mother_illness_1                                    object
# family_history_past_adopted_mother_illness_1                            object
# family_history_past_mother_illness_2                                    object
# family_history_past_adopted_mother_illness_2                            object
# family_history_number_full_brothers                                        int
# family_history_number_adopted_brothers                                     int
# family_history_number_full_sisters                                         int
# family_history_number_adopted_sisters                                      int
# family_history_past_siblings_illness_1                                  object
# family_history_past_adopted_siblings_illness_1                          object
# family_history_past_siblings_illness_2                                  object
# family_history_past_adopted_siblings_illness_2                          object
# family_history_number_older_siblings                                       int
# family_history_non_accidental_death                                        int
# data_source                                                             string
# collection_timestamp                            datetime64[ns, Asia/Jerusalem]
# collection_date                                                 datetime64[ns]
# timezone                                                              category
#
#                                                stability   units  \
# tabular_field_name
# sudden_death_family                             Accruing     NaN
# family_history                                  Accruing     NaN
# hypertension_family_number                      Accruing     NaN
# hyperlipidemia_family_number                    Accruing     NaN
# type_1_diabetes_family_number                   Accruing     NaN
# type_2_diabetes_family_number                   Accruing     NaN
# stroke_family_number                            Accruing     NaN
# kidney_disease_dialysis_family_number           Accruing     NaN
# autoimmune_diseases_family_number               Accruing     NaN
# hypercoagulation_family_number                  Accruing     NaN
# clotting_family_number                          Accruing     NaN
# crohn_family_number                             Accruing     NaN
# celiac_family_number                            Accruing     NaN
# dementia_under_60_family_number                 Accruing     NaN
# parkinson_family_number                         Accruing     NaN
# asthma_family_number                            Accruing     NaN
# cancer_type_family                              Accruing     NaN
# collection_timestamp                            Accruing     NaN
# collection_date                                 Accruing     NaN
# timezone                                        Accruing     NaN
# early_life_breastfeeding                        Accruing     NaN
# early_life_comparative_body_weight              Accruing     NaN
# early_life_comparative_body_height              Accruing     NaN
# early_life_handedness                           Accruing     NaN
# early_life_adopted                              Accruing     NaN
# early_life_multiple_birth                       Accruing     NaN
# early_life_mother_smoking                       Accruing     NaN
# family_history_father_alive                     Accruing     NaN
# family_history_adopted_father_alive             Accruing     NaN
# family_history_current_father_age               Accruing   Years
# family_history_current_adopted_father_age       Accruing   Years
# family_history_father_age_passing               Accruing   Years
# family_history_adopted_father_age_passing       Accruing   Years
# family_history_past_father_illness_1            Accruing     NaN
# family_history_past_adopted_father_illness_1    Accruing     NaN
# family_history_past_father_illness_2            Accruing     NaN
# family_history_past_adopted_father_illness_2    Accruing     NaN
# ...
# early_life_comparative_body_weight                        NaN
# early_life_comparative_body_height                        NaN
# early_life_handedness                                     NaN
# early_life_adopted                                        NaN
# early_life_multiple_birth                                 NaN
# early_life_mother_smoking                                 NaN
# family_history_father_alive                               NaN
# family_history_adopted_father_alive                       NaN
# family_history_current_father_age                         NaN
# family_history_current_adopted_father_age                 NaN
# family_history_father_age_passing                         NaN
# family_history_adopted_father_age_passing                 NaN
# family_history_past_father_illness_1                      NaN
# family_history_past_adopted_father_illness_1              NaN
# family_history_past_father_illness_2                      NaN
# family_history_past_adopted_father_illness_2              NaN
# family_history_mother_alive                               NaN
# family_history_adopted_mother_alive                       NaN
# family_history_current_mother_age                         NaN
# family_history_current_adopted_mother_age                 NaN
# family_history_mother_age_passing                         NaN
# family_history_adopted_mother_age_passing                 NaN
# family_history_past_mother_illness_1                      NaN
# family_history_past_adopted_mother_illness_1              NaN
# family_history_past_mother_illness_2                      NaN
# family_history_past_adopted_mother_illness_2              NaN
# family_history_number_full_brothers                       NaN
# family_history_number_adopted_brothers                    NaN
# family_history_number_full_sisters                        NaN
# family_history_number_adopted_sisters                     NaN
# family_history_past_siblings_illness_1                    NaN
# family_history_past_adopted_siblings_illness_1            NaN
# family_history_past_siblings_illness_2                    NaN
# family_history_past_adopted_siblings_illness_2            NaN
# family_history_number_older_siblings                      NaN
# family_history_non_accidental_death                       NaN
# data_source                                               NaN
# collection_timestamp                                      NaN
# collection_date                                           NaN
# timezone                                                  NaN
#
#                                                          strata       sexed  \
# tabular_field_name
# sudden_death_family                                     Primary  Both sexes
# family_history                                          Primary  Both sexes
# hypertension_family_number                              Primary  Both sexes
# hyperlipidemia_family_number                            Primary  Both sexes
# type_1_diabetes_family_number                           Primary  Both sexes
# type_2_diabetes_family_number                           Primary  Both sexes
# stroke_family_number                                    Primary  Both sexes
# kidney_disease_dialysis_family_number                   Primary  Both sexes
# autoimmune_diseases_family_number                       Primary  Both sexes
# hypercoagulation_family_number                          Primary  Both sexes
# clotting_family_number                                  Primary  Both sexes
# crohn_family_number                                     Primary  Both sexes
# celiac_family_number                                    Primary  Both sexes
# dementia_under_60_family_number                         Primary  Both sexes
# parkinson_family_number                                 Primary  Both sexes
# asthma_family_number                                    Primary  Both sexes
# cancer_type_family                                      Primary  Both sexes
# collection_timestamp                            Collection time  Both sexes
# collection_date                                 Collection time  Both sexes
# timezone                                        Collection time  Both sexes
# early_life_breastfeeding                                Primary  Both sexes
# early_life_comparative_body_weight                      Primary  Both sexes
# early_life_comparative_body_height                      Primary  Both sexes
# early_life_handedness                                   Primary  Both sexes
# early_life_adopted                                      Primary  Both sexes
# early_life_multiple_birth                               Primary  Both sexes
# early_life_mother_smoking                               Primary  Both sexes
# family_history_father_alive                             Primary  Both sexes
# family_history_adopted_father_alive                     Primary  Both sexes
# family_history_current_father_age                       Primary  Both sexes
# family_history_current_adopted_father_age               Primary  Both sexes
# family_history_father_age_passing                       Primary  Both sexes
# family_history_adopted_father_age_passing               Primary  Both sexes
# family_history_past_father_illness_1                    Primary  Both sexes
# family_history_past_adopted_father_illness_1            Primary  Both sexes
# family_history_past_father_illness_2                    Primary  Both sexes
# family_history_past_adopted_father_illness_2            Primary  Both sexes
# family_history_mother_alive                             Primary  Both sexes
# family_history_adopted_mother_alive                     Primary  Both sexes
# family_history_current_mother_age                       Primary  Both sexes
# family_history_current_adopted_mother_age               Primary  Both sexes
# family_history_mother_age_passing                       Primary  Both sexes
# family_history_adopted_mother_age_passing               Primary  Both sexes
# family_history_past_mother_illness_1                    Primary  Both sexes
# family_history_past_adopted_mother_illness_1            Primary  Both sexes
# family_history_past_mother_illness_2                    Primary  Both sexes
# family_history_past_adopted_mother_illness_2            Primary  Both sexes
# family_history_number_full_brothers                     Primary  Both sexes
# family_history_number_adopted_brothers                  Primary  Both sexes
# family_history_number_full_sisters                      Primary  Both sexes
# family_history_number_adopted_sisters                   Primary  Both sexes
# family_history_past_siblings_illness_1                  Primary  Both sexes
# family_history_past_adopted_siblings_illness_1          Primary  Both sexes
# family_history_past_siblings_illness_2                  Primary  Both sexes
# family_history_past_adopted_siblings_illness_2          Primary  Both sexes
# family_history_number_older_siblings                    Primary  Both sexes
# family_history_non_accidental_death                     Primary  Both sexes
# data_source                                             Primary  Both sexes
# collection_timestamp                            Collection time  Both sexes
# collection_date                                 Collection time  Both sexes
# timezone                                        Collection time  Both sexes
#
#                                                     debut  completed  \
# tabular_field_name
# sudden_death_family                             2/26/2020        NaN
# family_history                                  2/26/2020        NaN
# hypertension_family_number                      2/26/2020        NaN
# hyperlipidemia_family_number                    2/26/2020        NaN
# type_1_diabetes_family_number                   2/26/2020        NaN
# type_2_diabetes_family_number                   2/26/2020        NaN
# stroke_family_number                            2/26/2020        NaN
# kidney_disease_dialysis_family_number           2/26/2020        NaN
# autoimmune_diseases_family_number               2/26/2020        NaN
# hypercoagulation_family_number                  2/26/2020        NaN
# clotting_family_number                          2/26/2020        NaN
# crohn_family_number                             2/26/2020        NaN
# celiac_family_number                            2/26/2020        NaN
# dementia_under_60_family_number                 2/26/2020        NaN
# parkinson_family_number                         2/26/2020        NaN
# asthma_family_number                            2/26/2020        NaN
# cancer_type_family                              2/26/2020        NaN
# collection_timestamp                            2/26/2020        NaN
# collection_date                                 2/26/2020        NaN
# timezone                                        2/26/2020        NaN
# early_life_breastfeeding                         1/9/2019        NaN
# early_life_comparative_body_weight               1/9/2019        NaN
# early_life_comparative_body_height               1/9/2019        NaN
# early_life_handedness                            1/9/2019        NaN
# early_life_adopted                               1/9/2019        NaN
# early_life_multiple_birth                        1/9/2019        NaN
# early_life_mother_smoking                        1/9/2019        NaN
# family_history_father_alive                      1/9/2019        NaN
# family_history_adopted_father_alive              1/9/2019        NaN
# family_history_current_father_age                1/9/2019        NaN
# family_history_current_adopted_father_age        1/9/2019        NaN
# family_history_father_age_passing                1/9/2019        NaN
# family_history_adopted_father_age_passing        1/9/2019        NaN
# family_history_past_father_illness_1             1/9/2019        NaN
# family_history_past_adopted_father_illness_1     1/9/2019        NaN
# family_history_past_father_illness_2             1/9/2019        NaN
# family_history_past_adopted_father_illness_2     1/9/2019        NaN
# family_history_mother_alive                      1/9/2019        NaN
# family_history_adopted_mother_alive              1/9/2019        NaN
# family_history_current_mother_age                1/9/2019        NaN
# family_history_current_adopted_mother_age        1/9/2019        NaN
# family_history_mother_age_passing                1/9/2019        NaN
# family_history_adopted_mother_age_passing        1/9/2019        NaN
# family_history_past_mother_illness_1             1/9/2019        NaN
# family_history_past_adopted_mother_illness_1     1/9/2019        NaN
# family_history_past_mother_illness_2             1/9/2019        NaN
# family_history_past_adopted_mother_illness_2     1/9/2019        NaN
# family_history_number_full_brothers              1/9/2019        NaN
# family_history_number_adopted_brothers           1/9/2019        NaN
# family_history_number_full_sisters               1/9/2019        NaN
# family_history_number_adopted_sisters            1/9/2019        NaN
# family_history_past_siblings_illness_1           1/9/2019        NaN
# family_history_past_adopted_siblings_illness_1   1/9/2019        NaN
# family_history_past_siblings_illness_2           1/9/2019        NaN
# family_history_past_adopted_siblings_illness_2   1/9/2019        NaN
# family_history_number_older_siblings             1/9/2019        NaN
# family_history_non_accidental_death              1/9/2019        NaN
# data_source                                      1/9/2019        NaN
# collection_timestamp                             1/9/2019        NaN
# collection_date                                  1/9/2019        NaN
# timezone                                         1/9/2019        NaN
#
#                                                data_coding
# tabular_field_name
# sudden_death_family                                     21
# family_history                                      052_01
# hypertension_family_number                             NaN
# hyperlipidemia_family_number                           NaN
# type_1_diabetes_family_number                          NaN
# type_2_diabetes_family_number                          NaN
# stroke_family_number                                   NaN
# kidney_disease_dialysis_family_number                  NaN
# autoimmune_diseases_family_number                      NaN
# hypercoagulation_family_number                         NaN
# clotting_family_number                                 NaN
# crohn_family_number                                    NaN
# celiac_family_number                                   NaN
# dementia_under_60_family_number                        NaN
# parkinson_family_number                                NaN
# asthma_family_number                                   NaN
# cancer_type_family                                  052_02
# collection_timestamp                                   NaN
# collection_date                                        NaN
# timezone                                               NaN
# early_life_breastfeeding                            100349
# early_life_comparative_body_weight                  100428
# early_life_comparative_body_height                  100429
# early_life_handedness                               100430
# early_life_adopted                                  100349
# early_life_multiple_birth                           100349
# early_life_mother_smoking                           100349
# family_history_father_alive                         100349
# family_history_adopted_father_alive                 100349
# family_history_current_father_age                      NaN
# family_history_current_adopted_father_age              NaN
# family_history_father_age_passing                      NaN
# family_history_adopted_father_age_passing              NaN
# family_history_past_father_illness_1                  1010
# family_history_past_adopted_father_illness_1          1010
# family_history_past_father_illness_2                  1010
# family_history_past_adopted_father_illness_2          1010
# family_history_mother_alive                         100349
# family_history_adopted_mother_alive                 100349
# family_history_current_mother_age                      NaN
# family_history_current_adopted_mother_age              NaN
# family_history_mother_age_passing                      NaN
# family_history_adopted_mother_age_passing              NaN
# family_history_past_mother_illness_1                  1010
# family_history_past_adopted_mother_illness_1          1010
# family_history_past_mother_illness_2                  1010
# family_history_past_adopted_mother_illness_2          1010
# family_history_number_full_brothers                    NaN
# family_history_number_adopted_brothers                 NaN
# family_history_number_full_sisters                     NaN
# family_history_number_adopted_sisters                  NaN
# family_history_past_siblings_illness_1                1010
# family_history_past_adopted_siblings_illness_1        1010
# family_history_past_siblings_illness_2                1010
# family_history_past_adopted_siblings_illness_2        1010
# family_history_number_older_siblings                   NaN
# family_history_non_accidental_death                 100349
# data_source                                            NaN
# collection_timestamp                                   NaN
# collection_date                                        NaN
# timezone                                               NaN
