# %% [raw]
# ---
# output-file: 053-sociodemographics.html
# title: Sociodemographics
# ---

# %% [markdown]
# ### Description
#
# Sociodemographic data encompasses social, economic, and demographic characteristics of study participants that influence health outcomes and provide important context for interpreting health data. This includes information about ancestry and migration history, education, employment, household composition, living conditions, and socioeconomic status. These factors are essential for understanding health disparities, environmental exposures, and social determinants of health.
#
# ### Introduction
#
# The Human Phenotype Project conducts comprehensive data collection through online surveys, where participants voluntarily provide information on various aspects influencing their health. This includes sociodemographic data, captured through two lifestyle surveys (Inital UKBB and Follow-up UKBB survey) and the Initial Medical Survey.
#
# ### Measurement protocol
# <!-- long measurment protocol for the data browser -->
# These lifestyle surveys are modeled after the UK Biobank's touch screen questionnaire. Participants receive the full version via email to complete on an online platform, either before or after their baseline visit. A shorter, follow-up version of the questionnaire is then filled out by participants during subsequent visits.
#
# ### Data availability
# <!-- for the example notebooks -->
# The information is stored in 2 parquet files: `initial_medical.parquet`  and `ukbb.parquet` which contain the different data sources respectively the Initial Medical Survey and the  two lifestyle surveys (Inital UKBB and Follow-up UKBB survey).
#
# ### Summary of available data
# <!-- for the data browser -->
# The sociodemographic dataset includes comprehensive information organized into several categories:
#
# **Ancestry and Migration:**
# - Participant's country of birth and year of immigration (aliya)
# - Parents' countries of birth
# - Grandparents' countries of birth (both maternal and paternal sides)
#
# **Education and Qualifications:**
# - Highest level of education attained
# - Professional qualifications
# - Age at completion of full-time education
#
# **Employment:**
# - Current employment status
# - Duration in main current job (years and months)
# - Length of working day
# - Job characteristics (walking/standing, manual labor, shift work, night shifts)
# - Commuting patterns (frequency, transport type, distance, duration)
# - Remote work frequency
#
# **Household and Living Conditions:**
# - Type of accommodation
# - Heating and air conditioning availability
# - Length of residence at current address
# - Household size and relationships between household members
# - Number of vehicles in household
# - Current and past pet ownership (type of pets)
# - Residence area type (urban/rural)
# - Assisted living status
#
# **Socioeconomic Status:**
# - Average total household income after tax
# - Extra domestic job hours
#
# **Family Connections:**
# - Family members participating in the study (participant IDs and relationship degrees)
# - Household members participating in the study
#
# **Military Service (for Israeli population):**
# - Past military service
# - Position and duration of service
#
# This comprehensive sociodemographic data enables researchers to examine how social and economic factors interact with health outcomes and to account for these variables in analyses.
#
# ### Relevant links
#
# * [Pheno Knowledgebase](https://knowledgebase.pheno.ai/datasets/053-sociodemographics.html)
# * [Pheno Data Browser](https://pheno-demo-app.vercel.app/folder/53)

# %%
#| echo: false
import pandas as pd
pd.set_option("display.max_rows", 500)

# %%
from pheno_utils import PhenoLoader

# %%
pl = PhenoLoader('sociodemographics')
pl
# Out:
# PhenoLoader for sociodemographics with
# 52 fields
# 3 tables: ['initial_medical', 'ukbb', 'age_sex']

# %% [markdown]
# # Data dictionary

# %%
pl.dict
# Out:
#                                           folder_id      feature_set  \
# tabular_field_name
# collection_timestamp                             53  initial_medical
# collection_date                                  53  initial_medical
# timezone                                         53  initial_medical
# DOB                                              53  initial_medical
# country_of_birth                                 53  initial_medical
# year_of_aliya                                    53  initial_medical
# father_country_of_birth                          53  initial_medical
# grandfather_country_of_birth_father_side         53  initial_medical
# grandmother_country_of_birth_father_side         53  initial_medical
# mother_country_of_birth                          53  initial_medical
# grandfather_country_of_birth_mother_side         53  initial_medical
# grandmother_country_of_birth_mother_side         53  initial_medical
# education                                        53  initial_medical
# gender                                           53  initial_medical
# collection_timestamp                             53             ukbb
# collection_date                                  53             ukbb
# timezone                                         53             ukbb
# study_family_member                              53             ukbb
# study_family_member_participant_id               53             ukbb
# study_family_member_relationship                 53             ukbb
# study_household_member                           53             ukbb
# study_household_member_participant_id            53             ukbb
# domestic_household_type                          53             ukbb
# domestic_household_appliances                    53             ukbb
# domestic_household_years                         53             ukbb
# domestic_household_people_number                 53             ukbb
# domestic_household_people_relationship           53             ukbb
# domestic_household_car_number                    53             ukbb
# domestic_household_income                        53             ukbb
# domestic_job_status                              53             ukbb
# domestic_job_years                               53             ukbb
# domestic_job_months                              53             ukbb
# domestic_job_hours_daily                         53             ukbb
# domestic_job_office_days                         53             ukbb
# domestic_job_transport                           53             ukbb
# domestic_job_distance                            53             ukbb
# domestic_job_walking_standing                    53             ukbb
# domestic_job_manual_physical                     53             ukbb
# domestic_job_shifts                              53             ukbb
# domestic_job_night_shift                         53             ukbb
# domestic_education_qualifications                53             ukbb
# domestic_education_age                           53             ukbb
# extra_domestic_job_hours                         53             ukbb
# extra_domestic_past_pets                         53             ukbb
# extra_domestic_current_pets                      53             ukbb
# extra_domestic_current_pets_type                 53             ukbb
# extra_domestic_residence_area_type               53             ukbb
# exrta_domestic_current_assisted_living           53             ukbb
# extra_army_past_service                          53             ukbb
# extra_army_past_position                         53             ukbb
# extra_army_past_duration                         53             ukbb
# domestic_job_home_days                           53             ukbb
# data_source                                      55             ukbb
#
#                                                                                field_string  \
# tabular_field_name
# collection_timestamp                                                   Collection timestamp
# collection_date                                                             Collection date
# timezone                                                                           Timezone
# DOB                                                                                     DOB
# country_of_birth                                                           Country of birth
# year_of_aliya                                                                 Year of aliya
# father_country_of_birth                                             Father country of birth
# grandfather_country_of_birth_father_side           Grandfather country of birth father side
# grandmother_country_of_birth_father_side           Grandmother country of birth father side
# mother_country_of_birth                                             Mother country of birth
# grandfather_country_of_birth_mother_side           Grandfather country of birth mother side
# grandmother_country_of_birth_mother_side           Grandmother country of birth mother side
# education                                                                         Education
# gender                                                                               Gender
# collection_timestamp                                                   Collection timestamp
# collection_date                                                             Collection date
# timezone                                                                           Timezone
# study_family_member                                Family member participates in this study
# study_family_member_participant_id                             Family member participant ID
# study_family_member_relationship                       Family member degree of relationship
# study_household_member                          Household member participates in this study
# study_household_member_participant_id                       Household member participate ID
# domestic_household_type                                      Type of accommodation lived in
# domestic_household_appliances               Type of heating and/or air conditioning at home
# domestic_household_years                                  Length of time at current address
# domestic_household_people_number                              Number of people in household
# domestic_household_people_relationship    How are people in household related to partici...
# domestic_household_car_number                               Number of vehicles in household
# domestic_household_income                          Average total household income after tax
# domestic_job_status                                               Current employment status
# domestic_job_years                                       Years employed in main current job
# domestic_job_months                                     Months employed in main current job
# domestic_job_hours_daily                                 Length of working day for main job
# domestic_job_office_days                  Frequency of travelling from home to job workp...
# domestic_job_transport                        Transport type for commuting to job workplace
# domestic_job_distance                             \nDistance between home and job workplace
# domestic_job_walking_standing                       Job involves mainly walking or standing
# domestic_job_manual_physical                     Job involves heavy manual or physical work
# domestic_job_shifts                                                 Job involves shift work
# domestic_job_night_shift                                      Job involves night shift work
# domestic_education_qualifications                                            Qualifications
# domestic_education_age                                    Age completed full time education
# extra_domestic_job_hours                                           Extra domestic job hours
# extra_domestic_past_pets                                           Extra domestic past pets
# extra_domestic_current_pets                                     Extra domestic current pets
# extra_domestic_current_pets_type                           Extra domestic current pets type
# extra_domestic_residence_area_type                       Extra domestic residence area type
# exrta_domestic_current_assisted_living               Exrta domestic current assisted living
# extra_army_past_service                                             Extra army past service
# extra_army_past_position                                           Extra army past position
# extra_army_past_duration                                           Extra army past duration
# domestic_job_home_days                              Frequency of working remotely from home
# data_source                                                                     Data source
#
#                                                                   relative_location  \
# tabular_field_name
# collection_timestamp                      sociodemographics/initial_medical.parquet
# collection_date                           sociodemographics/initial_medical.parquet
# timezone                                  sociodemographics/initial_medical.parquet
# DOB                                       sociodemographics/initial_medical.parquet
# country_of_birth                          sociodemographics/initial_medical.parquet
# year_of_aliya                             sociodemographics/initial_medical.parquet
# father_country_of_birth                   sociodemographics/initial_medical.parquet
# grandfather_country_of_birth_father_side  sociodemographics/initial_medical.parquet
# grandmother_country_of_birth_father_side  sociodemographics/initial_medical.parquet
# mother_country_of_birth                   sociodemographics/initial_medical.parquet
# grandfather_country_of_birth_mother_side  sociodemographics/initial_medical.parquet
# grandmother_country_of_birth_mother_side  sociodemographics/initial_medical.parquet
# education                                 sociodemographics/initial_medical.parquet
# gender                                    sociodemographics/initial_medical.parquet
# collection_timestamp                                 sociodemographics/ukbb.parquet
# collection_date                                      sociodemographics/ukbb.parquet
# timezone                                             sociodemographics/ukbb.parquet
# study_family_member                                  sociodemographics/ukbb.parquet
# study_family_member_participant_id                   sociodemographics/ukbb.parquet
# study_family_member_relationship                     sociodemographics/ukbb.parquet
# study_household_member                               sociodemographics/ukbb.parquet
# study_household_member_participant_id                sociodemographics/ukbb.parquet
# domestic_household_type                              sociodemographics/ukbb.parquet
# domestic_household_appliances                        sociodemographics/ukbb.parquet
# domestic_household_years                             sociodemographics/ukbb.parquet
# domestic_household_people_number                     sociodemographics/ukbb.parquet
# domestic_household_people_relationship               sociodemographics/ukbb.parquet
# domestic_household_car_number                        sociodemographics/ukbb.parquet
# domestic_household_income                            sociodemographics/ukbb.parquet
# domestic_job_status                                  sociodemographics/ukbb.parquet
# domestic_job_years                                   sociodemographics/ukbb.parquet
# domestic_job_months                                  sociodemographics/ukbb.parquet
# domestic_job_hours_daily                             sociodemographics/ukbb.parquet
# domestic_job_office_days                             sociodemographics/ukbb.parquet
# domestic_job_transport                               sociodemographics/ukbb.parquet
# domestic_job_distance                                sociodemographics/ukbb.parquet
# domestic_job_walking_standing                        sociodemographics/ukbb.parquet
# domestic_job_manual_physical                         sociodemographics/ukbb.parquet
# domestic_job_shifts                                  sociodemographics/ukbb.parquet
# domestic_job_night_shift                             sociodemographics/ukbb.parquet
# domestic_education_qualifications                    sociodemographics/ukbb.parquet
# domestic_education_age                               sociodemographics/ukbb.parquet
# extra_domestic_job_hours                             sociodemographics/ukbb.parquet
# extra_domestic_past_pets                             sociodemographics/ukbb.parquet
# extra_domestic_current_pets                          sociodemographics/ukbb.parquet
# extra_domestic_current_pets_type                     sociodemographics/ukbb.parquet
# extra_domestic_residence_area_type                   sociodemographics/ukbb.parquet
# exrta_domestic_current_assisted_living               sociodemographics/ukbb.parquet
# extra_army_past_service                              sociodemographics/ukbb.parquet
# extra_army_past_position                             sociodemographics/ukbb.parquet
# extra_army_past_duration                             sociodemographics/ukbb.parquet
# domestic_job_home_days                               sociodemographics/ukbb.parquet
# data_source                                          sociodemographics/ukbb.parquet
#
#                                           bulk_file_extension  \
# tabular_field_name
# collection_timestamp                                      NaN
# collection_date                                           NaN
# timezone                                                  NaN
# DOB                                                       NaN
# country_of_birth                                          NaN
# year_of_aliya                                             NaN
# father_country_of_birth                                   NaN
# grandfather_country_of_birth_father_side                  NaN
# grandmother_country_of_birth_father_side                  NaN
# mother_country_of_birth                                   NaN
# grandfather_country_of_birth_mother_side                  NaN
# grandmother_country_of_birth_mother_side                  NaN
# education                                                 NaN
# gender                                                    NaN
# collection_timestamp                                      NaN
# collection_date                                           NaN
# timezone                                                  NaN
# study_family_member                                       NaN
# study_family_member_participant_id                        NaN
# study_family_member_relationship                          NaN
# study_household_member                                    NaN
# study_household_member_participant_id                     NaN
# domestic_household_type                                   NaN
# domestic_household_appliances                             NaN
# domestic_household_years                                  NaN
# domestic_household_people_number                          NaN
# domestic_household_people_relationship                    NaN
# domestic_household_car_number                             NaN
# domestic_household_income                                 NaN
# domestic_job_status                                       NaN
# domestic_job_years                                        NaN
# domestic_job_months                                       NaN
# domestic_job_hours_daily                                  NaN
# domestic_job_office_days                                  NaN
# domestic_job_transport                                    NaN
# domestic_job_distance                                     NaN
# domestic_job_walking_standing                             NaN
# domestic_job_manual_physical                              NaN
# domestic_job_shifts                                       NaN
# domestic_job_night_shift                                  NaN
# domestic_education_qualifications                         NaN
# domestic_education_age                                    NaN
# extra_domestic_job_hours                                  NaN
# extra_domestic_past_pets                                  NaN
# extra_domestic_current_pets                               NaN
# extra_domestic_current_pets_type                          NaN
# extra_domestic_residence_area_type                        NaN
# exrta_domestic_current_assisted_living                    NaN
# extra_army_past_service                                   NaN
# extra_army_past_position                                  NaN
# extra_army_past_duration                                  NaN
# domestic_job_home_days                                    NaN
# data_source                                               NaN
#
#                                           bulk_dictionary  \
# tabular_field_name
# collection_timestamp                                  NaN
# collection_date                                       NaN
# timezone                                              NaN
# DOB                                                   NaN
# country_of_birth                                      NaN
# year_of_aliya                                         NaN
# father_country_of_birth                               NaN
# grandfather_country_of_birth_father_side              NaN
# grandmother_country_of_birth_father_side              NaN
# mother_country_of_birth                               NaN
# grandfather_country_of_birth_mother_side              NaN
# grandmother_country_of_birth_mother_side              NaN
# education                                             NaN
# gender                                                NaN
# collection_timestamp                                  NaN
# collection_date                                       NaN
# timezone                                              NaN
# study_family_member                                   NaN
# study_family_member_participant_id                    NaN
# study_family_member_relationship                      NaN
# study_household_member                                NaN
# study_household_member_participant_id                 NaN
# domestic_household_type                               NaN
# domestic_household_appliances                         NaN
# domestic_household_years                              NaN
# domestic_household_people_number                      NaN
# domestic_household_people_relationship                NaN
# domestic_household_car_number                         NaN
# domestic_household_income                             NaN
# domestic_job_status                                   NaN
# domestic_job_years                                    NaN
# domestic_job_months                                   NaN
# domestic_job_hours_daily                              NaN
# domestic_job_office_days                              NaN
# domestic_job_transport                                NaN
# domestic_job_distance                                 NaN
# domestic_job_walking_standing                         NaN
# domestic_job_manual_physical                          NaN
# domestic_job_shifts                                   NaN
# domestic_job_night_shift                              NaN
# domestic_education_qualifications                     NaN
# domestic_education_age                                NaN
# extra_domestic_job_hours                              NaN
# extra_domestic_past_pets                              NaN
# extra_domestic_current_pets                           NaN
# extra_domestic_current_pets_type                      NaN
# extra_domestic_residence_area_type                    NaN
# exrta_domestic_current_assisted_living                NaN
# extra_army_past_service                               NaN
# extra_army_past_position                              NaN
# extra_army_past_duration                              NaN
# domestic_job_home_days                                NaN
# data_source                                           NaN
#
#                                                                          description_string  \
# tabular_field_name
# collection_timestamp                                   Timestamp of measurements collection
# collection_date                                              Date of measurments collection
# timezone                                                        Timezone of the measurments
# DOB                                                                              Birth year
# country_of_birth                                                                 Birth Land
# year_of_aliya                                                      Year of aliyah to Israel
# father_country_of_birth                     Grandfather's country of birth on father's side
# grandfather_country_of_birth_father_side   Grandmother's country of birth on father's  side
# grandmother_country_of_birth_father_side                           Grandmother's Birth Land
# mother_country_of_birth                                              Country of your mother
# grandfather_country_of_birth_mother_side    Grandfather's country of birth on mother's side
# grandmother_country_of_birth_mother_side    Grandmother's country of birth on mother's side
# education                                                                   Education level
# gender                                                                               Gender
# collection_timestamp                                   Timestamp of measurements collection
# collection_date                                              Date of measurments collection
# timezone                                                        Timezone of the measurments
# study_family_member                       Is a member of your family a participant in th...
# study_family_member_participant_id                            What is their participant ID?
# study_family_member_relationship             What is your degree of relationship with them?
# study_household_member                    Does anyone in your household participate in t...
# study_household_member_participant_id                        What are their participant ID?
# domestic_household_type                          What type of accommodation do you live in?
# domestic_household_appliances             Do you have any of the following in your home?...
# domestic_household_years                  How many years have you lived at your current ...
# domestic_household_people_number          Including yourself, how many people are living...
# domestic_household_people_relationship    How are the other people who live with you rel...
# domestic_household_car_number             How many cars or vans are owned, or available ...
# domestic_household_income                 What is the average total income after tax rec...
# domestic_job_status                       Which of the following describes your current ...
# domestic_job_years                        How many years have you worked in your current...
# domestic_job_months                       How many months have you worked in your curren...
# domestic_job_hours_daily                  In a typical DAY, how many hours do you spend ...
# domestic_job_office_days                  How many days a WEEK do you travel from home t...
# domestic_job_transport                    What types of transport do you use to get to a...
# domestic_job_distance                     About how many km is it between your home and ...
# domestic_job_walking_standing             Does your work involve walking or standing for...
# domestic_job_manual_physical              Does your work involve heavy manual or physica...
# domestic_job_shifts                                      Does your work involve shift work?
# domestic_job_night_shift                               Does your work involve night shifts?
# domestic_education_qualifications         Which of the following qualifications do you h...
# domestic_education_age                    At what age did you complete your continuous f...
# extra_domestic_job_hours                                           Extra domestic job hours
# extra_domestic_past_pets                                           Extra domestic past pets
# extra_domestic_current_pets                                     Extra domestic current pets
# extra_domestic_current_pets_type                           Extra domestic current pets type
# extra_domestic_residence_area_type                       Extra domestic residence area type
# exrta_domestic_current_assisted_living               Exrta domestic current assisted living
# extra_army_past_service                                             Extra army past service
# extra_army_past_position                                           Extra army past position
# extra_army_past_duration                                           Extra army past duration
# domestic_job_home_days                              Frequency of working remotely from home
# data_source                                              Data source of survey information
#
#                                                       field_type  \
# tabular_field_name
# collection_timestamp                                    Datetime
# collection_date                                             Date
# timezone                                    Categorical (single)
# DOB                                                      Integer
# country_of_birth                            Categorical (single)
# year_of_aliya                                            Integer
# father_country_of_birth                     Categorical (single)
# grandfather_country_of_birth_father_side    Categorical (single)
# grandmother_country_of_birth_father_side    Categorical (single)
# mother_country_of_birth                     Categorical (single)
# grandfather_country_of_birth_mother_side    Categorical (single)
# grandmother_country_of_birth_mother_side    Categorical (single)
# education                                   Categorical (single)
# gender                                      Categorical (single)
# collection_timestamp                                    Datetime
# collection_date                                             Date
# timezone                                    Categorical (single)
# study_family_member                         Categorical (single)
# study_family_member_participant_id                       Integer
# study_family_member_relationship            Categorical (single)
# study_household_member                      Categorical (single)
# study_household_member_participant_id                    Integer
# domestic_household_type                     Categorical (single)
# domestic_household_appliances             Categorical (multiple)
# domestic_household_years                                 Integer
# domestic_household_people_number                         Integer
# domestic_household_people_relationship    Categorical (multiple)
# domestic_household_car_number               Categorical (single)
# domestic_household_income                   Categorical (single)
# domestic_job_status                       Categorical (multiple)
# domestic_job_years                                       Integer
# domestic_job_months                                      Integer
# domestic_job_hours_daily                                 Integer
# domestic_job_office_days                                 Integer
# domestic_job_transport                    Categorical (multiple)
# domestic_job_distance                                    Integer
# domestic_job_walking_standing               Categorical (single)
# domestic_job_manual_physical                Categorical (single)
# domestic_job_shifts                         Categorical (single)
# domestic_job_night_shift                    Categorical (single)
# domestic_education_qualifications         Categorical (multiple)
# domestic_education_age                                   Integer
# extra_domestic_job_hours                                 Integer
# extra_domestic_past_pets                    Categorical (single)
# extra_domestic_current_pets                 Categorical (single)
# extra_domestic_current_pets_type          Categorical (multiple)
# extra_domestic_residence_area_type          Categorical (single)
# exrta_domestic_current_assisted_living      Categorical (single)
# extra_army_past_service                     Categorical (single)
# extra_army_past_position                    Categorical (single)
# extra_army_past_duration                                 Integer
# domestic_job_home_days                                   Integer
# data_source                                                 Text
#
#                                                             pandas_dtype  \
# tabular_field_name
# collection_timestamp                      datetime64[ns, Asia/Jerusalem]
# collection_date                                           datetime64[ns]
# timezone                                                        category
# DOB                                                                  int
# country_of_birth                                                     int
# year_of_aliya                                                        int
# father_country_of_birth                                              int
# grandfather_country_of_birth_father_side                             int
# grandmother_country_of_birth_father_side                             int
# mother_country_of_birth                                              int
# grandfather_country_of_birth_mother_side                             int
# grandmother_country_of_birth_mother_side                             int
# education                                                            int
# gender                                                               int
# collection_timestamp                      datetime64[ns, Asia/Jerusalem]
# collection_date                                           datetime64[ns]
# timezone                                                          string
# study_family_member                                                  int
# study_family_member_participant_id                                   int
# study_family_member_relationship                                     int
# study_household_member                                               int
# study_household_member_participant_id                                int
# domestic_household_type                                              int
# domestic_household_appliances                                     object
# domestic_household_years                                             int
# domestic_household_people_number                                     int
# domestic_household_people_relationship                            object
# domestic_household_car_number                                        int
# domestic_household_income                                            int
# domestic_job_status                                               object
# domestic_job_years                                                   int
# domestic_job_months                                                  int
# domestic_job_hours_daily                                             int
# domestic_job_office_days                                             int
# domestic_job_transport                                            object
# domestic_job_distance                                                int
# domestic_job_walking_standing                                        int
# domestic_job_manual_physical                                         int
# domestic_job_shifts                                                  int
# domestic_job_night_shift                                             int
# domestic_education_qualifications                                 object
# domestic_education_age                                               int
# extra_domestic_job_hours                                             int
# extra_domestic_past_pets                                             int
# extra_domestic_current_pets                                          int
# extra_domestic_current_pets_type                                  object
# extra_domestic_residence_area_type                                   int
# exrta_domestic_current_assisted_living                               int
# extra_army_past_service                                              int
# extra_army_past_position                                             int
# extra_army_past_duration                                             int
# domestic_job_home_days                                               int
# data_source                                                       string
#
#                                          stability      units  sampling_rate  \
# tabular_field_name
# collection_timestamp                      Accruing       Time            NaN
# collection_date                           Accruing       Time            NaN
# timezone                                  Accruing        NaN            NaN
# DOB                                       Accruing       year            NaN
# country_of_birth                          Accruing        NaN            NaN
# year_of_aliya                             Accruing       year            NaN
# father_country_of_birth                   Accruing        NaN            NaN
# grandfather_country_of_birth_father_side  Accruing        NaN            NaN
# grandmother_country_of_birth_father_side  Accruing        NaN            NaN
# mother_country_of_birth                   Accruing        NaN            NaN
# grandfather_country_of_birth_mother_side  Accruing        NaN            NaN
# grandmother_country_of_birth_mother_side  Accruing        NaN            NaN
# education                                 Accruing        NaN            NaN
# gender                                    Accruing        NaN            NaN
# collection_timestamp                      Accruing       Time            NaN
# collection_date                           Accruing       Time            NaN
# timezone                                  Accruing        NaN            NaN
# study_family_member                       Accruing        NaN            NaN
# study_family_member_participant_id        Accruing        NaN            NaN
# study_family_member_relationship          Accruing        NaN            NaN
# study_household_member                    Accruing        NaN            NaN
# study_household_member_participant_id     Accruing        NaN            NaN
# domestic_household_type                   Accruing        NaN            NaN
# domestic_household_appliances             Accruing        NaN            NaN
# domestic_household_years                  Accruing      Years            NaN
# domestic_household_people_number          Accruing     People            NaN
# domestic_household_people_relationship    Accruing        NaN            NaN
# domestic_household_car_number             Accruing       Cars            NaN
# domestic_household_income                 Accruing  NIS/Month            NaN
# domestic_job_status                       Accruing        NaN            NaN
# domestic_job_years                        Accruing      Years            NaN
# domestic_job_months                       Accruing     Months            NaN
# domestic_job_hours_daily                  Accruing  Hours/Day            NaN
# domestic_job_office_days                  Accruing  Days/Week            NaN
# domestic_job_transport                    Accruing        NaN            NaN
# domestic_job_distance                     Accruing         Km            NaN
# domestic_job_walking_standing             Accruing        NaN            NaN
# domestic_job_manual_physical              Accruing        NaN            NaN
# domestic_job_shifts                       Accruing        NaN            NaN
# domestic_job_night_shift                  Accruing        NaN            NaN
# domestic_education_qualifications         Accruing        NaN            NaN
# domestic_education_age                    Accruing      Years            NaN
# extra_domestic_job_hours                  Accruing      Hours            NaN
# extra_domestic_past_pets                  Accruing        NaN            NaN
# extra_domestic_current_pets               Accruing        NaN            NaN
# extra_domestic_current_pets_type          Accruing        NaN            NaN
# extra_domestic_residence_area_type        Accruing        NaN            NaN
# exrta_domestic_current_assisted_living    Accruing        NaN            NaN
# extra_army_past_service                   Accruing        NaN            NaN
# extra_army_past_position                  Accruing        NaN            NaN
# extra_army_past_duration                  Accruing      Years            NaN
# domestic_job_home_days                    Accruing        NaN            NaN
# data_source                               Accruing        NaN            NaN
#
#                                                    strata       sexed  \
# tabular_field_name
# collection_timestamp                      Collection time  Both sexes
# collection_date                           Collection time  Both sexes
# timezone                                  Collection time  Both sexes
# DOB                                               Primary  Both sexes
# country_of_birth                                  Primary  Both sexes
# year_of_aliya                                     Primary  Both sexes
# father_country_of_birth                           Primary  Both sexes
# grandfather_country_of_birth_father_side          Primary  Both sexes
# grandmother_country_of_birth_father_side          Primary  Both sexes
# mother_country_of_birth                           Primary  Both sexes
# grandfather_country_of_birth_mother_side          Primary  Both sexes
# grandmother_country_of_birth_mother_side          Primary  Both sexes
# education                                         Primary  Both sexes
# gender                                            Primary  Both sexes
# collection_timestamp                      Collection time  Both sexes
# collection_date                           Collection time  Both sexes
# timezone                                  Collection time  Both sexes
# study_family_member                               Primary  Both sexes
# study_family_member_participant_id                Primary  Both sexes
# study_family_member_relationship                  Primary  Both sexes
# study_household_member                            Primary  Both sexes
# study_household_member_participant_id             Primary  Both sexes
# domestic_household_type                           Primary  Both sexes
# domestic_household_appliances                     Primary  Both sexes
# domestic_household_years                          Primary  Both sexes
# domestic_household_people_number                  Primary  Both sexes
# domestic_household_people_relationship            Primary  Both sexes
# domestic_household_car_number                     Primary  Both sexes
# domestic_household_income                         Primary  Both sexes
# domestic_job_status                               Primary  Both sexes
# domestic_job_years                                Primary  Both sexes
# domestic_job_months                               Primary  Both sexes
# domestic_job_hours_daily                          Primary  Both sexes
# domestic_job_office_days                          Primary  Both sexes
# domestic_job_transport                            Primary  Both sexes
# domestic_job_distance                             Primary  Both sexes
# domestic_job_walking_standing                     Primary  Both sexes
# domestic_job_manual_physical                      Primary  Both sexes
# domestic_job_shifts                               Primary  Both sexes
# domestic_job_night_shift                          Primary  Both sexes
# domestic_education_qualifications                 Primary  Both sexes
# domestic_education_age                            Primary  Both sexes
# extra_domestic_job_hours                          Primary  Both sexes
# extra_domestic_past_pets                          Primary  Both sexes
# extra_domestic_current_pets                       Primary  Both sexes
# extra_domestic_current_pets_type                  Primary  Both sexes
# extra_domestic_residence_area_type                Primary  Both sexes
# exrta_domestic_current_assisted_living            Primary  Both sexes
# extra_army_past_service                           Primary  Both sexes
# extra_army_past_position                          Primary  Both sexes
# extra_army_past_duration                          Primary  Both sexes
# domestic_job_home_days                            Primary  Both sexes
# data_source                                     Auxiliary  Both sexes
#
#                                               debut  completed data_coding  \
# tabular_field_name
# collection_timestamp                      2/26/2020        NaN         NaN
# collection_date                           2/26/2020        NaN         NaN
# timezone                                  2/26/2020        NaN         NaN
# DOB                                       2/26/2020        NaN         NaN
# country_of_birth                          2/26/2020        NaN      053_01
# year_of_aliya                             2/26/2020        NaN         NaN
# father_country_of_birth                   2/26/2020        NaN      053_01
# grandfather_country_of_birth_father_side  2/26/2020        NaN      053_01
# grandmother_country_of_birth_father_side  2/26/2020        NaN      053_01
# mother_country_of_birth                   2/26/2020        NaN      053_01
# grandfather_country_of_birth_mother_side  2/26/2020        NaN      053_01
# grandmother_country_of_birth_mother_side  2/26/2020        NaN      053_01
# education                                 2/26/2020        NaN      053_02
# gender                                    2/26/2020        NaN           9
# collection_timestamp                       1/9/2019        NaN         NaN
# collection_date                            1/9/2019        NaN         NaN
# timezone                                   1/9/2019        NaN         NaN
# study_family_member                        1/9/2019        NaN           7
# study_family_member_participant_id         1/9/2019        NaN         NaN
# study_family_member_relationship           1/9/2019        NaN     P100200
# study_household_member                     1/9/2019        NaN           7
# study_household_member_participant_id      1/9/2019        NaN         NaN
# domestic_household_type                    1/9/2019        NaN      100286
# domestic_household_appliances              1/9/2019        NaN     P100288
# domestic_household_years                   1/9/2019        NaN         NaN
# domestic_household_people_number           1/9/2019        NaN         NaN
# domestic_household_people_relationship     1/9/2019        NaN     P100292
# domestic_household_car_number              1/9/2019        NaN      100293
# domestic_household_income                  1/9/2019        NaN     P100294
# domestic_job_status                        1/9/2019        NaN     P100295
# domestic_job_years                         1/9/2019        NaN         NaN
# domestic_job_months                        1/9/2019        NaN         NaN
# domestic_job_hours_daily                   1/9/2019        NaN         NaN
# domestic_job_office_days                   1/9/2019        NaN         NaN
# domestic_job_transport                     1/9/2019        NaN     P100299
# domestic_job_distance                      1/9/2019        NaN         NaN
# domestic_job_walking_standing              1/9/2019        NaN      100301
# domestic_job_manual_physical               1/9/2019        NaN      100301
# domestic_job_shifts                        1/9/2019        NaN      100301
# domestic_job_night_shift                   1/9/2019        NaN      100301
# domestic_education_qualifications          1/9/2019        NaN     P100305
# domestic_education_age                     1/9/2019        NaN         NaN
# extra_domestic_job_hours                   1/9/2019        NaN         NaN
# extra_domestic_past_pets                   1/9/2019        NaN           7
# extra_domestic_current_pets                1/9/2019        NaN           7
# extra_domestic_current_pets_type           1/9/2019        NaN      040_09
# extra_domestic_residence_area_type         1/9/2019        NaN      040_10
# exrta_domestic_current_assisted_living     1/9/2019        NaN     P100352
# extra_army_past_service                    1/9/2019        NaN      040_11
# extra_army_past_position                   1/9/2019        NaN      040_12
# extra_army_past_duration                   1/9/2019        NaN         NaN
# domestic_job_home_days                    2/17/2020        NaN         NaN
# data_source                               2/26/2020        NaN         NaN
#
#                                            array
# tabular_field_name
# collection_timestamp                      Single
# collection_date                           Single
# timezone                                  Single
# DOB                                       Single
# country_of_birth                          Single
# year_of_aliya                             Single
# father_country_of_birth                   Single
# grandfather_country_of_birth_father_side  Single
# grandmother_country_of_birth_father_side  Single
# mother_country_of_birth                   Single
# grandfather_country_of_birth_mother_side  Single
# grandmother_country_of_birth_mother_side  Single
# education                                 Single
# gender                                    Single
# collection_timestamp                      Single
# collection_date                           Single
# timezone                                  Single
# study_family_member                       Single
# study_family_member_participant_id        Single
# study_family_member_relationship          Single
# study_household_member                    Single
# study_household_member_participant_id     Single
# domestic_household_type                   Single
# domestic_household_appliances             Single
# domestic_household_years                  Single
# domestic_household_people_number          Single
# domestic_household_people_relationship    Single
# domestic_household_car_number             Single
# domestic_household_income                 Single
# domestic_job_status                       Single
# domestic_job_years                        Single
# domestic_job_months                       Single
# domestic_job_hours_daily                  Single
# domestic_job_office_days                  Single
# domestic_job_transport                    Single
# domestic_job_distance                     Single
# domestic_job_walking_standing             Single
# domestic_job_manual_physical              Single
# domestic_job_shifts                       Single
# domestic_job_night_shift                  Single
# domestic_education_qualifications         Single
# domestic_education_age                    Single
# extra_domestic_job_hours                  Single
# extra_domestic_past_pets                  Single
# extra_domestic_current_pets               Single
# extra_domestic_current_pets_type          Single
# extra_domestic_residence_area_type        Single
# exrta_domestic_current_assisted_living    Single
# extra_army_past_service                   Single
# extra_army_past_position                  Single
# extra_army_past_duration                  Single
# domestic_job_home_days                    Single
# data_source                               Single
