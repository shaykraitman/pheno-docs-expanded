# %% [raw]
# ---
# output-file: 049-medical_symptoms.html
# title: Medical Symptoms
# ---

# %% [markdown]
# ### Description
#
# Medical symptoms data captures detailed information about an individual's current health status by recording physical and mental symptoms they experience. This data includes subjective descriptions such as pain levels, fatigue, and other discomforts, along with observed signs like fever or swelling. Tracking symptoms over time helps in identifying potential health issues, understanding disease onset and progression, and supporting diagnosis. It provides valuable real-time insights into patient well-being and is crucial for personalized healthcare management and treatment planning.
#
# ### Introduction
#
# The Human Phenotype Project study collects medical data through online surveys, where participants self-report their experiences with various medical symptoms. This method depends on individuals accurately conveying their own health experiences. Obtaining detailed and thorough information about the symptoms people experience is essential to understand their actual impact on individual health.
#
# ### Measurement protocol
# <!-- long measurment protocol for the data browser -->
# In the initial phase of the study, during registration, participants are asked to provide information about any medical symptoms they have experienced in the Initial Medical Survey. Additional data is then collected in the Follow-up UKBB Survey during subsequent visits, allowing for ongoing tracking of these symptoms
#
# An additional survey is asked to participants focusing on Irritable Bowel Syndrome (IBS) and digestive health. This digestive health survey is an adaptation of the UK Biobank online gastro-intestinal health self-assessment questionnaire. Many of the questions in the UK Biobank gut health (IBS) questionnaire were adopted from the World Gastroenterology Association questionnaire (2009). Questions asked are related to the participant’s bowel habits, characterization of abdominal pain patterns, accompanying symptoms, and history of IBS in the family.
#
# ### Data availability
# <!-- for the example notebooks -->
# The information is stored in 3 parquest files: `initial_medical.parquet`, `follow_up_ukbb.parquet` and `digestve_health.parquet`
#
# ### Summary of available data
# <!-- for the data browser -->
# 1. Initial Medical Survey: A DataFrame containing tabular features representing responses related to medical symptoms from the initial medical survey.
# 2. Lifestyle Survey: A DataFrame containing tabular features representing responses related to medical symptoms, from the lifestyle survey.
# 3. Digestive Health: A DataFrame containing tabular features focused on reported medical symptoms specifically related to digestive health, such as abdominal pain, bloating, and bowel habits.
#
# ### Relevant links
#
# * [Pheno Knowledgebase](https://knowledgebase.pheno.ai/datasets/049-medical_symptoms)
# * [Pheno Data Browser](https://pheno-demo-app.vercel.app/folder/49)

# %%
#| echo: false
import pandas as pd
pd.set_option("display.max_rows", 500)

# %%
from pheno_utils import PhenoLoader

# %%
pl = PhenoLoader('medical_symptoms')
pl
# Out:
# PhenoLoader for medical_symptoms with
# 86 fields
# 4 tables: ['initial_medical', 'follow_up_ukbb', 'digestive_health', 'age_sex']

# %% [markdown]
# # Data dictionary

# %%
pl.dict
# Out:
#                                                   folder_id       feature_set  \
# tabular_field_name
# collection_timestamp                                     49   initial_medical
# collection_date                                          49   initial_medical
# timezone                                                 49   initial_medical
# are_you_suffering_for_the_following_symptoms             49   initial_medical
# how_often_headache                                       49   initial_medical
# chest_pain_during_power_walking_up_stairs_uphill         49   initial_medical
# chest_pain_dissipates_with_rest                          49   initial_medical
# leg_pain_stops_with_rest                                 49   initial_medical
# mood_most_days                                           49   initial_medical
# tired_day                                                49   initial_medical
# hard_to_climb                                            49   initial_medical
# hard_to_routine                                          49   initial_medical
# rarely_leave_home                                        49   initial_medical
# rarely_spent_time_friends_family                         49   initial_medical
# hard_to_work                                             49   initial_medical
# hard_to_relax                                            49   initial_medical
# hard_to_have_sex                                         49   initial_medical
# feeling_tired                                            49   initial_medical
# feeling_like_a_burdan                                    49   initial_medical
# worried_about_your_health                                49   initial_medical
# collection_timestamp                                     49    follow_up_ukbb
# collection_date                                          49    follow_up_ukbb
# timezone                                                 49    follow_up_ukbb
# mlhfq_rest_during_day                                    49    follow_up_ukbb
# mlhfq_difficulty_walking                                 49    follow_up_ukbb
# mlhfq_difficulty_house_work                              49    follow_up_ukbb
# mlhfq_rarely_leave_house                                 49    follow_up_ukbb
# mlhfq_rarely_socialize                                   49    follow_up_ukbb
# mlhfq_difficulty_working                                 49    follow_up_ukbb
# mlhfq_difficulty_maintining_hobbies                      49    follow_up_ukbb
# mlhfq_difficulty_intercourse                             49    follow_up_ukbb
# mlhfq_fatigue                                            49    follow_up_ukbb
# mlhfq_liability                                          49    follow_up_ukbb
# mlhfq_medical_state_concers                              49    follow_up_ukbb
# collection_timestamp                                     49  digestive_health
# collection_date                                          49  digestive_health
# timezone                                                 49  digestive_health
# abdomen_pain_frequency_past_3_months                     49  digestive_health
# abdomen_pain_women_during_period                         49  digestive_health
# abdomen_pain_past_6_months                               49  digestive_health
# abdomen_pain_improve_after_bowl_movement                 49  digestive_health
# abdomen_pain_increases_bowl_movements                    49  digestive_health
# abdomen_pain_decreases_bowl_movements                    49  digestive_health
# soft_stool_during_abdomen_pain                           49  digestive_health
# hard_stool_during_abdomen_pain                           49  digestive_health
# hard_stool_frequency_past_3_months                       49  digestive_health
# soft_stool_frequency_past_3_months                       49  digestive_health
# abdomen_pain_current                                     49  digestive_health
# abdomen_pain_current_severity                            49  digestive_health
# abdomen_pain_days_out_of_10                              49  digestive_health
# abdomen_pain_current_distension                          49  digestive_health
# abdomen_pain_current_distension_severity                 49  digestive_health
# bowl_movements_current_satisfaction                      49  digestive_health
# abdomen_pain_current_general_interference                49  digestive_health
# bowl_movements_daily_max                                 49  digestive_health
# bowl_movements_daily_min                                 49  digestive_health
# bowl_movements_daily_average                             49  digestive_health
# abdomen_pain_work_weeks_missed_number                    49  digestive_health
# abdomen_pain_work_weeks_missed_choice                    49  digestive_health
# abdomen_pain_work_weeks_suffering                        49  digestive_health
# back_pain_past_3_months                                  49  digestive_health
# legs_joint_pain_past_3_months                            49  digestive_health
# menstural_cramps_past_3_months                           49  digestive_health
# headaches_past_3_months                                  49  digestive_health
# chest_pain_past_3_months                                 49  digestive_health
# dizziness_past_3_months                                  49  digestive_health
# fainting_past_3_months                                   49  digestive_health
# heart_race_past_3_months                                 49  digestive_health
# shortness_of_breath_past_3_months                        49  digestive_health
# intercourse_pain_past_3_months                           49  digestive_health
# bladder_irritability_past_3_months                       49  digestive_health
# nausea_past_3_months                                     49  digestive_health
# tired_past_3_months                                      49  digestive_health
# sleeping_trouble_past_3_months                           49  digestive_health
# anxiety_treatment_past                                   49  digestive_health
# depression_treatment_past                                49  digestive_health
# sensitive_stomach                                        49  digestive_health
# history_family_ibs                                       49  digestive_health
# history_birth_caesarian_section                          49  digestive_health
# history_childhood_antibiotics                            49  digestive_health
# history_diagnoses_celiac                                 49  digestive_health
# history_diagnoses_celiac_method                          49  digestive_health
# history_diagnoses_ibs                                    49  digestive_health
# history_ibs_symptoms_speed                               49  digestive_health
# history_ibs_first_symptoms_infection                     49  digestive_health
# history_ibs_first_symptoms_infection_choice              49  digestive_health
# history_ibs_first_symptoms_fever                         49  digestive_health
# history_ibs_first_symptoms_diarrhoea                     49  digestive_health
# history_ibs_first_symptoms_bloody_diarrhoea              49  digestive_health
# history_ibs_first_symptoms_vomiting                      49  digestive_health
#
#                                                                                        field_string  \
# tabular_field_name
# collection_timestamp                                                           Collection timestamp
# collection_date                                                                     Collection date
# timezone                                                                                   Timezone
# are_you_suffering_for_the_following_symptoms           Are you suffering for the following symptoms
# how_often_headache                                                               How often headache
# chest_pain_during_power_walking_up_stairs_uphill   Chest pain during power walking up stairs uphill
# chest_pain_dissipates_with_rest                                     Chest pain dissipates with rest
# leg_pain_stops_with_rest                                                   Leg pain stops with rest
# mood_most_days                                                                       Mood most days
# tired_day                                                                                 Tired day
# hard_to_climb                                                                         Hard to climb
# hard_to_routine                                                                     Hard to routine
# rarely_leave_home                                                                 Rarely leave home
# rarely_spent_time_friends_family                                   Rarely spent time firends family
# hard_to_work                                                                           Hard to work
# hard_to_relax                                                                         Hard to relax
# hard_to_have_sex                                                                   Hard to have sex
# feeling_tired                                                                         Feeling tired
# feeling_like_a_burdan                                                         Feeling like a burdan
# worried_about_your_health                                                 Worried about your health
# collection_timestamp                                                           Collection timestamp
# collection_date                                                                     Collection date
# timezone                                                                                   Timezone
# mlhfq_rest_during_day                                  Do you feel the need to rest during the day?
# mlhfq_difficulty_walking                          Do you feel difficulty walking or climbing sta...
# mlhfq_difficulty_house_work                       Do you have difficulty doing routine tasks at ...
# mlhfq_rarely_leave_house                                            Do you rarely leave your house?
# mlhfq_rarely_socialize                             Do you rarely socialize with family and friends?
# mlhfq_difficulty_working                          Do you feel physical difficulty working for a ...
# mlhfq_difficulty_maintining_hobbies               Do you find it difficult to engage in hobbies ...
# mlhfq_difficulty_intercourse                                     Do you have difficulty having sex?
# mlhfq_fatigue                                             Do you feel tired, weak, have low energy?
# mlhfq_liability                                   Have you felt a burden on your environment due...
# mlhfq_medical_state_concers                                      Are you worried about your health?
# collection_timestamp                                                           Collection timestamp
# collection_date                                                                     Collection date
# timezone                                                                                   Timezone
# abdomen_pain_frequency_past_3_months              Frequency of discomfort/pain in abdomen in las...
# abdomen_pain_women_during_period                  Discomfort/pain occurring only during menstrua...
# abdomen_pain_past_6_months                         Abdominal discomfort/pain for 6 months or longer
# abdomen_pain_improve_after_bowl_movement          Frequency of discomfort/pain getting better or...
# abdomen_pain_increases_bowl_movements             More frequent bowel movements when abdominal d...
# abdomen_pain_decreases_bowl_movements             Less frequent bowel movements when abdominal d...
# soft_stool_during_abdomen_pain                    Stools looser when abdominal discomfort/pain s...
# hard_stool_during_abdomen_pain                    Frequency of harder stools when abdominal disc...
# hard_stool_frequency_past_3_months                Frequency of hard/lumpy stools in the last 3 m...
# soft_stool_frequency_past_3_months                Frequency of loose/mushy/watery stools in the ...
# abdomen_pain_current                              Currently (in last 3 months) suffer from abdom...
# abdomen_pain_current_severity                                    Severity of current abdominal pain
# abdomen_pain_days_out_of_10                          Number of days (out of 10) with abdominal pain
# abdomen_pain_current_distension                          Currently suffer from abdominal distension
# abdomen_pain_current_distension_severity          Severity of current abdominal distension/tight...
# bowl_movements_current_satisfaction                                  Satisfaction with bowel habits
# abdomen_pain_current_general_interference         Degree to which abdominal pain/discomfort/alte...
# bowl_movements_daily_max                             Greatest number of times bowels opened per day
# bowl_movements_daily_min                               Least number of times bowels opened per week
# bowl_movements_daily_average                          Average number of times bowels opened per day
# abdomen_pain_work_weeks_missed_number             Number of weeks absent from work due to IBS, i...
# abdomen_pain_work_weeks_missed_choice                                  When gave up work due to IBS
# abdomen_pain_work_weeks_suffering                 Number of weeks (in the last year) at work suf...
# back_pain_past_3_months                           Degree bothered by back pain in the past 3 months
# legs_joint_pain_past_3_months                     Degree bothered by pain in arms/legs/joints in...
# menstural_cramps_past_3_months                    Degree bothered by menstrual cramps or other p...
# headaches_past_3_months                           Degree bothered by headaches in the last 3 months
# chest_pain_past_3_months                          Degree bothered by chest pain in the last 3 mo...
# dizziness_past_3_months                           Degree bothered by dizziness in the last 3 months
# fainting_past_3_months                            Degree bothered by fainting spells in the last...
# heart_race_past_3_months                          Degree bothered by feeling heart pound/race in...
# shortness_of_breath_past_3_months                 Degree bothered by shortness of breath in the ...
# intercourse_pain_past_3_months                    Degree bothered by pain/problems during interc...
# bladder_irritability_past_3_months                Degree bothered by urinary frequency/bladder i...
# nausea_past_3_months                                 Degree bothered by nausea in the last 3 months
# tired_past_3_months                               Degree bothered by feeling tired all the time ...
# sleeping_trouble_past_3_months                    Degree bothered by trouble sleeping in the las...
# anxiety_treatment_past                               Ever been offered/sought treatment for anxiety
# depression_treatment_past                         Ever been offered/sought treatment for depression
# sensitive_stomach                                                                 Sensitive stomach
# history_family_ibs                                                            Family history of IBS
# history_birth_caesarian_section                                           Born by caesarian section
# history_childhood_antibiotics                     Long-term/recurrent antibiotics as child or te...
# history_diagnoses_celiac                          Diagnosed with coeliac disease or gluten sensi...
# history_diagnoses_celiac_method                   Method of coeliac disease/gluten sensitivity d...
# history_diagnoses_ibs                                                       Ever diagnosed with IBS
# history_ibs_symptoms_speed                                           Speed of onset of IBS symptoms
# history_ibs_first_symptoms_infection              Infectious illness diagnosis status when IBS s...
# history_ibs_first_symptoms_infection_choice       Infection diagnosed alongside IBS when IBS sym...
# history_ibs_first_symptoms_fever                                Fever when IBS symptoms first began
# history_ibs_first_symptoms_diarrhoea                        Diarrhoea when IBS symptoms first began
# history_ibs_first_symptoms_bloody_diarrhoea          Bloody diarrhoea when IBS symptoms first began
# history_ibs_first_symptoms_vomiting                          Vomiting when IBS symptoms first began
#
#                                                                           relative_location  \
# tabular_field_name
# collection_timestamp                               medical_symptoms/initial_medical.parquet
# collection_date                                    medical_symptoms/initial_medical.parquet
# timezone                                           medical_symptoms/initial_medical.parquet
# are_you_suffering_for_the_following_symptoms       medical_symptoms/initial_medical.parquet
# how_often_headache                                 medical_symptoms/initial_medical.parquet
# chest_pain_during_power_walking_up_stairs_uphill   medical_symptoms/initial_medical.parquet
# chest_pain_dissipates_with_rest                    medical_symptoms/initial_medical.parquet
# leg_pain_stops_with_rest                           medical_symptoms/initial_medical.parquet
# mood_most_days                                     medical_symptoms/initial_medical.parquet
# tired_day                                          medical_symptoms/initial_medical.parquet
# hard_to_climb                                      medical_symptoms/initial_medical.parquet
# hard_to_routine                                    medical_symptoms/initial_medical.parquet
# rarely_leave_home                                  medical_symptoms/initial_medical.parquet
# rarely_spent_time_friends_family                   medical_symptoms/initial_medical.parquet
# hard_to_work                                       medical_symptoms/initial_medical.parquet
# hard_to_relax                                      medical_symptoms/initial_medical.parquet
# hard_to_have_sex                                   medical_symptoms/initial_medical.parquet
# feeling_tired                                      medical_symptoms/initial_medical.parquet
# feeling_like_a_burdan                              medical_symptoms/initial_medical.parquet
# worried_about_your_health                          medical_symptoms/initial_medical.parquet
# collection_timestamp                                medical_symptoms/follow_up_ukbb.parquet
# collection_date                                     medical_symptoms/follow_up_ukbb.parquet
# timezone                                            medical_symptoms/follow_up_ukbb.parquet
# mlhfq_rest_during_day                               medical_symptoms/follow_up_ukbb.parquet
# mlhfq_difficulty_walking                            medical_symptoms/follow_up_ukbb.parquet
# mlhfq_difficulty_house_work                         medical_symptoms/follow_up_ukbb.parquet
# mlhfq_rarely_leave_house                            medical_symptoms/follow_up_ukbb.parquet
# mlhfq_rarely_socialize                              medical_symptoms/follow_up_ukbb.parquet
# mlhfq_difficulty_working                            medical_symptoms/follow_up_ukbb.parquet
# mlhfq_difficulty_maintining_hobbies                 medical_symptoms/follow_up_ukbb.parquet
# mlhfq_difficulty_intercourse                        medical_symptoms/follow_up_ukbb.parquet
# mlhfq_fatigue                                       medical_symptoms/follow_up_ukbb.parquet
# mlhfq_liability                                     medical_symptoms/follow_up_ukbb.parquet
# mlhfq_medical_state_concers                         medical_symptoms/follow_up_ukbb.parquet
# collection_timestamp                              medical_symptoms/digestive_health.parquet
# collection_date                                   medical_symptoms/digestive_health.parquet
# timezone                                          medical_symptoms/digestive_health.parquet
# abdomen_pain_frequency_past_3_months              medical_symptoms/digestive_health.parquet
# abdomen_pain_women_during_period                  medical_symptoms/digestive_health.parquet
# abdomen_pain_past_6_months                        medical_symptoms/digestive_health.parquet
# abdomen_pain_improve_after_bowl_movement          medical_symptoms/digestive_health.parquet
# abdomen_pain_increases_bowl_movements             medical_symptoms/digestive_health.parquet
# abdomen_pain_decreases_bowl_movements             medical_symptoms/digestive_health.parquet
# soft_stool_during_abdomen_pain                    medical_symptoms/digestive_health.parquet
# hard_stool_during_abdomen_pain                    medical_symptoms/digestive_health.parquet
# hard_stool_frequency_past_3_months                medical_symptoms/digestive_health.parquet
# soft_stool_frequency_past_3_months                medical_symptoms/digestive_health.parquet
# abdomen_pain_current                              medical_symptoms/digestive_health.parquet
# abdomen_pain_current_severity                     medical_symptoms/digestive_health.parquet
# abdomen_pain_days_out_of_10                       medical_symptoms/digestive_health.parquet
# abdomen_pain_current_distension                   medical_symptoms/digestive_health.parquet
# abdomen_pain_current_distension_severity          medical_symptoms/digestive_health.parquet
# bowl_movements_current_satisfaction               medical_symptoms/digestive_health.parquet
# abdomen_pain_current_general_interference         medical_symptoms/digestive_health.parquet
# bowl_movements_daily_max                          medical_symptoms/digestive_health.parquet
# bowl_movements_daily_min                          medical_symptoms/digestive_health.parquet
# bowl_movements_daily_average                      medical_symptoms/digestive_health.parquet
# abdomen_pain_work_weeks_missed_number             medical_symptoms/digestive_health.parquet
# abdomen_pain_work_weeks_missed_choice             medical_symptoms/digestive_health.parquet
# abdomen_pain_work_weeks_suffering                 medical_symptoms/digestive_health.parquet
# back_pain_past_3_months                           medical_symptoms/digestive_health.parquet
# legs_joint_pain_past_3_months                     medical_symptoms/digestive_health.parquet
# menstural_cramps_past_3_months                    medical_symptoms/digestive_health.parquet
# headaches_past_3_months                           medical_symptoms/digestive_health.parquet
# chest_pain_past_3_months                          medical_symptoms/digestive_health.parquet
# dizziness_past_3_months                           medical_symptoms/digestive_health.parquet
# fainting_past_3_months                            medical_symptoms/digestive_health.parquet
# heart_race_past_3_months                          medical_symptoms/digestive_health.parquet
# shortness_of_breath_past_3_months                 medical_symptoms/digestive_health.parquet
# intercourse_pain_past_3_months                    medical_symptoms/digestive_health.parquet
# bladder_irritability_past_3_months                medical_symptoms/digestive_health.parquet
# nausea_past_3_months                              medical_symptoms/digestive_health.parquet
# tired_past_3_months                               medical_symptoms/digestive_health.parquet
# sleeping_trouble_past_3_months                    medical_symptoms/digestive_health.parquet
# anxiety_treatment_past                            medical_symptoms/digestive_health.parquet
# depression_treatment_past                         medical_symptoms/digestive_health.parquet
# sensitive_stomach                                 medical_symptoms/digestive_health.parquet
# history_family_ibs                                medical_symptoms/digestive_health.parquet
# history_birth_caesarian_section                   medical_symptoms/digestive_health.parquet
# history_childhood_antibiotics                     medical_symptoms/digestive_health.parquet
# history_diagnoses_celiac                          medical_symptoms/digestive_health.parquet
# history_diagnoses_celiac_method                   medical_symptoms/digestive_health.parquet
# history_diagnoses_ibs                             medical_symptoms/digestive_health.parquet
# history_ibs_symptoms_speed                        medical_symptoms/digestive_health.parquet
# history_ibs_first_symptoms_infection              medical_symptoms/digestive_health.parquet
# history_ibs_first_symptoms_infection_choice       medical_symptoms/digestive_health.parquet
# history_ibs_first_symptoms_fever                  medical_symptoms/digestive_health.parquet
# history_ibs_first_symptoms_diarrhoea              medical_symptoms/digestive_health.parquet
# history_ibs_first_symptoms_bloody_diarrhoea       medical_symptoms/digestive_health.parquet
# history_ibs_first_symptoms_vomiting               medical_symptoms/digestive_health.parquet
#
#                                                   bulk_file_extension  \
# tabular_field_name
# collection_timestamp                                              NaN
# collection_date                                                   NaN
# timezone                                                          NaN
# are_you_suffering_for_the_following_symptoms                      NaN
# how_often_headache                                                NaN
# chest_pain_during_power_walking_up_stairs_uphill                  NaN
# chest_pain_dissipates_with_rest                                   NaN
# leg_pain_stops_with_rest                                          NaN
# mood_most_days                                                    NaN
# tired_day                                                         NaN
# hard_to_climb                                                     NaN
# hard_to_routine                                                   NaN
# rarely_leave_home                                                 NaN
# rarely_spent_time_friends_family                                  NaN
# hard_to_work                                                      NaN
# hard_to_relax                                                     NaN
# hard_to_have_sex                                                  NaN
# feeling_tired                                                     NaN
# feeling_like_a_burdan                                             NaN
# worried_about_your_health                                         NaN
# collection_timestamp                                              NaN
# collection_date                                                   NaN
# timezone                                                          NaN
# mlhfq_rest_during_day                                             NaN
# mlhfq_difficulty_walking                                          NaN
# mlhfq_difficulty_house_work                                       NaN
# mlhfq_rarely_leave_house                                          NaN
# mlhfq_rarely_socialize                                            NaN
# mlhfq_difficulty_working                                          NaN
# mlhfq_difficulty_maintining_hobbies                               NaN
# mlhfq_difficulty_intercourse                                      NaN
# mlhfq_fatigue                                                     NaN
# mlhfq_liability                                                   NaN
# mlhfq_medical_state_concers                                       NaN
# collection_timestamp                                              NaN
# collection_date                                                   NaN
# timezone                                                          NaN
# abdomen_pain_frequency_past_3_months                              NaN
# abdomen_pain_women_during_period                                  NaN
# abdomen_pain_past_6_months                                        NaN
# abdomen_pain_improve_after_bowl_movement                          NaN
# abdomen_pain_increases_bowl_movements                             NaN
# abdomen_pain_decreases_bowl_movements                             NaN
# soft_stool_during_abdomen_pain                                    NaN
# hard_stool_during_abdomen_pain                                    NaN
# hard_stool_frequency_past_3_months                                NaN
# soft_stool_frequency_past_3_months                                NaN
# abdomen_pain_current                                              NaN
# abdomen_pain_current_severity                                     NaN
# abdomen_pain_days_out_of_10                                       NaN
# abdomen_pain_current_distension                                   NaN
# abdomen_pain_current_distension_severity                          NaN
# bowl_movements_current_satisfaction                               NaN
# abdomen_pain_current_general_interference                         NaN
# bowl_movements_daily_max                                          NaN
# bowl_movements_daily_min                                          NaN
# bowl_movements_daily_average                                      NaN
# abdomen_pain_work_weeks_missed_number                             NaN
# abdomen_pain_work_weeks_missed_choice                             NaN
# abdomen_pain_work_weeks_suffering                                 NaN
# back_pain_past_3_months                                           NaN
# legs_joint_pain_past_3_months                                     NaN
# menstural_cramps_past_3_months                                    NaN
# headaches_past_3_months                                           NaN
# chest_pain_past_3_months                                          NaN
# dizziness_past_3_months                                           NaN
# fainting_past_3_months                                            NaN
# heart_race_past_3_months                                          NaN
# shortness_of_breath_past_3_months                                 NaN
# intercourse_pain_past_3_months                                    NaN
# bladder_irritability_past_3_months                                NaN
# nausea_past_3_months                                              NaN
# tired_past_3_months                                               NaN
# sleeping_trouble_past_3_months                                    NaN
# anxiety_treatment_past                                            NaN
# depression_treatment_past                                         NaN
# sensitive_stomach                                                 NaN
# history_family_ibs                                                NaN
# history_birth_caesarian_section                                   NaN
# history_childhood_antibiotics                                     NaN
# history_diagnoses_celiac                                          NaN
# history_diagnoses_celiac_method                                   NaN
# history_diagnoses_ibs                                             NaN
# history_ibs_symptoms_speed                                        NaN
# history_ibs_first_symptoms_infection                              NaN
# history_ibs_first_symptoms_infection_choice                       NaN
# history_ibs_first_symptoms_fever                                  NaN
# history_ibs_first_symptoms_diarrhoea                              NaN
# history_ibs_first_symptoms_bloody_diarrhoea                       NaN
# history_ibs_first_symptoms_vomiting                               NaN
#
#                                                   bulk_dictionary  \
# tabular_field_name
# collection_timestamp                                          NaN
# collection_date                                               NaN
# timezone                                                      NaN
# are_you_suffering_for_the_following_symptoms                  NaN
# how_often_headache                                            NaN
# chest_pain_during_power_walking_up_stairs_uphill              NaN
# chest_pain_dissipates_with_rest                               NaN
# leg_pain_stops_with_rest                                      NaN
# mood_most_days                                                NaN
# tired_day                                                     NaN
# hard_to_climb                                                 NaN
# hard_to_routine                                               NaN
# rarely_leave_home                                             NaN
# rarely_spent_time_friends_family                              NaN
# hard_to_work                                                  NaN
# hard_to_relax                                                 NaN
# hard_to_have_sex                                              NaN
# feeling_tired                                                 NaN
# feeling_like_a_burdan                                         NaN
# worried_about_your_health                                     NaN
# collection_timestamp                                          NaN
# collection_date                                               NaN
# timezone                                                      NaN
# mlhfq_rest_during_day                                         NaN
# mlhfq_difficulty_walking                                      NaN
# mlhfq_difficulty_house_work                                   NaN
# mlhfq_rarely_leave_house                                      NaN
# mlhfq_rarely_socialize                                        NaN
# mlhfq_difficulty_working                                      NaN
# mlhfq_difficulty_maintining_hobbies                           NaN
# mlhfq_difficulty_intercourse                                  NaN
# mlhfq_fatigue                                                 NaN
# mlhfq_liability                                               NaN
# mlhfq_medical_state_concers                                   NaN
# collection_timestamp                                          NaN
# collection_date                                               NaN
# timezone                                                      NaN
# abdomen_pain_frequency_past_3_months                          NaN
# abdomen_pain_women_during_period                              NaN
# abdomen_pain_past_6_months                                    NaN
# abdomen_pain_improve_after_bowl_movement                      NaN
# abdomen_pain_increases_bowl_movements                         NaN
# abdomen_pain_decreases_bowl_movements                         NaN
# soft_stool_during_abdomen_pain                                NaN
# hard_stool_during_abdomen_pain                                NaN
# hard_stool_frequency_past_3_months                            NaN
# soft_stool_frequency_past_3_months                            NaN
# abdomen_pain_current                                          NaN
# abdomen_pain_current_severity                                 NaN
# abdomen_pain_days_out_of_10                                   NaN
# abdomen_pain_current_distension                               NaN
# abdomen_pain_current_distension_severity                      NaN
# bowl_movements_current_satisfaction                           NaN
# abdomen_pain_current_general_interference                     NaN
# bowl_movements_daily_max                                      NaN
# bowl_movements_daily_min                                      NaN
# bowl_movements_daily_average                                  NaN
# abdomen_pain_work_weeks_missed_number                         NaN
# abdomen_pain_work_weeks_missed_choice                         NaN
# abdomen_pain_work_weeks_suffering                             NaN
# back_pain_past_3_months                                       NaN
# legs_joint_pain_past_3_months                                 NaN
# menstural_cramps_past_3_months                                NaN
# headaches_past_3_months                                       NaN
# chest_pain_past_3_months                                      NaN
# dizziness_past_3_months                                       NaN
# fainting_past_3_months                                        NaN
# heart_race_past_3_months                                      NaN
# shortness_of_breath_past_3_months                             NaN
# intercourse_pain_past_3_months                                NaN
# bladder_irritability_past_3_months                            NaN
# nausea_past_3_months                                          NaN
# tired_past_3_months                                           NaN
# sleeping_trouble_past_3_months                                NaN
# anxiety_treatment_past                                        NaN
# depression_treatment_past                                     NaN
# sensitive_stomach                                             NaN
# history_family_ibs                                            NaN
# history_birth_caesarian_section                               NaN
# history_childhood_antibiotics                                 NaN
# history_diagnoses_celiac                                      NaN
# history_diagnoses_celiac_method                               NaN
# history_diagnoses_ibs                                         NaN
# history_ibs_symptoms_speed                                    NaN
# history_ibs_first_symptoms_infection                          NaN
# history_ibs_first_symptoms_infection_choice                   NaN
# history_ibs_first_symptoms_fever                              NaN
# history_ibs_first_symptoms_diarrhoea                          NaN
# history_ibs_first_symptoms_bloody_diarrhoea                   NaN
# history_ibs_first_symptoms_vomiting                           NaN
#
#                                                                                  description_string  \
# tabular_field_name
# collection_timestamp                                           Timestamp of measurements collection
# collection_date                                                      Date of measurments collection
# timezone                                                                Timezone of the measurments
# are_you_suffering_for_the_following_symptoms           Are you suffering for the following symptoms
# how_often_headache                                              How often  do you have a headaches?
# chest_pain_during_power_walking_up_stairs_uphill  Does the chest pain/discomfort occur when you ...
# chest_pain_dissipates_with_rest                              Does the chest pain go away with rest?
# leg_pain_stops_with_rest                              Does the leg pain stop when you stop walking?
# mood_most_days                                            How would you define your mood most days?
# tired_day                                         Do you feel like you need to rest during the t...
# hard_to_climb                                     Do you feel difficulty walking or climbing sta...
# hard_to_routine                                   Do you have difficulty doing routine tasks at ...
# rarely_leave_home                                      Do you tend to leave your house only rarely?
# rarely_spent_time_friends_family                  Do you socialize with family and friends only ...
# hard_to_work                                      Do you feel physical difficulty or limitation ...
# hard_to_relax                                     Do you find it difficult to engage in hobbies ...
# hard_to_have_sex                                                 Do you have difficulty having sex?
# feeling_tired                                             Do you feel tired, weak, have low energy?
# feeling_like_a_burdan                             Did you feel a burden on your environment due ...
# worried_about_your_health                             Are you worried due to your health condition?
# collection_timestamp                                           Timestamp of measurements collection
# collection_date                                                      Date of measurments collection
# timezone                                                                Timezone of the measurments
# mlhfq_rest_during_day                                  Do you feel the need to rest during the day?
# mlhfq_difficulty_walking                          Do you feel difficulty walking or climbing sta...
# mlhfq_difficulty_house_work                       Do you have difficulty doing routine tasks at ...
# mlhfq_rarely_leave_house                                            Do you rarely leave your house?
# mlhfq_rarely_socialize                             Do you rarely socialize with family and friends?
# mlhfq_difficulty_working                          Do you feel physical difficulty working for a ...
# mlhfq_difficulty_maintining_hobbies               Do you find it difficult to engage in hobbies ...
# mlhfq_difficulty_intercourse                                     Do you have difficulty having sex?
# mlhfq_fatigue                                             Do you feel tired, weak, have low energy?
# mlhfq_liability                                   Have you felt a burden on your environment due...
# mlhfq_medical_state_concers                                      Are you worried about your health?
# collection_timestamp                                                           Collection timestamp
# collection_date                                                                     Collection date
# timezone                                                                Timezone of the measurments
# abdomen_pain_frequency_past_3_months              In the last 3 months, how often did you have d...
# abdomen_pain_women_during_period                  Did this discomfort or pain occur only during ...
# abdomen_pain_past_6_months                        Have you had this discomfort or pain 6 months ...
# abdomen_pain_improve_after_bowl_movement          How often did this discomfort or pain get bett...
# abdomen_pain_increases_bowl_movements             When this discomfort or pain started, did you ...
# abdomen_pain_decreases_bowl_movements             When this discomfort or pain started, did you ...
# soft_stool_during_abdomen_pain                    When this discomfort or pain started, were you...
# hard_stool_during_abdomen_pain                    When this discomfort or pain started, how ofte...
# hard_stool_frequency_past_3_months                In the last 3 months, how often did you have h...
# soft_stool_frequency_past_3_months                In the last 3 months, how often did you have l...
# abdomen_pain_current                              Do you currently (in the last 3 months) suffer...
# abdomen_pain_current_severity                                    How severe is your abdominal pain?
# abdomen_pain_days_out_of_10                       Please move the slider to select the number of...
# abdomen_pain_current_distension                   Do you currently suffer from abdominal distens...
# abdomen_pain_current_distension_severity          How severe is your abdominal distension/tightn...
# bowl_movements_current_satisfaction               How happy/satisfied are you with your bowel ha...
# abdomen_pain_current_general_interference         Please indicate how much abdominal pain or dis...
# bowl_movements_daily_max                          What is the greatest number of times you open ...
# bowl_movements_daily_min                          What is the least number of times you open you...
# bowl_movements_daily_average                      What is the average number of times you open y...
# abdomen_pain_work_weeks_missed_number             In the last year approximately how many weeks ...
# abdomen_pain_work_weeks_missed_choice             Question asked when the participant had given ...
# abdomen_pain_work_weeks_suffering                 Question asked how many weeks (in the last yea...
# back_pain_past_3_months                           During the past 3 months, how much have you be...
# legs_joint_pain_past_3_months                     During the past 3 months, how much have you be...
# menstural_cramps_past_3_months                    During the past 3 months, how much have you be...
# headaches_past_3_months                           During the past 3 months, how much have you be...
# chest_pain_past_3_months                          During the past 3 months, how much have you be...
# dizziness_past_3_months                           During the past 3 months, how much have you be...
# fainting_past_3_months                            During the past 3 months, how much have you be...
# heart_race_past_3_months                          During the past 3 months, how much have you be...
# shortness_of_breath_past_3_months                 During the past 3 months, how much have you be...
# intercourse_pain_past_3_months                    During the past 3 months, how much have you be...
# bladder_irritability_past_3_months                During the past 3 months, how much have you be...
# nausea_past_3_months                              During the past 3 months, how much have you be...
# tired_past_3_months                               During the past 3 months, how much have you be...
# sleeping_trouble_past_3_months                    During the past 3 months, how much have you be...
# anxiety_treatment_past                            Have you ever been offered or sought treatment...
# depression_treatment_past                         Have you ever been offered or sought treatment...
# sensitive_stomach                                                  Do you have a sensitive stomach?
# history_family_ibs                                Do you have a family history of IBS in your pa...
# history_birth_caesarian_section                                 Were you born by caesarian section?
# history_childhood_antibiotics                     During childhood or as a teenager did you rece...
# history_diagnoses_celiac                          Have you been diagnosed with coeliac disease/g...
# history_diagnoses_celiac_method                   When you were diagnosed with coeliac disease/g...
# history_diagnoses_ibs                                        Have you ever been diagnosed with IBS?
# history_ibs_symptoms_speed                        Did your IBS symptoms start suddenly, over one...
# history_ibs_first_symptoms_infection              When your IBS symptoms first began (or up to t...
# history_ibs_first_symptoms_infection_choice       Question asked the participant to select the i...
# history_ibs_first_symptoms_fever                  When your IBS symptoms first began (or up to t...
# ...
# abdomen_pain_current_distension_severity                NaN
# bowl_movements_current_satisfaction                     NaN
# abdomen_pain_current_general_interference               NaN
# bowl_movements_daily_max                                NaN
# bowl_movements_daily_min                                NaN
# bowl_movements_daily_average                            NaN
# abdomen_pain_work_weeks_missed_number                   NaN
# abdomen_pain_work_weeks_missed_choice                   NaN
# abdomen_pain_work_weeks_suffering                       NaN
# back_pain_past_3_months                                 NaN
# legs_joint_pain_past_3_months                           NaN
# menstural_cramps_past_3_months                          NaN
# headaches_past_3_months                                 NaN
# chest_pain_past_3_months                                NaN
# dizziness_past_3_months                                 NaN
# fainting_past_3_months                                  NaN
# heart_race_past_3_months                                NaN
# shortness_of_breath_past_3_months                       NaN
# intercourse_pain_past_3_months                          NaN
# bladder_irritability_past_3_months                      NaN
# nausea_past_3_months                                    NaN
# tired_past_3_months                                     NaN
# sleeping_trouble_past_3_months                          NaN
# anxiety_treatment_past                                  NaN
# depression_treatment_past                               NaN
# sensitive_stomach                                       NaN
# history_family_ibs                                      NaN
# history_birth_caesarian_section                         NaN
# history_childhood_antibiotics                           NaN
# history_diagnoses_celiac                                NaN
# history_diagnoses_celiac_method                         NaN
# history_diagnoses_ibs                                   NaN
# history_ibs_symptoms_speed                              NaN
# history_ibs_first_symptoms_infection                    NaN
# history_ibs_first_symptoms_infection_choice             NaN
# history_ibs_first_symptoms_fever                        NaN
# history_ibs_first_symptoms_diarrhoea                    NaN
# history_ibs_first_symptoms_bloody_diarrhoea             NaN
# history_ibs_first_symptoms_vomiting                     NaN
#
#                                                                     pandas_dtype  \
# tabular_field_name
# collection_timestamp                              datetime64[ns, Asia/Jerusalem]
# collection_date                                                   datetime64[ns]
# timezone                                                                  string
# are_you_suffering_for_the_following_symptoms                              object
# how_often_headache                                                           int
# chest_pain_during_power_walking_up_stairs_uphill                             int
# chest_pain_dissipates_with_rest                                              int
# leg_pain_stops_with_rest                                                     int
# mood_most_days                                                               int
# tired_day                                                                    int
# hard_to_climb                                                                int
# hard_to_routine                                                              int
# rarely_leave_home                                                            int
# rarely_spent_time_friends_family                                             int
# hard_to_work                                                                 int
# hard_to_relax                                                                int
# hard_to_have_sex                                                             int
# feeling_tired                                                                int
# feeling_like_a_burdan                                                        int
# worried_about_your_health                                                    int
# collection_timestamp                              datetime64[ns, Asia/Jerusalem]
# collection_date                                                   datetime64[ns]
# timezone                                                                category
# mlhfq_rest_during_day                                                        int
# mlhfq_difficulty_walking                                                     int
# mlhfq_difficulty_house_work                                                  int
# mlhfq_rarely_leave_house                                                     int
# mlhfq_rarely_socialize                                                       int
# mlhfq_difficulty_working                                                     int
# mlhfq_difficulty_maintining_hobbies                                          int
# mlhfq_difficulty_intercourse                                                 int
# mlhfq_fatigue                                                                int
# mlhfq_liability                                                              int
# mlhfq_medical_state_concers                                                  int
# collection_timestamp                              datetime64[ns, Asia/Jerusalem]
# collection_date                                                   datetime64[ns]
# timezone                                                                  string
# abdomen_pain_frequency_past_3_months                                         int
# abdomen_pain_women_during_period                                             int
# abdomen_pain_past_6_months                                                   int
# abdomen_pain_improve_after_bowl_movement                                     int
# abdomen_pain_increases_bowl_movements                                        int
# abdomen_pain_decreases_bowl_movements                                        int
# soft_stool_during_abdomen_pain                                               int
# hard_stool_during_abdomen_pain                                               int
# hard_stool_frequency_past_3_months                                           int
# soft_stool_frequency_past_3_months                                           int
# abdomen_pain_current                                                         int
# abdomen_pain_current_severity                                                int
# abdomen_pain_days_out_of_10                                                  int
# abdomen_pain_current_distension                                              int
# abdomen_pain_current_distension_severity                                     int
# bowl_movements_current_satisfaction                                          int
# abdomen_pain_current_general_interference                                    int
# bowl_movements_daily_max                                                     int
# bowl_movements_daily_min                                                     int
# bowl_movements_daily_average                                                 int
# abdomen_pain_work_weeks_missed_number                                        int
# abdomen_pain_work_weeks_missed_choice                                     object
# abdomen_pain_work_weeks_suffering                                            int
# back_pain_past_3_months                                                      int
# legs_joint_pain_past_3_months                                                int
# menstural_cramps_past_3_months                                               int
# headaches_past_3_months                                                      int
# chest_pain_past_3_months                                                     int
# dizziness_past_3_months                                                      int
# fainting_past_3_months                                                       int
# heart_race_past_3_months                                                     int
# shortness_of_breath_past_3_months                                            int
# intercourse_pain_past_3_months                                               int
# bladder_irritability_past_3_months                                           int
# nausea_past_3_months                                                         int
# tired_past_3_months                                                          int
# sleeping_trouble_past_3_months                                               int
# anxiety_treatment_past                                                       int
# depression_treatment_past                                                    int
# sensitive_stomach                                                            int
# history_family_ibs                                                           int
# history_birth_caesarian_section                                              int
# history_childhood_antibiotics                                                int
# history_diagnoses_celiac                                                     int
# history_diagnoses_celiac_method                                              int
# history_diagnoses_ibs                                                        int
# history_ibs_symptoms_speed                                                   int
# history_ibs_first_symptoms_infection                                         int
# history_ibs_first_symptoms_infection_choice                                  int
# history_ibs_first_symptoms_fever                                             int
# history_ibs_first_symptoms_diarrhoea                                         int
# history_ibs_first_symptoms_bloody_diarrhoea                                  int
# history_ibs_first_symptoms_vomiting                                          int
#
#                                                  data_coding
# tabular_field_name
# collection_timestamp                                     NaN
# collection_date                                          NaN
# timezone                                                 NaN
# are_you_suffering_for_the_following_symptoms          049_01
# how_often_headache                                    049_02
# chest_pain_during_power_walking_up_stairs_uphill           7
# chest_pain_dissipates_with_rest                            7
# leg_pain_stops_with_rest                                   7
# mood_most_days                                        049_03
# tired_day                                             049_04
# hard_to_climb                                         049_04
# hard_to_routine                                       049_04
# rarely_leave_home                                     049_04
# rarely_spent_time_friends_family                      049_04
# hard_to_work                                          049_04
# hard_to_relax                                         049_04
# hard_to_have_sex                                      049_04
# feeling_tired                                         049_04
# feeling_like_a_burdan                                 049_04
# worried_about_your_health                             049_04
# collection_timestamp                                     NaN
# collection_date                                          NaN
# timezone                                                 NaN
# mlhfq_rest_during_day                                    NaN
# mlhfq_difficulty_walking                                 NaN
# mlhfq_difficulty_house_work                              NaN
# mlhfq_rarely_leave_house                                 NaN
# mlhfq_rarely_socialize                                   NaN
# mlhfq_difficulty_working                                 NaN
# mlhfq_difficulty_maintining_hobbies                      NaN
# mlhfq_difficulty_intercourse                             NaN
# mlhfq_fatigue                                            NaN
# mlhfq_liability                                          NaN
# mlhfq_medical_state_concers                              NaN
# collection_timestamp                                     NaN
# collection_date                                          NaN
# timezone                                                 NaN
# abdomen_pain_frequency_past_3_months                  042_01
# abdomen_pain_women_during_period                      042_02
# abdomen_pain_past_6_months                               503
# abdomen_pain_improve_after_bowl_movement                 950
# abdomen_pain_increases_bowl_movements                    950
# abdomen_pain_decreases_bowl_movements                    950
# soft_stool_during_abdomen_pain                           950
# hard_stool_during_abdomen_pain                           950
# hard_stool_frequency_past_3_months                       950
# soft_stool_frequency_past_3_months                       950
# abdomen_pain_current                                     503
# abdomen_pain_current_severity                            NaN
# abdomen_pain_days_out_of_10                              NaN
# abdomen_pain_current_distension                          503
# abdomen_pain_current_distension_severity                 NaN
# bowl_movements_current_satisfaction                      NaN
# abdomen_pain_current_general_interference                NaN
# bowl_movements_daily_max                                 NaN
# bowl_movements_daily_min                                 NaN
# bowl_movements_daily_average                             NaN
# abdomen_pain_work_weeks_missed_number                    NaN
# abdomen_pain_work_weeks_missed_choice                 042_03
# abdomen_pain_work_weeks_suffering                        NaN
# back_pain_past_3_months                                  399
# legs_joint_pain_past_3_months                            399
# menstural_cramps_past_3_months                           399
# headaches_past_3_months                                  399
# chest_pain_past_3_months                                 399
# dizziness_past_3_months                                  399
# fainting_past_3_months                                   399
# heart_race_past_3_months                                 399
# shortness_of_breath_past_3_months                        399
# intercourse_pain_past_3_months                           399
# bladder_irritability_past_3_months                       399
# nausea_past_3_months                                     399
# tired_past_3_months                                      399
# sleeping_trouble_past_3_months                           399
# anxiety_treatment_past                                   503
# depression_treatment_past                                503
# sensitive_stomach                                        502
# history_family_ibs                                       502
# history_birth_caesarian_section                          502
# history_childhood_antibiotics                            502
# history_diagnoses_celiac                                 502
# history_diagnoses_celiac_method                         1862
# history_diagnoses_ibs                                    502
# history_ibs_symptoms_speed                              2730
# history_ibs_first_symptoms_infection                     503
# history_ibs_first_symptoms_infection_choice             7310
# history_ibs_first_symptoms_fever                         503
# history_ibs_first_symptoms_diarrhoea                     503
# history_ibs_first_symptoms_bloody_diarrhoea              503
# history_ibs_first_symptoms_vomiting                      503
