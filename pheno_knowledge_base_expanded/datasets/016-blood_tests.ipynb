# %% [raw]
# ---
# output-file: 016-blood_tests.html
# title: Blood Tests
# ---

# %% [markdown]
# ### Description
#
# The lab tests in this dataset of the Human Phenotype Project are based on tests performed to participants in the community as part of their regular medical care at their HMO (Health Maintenance Organization). Participants are asked to upload their blood/urine tests done at their HMOs from previous years. These tests range from the very common CBC and chemistry tests, vitamins levels and other laboratory tests.
#
# ### Introduction
#
# Laboratory (Lab) tests are often used in health care to determine physiological and biochemical states, such as disease, mineral content, pharmaceutical drug effectiveness, and organ function. The lab tests in this data set of the Human Phenotype Project are based on tests performed to participants in the community as part of their regular medical care at their HMO.
# Following registration and follow-up calls or visits the participants receive an email asking for and providing instructions on how to upload their lab test results. The participants are provided with a list of recommended tests to upload (specified in the list below) and the recommended time window for some tests (last 3 months or from the previous one year).  Each participant uploads blood tests that were done throughout the years with their HMO. Upon upload, the file is analyzed based on its format, and all readable tests that can be extracted are uploaded to a PostgreSQL database.
#
# Note that this data is created by the users own volition and the tests are done independent of their visits to the clinical testing  center (CTC).
#
# #### List of recommended tests for upload:
#
# ##### Tests recommended from previous year:
# HbA1C%, tota cholesterol, HDL, LDL, Triglycerides.
# ##### Tests recommended from the last 3 months:
# Creatinine, Glucose, CBC (WBC, RBC, Hemoglobin, Hematocrite, Platelets, MCV, MCH, MCHC, RDW, Mean Platelet Volume, Neutrophils%, Lymphocytes%, Monocytes%, Eosinophils%, Basophils%)
# ##### Tests without time  recommendation:
# TSH, CRP, Albumin, Total Protein, Bilirubin, AST-GOT, ALT-GPT, GGT, Alkaline phosphatase, Sodium, Potassium, Chloride, Calcium, Phosphor, Uric acid, B12, Vitamin D, Folic acid and Ferritin.
#
# ### Measurement protocol
# <!-- long measurment protocol for the data browser -->
# Every blood/urine test has its own measurement protocol.
# * Some blood tests require the participant itself to act differently prior to the test - whether it’s fasting, drinking concentrated glucose/lactose, sampling urine etc.
# * The technician has also a large part of the test, by selecting relevant buffers for every one of the tests and have it’s own complete protocol per test.
# * And the lab - each HMO would have their own storing protocols, measuring with different machines with different sensitivity thresholds and their own standards (usually aligned between different HMO, but not necessarily).
#
# ### Data availability
# <!-- for the example notebooks -->
# The information is stored in 1 parquet file `blood_tests.parquet`.
#
# ### Summary of available data
# <!-- for the data browser -->
# All the participant provided blood tests are stored in a single .parquet file. Each row depicts a single test done (either blood or urine) for an individual. It consists of the test’s name, unit, date and value (split into 2 columns - continuous and categorical) with some extra metadata columns.
#
# The duplicate value columns are an artifact of some tests having both float variables and notes from the HMOs instead of continuous values. We represent these notes as categorical values such as “value under detectable threshold” or “toxic levels” etc (e.g. urine microalbumin mostly contains float values, but it can also have “threshold under 3mg/l” in the categorical column). These notes are not values per-se, and replacing them with continuous values is not straightforward but they should be considered nonetheless.
#
# ### Relevant links
#
# * [Pheno Knowledgebase](https://knowledgebase.pheno.ai/datasets/016-blood_tests.html)
# * [Pheno Data Browser](https://pheno-demo-app.vercel.app/folder/16)

# %%
#| echo: false
import pandas as pd
pd.set_option("display.max_rows", 500)

# %%
from pheno_utils import PhenoLoader

# %%
pl = PhenoLoader('blood_tests')
pl
# Out:
# PhenoLoader for blood_tests with
# 67 fields
# 2 tables: ['blood_tests', 'age_sex']

# %% [markdown]
# # Data dictionary

# %%
pl.dict
# Out:
#                                           folder_id  feature_set  \
# tabular_field_name
# hmo                                              16  blood_tests
# collection_date                                  16  blood_tests
# bt__albumin_float_value                          16  blood_tests
# bt__alkaline_phosphatase_float_value             16  blood_tests
# bt__alt_float_value                              16  blood_tests
# bt__ast_float_value                              16  blood_tests
# bt__basophils_%_float_value                      16  blood_tests
# bt__basophils_abs_float_value                    16  blood_tests
# bt__calcium_float_value                          16  blood_tests
# bt__creatinine_float_value                       16  blood_tests
# bt__direct_bilirubin_categorical_value           16  blood_tests
# bt__direct_bilirubin_float_value                 16  blood_tests
# bt__eosinophils_%_float_value                    16  blood_tests
# bt__eosinophils_abs_float_value                  16  blood_tests
# bt__estradiol_categorical_value                  16  blood_tests
# bt__estradiol_float_value                        16  blood_tests
# bt__ferritin_categorical_value                   16  blood_tests
# bt__ferritin_float_value                         16  blood_tests
# bt__ggt_float_value                              16  blood_tests
# bt__glucose_float_value                          16  blood_tests
# bt__hba1c_float_value                            16  blood_tests
# bt__hdl_cholesterol_float_value                  16  blood_tests
# bt__hematocrit_float_value                       16  blood_tests
# bt__hemoglobin_float_value                       16  blood_tests
# bt__ldl_cholesterol_float_value                  16  blood_tests
# bt__lymphocytes_%_float_value                    16  blood_tests
# bt__lymphocytes_abs_float_value                  16  blood_tests
# bt__mch_float_value                              16  blood_tests
# bt__mchc_float_value                             16  blood_tests
# bt__mcv_float_value                              16  blood_tests
# bt__monocytes_%_float_value                      16  blood_tests
# bt__monocytes_abs_float_value                    16  blood_tests
# bt__mpv_float_value                              16  blood_tests
# bt__neutrophils_%_float_value                    16  blood_tests
# bt__neutrophils_abs_float_value                  16  blood_tests
# bt__non_hdl_cholesterol_float_value              16  blood_tests
# bt__phosphore_float_value                        16  blood_tests
# bt__platelets_float_value                        16  blood_tests
# bt__potassium_float_value                        16  blood_tests
# bt__rbc_float_value                              16  blood_tests
# bt__rdw_float_value                              16  blood_tests
# bt__rheumatoid_factor_categorical_value          16  blood_tests
# bt__rheumatoid_factor_float_value                16  blood_tests
# bt__sodium_float_value                           16  blood_tests
# bt__testosterone_total_categorical_value         16  blood_tests
# bt__testosterone_total_float_value               16  blood_tests
# bt__total_bilirubin_categorical_value            16  blood_tests
# bt__total_bilirubin_float_value                  16  blood_tests
# bt__total_cholesterol_float_value                16  blood_tests
# bt__total_protein_float_value                    16  blood_tests
# bt__triglycerides_float_value                    16  blood_tests
# bt__tsh_categorical_value                        16  blood_tests
# bt__tsh_float_value                              16  blood_tests
# bt__urate_float_value                            16  blood_tests
# bt__urea_float_value                             16  blood_tests
# bt__vitamin_b12_categorical_value                16  blood_tests
# bt__vitamin_b12_float_value                      16  blood_tests
# bt__vitamin_d_categorical_value                  16  blood_tests
# bt__vitamin_d_float_value                        16  blood_tests
# bt__wbc_float_value                              16  blood_tests
# urine__acr_categorical_value                     16  blood_tests
# urine__acr_float_value                           16  blood_tests
# urine__creatinine_float_value                    16  blood_tests
# urine__microalbumin_categorical_value            16  blood_tests
# urine__microalbumin_float_value                  16  blood_tests
#
#                                                                            field_string  \
# tabular_field_name
# hmo                                                                                 HMO
# collection_date                                                         Collection date
# bt__albumin_float_value                                Blood test - Albumin (Numerical)
# bt__alkaline_phosphatase_float_value      Blood test - Alkaline Phosphatase (Numerical)
# bt__alt_float_value                                        Blood test - ALT (Numerical)
# bt__ast_float_value                                        Blood test - AST (Numerical)
# bt__basophils_%_float_value                        Blood test - Basophils % (Numerical)
# bt__basophils_abs_float_value                      Blood test - Basophils # (Numerical)
# bt__calcium_float_value                                Blood test - Calcium (Numerical)
# bt__creatinine_float_value                          Blood test - Creatinine (Numerical)
# bt__direct_bilirubin_categorical_value      Blood test - Direct Bilirubin (Categorical)
# bt__direct_bilirubin_float_value              Blood test - Direct Bilirubin (Numerical)
# bt__eosinophils_%_float_value                    Blood test - Eosinophils % (Numerical)
# bt__eosinophils_abs_float_value                  Blood test - Eosinophils # (Numerical)
# bt__estradiol_categorical_value                    Blood test - Estradiol (Categorical)
# bt__estradiol_float_value                            Blood test - Estradiol (Numerical)
# bt__ferritin_categorical_value                      Blood test - Ferritin (Categorical)
# bt__ferritin_float_value                              Blood test - Ferritin (Numerical)
# bt__ggt_float_value                                        Blood test - GGT (Numerical)
# bt__glucose_float_value                                Blood test - Glucose (Numerical)
# bt__hba1c_float_value                                    Blood test - HbA1C (Numerical)
# bt__hdl_cholesterol_float_value                Blood test - HDL Cholesterol (Numerical)
# bt__hematocrit_float_value                          Blood test - Hematocrit (Numerical)
# bt__hemoglobin_float_value                          Blood test - Hemoglobin (Numerical)
# bt__ldl_cholesterol_float_value                Blood test - LDL Cholesterol (Numerical)
# bt__lymphocytes_%_float_value                    Blood test - Lymphocytes % (Numerical)
# bt__lymphocytes_abs_float_value                  Blood test - Lymphocytes # (Numerical)
# bt__mch_float_value                                        Blood test - MCH (Numerical)
# bt__mchc_float_value                                      Blood test - MCHC (Numerical)
# bt__mcv_float_value                                        Blood test - MCV (Numerical)
# bt__monocytes_%_float_value                        Blood test - Monocytes % (Numerical)
# bt__monocytes_abs_float_value                      Blood test - Monocytes # (Numerical)
# bt__mpv_float_value                                        Blood test - MPV (Numerical)
# bt__neutrophils_%_float_value                    Blood test - Neutrophils % (Numerical)
# bt__neutrophils_abs_float_value                  Blood test - Neutrophils # (Numerical)
# bt__non_hdl_cholesterol_float_value        Blood test - Non HDL Cholesterol (Numerical)
# bt__phosphore_float_value                            Blood test - Phosphore (Numerical)
# bt__platelets_float_value                            Blood test - Platelets (Numerical)
# bt__potassium_float_value                            Blood test - Potassium (Numerical)
# bt__rbc_float_value                                        Blood test - RBC (Numerical)
# bt__rdw_float_value                                        Blood test - RDW (Numerical)
# bt__rheumatoid_factor_categorical_value    Blood test - Rheumatoid Factor (Categorical)
# bt__rheumatoid_factor_float_value            Blood test - Rheumatoid Factor (Numerical)
# bt__sodium_float_value                                  Blood test - Sodium (Numerical)
# bt__testosterone_total_categorical_value  Blood test - Testosterone Total (Categorical)
# bt__testosterone_total_float_value          Blood test - Testosterone Total (Numerical)
# bt__total_bilirubin_categorical_value        Blood test - Total Bilirubin (Categorical)
# bt__total_bilirubin_float_value                Blood test - Total Bilirubin (Numerical)
# bt__total_cholesterol_float_value            Blood test - Total Cholesterol (Numerical)
# bt__total_protein_float_value                    Blood test - Total Protein (Numerical)
# bt__triglycerides_float_value                    Blood test - Triglycerides (Numerical)
# bt__tsh_categorical_value                                Blood test - TSH (Categorical)
# bt__tsh_float_value                                        Blood test - TSH (Numerical)
# bt__urate_float_value                                    Blood test - Urate (Numerical)
# bt__urea_float_value                                      Blood test - Urea (Numerical)
# bt__vitamin_b12_categorical_value                Blood test - Vitamin B12 (Categorical)
# bt__vitamin_b12_float_value                        Blood test - Vitamin B12 (Numerical)
# bt__vitamin_d_categorical_value                    Blood test - Vitamin D (Categorical)
# bt__vitamin_d_float_value                            Blood test - Vitamin D (Numerical)
# bt__wbc_float_value                                        Blood test - WBC (Numerical)
# urine__acr_categorical_value                             Urine test - ACR (Categorical)
# urine__acr_float_value                                     Urine test - ACR (Numerical)
# urine__creatinine_float_value                       Urine test - Creatinine (Numerical)
# urine__microalbumin_categorical_value           Urine test - Microalbumin (Categorical)
# urine__microalbumin_float_value                   Urine test - Microalbumin (Numerical)
#
#                                                                          description_string  \
# tabular_field_name
# hmo                                                                   One of 4 Isreali HMOs
# collection_date                                                             Collection date
# bt__albumin_float_value                                                             Albumin
# bt__alkaline_phosphatase_float_value                            ALKP - Alkaline Phosphatase
# bt__alt_float_value                                   ALT (GPT) - Alanine Aminotransferease
# bt__ast_float_value                                  AST (GOT) - Aspartate Aminotransferase
# bt__basophils_%_float_value                                      Baso % - Basophils percent
# bt__basophils_abs_float_value                                   Baso # - Basophils absolute
# bt__calcium_float_value                                                        Ca - Calcium
# bt__creatinine_float_value                                                       Creatinine
# bt__direct_bilirubin_categorical_value                          Bilirubin Direct/Conjugated
# bt__direct_bilirubin_float_value                                Bilirubin Direct/Conjugated
# bt__eosinophils_%_float_value                                   Eos % - eosinophils percent
# bt__eosinophils_abs_float_value                                Eos # - eosinophils absolute
# bt__estradiol_categorical_value                                              E2 - Estradiol
# bt__estradiol_float_value                                                    E2 - Estradiol
# bt__ferritin_categorical_value                                                     Ferritin
# bt__ferritin_float_value                                                           Ferritin
# bt__ggt_float_value                                      GGT - gama-Glutamyl Transpeptidase
# bt__glucose_float_value                                                             Glucose
# bt__hba1c_float_value                                                               HbA1C %
# bt__hdl_cholesterol_float_value                                             HDL Cholesterol
# bt__hematocrit_float_value                                                 HCT - Hematocrit
# bt__hemoglobin_float_value                                                  Hb - Hemoglobin
# bt__ldl_cholesterol_float_value                                             LDL Cholesterol
# bt__lymphocytes_%_float_value                                  Lymp % - Lymphocytes percent
# bt__lymphocytes_abs_float_value                               Lymp # - Lymphocytes absolute
# bt__mch_float_value                                              MCH - Mean cell Hemoglobin
# bt__mchc_float_value                              MCHC - Mean cell Hemoglobin concentration
# bt__mcv_float_value                       MCV - Mean Corpuscular Volume or Mean cell volume
# bt__monocytes_%_float_value                                     Mono % - Monoctypes percent
# bt__monocytes_abs_float_value                                  Mono % - Monoctypes absolute
# bt__mpv_float_value                                              MPV - Mean Platelet Volume
# bt__neutrophils_%_float_value                                  Neut % - Neutrophils percent
# bt__neutrophils_abs_float_value                               Neut # - Neutrophils absolute
# bt__non_hdl_cholesterol_float_value                                     Non HDL Cholesterol
# bt__phosphore_float_value                                                     P - Phosphore
# bt__platelets_float_value                                                   PLT - Platelets
# bt__potassium_float_value                                                    K+ - Potassium
# bt__rbc_float_value                                                   RBC - Red Blood Cells
# bt__rdw_float_value                                 RDW - Red Blood Cell Distribution Width
# bt__rheumatoid_factor_categorical_value                           Rheumatoid Factor Quantit
# bt__rheumatoid_factor_float_value                                 Rheumatoid Factor Quantit
# bt__sodium_float_value                                                          Na - Sodium
# bt__testosterone_total_categorical_value                                Total Testosterone
# bt__testosterone_total_float_value                                      Total Testosterone
# bt__total_bilirubin_categorical_value                                      Total Billirubin
# bt__total_bilirubin_float_value                                            Total Billirubin
# bt__total_cholesterol_float_value                                         Total Cholesterol
# bt__total_protein_float_value                                                 Total Protien
# bt__triglycerides_float_value                                                 Triglycerides
# bt__tsh_categorical_value                                 TSH - Thyroid-stimulating hormone
# bt__tsh_float_value                                       TSH - Thyroid-stimulating hormone
# bt__urate_float_value                                                     Urate / Uric Acid
# bt__urea_float_value                                                                   Urea
# bt__vitamin_b12_categorical_value                                   Vitamin B12 - Cobalamin
# bt__vitamin_b12_float_value                                         Vitamin B12 - Cobalamin
# bt__vitamin_d_categorical_value                                                   Vitamin D
# bt__vitamin_d_float_value                                                         Vitamin D
# bt__wbc_float_value                                                 WBC - White blood cells
# urine__acr_categorical_value                         Urine ACR - Albumin / Creatinine Ratio
# urine__acr_float_value                               Urine ACR - Albumin / Creatinine Ratio
# urine__creatinine_float_value                                                    Creatinine
# urine__microalbumin_categorical_value                                          Microalbumin
# urine__microalbumin_float_value                                                Microalbumin
#
#                                                         relative_location  \
# tabular_field_name
# hmo                                       blood_tests/blood_tests.parquet
# collection_date                           blood_tests/blood_tests.parquet
# bt__albumin_float_value                   blood_tests/blood_tests.parquet
# bt__alkaline_phosphatase_float_value      blood_tests/blood_tests.parquet
# bt__alt_float_value                       blood_tests/blood_tests.parquet
# bt__ast_float_value                       blood_tests/blood_tests.parquet
# bt__basophils_%_float_value               blood_tests/blood_tests.parquet
# bt__basophils_abs_float_value             blood_tests/blood_tests.parquet
# bt__calcium_float_value                   blood_tests/blood_tests.parquet
# bt__creatinine_float_value                blood_tests/blood_tests.parquet
# bt__direct_bilirubin_categorical_value    blood_tests/blood_tests.parquet
# bt__direct_bilirubin_float_value          blood_tests/blood_tests.parquet
# bt__eosinophils_%_float_value             blood_tests/blood_tests.parquet
# bt__eosinophils_abs_float_value           blood_tests/blood_tests.parquet
# bt__estradiol_categorical_value           blood_tests/blood_tests.parquet
# bt__estradiol_float_value                 blood_tests/blood_tests.parquet
# bt__ferritin_categorical_value            blood_tests/blood_tests.parquet
# bt__ferritin_float_value                  blood_tests/blood_tests.parquet
# bt__ggt_float_value                       blood_tests/blood_tests.parquet
# bt__glucose_float_value                   blood_tests/blood_tests.parquet
# bt__hba1c_float_value                     blood_tests/blood_tests.parquet
# bt__hdl_cholesterol_float_value           blood_tests/blood_tests.parquet
# bt__hematocrit_float_value                blood_tests/blood_tests.parquet
# bt__hemoglobin_float_value                blood_tests/blood_tests.parquet
# bt__ldl_cholesterol_float_value           blood_tests/blood_tests.parquet
# bt__lymphocytes_%_float_value             blood_tests/blood_tests.parquet
# bt__lymphocytes_abs_float_value           blood_tests/blood_tests.parquet
# bt__mch_float_value                       blood_tests/blood_tests.parquet
# bt__mchc_float_value                      blood_tests/blood_tests.parquet
# bt__mcv_float_value                       blood_tests/blood_tests.parquet
# bt__monocytes_%_float_value               blood_tests/blood_tests.parquet
# bt__monocytes_abs_float_value             blood_tests/blood_tests.parquet
# bt__mpv_float_value                       blood_tests/blood_tests.parquet
# bt__neutrophils_%_float_value             blood_tests/blood_tests.parquet
# bt__neutrophils_abs_float_value           blood_tests/blood_tests.parquet
# bt__non_hdl_cholesterol_float_value       blood_tests/blood_tests.parquet
# bt__phosphore_float_value                 blood_tests/blood_tests.parquet
# bt__platelets_float_value                 blood_tests/blood_tests.parquet
# bt__potassium_float_value                 blood_tests/blood_tests.parquet
# bt__rbc_float_value                       blood_tests/blood_tests.parquet
# bt__rdw_float_value                       blood_tests/blood_tests.parquet
# bt__rheumatoid_factor_categorical_value   blood_tests/blood_tests.parquet
# bt__rheumatoid_factor_float_value         blood_tests/blood_tests.parquet
# bt__sodium_float_value                    blood_tests/blood_tests.parquet
# bt__testosterone_total_categorical_value  blood_tests/blood_tests.parquet
# bt__testosterone_total_float_value        blood_tests/blood_tests.parquet
# bt__total_bilirubin_categorical_value     blood_tests/blood_tests.parquet
# bt__total_bilirubin_float_value           blood_tests/blood_tests.parquet
# bt__total_cholesterol_float_value         blood_tests/blood_tests.parquet
# bt__total_protein_float_value             blood_tests/blood_tests.parquet
# bt__triglycerides_float_value             blood_tests/blood_tests.parquet
# bt__tsh_categorical_value                 blood_tests/blood_tests.parquet
# bt__tsh_float_value                       blood_tests/blood_tests.parquet
# bt__urate_float_value                     blood_tests/blood_tests.parquet
# bt__urea_float_value                      blood_tests/blood_tests.parquet
# bt__vitamin_b12_categorical_value         blood_tests/blood_tests.parquet
# bt__vitamin_b12_float_value               blood_tests/blood_tests.parquet
# bt__vitamin_d_categorical_value           blood_tests/blood_tests.parquet
# bt__vitamin_d_float_value                 blood_tests/blood_tests.parquet
# bt__wbc_float_value                       blood_tests/blood_tests.parquet
# urine__acr_categorical_value              blood_tests/blood_tests.parquet
# urine__acr_float_value                    blood_tests/blood_tests.parquet
# urine__creatinine_float_value             blood_tests/blood_tests.parquet
# urine__microalbumin_categorical_value     blood_tests/blood_tests.parquet
# urine__microalbumin_float_value           blood_tests/blood_tests.parquet
#
#                                           bulk_dictionary  \
# tabular_field_name
# hmo                                                   NaN
# collection_date                                       NaN
# bt__albumin_float_value                               NaN
# bt__alkaline_phosphatase_float_value                  NaN
# bt__alt_float_value                                   NaN
# bt__ast_float_value                                   NaN
# bt__basophils_%_float_value                           NaN
# bt__basophils_abs_float_value                         NaN
# bt__calcium_float_value                               NaN
# bt__creatinine_float_value                            NaN
# bt__direct_bilirubin_categorical_value                NaN
# bt__direct_bilirubin_float_value                      NaN
# bt__eosinophils_%_float_value                         NaN
# bt__eosinophils_abs_float_value                       NaN
# bt__estradiol_categorical_value                       NaN
# bt__estradiol_float_value                             NaN
# bt__ferritin_categorical_value                        NaN
# bt__ferritin_float_value                              NaN
# bt__ggt_float_value                                   NaN
# bt__glucose_float_value                               NaN
# bt__hba1c_float_value                                 NaN
# bt__hdl_cholesterol_float_value                       NaN
# bt__hematocrit_float_value                            NaN
# bt__hemoglobin_float_value                            NaN
# bt__ldl_cholesterol_float_value                       NaN
# bt__lymphocytes_%_float_value                         NaN
# bt__lymphocytes_abs_float_value                       NaN
# bt__mch_float_value                                   NaN
# bt__mchc_float_value                                  NaN
# bt__mcv_float_value                                   NaN
# bt__monocytes_%_float_value                           NaN
# bt__monocytes_abs_float_value                         NaN
# bt__mpv_float_value                                   NaN
# bt__neutrophils_%_float_value                         NaN
# bt__neutrophils_abs_float_value                       NaN
# bt__non_hdl_cholesterol_float_value                   NaN
# bt__phosphore_float_value                             NaN
# bt__platelets_float_value                             NaN
# bt__potassium_float_value                             NaN
# bt__rbc_float_value                                   NaN
# bt__rdw_float_value                                   NaN
# bt__rheumatoid_factor_categorical_value               NaN
# bt__rheumatoid_factor_float_value                     NaN
# bt__sodium_float_value                                NaN
# bt__testosterone_total_categorical_value              NaN
# bt__testosterone_total_float_value                    NaN
# bt__total_bilirubin_categorical_value                 NaN
# bt__total_bilirubin_float_value                       NaN
# bt__total_cholesterol_float_value                     NaN
# bt__total_protein_float_value                         NaN
# bt__triglycerides_float_value                         NaN
# bt__tsh_categorical_value                             NaN
# bt__tsh_float_value                                   NaN
# bt__urate_float_value                                 NaN
# bt__urea_float_value                                  NaN
# bt__vitamin_b12_categorical_value                     NaN
# bt__vitamin_b12_float_value                           NaN
# bt__vitamin_d_categorical_value                       NaN
# bt__vitamin_d_float_value                             NaN
# bt__wbc_float_value                                   NaN
# urine__acr_categorical_value                          NaN
# urine__acr_float_value                                NaN
# urine__creatinine_float_value                         NaN
# urine__microalbumin_categorical_value                 NaN
# urine__microalbumin_float_value                       NaN
#
#                                                     field_type  data_coding  \
# tabular_field_name
# hmo                                       Categorical (single)          NaN
# collection_date                                           Date          NaN
# bt__albumin_float_value                             Continuous          NaN
# bt__alkaline_phosphatase_float_value                Continuous          NaN
# bt__alt_float_value                                 Continuous          NaN
# bt__ast_float_value                                 Continuous          NaN
# bt__basophils_%_float_value                         Continuous          NaN
# bt__basophils_abs_float_value                       Continuous          NaN
# bt__calcium_float_value                             Continuous          NaN
# bt__creatinine_float_value                          Continuous          NaN
# bt__direct_bilirubin_categorical_value              Continuous          NaN
# bt__direct_bilirubin_float_value                    Continuous          NaN
# bt__eosinophils_%_float_value                       Continuous          NaN
# bt__eosinophils_abs_float_value                     Continuous          NaN
# bt__estradiol_categorical_value                     Continuous          NaN
# bt__estradiol_float_value                           Continuous          NaN
# bt__ferritin_categorical_value                      Continuous          NaN
# bt__ferritin_float_value                            Continuous          NaN
# bt__ggt_float_value                                 Continuous          NaN
# bt__glucose_float_value                             Continuous          NaN
# bt__hba1c_float_value                               Continuous          NaN
# bt__hdl_cholesterol_float_value                     Continuous          NaN
# bt__hematocrit_float_value                          Continuous          NaN
# bt__hemoglobin_float_value                          Continuous          NaN
# bt__ldl_cholesterol_float_value                     Continuous          NaN
# bt__lymphocytes_%_float_value                       Continuous          NaN
# bt__lymphocytes_abs_float_value                     Continuous          NaN
# bt__mch_float_value                                 Continuous          NaN
# bt__mchc_float_value                                Continuous          NaN
# bt__mcv_float_value                                 Continuous          NaN
# bt__monocytes_%_float_value                         Continuous          NaN
# bt__monocytes_abs_float_value                       Continuous          NaN
# bt__mpv_float_value                                 Continuous          NaN
# bt__neutrophils_%_float_value                       Continuous          NaN
# bt__neutrophils_abs_float_value                     Continuous          NaN
# bt__non_hdl_cholesterol_float_value                 Continuous          NaN
# bt__phosphore_float_value                           Continuous          NaN
# bt__platelets_float_value                           Continuous          NaN
# bt__potassium_float_value                           Continuous          NaN
# bt__rbc_float_value                                 Continuous          NaN
# bt__rdw_float_value                                 Continuous          NaN
# bt__rheumatoid_factor_categorical_value             Continuous          NaN
# bt__rheumatoid_factor_float_value                   Continuous          NaN
# bt__sodium_float_value                              Continuous          NaN
# bt__testosterone_total_categorical_value  Categorical (single)          NaN
# bt__testosterone_total_float_value                  Continuous          NaN
# bt__total_bilirubin_categorical_value     Categorical (single)          NaN
# bt__total_bilirubin_float_value                     Continuous          NaN
# bt__total_cholesterol_float_value                   Continuous          NaN
# bt__total_protein_float_value                       Continuous          NaN
# bt__triglycerides_float_value                       Continuous          NaN
# bt__tsh_categorical_value                 Categorical (single)          NaN
# bt__tsh_float_value                                 Continuous          NaN
# bt__urate_float_value                               Continuous          NaN
# bt__urea_float_value                                Continuous          NaN
# bt__vitamin_b12_categorical_value         Categorical (single)          NaN
# bt__vitamin_b12_float_value                         Continuous          NaN
# bt__vitamin_d_categorical_value           Categorical (single)          NaN
# bt__vitamin_d_float_value                           Continuous          NaN
# bt__wbc_float_value                                 Continuous          NaN
# urine__acr_categorical_value              Categorical (single)          NaN
# urine__acr_float_value                              Continuous          NaN
# urine__creatinine_float_value                       Continuous          NaN
# urine__microalbumin_categorical_value     Categorical (single)          NaN
# urine__microalbumin_float_value                     Continuous          NaN
#
#                                          stability            units  \
# tabular_field_name
# hmo                                       Accruing              NaN
# collection_date                           Accruing              NaN
# bt__albumin_float_value                   Accruing             g/dl
# bt__alkaline_phosphatase_float_value      Accruing              u/l
# bt__alt_float_value                       Accruing              u/l
# bt__ast_float_value                       Accruing              u/l
# bt__basophils_%_float_value               Accruing                %
# bt__basophils_abs_float_value             Accruing             k/ul
# bt__calcium_float_value                   Accruing            mg/dl
# bt__creatinine_float_value                Accruing            mg/dl
# bt__direct_bilirubin_categorical_value    Accruing              NaN
# bt__direct_bilirubin_float_value          Accruing            mg/dl
# bt__eosinophils_%_float_value             Accruing                %
# bt__eosinophils_abs_float_value           Accruing             k/ul
# bt__estradiol_categorical_value           Accruing              NaN
# bt__estradiol_float_value                 Accruing           pmol/l
# bt__ferritin_categorical_value            Accruing              NaN
# bt__ferritin_float_value                  Accruing            ng/ml
# bt__ggt_float_value                       Accruing              u/l
# bt__glucose_float_value                   Accruing            mg/dl
# bt__hba1c_float_value                     Accruing                %
# bt__hdl_cholesterol_float_value           Accruing            mg/dl
# bt__hematocrit_float_value                Accruing                %
# bt__hemoglobin_float_value                Accruing             g/dl
# bt__ldl_cholesterol_float_value           Accruing            mg/dl
# bt__lymphocytes_%_float_value             Accruing                %
# bt__lymphocytes_abs_float_value           Accruing             k/ul
# bt__mch_float_value                       Accruing          pg/cell
# bt__mchc_float_value                      Accruing             g/dl
# bt__mcv_float_value                       Accruing               fl
# bt__monocytes_%_float_value               Accruing                %
# bt__monocytes_abs_float_value             Accruing             k/ul
# bt__mpv_float_value                       Accruing               fl
# bt__neutrophils_%_float_value             Accruing                %
# bt__neutrophils_abs_float_value           Accruing             k/ul
# bt__non_hdl_cholesterol_float_value       Accruing            mg/dl
# bt__phosphore_float_value                 Accruing            mg/dl
# bt__platelets_float_value                 Accruing             k/ul
# bt__potassium_float_value                 Accruing           mmol/l
# bt__rbc_float_value                       Accruing             m/ul
# bt__rdw_float_value                       Accruing                %
# bt__rheumatoid_factor_categorical_value   Accruing              NaN
# bt__rheumatoid_factor_float_value         Accruing            iu/ml
# bt__sodium_float_value                    Accruing           mmol/l
# bt__testosterone_total_categorical_value  Accruing              NaN
# bt__testosterone_total_float_value        Accruing           nmol/l
# bt__total_bilirubin_categorical_value     Accruing              NaN
# bt__total_bilirubin_float_value           Accruing            mg/dl
# bt__total_cholesterol_float_value         Accruing            mg/dl
# bt__total_protein_float_value             Accruing             g/dl
# bt__triglycerides_float_value             Accruing            mg/dl
# bt__tsh_categorical_value                 Accruing              NaN
# bt__tsh_float_value                       Accruing            miu/l
# bt__urate_float_value                     Accruing            mg/dl
# bt__urea_float_value                      Accruing            mg/dl
# bt__vitamin_b12_categorical_value         Accruing              NaN
# bt__vitamin_b12_float_value               Accruing            pg/ml
# bt__vitamin_d_categorical_value           Accruing              NaN
# bt__vitamin_d_float_value                 Accruing            ng/ml
# bt__wbc_float_value                       Accruing             k/ul
# urine__acr_categorical_value              Accruing              NaN
# urine__acr_float_value                    Accruing  mg/g creatinine
# urine__creatinine_float_value             Accruing            mg/dl
# urine__microalbumin_categorical_value     Accruing              NaN
# urine__microalbumin_float_value           Accruing             mg/l
#
#                                           sampling_rate  bulk_file_extension  \
# tabular_field_name
# hmo                                                 NaN                  NaN
# collection_date                                     NaN                  NaN
# bt__albumin_float_value                             NaN                  NaN
# bt__alkaline_phosphatase_float_value                NaN                  NaN
# bt__alt_float_value                                 NaN                  NaN
# bt__ast_float_value                                 NaN                  NaN
# bt__basophils_%_float_value                         NaN                  NaN
# bt__basophils_abs_float_value                       NaN                  NaN
# bt__calcium_float_value                             NaN                  NaN
# bt__creatinine_float_value                          NaN                  NaN
# bt__direct_bilirubin_categorical_value              NaN                  NaN
# bt__direct_bilirubin_float_value                    NaN                  NaN
# bt__eosinophils_%_float_value                       NaN                  NaN
# bt__eosinophils_abs_float_value                     NaN                  NaN
# bt__estradiol_categorical_value                     NaN                  NaN
# bt__estradiol_float_value                           NaN                  NaN
# bt__ferritin_categorical_value                      NaN                  NaN
# bt__ferritin_float_value                            NaN                  NaN
# bt__ggt_float_value                                 NaN                  NaN
# bt__glucose_float_value                             NaN                  NaN
# bt__hba1c_float_value                               NaN                  NaN
# bt__hdl_cholesterol_float_value                     NaN                  NaN
# bt__hematocrit_float_value                          NaN                  NaN
# bt__hemoglobin_float_value                          NaN                  NaN
# bt__ldl_cholesterol_float_value                     NaN                  NaN
# bt__lymphocytes_%_float_value                       NaN                  NaN
# bt__lymphocytes_abs_float_value                     NaN                  NaN
# bt__mch_float_value                                 NaN                  NaN
# bt__mchc_float_value                                NaN                  NaN
# bt__mcv_float_value                                 NaN                  NaN
# bt__monocytes_%_float_value                         NaN                  NaN
# bt__monocytes_abs_float_value                       NaN                  NaN
# bt__mpv_float_value                                 NaN                  NaN
# bt__neutrophils_%_float_value                       NaN                  NaN
# bt__neutrophils_abs_float_value                     NaN                  NaN
# bt__non_hdl_cholesterol_float_value                 NaN                  NaN
# bt__phosphore_float_value                           NaN                  NaN
# bt__platelets_float_value                           NaN                  NaN
# bt__potassium_float_value                           NaN                  NaN
# bt__rbc_float_value                                 NaN                  NaN
# bt__rdw_float_value                                 NaN                  NaN
# bt__rheumatoid_factor_categorical_value             NaN                  NaN
# bt__rheumatoid_factor_float_value                   NaN                  NaN
# bt__sodium_float_value                              NaN                  NaN
# bt__testosterone_total_categorical_value            NaN                  NaN
# bt__testosterone_total_float_value                  NaN                  NaN
# bt__total_bilirubin_categorical_value               NaN                  NaN
# bt__total_bilirubin_float_value                     NaN                  NaN
# bt__total_cholesterol_float_value                   NaN                  NaN
# bt__total_protein_float_value                       NaN                  NaN
# bt__triglycerides_float_value                       NaN                  NaN
# bt__tsh_categorical_value                           NaN                  NaN
# bt__tsh_float_value                                 NaN                  NaN
# bt__urate_float_value                               NaN                  NaN
# bt__urea_float_value                                NaN                  NaN
# bt__vitamin_b12_categorical_value                   NaN                  NaN
# bt__vitamin_b12_float_value                         NaN                  NaN
# bt__vitamin_d_categorical_value                     NaN                  NaN
# bt__vitamin_d_float_value                           NaN                  NaN
# bt__wbc_float_value                                 NaN                  NaN
# urine__acr_categorical_value                        NaN                  NaN
# urine__acr_float_value                              NaN                  NaN
# urine__creatinine_float_value                       NaN                  NaN
# urine__microalbumin_categorical_value               NaN                  NaN
# urine__microalbumin_float_value                     NaN                  NaN
#
#                                              strata       sexed   array  \
# tabular_field_name
# hmo                                         Primary  Both sexes  Single
# collection_date                           Auxiliary  Both sexes  Single
# bt__albumin_float_value                     Primary  Both sexes  Single
# bt__alkaline_phosphatase_float_value        Primary  Both sexes  Single
# bt__alt_float_value                         Primary  Both sexes  Single
# bt__ast_float_value                         Primary  Both sexes  Single
# bt__basophils_%_float_value                 Primary  Both sexes  Single
# bt__basophils_abs_float_value               Primary  Both sexes  Single
# bt__calcium_float_value                     Primary  Both sexes  Single
# bt__creatinine_float_value                  Primary  Both sexes  Single
# bt__direct_bilirubin_categorical_value      Primary  Both sexes  Single
# bt__direct_bilirubin_float_value            Primary  Both sexes  Single
# bt__eosinophils_%_float_value               Primary  Both sexes  Single
# bt__eosinophils_abs_float_value             Primary  Both sexes  Single
# bt__estradiol_categorical_value             Primary  Both sexes  Single
# bt__estradiol_float_value                   Primary  Both sexes  Single
# bt__ferritin_categorical_value              Primary  Both sexes  Single
# bt__ferritin_float_value                    Primary  Both sexes  Single
# bt__ggt_float_value                         Primary  Both sexes  Single
# bt__glucose_float_value                     Primary  Both sexes  Single
# bt__hba1c_float_value                       Primary  Both sexes  Single
# bt__hdl_cholesterol_float_value             Primary  Both sexes  Single
# bt__hematocrit_float_value                  Primary  Both sexes  Single
# bt__hemoglobin_float_value                  Primary  Both sexes  Single
# bt__ldl_cholesterol_float_value             Primary  Both sexes  Single
# bt__lymphocytes_%_float_value               Primary  Both sexes  Single
# bt__lymphocytes_abs_float_value             Primary  Both sexes  Single
# bt__mch_float_value                         Primary  Both sexes  Single
# bt__mchc_float_value                        Primary  Both sexes  Single
# bt__mcv_float_value                         Primary  Both sexes  Single
# bt__monocytes_%_float_value                 Primary  Both sexes  Single
# bt__monocytes_abs_float_value               Primary  Both sexes  Single
# bt__mpv_float_value                         Primary  Both sexes  Single
# bt__neutrophils_%_float_value               Primary  Both sexes  Single
# bt__neutrophils_abs_float_value             Primary  Both sexes  Single
# bt__non_hdl_cholesterol_float_value         Primary  Both sexes  Single
# bt__phosphore_float_value                   Primary  Both sexes  Single
# bt__platelets_float_value                   Primary  Both sexes  Single
# bt__potassium_float_value                   Primary  Both sexes  Single
# bt__rbc_float_value                         Primary  Both sexes  Single
# bt__rdw_float_value                         Primary  Both sexes  Single
# bt__rheumatoid_factor_categorical_value     Primary  Both sexes  Single
# bt__rheumatoid_factor_float_value           Primary  Both sexes  Single
# bt__sodium_float_value                      Primary  Both sexes  Single
# bt__testosterone_total_categorical_value    Primary  Both sexes  Single
# bt__testosterone_total_float_value          Primary  Both sexes  Single
# bt__total_bilirubin_categorical_value       Primary  Both sexes  Single
# bt__total_bilirubin_float_value             Primary  Both sexes  Single
# bt__total_cholesterol_float_value           Primary  Both sexes  Single
# bt__total_protein_float_value               Primary  Both sexes  Single
# bt__triglycerides_float_value               Primary  Both sexes  Single
# bt__tsh_categorical_value                   Primary  Both sexes  Single
# bt__tsh_float_value                         Primary  Both sexes  Single
# bt__urate_float_value                       Primary  Both sexes  Single
# bt__urea_float_value                        Primary  Both sexes  Single
# bt__vitamin_b12_categorical_value           Primary  Both sexes  Single
# bt__vitamin_b12_float_value                 Primary  Both sexes  Single
# bt__vitamin_d_categorical_value             Primary  Both sexes  Single
# bt__vitamin_d_float_value                   Primary  Both sexes  Single
# bt__wbc_float_value                         Primary  Both sexes  Single
# urine__acr_categorical_value                Primary  Both sexes  Single
# urine__acr_float_value                      Primary  Both sexes  Single
# urine__creatinine_float_value               Primary  Both sexes  Single
# urine__microalbumin_categorical_value       Primary  Both sexes  Single
# urine__microalbumin_float_value             Primary  Both sexes  Single
#
#                                                debut  completed  \
# tabular_field_name
# hmo                                       2015-01-01        NaN
# collection_date                           2015-01-01        NaN
# bt__albumin_float_value                   2015-01-01        NaN
# bt__alkaline_phosphatase_float_value      2015-01-01        NaN
# bt__alt_float_value                       2015-01-01        NaN
# bt__ast_float_value                       2015-01-01        NaN
# bt__basophils_%_float_value               2015-01-01        NaN
# bt__basophils_abs_float_value             2015-01-01        NaN
# bt__calcium_float_value                   2015-01-01        NaN
# bt__creatinine_float_value                2015-01-01        NaN
# bt__direct_bilirubin_categorical_value    2015-01-01        NaN
# bt__direct_bilirubin_float_value          2015-01-01        NaN
# bt__eosinophils_%_float_value             2015-01-01        NaN
# bt__eosinophils_abs_float_value           2015-01-01        NaN
# bt__estradiol_categorical_value           2015-01-01        NaN
# bt__estradiol_float_value                 2015-01-01        NaN
# bt__ferritin_categorical_value            2015-01-01        NaN
# bt__ferritin_float_value                  2015-01-01        NaN
# bt__ggt_float_value                       2015-01-01        NaN
# bt__glucose_float_value                   2015-01-01        NaN
# bt__hba1c_float_value                     2015-01-01        NaN
# bt__hdl_cholesterol_float_value           2015-01-01        NaN
# bt__hematocrit_float_value                2015-01-01        NaN
# bt__hemoglobin_float_value                2015-01-01        NaN
# bt__ldl_cholesterol_float_value           2015-01-01        NaN
# bt__lymphocytes_%_float_value             2015-01-01        NaN
# bt__lymphocytes_abs_float_value           2015-01-01        NaN
# bt__mch_float_value                       2015-01-01        NaN
# bt__mchc_float_value                      2015-01-01        NaN
# bt__mcv_float_value                       2015-01-01        NaN
# bt__monocytes_%_float_value               2015-01-01        NaN
# bt__monocytes_abs_float_value             2015-01-01        NaN
# bt__mpv_float_value                       2015-01-01        NaN
# bt__neutrophils_%_float_value             2015-01-01        NaN
# bt__neutrophils_abs_float_value           2015-01-01        NaN
# bt__non_hdl_cholesterol_float_value       2015-01-01        NaN
# bt__phosphore_float_value                 2015-01-01        NaN
# bt__platelets_float_value                 2015-01-01        NaN
# bt__potassium_float_value                 2015-01-01        NaN
# bt__rbc_float_value                       2015-01-01        NaN
# bt__rdw_float_value                       2015-01-01        NaN
# bt__rheumatoid_factor_categorical_value   2015-01-01        NaN
# bt__rheumatoid_factor_float_value         2015-01-01        NaN
# bt__sodium_float_value                    2015-01-01        NaN
# bt__testosterone_total_categorical_value  2015-01-01        NaN
# bt__testosterone_total_float_value        2015-01-01        NaN
# bt__total_bilirubin_categorical_value     2015-01-01        NaN
# bt__total_bilirubin_float_value           2015-01-01        NaN
# bt__total_cholesterol_float_value         2015-01-01        NaN
# bt__total_protein_float_value             2015-01-01        NaN
# bt__triglycerides_float_value             2015-01-01        NaN
# bt__tsh_categorical_value                 2015-01-01        NaN
# bt__tsh_float_value                       2015-01-01        NaN
# bt__urate_float_value                     2015-01-01        NaN
# bt__urea_float_value                      2015-01-01        NaN
# bt__vitamin_b12_categorical_value         2015-01-01        NaN
# bt__vitamin_b12_float_value               2015-01-01        NaN
# bt__vitamin_d_categorical_value           2015-01-01        NaN
# bt__vitamin_d_float_value                 2015-01-01        NaN
# bt__wbc_float_value                       2015-01-01        NaN
# urine__acr_categorical_value              2015-01-01        NaN
# urine__acr_float_value                    2015-01-01        NaN
# urine__creatinine_float_value             2015-01-01        NaN
# urine__microalbumin_categorical_value     2015-01-01        NaN
# urine__microalbumin_float_value           2015-01-01        NaN
#
#                                           transformation list_of_tags  \
# tabular_field_name
# hmo                                                  NaN  Blood Tests
# collection_date                                      NaN  Blood Tests
# bt__albumin_float_value                              NaN  Blood Tests
# bt__alkaline_phosphatase_float_value                 NaN  Blood Tests
# bt__alt_float_value                                  NaN  Blood Tests
# bt__ast_float_value                                  NaN  Blood Tests
# bt__basophils_%_float_value                          NaN  Blood Tests
# bt__basophils_abs_float_value                        NaN  Blood Tests
# bt__calcium_float_value                              NaN  Blood Tests
# bt__creatinine_float_value                           NaN  Blood Tests
# bt__direct_bilirubin_categorical_value               NaN  Blood Tests
# bt__direct_bilirubin_float_value                     NaN  Blood Tests
# bt__eosinophils_%_float_value                        NaN  Blood Tests
# bt__eosinophils_abs_float_value                      NaN  Blood Tests
# bt__estradiol_categorical_value                      NaN  Blood Tests
# bt__estradiol_float_value                            NaN  Blood Tests
# bt__ferritin_categorical_value                       NaN  Blood Tests
# bt__ferritin_float_value                             NaN  Blood Tests
# bt__ggt_float_value                                  NaN  Blood Tests
# bt__glucose_float_value                              NaN  Blood Tests
# bt__hba1c_float_value                                NaN  Blood Tests
# bt__hdl_cholesterol_float_value                      NaN  Blood Tests
# bt__hematocrit_float_value                           NaN  Blood Tests
# bt__hemoglobin_float_value                           NaN  Blood Tests
# bt__ldl_cholesterol_float_value                      NaN  Blood Tests
# bt__lymphocytes_%_float_value                        NaN  Blood Tests
# bt__lymphocytes_abs_float_value                      NaN  Blood Tests
# bt__mch_float_value                                  NaN  Blood Tests
# bt__mchc_float_value                                 NaN  Blood Tests
# bt__mcv_float_value                                  NaN  Blood Tests
# bt__monocytes_%_float_value                          NaN  Blood Tests
# bt__monocytes_abs_float_value                        NaN  Blood Tests
# bt__mpv_float_value                                  NaN  Blood Tests
# bt__neutrophils_%_float_value                        NaN  Blood Tests
# bt__neutrophils_abs_float_value                      NaN  Blood Tests
# bt__non_hdl_cholesterol_float_value                  NaN  Blood Tests
# bt__phosphore_float_value                            NaN  Blood Tests
# bt__platelets_float_value                            NaN  Blood Tests
# bt__potassium_float_value                            NaN  Blood Tests
# bt__rbc_float_value                                  NaN  Blood Tests
# bt__rdw_float_value                                  NaN  Blood Tests
# bt__rheumatoid_factor_categorical_value              NaN  Blood Tests
# bt__rheumatoid_factor_float_value                    NaN  Blood Tests
# bt__sodium_float_value                               NaN  Blood Tests
# bt__testosterone_total_categorical_value             NaN  Blood Tests
# bt__testosterone_total_float_value                   NaN  Blood Tests
# bt__total_bilirubin_categorical_value                NaN  Blood Tests
# bt__total_bilirubin_float_value                      NaN  Blood Tests
# bt__total_cholesterol_float_value                    NaN  Blood Tests
# bt__total_protein_float_value                        NaN  Blood Tests
# bt__triglycerides_float_value                        NaN  Blood Tests
# bt__tsh_categorical_value                            NaN  Blood Tests
# bt__tsh_float_value                                  NaN  Blood Tests
# bt__urate_float_value                                NaN  Blood Tests
# bt__urea_float_value                                 NaN  Blood Tests
# bt__vitamin_b12_categorical_value                    NaN  Blood Tests
# bt__vitamin_b12_float_value                          NaN  Blood Tests
# bt__vitamin_d_categorical_value                      NaN  Blood Tests
# bt__vitamin_d_float_value                            NaN  Blood Tests
# bt__wbc_float_value                                  NaN  Blood Tests
# urine__acr_categorical_value                         NaN  Blood Tests
# urine__acr_float_value                               NaN  Blood Tests
# urine__creatinine_float_value                        NaN  Blood Tests
# urine__microalbumin_categorical_value                NaN  Blood Tests
# urine__microalbumin_float_value                      NaN  Blood Tests
#
#                                             pandas_dtype
# tabular_field_name
# hmo                                             category
# collection_date                           datetime64[ns]
# bt__albumin_float_value                            float
# bt__alkaline_phosphatase_float_value               float
# bt__alt_float_value                                float
# bt__ast_float_value                                float
# bt__basophils_%_float_value                        float
# bt__basophils_abs_float_value                      float
# bt__calcium_float_value                            float
# bt__creatinine_float_value                         float
# bt__direct_bilirubin_categorical_value          category
# bt__direct_bilirubin_float_value                   float
# bt__eosinophils_%_float_value                      float
# bt__eosinophils_abs_float_value                    float
# bt__estradiol_categorical_value                 category
# bt__estradiol_float_value                          float
# bt__ferritin_categorical_value                  category
# bt__ferritin_float_value                           float
# bt__ggt_float_value                                float
# bt__glucose_float_value                            float
# bt__hba1c_float_value                              float
# bt__hdl_cholesterol_float_value                    float
# bt__hematocrit_float_value                         float
# bt__hemoglobin_float_value                         float
# bt__ldl_cholesterol_float_value                    float
# bt__lymphocytes_%_float_value                      float
# bt__lymphocytes_abs_float_value                    float
# bt__mch_float_value                                float
# bt__mchc_float_value                               float
# bt__mcv_float_value                                float
# bt__monocytes_%_float_value                        float
# bt__monocytes_abs_float_value                      float
# bt__mpv_float_value                                float
# bt__neutrophils_%_float_value                      float
# bt__neutrophils_abs_float_value                    float
# bt__non_hdl_cholesterol_float_value                float
# bt__phosphore_float_value                          float
# bt__platelets_float_value                          float
# bt__potassium_float_value                          float
# bt__rbc_float_value                                float
# bt__rdw_float_value                                float
# bt__rheumatoid_factor_categorical_value         category
# bt__rheumatoid_factor_float_value                  float
# bt__sodium_float_value                             float
# bt__testosterone_total_categorical_value        category
# bt__testosterone_total_float_value                 float
# bt__total_bilirubin_categorical_value           category
# bt__total_bilirubin_float_value                    float
# bt__total_cholesterol_float_value                  float
# bt__total_protein_float_value                      float
# bt__triglycerides_float_value                      float
# bt__tsh_categorical_value                       category
# bt__tsh_float_value                                float
# bt__urate_float_value                              float
# bt__urea_float_value                               float
# bt__vitamin_b12_categorical_value               category
# bt__vitamin_b12_float_value                        float
# bt__vitamin_d_categorical_value                 category
# bt__vitamin_d_float_value                          float
# bt__wbc_float_value                                float
# urine__acr_categorical_value                    category
# urine__acr_float_value                             float
# urine__creatinine_float_value                      float
# urine__microalbumin_categorical_value           category
# urine__microalbumin_float_value                    float
