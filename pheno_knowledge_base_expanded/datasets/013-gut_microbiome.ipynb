# %% [raw]
# ---
# output-file: 013-gut_microbiome.html
# title: Gut Microbiome
# ---

# %% [markdown]
# ### Description
# <!-- just for gut microbiome: shortened from the original introduction in the data doc -->
# Metagenomics is the study of genetic material from environmental samples, including microbial communities. It involves sequencing the DNA of all microorganisms in the sample, rather than isolating individual organisms. Metagenomics enables the identification and functional analysis of microorganisms in diverse environments, including soil, water, and the human body.
#
# This dataset maps out the human gut microbiota per participant via shotgun metagenomic sequencing given stool samples. It is then compared to known references of gut flora to measure prevalence of specific microbes.
#
# ### Introduction
# <!-- just for gut microbiome: shortened from the original introduction in the data doc -->
# The human gut, a complex and dynamic ecosystem, harbors a myriad of microorganisms collectively known as the gut microbiome. This community plays a critical role in various physiological processes such as immune modulation, metabolic regulation, and even functions as an endocrine organ. However, the vast complexity and diversity of the gut microbiome have remained largely elusive due to traditional culture methods' limitations. Recent advances in next-generation sequencing technologies, particularly metagenomics, have paved the way for a more comprehensive understanding of the gut microbiome.
#
# Gut metagenomics refers to the study of the collective genetic material of all microorganisms present in the gut, gleaned directly from fecal samples. It provides a powerful tool for the identification and quantification of diverse microbial species and their functional roles, including their influence on metabolic pathways, their virulence factors, antibiotic resistance profiles, and more. Moreover, gut metagenomics can reveal the taxonomic diversity and community structure of the microbiome, offering insights into the intricate relationship between the microbiome and its host.
#
# ### Measurement protocol
# <!-- long measurment protocol for the data browser -->
# To measure the genetic makeup of the human gut flora given stool samples via metagenomics, the following steps done:
#
# 1. Collection of stool sample: For each visit, a stool sample is collected from the individual and stored appropriately to preserve the microbial community.
# 2. DNA extraction: DNA is extracted from the stool sample using specialized techniques to isolate the microbial DNA from other materials present in the sample.
# 3. DNA fragmentation and sequencing: The extracted DNA is then fragmented into small pieces and sequenced using high-throughput sequencing technologies.
# 4. Quality control: The resulting raw sequencing data is then pre-processed, removing low-quality reads and artifacts of the sequencing methodology.
# 5. Taxonomic classification: The processed sequencing data is then compared to databases of known microbial sequences to identify and classify the microbial species presence and their respective abundances in the sample.
#
# ### Data availability
# <!-- for the example notebooks -->
# The information is stored in multiple parquet files:
#
# - `gut_microbiome.parquet`: Sequencing and QC statistics.
# - `urs`: Segal Lab relative abundance.
# - `metaphlan_*`: 8 tables with MetaPhlAn 4 relative abundances, separated by taxonomic levels.
#
# ```{mermaid}
# graph LR;
#     A(Raw FASTQ File) --> |Trimmomatic| B(Clean FASTQ File)
#     A --> |FASTQC| C(QC HTML)
#
#     B --> |BWA| D(Non Human Reads)
#     B --> |BWA| E(Human Reads)
#
#     D --> |MetaPhlAn 4| F(MetaPhlAn 4 Abundances<br>Tabular)
#     D --> G("URS (Segal) Abundances<br>Tabular")
#
#     E --> |GATK4| H(Human Variants<br>Plink)
#
#     F --> I(Pipeline Metadata)
#     G --> I
#     H --> I
#     C --> I
# ```
#
# ### Summary of available data
# <!-- for the data browser -->
# 1. Sequencing and QC statistics.
# 2. FASTQ files: Raw sequencing files, trimmed files, and files filtered from human reads.
# 3. PLINK BED files: Containing human variants.
# 4. URS relative abundances of 3594 representative gut microbes.
# 5. MetaPhlAn 4 relative abundances, separated by taxonomic levels.
#     - The data browser displays the relative abundances of a subset of 300 bacterial species.
#
# ![available data](gutmb_data.png)
#
# ### Relevant links
#
# * [Pheno Knowledgebase](https://knowledgebase.pheno.ai/datasets/013-gut_microbiome.html)
# * [Pheno Data Browser](https://pheno-demo-app.vercel.app/folder/13)

# %%
#| echo: false
import pandas as pd
pd.set_option("display.max_rows", 500)

# %%
from pheno_utils import PhenoLoader

# %%
pl = PhenoLoader('gut_microbiome')
pl
# Out:
# PhenoLoader for gut_microbiome with
# 46 fields
# 2 tables: ['gut_microbiome', 'age_sex']

# %% [markdown]
# # Data dictionary

# %%
pl.dict
# Out:
#                                                     folder_id  \
# tabular_field_name
# collection_timestamp                                     13.0
# collection_date                                          13.0
# timezone                                                 13.0
# sample_name                                              13.0
# urs_metadata_parquet                                     13.0
# ...                                                       ...
# k__Bacteria|p__Verrucomicrobia|c__Verrucomicrob...        NaN
# k__Eukaryota|p__Ascomycota|c__Saccharomycetes|o...        NaN
# k__Eukaryota|p__Eukaryota_unclassified|c__Eukar...        NaN
# k__Eukaryota|p__Eukaryota_unclassified|c__Eukar...        NaN
# k__Eukaryota|p__Eukaryota_unclassified|c__Eukar...        NaN
#
#                                                                   feature_set  \
# tabular_field_name
# collection_timestamp                                           gut_microbiome
# collection_date                                                gut_microbiome
# timezone                                                       gut_microbiome
# sample_name                                                    gut_microbiome
# urs_metadata_parquet                                urs_abundances_aggregated
# ...                                                                       ...
# k__Bacteria|p__Verrucomicrobia|c__Verrucomicrob...                        NaN
# k__Eukaryota|p__Ascomycota|c__Saccharomycetes|o...                        NaN
# k__Eukaryota|p__Eukaryota_unclassified|c__Eukar...                        NaN
# k__Eukaryota|p__Eukaryota_unclassified|c__Eukar...                        NaN
# k__Eukaryota|p__Eukaryota_unclassified|c__Eukar...                        NaN
#
#                                                                                          field_string  \
# tabular_field_name
# collection_timestamp                                                                Sampled timestamp
# collection_date                                                                          Sampled date
# timezone                                                                                     Timezone
# sample_name                                                                               Sample name
# urs_metadata_parquet                                                          URS abundances metadata
# ...                                                                                               ...
# k__Bacteria|p__Verrucomicrobia|c__Verrucomicrob...  k__Bacteria|p__Verrucomicrobia|c__Verrucomicro...
# k__Eukaryota|p__Ascomycota|c__Saccharomycetes|o...  k__Eukaryota|p__Ascomycota|c__Saccharomycetes|...
# k__Eukaryota|p__Eukaryota_unclassified|c__Eukar...  k__Eukaryota|p__Eukaryota_unclassified|c__Euka...
# k__Eukaryota|p__Eukaryota_unclassified|c__Eukar...  k__Eukaryota|p__Eukaryota_unclassified|c__Euka...
# k__Eukaryota|p__Eukaryota_unclassified|c__Eukar...  k__Eukaryota|p__Eukaryota_unclassified|c__Euka...
#
#                                                                       description_string  \
# tabular_field_name
# collection_timestamp                                               Time sample was given
# collection_date                                                    Date sample was given
# timezone                                                                        Timezone
# sample_name                                                                  Sample Name
# urs_metadata_parquet                                Organism classification and taxonomy
# ...                                                                                  ...
# k__Bacteria|p__Verrucomicrobia|c__Verrucomicrob...                            t__SGB9222
# k__Eukaryota|p__Ascomycota|c__Saccharomycetes|o...                            t__EUK4932
# k__Eukaryota|p__Eukaryota_unclassified|c__Eukar...                           t__EUK46681
# k__Eukaryota|p__Eukaryota_unclassified|c__Eukar...                          t__EUK944036
# k__Eukaryota|p__Eukaryota_unclassified|c__Eukar...                            t__EUK5741
#
#                                                    bulk_dictionary  \
# tabular_field_name
# collection_timestamp                                           NaN
# collection_date                                                NaN
# timezone                                                       NaN
# sample_name                                                    NaN
# urs_metadata_parquet                                           NaN
# ...                                                            ...
# k__Bacteria|p__Verrucomicrobia|c__Verrucomicrob...             NaN
# k__Eukaryota|p__Ascomycota|c__Saccharomycetes|o...             NaN
# k__Eukaryota|p__Eukaryota_unclassified|c__Eukar...             NaN
# k__Eukaryota|p__Eukaryota_unclassified|c__Eukar...             NaN
# k__Eukaryota|p__Eukaryota_unclassified|c__Eukar...             NaN
#
#                                                                         relative_location  \
# tabular_field_name
# collection_timestamp                                gut_microbiome/gut_microbiome.parquet
# collection_date                                     gut_microbiome/gut_microbiome.parquet
# timezone                                            gut_microbiome/gut_microbiome.parquet
# sample_name                                         gut_microbiome/gut_microbiome.parquet
# urs_metadata_parquet                                gut_microbiome/gut_microbiome.parquet
# ...                                                                                   ...
# k__Bacteria|p__Verrucomicrobia|c__Verrucomicrob...                                    NaN
# k__Eukaryota|p__Ascomycota|c__Saccharomycetes|o...                                    NaN
# k__Eukaryota|p__Eukaryota_unclassified|c__Eukar...                                    NaN
# k__Eukaryota|p__Eukaryota_unclassified|c__Eukar...                                    NaN
# k__Eukaryota|p__Eukaryota_unclassified|c__Eukar...                                    NaN
#
#                                                     data_coding stability  \
# tabular_field_name
# collection_timestamp                                        NaN  Accruing
# collection_date                                             NaN  Accruing
# timezone                                                    NaN  Accruing
# sample_name                                                 NaN  Accruing
# urs_metadata_parquet                                        NaN  Accruing
# ...                                                         ...       ...
# k__Bacteria|p__Verrucomicrobia|c__Verrucomicrob...          NaN       NaN
# k__Eukaryota|p__Ascomycota|c__Saccharomycetes|o...          NaN       NaN
# k__Eukaryota|p__Eukaryota_unclassified|c__Eukar...          NaN       NaN
# k__Eukaryota|p__Eukaryota_unclassified|c__Eukar...          NaN       NaN
# k__Eukaryota|p__Eukaryota_unclassified|c__Eukar...          NaN       NaN
#
#                                                       units  sampling_rate  \
# tabular_field_name
# collection_timestamp                                   Time            NaN
# collection_date                                        Time            NaN
# timezone                                                NaN            NaN
# sample_name                                             NaN            NaN
# urs_metadata_parquet                                    NaN            NaN
# ...                                                     ...            ...
# k__Bacteria|p__Verrucomicrobia|c__Verrucomicrob...  percent            NaN
# k__Eukaryota|p__Ascomycota|c__Saccharomycetes|o...  percent            NaN
# k__Eukaryota|p__Eukaryota_unclassified|c__Eukar...  percent            NaN
# k__Eukaryota|p__Eukaryota_unclassified|c__Eukar...  percent            NaN
# k__Eukaryota|p__Eukaryota_unclassified|c__Eukar...  percent            NaN
#
#                                                     ...   array debut  \
# tabular_field_name                                  ...
# collection_timestamp                                ...  Single   NaN
# collection_date                                     ...  Single   NaN
# timezone                                            ...  Single   NaN
# sample_name                                         ...  Single   NaN
# urs_metadata_parquet                                ...  Single   NaN
# ...                                                 ...     ...   ...
# k__Bacteria|p__Verrucomicrobia|c__Verrucomicrob...  ...     NaN   NaN
# k__Eukaryota|p__Ascomycota|c__Saccharomycetes|o...  ...     NaN   NaN
# k__Eukaryota|p__Eukaryota_unclassified|c__Eukar...  ...     NaN   NaN
# k__Eukaryota|p__Eukaryota_unclassified|c__Eukar...  ...     NaN   NaN
# k__Eukaryota|p__Eukaryota_unclassified|c__Eukar...  ...     NaN   NaN
#
#                                                    completed transformation  \
# tabular_field_name
# collection_timestamp                                     NaN            NaN
# collection_date                                          NaN            NaN
# timezone                                                 NaN            NaN
# sample_name                                              NaN            NaN
# urs_metadata_parquet                                     NaN            NaN
# ...                                                      ...            ...
# k__Bacteria|p__Verrucomicrobia|c__Verrucomicrob...       NaN            NaN
# k__Eukaryota|p__Ascomycota|c__Saccharomycetes|o...       NaN            NaN
# k__Eukaryota|p__Eukaryota_unclassified|c__Eukar...       NaN            NaN
# k__Eukaryota|p__Eukaryota_unclassified|c__Eukar...       NaN            NaN
# k__Eukaryota|p__Eukaryota_unclassified|c__Eukar...       NaN            NaN
#
#                                                       list_of_tags  \
# tabular_field_name
# collection_timestamp                                Gut Microbiome
# collection_date                                     Gut Microbiome
# timezone                                            Gut Microbiome
# sample_name                                         Gut Microbiome
# urs_metadata_parquet                                Gut Microbiome
# ...                                                            ...
# k__Bacteria|p__Verrucomicrobia|c__Verrucomicrob...             NaN
# k__Eukaryota|p__Ascomycota|c__Saccharomycetes|o...             NaN
# k__Eukaryota|p__Eukaryota_unclassified|c__Eukar...             NaN
# k__Eukaryota|p__Eukaryota_unclassified|c__Eukar...             NaN
# k__Eukaryota|p__Eukaryota_unclassified|c__Eukar...             NaN
#
#                                                                       pandas_dtype  \
# tabular_field_name
# collection_timestamp                                datetime64[ns, Asia/Jerusalem]
# collection_date                                                     datetime64[ns]
# timezone                                                                  category
# sample_name                                                                 string
# urs_metadata_parquet                                                      category
# ...                                                                            ...
# k__Bacteria|p__Verrucomicrobia|c__Verrucomicrob...                         float64
# k__Eukaryota|p__Ascomycota|c__Saccharomycetes|o...                         float64
# k__Eukaryota|p__Eukaryota_unclassified|c__Eukar...                         float64
# k__Eukaryota|p__Eukaryota_unclassified|c__Eukar...                         float64
# k__Eukaryota|p__Eukaryota_unclassified|c__Eukar...                         float64
#
#                                                     min_plausible_value  \
# tabular_field_name
# collection_timestamp                                                NaN
# collection_date                                                     NaN
# timezone                                                            NaN
# sample_name                                                         NaN
# urs_metadata_parquet                                                NaN
# ...                                                                 ...
# k__Bacteria|p__Verrucomicrobia|c__Verrucomicrob...                  NaN
# k__Eukaryota|p__Ascomycota|c__Saccharomycetes|o...                  NaN
# k__Eukaryota|p__Eukaryota_unclassified|c__Eukar...                  NaN
# k__Eukaryota|p__Eukaryota_unclassified|c__Eukar...                  NaN
# k__Eukaryota|p__Eukaryota_unclassified|c__Eukar...                  NaN
#
#                                                     max_plausible_value  \
# tabular_field_name
# collection_timestamp                                                NaN
# collection_date                                                     NaN
# timezone                                                            NaN
# sample_name                                                         NaN
# urs_metadata_parquet                                                NaN
# ...                                                                 ...
# k__Bacteria|p__Verrucomicrobia|c__Verrucomicrob...                  NaN
# k__Eukaryota|p__Ascomycota|c__Saccharomycetes|o...                  NaN
# k__Eukaryota|p__Eukaryota_unclassified|c__Eukar...                  NaN
# k__Eukaryota|p__Eukaryota_unclassified|c__Eukar...                  NaN
# k__Eukaryota|p__Eukaryota_unclassified|c__Eukar...                  NaN
#
#                                                    dependency  \
# tabular_field_name
# collection_timestamp                                      NaN
# collection_date                                           NaN
# timezone                                                  NaN
# sample_name                                               NaN
# urs_metadata_parquet                                      NaN
# ...                                                       ...
# k__Bacteria|p__Verrucomicrobia|c__Verrucomicrob...        NaN
# k__Eukaryota|p__Ascomycota|c__Saccharomycetes|o...        NaN
# k__Eukaryota|p__Eukaryota_unclassified|c__Eukar...        NaN
# k__Eukaryota|p__Eukaryota_unclassified|c__Eukar...        NaN
# k__Eukaryota|p__Eukaryota_unclassified|c__Eukar...        NaN
#
#                                                                       parent_dataframe
# tabular_field_name
# collection_timestamp                                                               NaN
# collection_date                                                                    NaN
# timezone                                                                           NaN
# sample_name                                                                        NaN
# urs_metadata_parquet                                                               NaN
# ...                                                                                ...
# k__Bacteria|p__Verrucomicrobia|c__Verrucomicrob...  metaphlan_abundance_strain_parquet
# k__Eukaryota|p__Ascomycota|c__Saccharomycetes|o...  metaphlan_abundance_strain_parquet
# k__Eukaryota|p__Eukaryota_unclassified|c__Eukar...  metaphlan_abundance_strain_parquet
# k__Eukaryota|p__Eukaryota_unclassified|c__Eukar...  metaphlan_abundance_strain_parquet
# k__Eukaryota|p__Eukaryota_unclassified|c__Eukar...  metaphlan_abundance_strain_parquet
#
# [9929 rows x 24 columns]
