# %% [raw]
# ---
# output-file: 004-liver_ultrasound.html
# title: Liver Ultrasound
# ---

# %% [markdown]
# ### Description
#
# Measures of liver health from a liver ultrasound and 2D shear wave elastography (2D-SWE), including measures of viscosity, elasticity, attenuation, and sound speed.
#
# ### Introduction
#
# Liver ultrasound was performed using the Supersonic Aixplorer MACH 30 (Hologic, USA). The Supersonic Imagine Aixplorer is an ultrasound device that is able to measure the liver's stiffness, viscosity, attenuation and sound speed to diagnose and monitor liver conditions such as steatosis, fibrosis and inflammation. The device uses several ultrasound-based measures, including Speed of Sound (SSp.PLUS), Attenuation Index (Att.PLUS), Viscosity (Vi.PLUS) and Elasticity (Two-Dimensional ShareWave Elastography (2D-SWE)) to evaluate the liver and improve diagnosis performance. These measurements have been shown to be correlated to different stages of liver conditions.
#
# Ultrasound-based liver measurements were performed using ShearWave Elastography (2D- SWE.PLUS) for elasticity assessment, sound speed Plane-wave ultrasound and attenuation. Plane-wave ultrasound was measured for assessment of liver steatosis (fatness) and viscosity plane-wave ultrasound for assessment of viscosity as a marker of inflammation. Measurements were performed with a C6-1X convex transducer using the UltraFast software available on the Mach 30 ultrasound system. US images of the liver were also saved.
#
# ### Measurement protocol
# <!-- long measurment protocol for the data browser -->
# All patients were examined in supine position, with the right arm elevated above the head, by an intercostal approach, in the right liver lobe. Acquisitions were performed during neutral respiratory apnea. Initially the Attenuation and Speed of Sound were measured from a homogeneous area of the liver parenchyma free of vessels or other structures. Measurements were performed from 3 different liver regions. 2D-SWE and viscosity were then measured from 3 different locations in an area of relative uniform elasticity, at a depth of 3–5 cm using stability index tool (SI) derived from the spatial and temporal stiffness stability at a stability index >90%.
#
# ![Liver US example](004-liver_ultrasound/liver_ultrasound_swe_and_vi_image.png)
#
# ### Data availability
# <!-- for the example notebooks -->
# The information is stored in 2 parquet files: `liver_ultrasound.parquet`and `liver_ultrasound_aggregated.parquet`
#
# ### Summary of available data
# <!-- for the data browser -->
# 1. Liver ultrasound image DICOM file
# 2. Liver ultrasound image file
# 3. Derived measures (e.g. viscosity, elasticity, and attenuation)
# 4. Auxiliary data (e.g. stability index)
#
# ### Relevant links
#
# - [Pheno Knowledgebase](https://knowledgebase.pheno.ai/datasets/004-liver_ultrasound.html)
# - [Pheno Data Browser](https://pheno-demo-app.vercel.app/folder/4)

# %%
#| echo: false
import pandas as pd
pd.set_option("display.max_rows", 500)

# %%
from pheno_utils import PhenoLoader

# %%
pl = PhenoLoader('liver_ultrasound')
pl
# Out:
# PhenoLoader for liver_ultrasound with
# 58 fields
# 3 tables: ['liver_ultrasound', 'liver_ultrasound_aggregated', 'age_sex']

# %% [markdown]
# # Data dictionary

# %%
pl.dict
# Out:
#                                                                                     field_string  \
# tabular_field_name
# timezone                                                                                Timezone
# collection_date                                                     Collection date (YYYY-MM-DD)
# collection_timestamp                                                        Collection timestamp
# liver_ultrasound_qbox_depth                                          Liver ultrasound qbox depth
# liver_ultrasound_qbox_diameter                                    Liver ultrasound qbox diameter
# liver_ultrasound_stability_index                                Liver ultrasound stability index
# elasticity_qbox_minimum                                                Elasticity (qbox minimum)
# elasticity_qbox_maximum                                                Elasticity (qbox maximum)
# elasticity_qbox_median                                                  Elasticity (qbox median)
# elasticity_qbox_standard_deviation                          Elasticity (qbox standard deviation)
# elasticity_qbox_mean                                                      Elasticity (qbox mean)
# velocity_qbox_minimum                                                    Velocity (qbox minimum)
# velocity_qbox_maximum                                                    Velocity (qbox maximum)
# velocity_qbox_median                                                      Velocity (qbox median)
# velocity_qbox_standard_deviation                              Velocity (qbox standard deviation)
# velocity_qbox_mean                                                          Velocity (qbox mean)
# viscosity_qbox_median                                                    Viscosity (qbox median)
# viscosity_qbox_standard_deviation                            Viscosity (qbox standard deviation)
# viscosity_qbox_mean                                                        Viscosity (qbox mean)
# dispersion_qbox_median                                                  Dispersion (qbox median)
# dispersion_qbox_standard_deviation                          Dispersion (qbox standard deviation)
# dispersion_qbox_mean                                                      Dispersion (qbox mean)
# attenuation_coefficient_qbox                                      Attenuation coefficient (qbox)
# speed_of_sound_qbox                                                        Speed of sound (qbox)
# elasticity_mean_minimum_of_qboxes                            Elasticity (mean minimum of qboxes)
# elasticity_mean_maximum_of_qboxes                            Elasticity (mean maximum of qboxes)
# elasticity_mean_median_of_qboxes                              Elasticity (mean median of qboxes)
# elasticity_mean_standard_deviation_of_qboxes      Elasticity (mean standard deviation of qboxes)
# elasticity_mean_mean_of_qboxes                                  Elasticity (mean mean of qboxes)
# elasticity_median_minimum_of_qboxes                        Elasticity (median minimum of qboxes)
# elasticity_median_maximum_of_qboxes                        Elasticity (median maximum of qboxes)
# elasticity_median_median_of_qboxes                          Elasticity (median median of qboxes)
# elasticity_median_standard_deviation_of_qboxes  Elasticity (median standard deviation of qboxes)
# elasticity_median_mean_of_qboxes                              Elasticity (median mean of qboxes)
# velocity_mean_minimum_of_qboxes                                Velocity (mean minimum of qboxes)
# velocity_mean_maximum_of_qboxes                                Velocity (mean maximum of qboxes)
# velocity_mean_median_of_qboxes                                  Velocity (mean median of qboxes)
# velocity_mean_standard_deviation_of_qboxes          Velocity (mean standard deviation of qboxes)
# velocity_mean_mean_of_qboxes                                      Velocity (mean mean of qboxes)
# velocity_median_minimum_of_qboxes                            Velocity (median minimum of qboxes)
# velocity_median_maximum_of_qboxes                            Velocity (median maximum of qboxes)
# velocity_median_median_of_qboxes                              Velocity (median median of qboxes)
# velocity_median_standard_deviation_of_qboxes      Velocity (median standard deviation of qboxes)
# velocity_median_mean_of_qboxes                                  Velocity (median mean of qboxes)
# viscosity_mean_median_of_qboxes                                Viscosity (mean median of qboxes)
# viscosity_mean_standard_deviation_of_qboxes        Viscosity (mean standard deviation of qboxes)
# viscosity_mean_mean_of_qboxes                                    Viscosity (mean mean of qboxes)
# viscosity_median_median_of_qboxes                            Viscosity (median median of qboxes)
# viscosity_median_standard_deviation_of_qboxes    Viscosity (median standard deviation of qboxes)
# viscosity_median_mean_of_median                                Viscosity (median mean of median)
# dispersion_mean_median_of_qboxes                              Dispersion (mean median of qboxes)
# dispersion_mean_standard_deviation_of_qboxes      Dispersion (mean standard deviation of qboxes)
# dispersion_mean_mean_of_qboxes                                  Dispersion (mean mean of qboxes)
# dispersion_median_median_of_qboxes                          Dispersion (median median of qboxes)
# dispersion_median_standard_deviation_of_qboxes  Dispersion (median standard deviation of qboxes)
# dispersion_median_mean_of_median                              Dispersion (median mean of median)
#
#                                                                                description_string  \
# tabular_field_name
# timezone                                                                                 Timezone
# collection_date                                                      Collection date (YYYY-MM-DD)
# collection_timestamp                                                         Collection timestamp
# liver_ultrasound_qbox_depth                     Liver ultrasound ShearWave Elastography (SWE) ...
# liver_ultrasound_qbox_diameter                                Liver ultrasound SWE Q-Box diameter
# liver_ultrasound_stability_index                Liver ultrasound stability index tool (SI) for...
# elasticity_qbox_minimum                         Elasticity, minimum value measured within the ...
# elasticity_qbox_maximum                         Elasticity, maximum value measured within the ...
# elasticity_qbox_median                          Elasticity, median of the values measured with...
# elasticity_qbox_standard_deviation              Elasticity, standard deviation of values measu...
# elasticity_qbox_mean                            Elasticity, mean of the values measured within...
# velocity_qbox_minimum                           Velocity of the shear wave, minimum value meas...
# velocity_qbox_maximum                           Velocity of the shear wave, maximum value meas...
# velocity_qbox_median                            Velocity of the shear wave, median of the valu...
# velocity_qbox_standard_deviation                Velocity of the shear wave, standard deviation...
# velocity_qbox_mean                              Velocity of the shear wave, mean of the values...
# viscosity_qbox_median                           Viscosity, median of the values measured withi...
# viscosity_qbox_standard_deviation               Viscosity, standard deviation of values measur...
# viscosity_qbox_mean                             Viscosity, mean of the values measured within ...
# dispersion_qbox_median                          Shear wave dispersion median of the values mea...
# dispersion_qbox_standard_deviation              Shear wave dispersion standard deviation of th...
# dispersion_qbox_mean                            Shear wave dispersion mean of the values measu...
# attenuation_coefficient_qbox                    Attenuation Plane-Wave Ultrasound (Att.P) coef...
# speed_of_sound_qbox                                  Sound Speed Plane-Wave Ultrasound (SSp.PLUS)
# elasticity_mean_minimum_of_qboxes                             Elasticity (mean minimum of qboxes)
# elasticity_mean_maximum_of_qboxes                             Elasticity (mean maximum of qboxes)
# elasticity_mean_median_of_qboxes                               Elasticity (mean median of qboxes)
# elasticity_mean_standard_deviation_of_qboxes       Elasticity (mean standard deviation of qboxes)
# elasticity_mean_mean_of_qboxes                                   Elasticity (mean mean of qboxes)
# elasticity_median_minimum_of_qboxes                         Elasticity (median minimum of qboxes)
# elasticity_median_maximum_of_qboxes                         Elasticity (median maximum of qboxes)
# elasticity_median_median_of_qboxes                           Elasticity (median median of qboxes)
# elasticity_median_standard_deviation_of_qboxes   Elasticity (median standard deviation of qboxes)
# elasticity_median_mean_of_qboxes                               Elasticity (median mean of qboxes)
# velocity_mean_minimum_of_qboxes                                 Velocity (mean minimum of qboxes)
# velocity_mean_maximum_of_qboxes                                 Velocity (mean maximum of qboxes)
# velocity_mean_median_of_qboxes                                   Velocity (mean median of qboxes)
# velocity_mean_standard_deviation_of_qboxes           Velocity (mean standard deviation of qboxes)
# velocity_mean_mean_of_qboxes                                       Velocity (mean mean of qboxes)
# velocity_median_minimum_of_qboxes                             Velocity (median minimum of qboxes)
# velocity_median_maximum_of_qboxes                             Velocity (median maximum of qboxes)
# velocity_median_median_of_qboxes                               Velocity (median median of qboxes)
# velocity_median_standard_deviation_of_qboxes       Velocity (median standard deviation of qboxes)
# velocity_median_mean_of_qboxes                                   Velocity (median mean of qboxes)
# viscosity_mean_median_of_qboxes                                 Viscosity (mean median of qboxes)
# viscosity_mean_standard_deviation_of_qboxes         Viscosity (mean standard deviation of qboxes)
# viscosity_mean_mean_of_qboxes                                     Viscosity (mean mean of qboxes)
# viscosity_median_median_of_qboxes                             Viscosity (median median of qboxes)
# viscosity_median_standard_deviation_of_qboxes     Viscosity (median standard deviation of qboxes)
# viscosity_median_mean_of_median                                 Viscosity (median mean of median)
# dispersion_mean_median_of_qboxes                               Dispersion (mean median of qboxes)
# dispersion_mean_standard_deviation_of_qboxes       Dispersion (mean standard deviation of qboxes)
# dispersion_mean_mean_of_qboxes                                   Dispersion (mean mean of qboxes)
# dispersion_median_median_of_qboxes                           Dispersion (median median of qboxes)
# dispersion_median_standard_deviation_of_qboxes   Dispersion (median standard deviation of qboxes)
# dispersion_median_mean_of_median                               Dispersion (median mean of median)
#
#                                                 folder_id  \
# tabular_field_name
# timezone                                                4
# collection_date                                         4
# collection_timestamp                                    4
# liver_ultrasound_qbox_depth                             4
# liver_ultrasound_qbox_diameter                          4
# liver_ultrasound_stability_index                        4
# elasticity_qbox_minimum                                 4
# elasticity_qbox_maximum                                 4
# elasticity_qbox_median                                  4
# elasticity_qbox_standard_deviation                      4
# elasticity_qbox_mean                                    4
# velocity_qbox_minimum                                   4
# velocity_qbox_maximum                                   4
# velocity_qbox_median                                    4
# velocity_qbox_standard_deviation                        4
# velocity_qbox_mean                                      4
# viscosity_qbox_median                                   4
# viscosity_qbox_standard_deviation                       4
# viscosity_qbox_mean                                     4
# dispersion_qbox_median                                  4
# dispersion_qbox_standard_deviation                      4
# dispersion_qbox_mean                                    4
# attenuation_coefficient_qbox                            4
# speed_of_sound_qbox                                     4
# elasticity_mean_minimum_of_qboxes                       4
# elasticity_mean_maximum_of_qboxes                       4
# elasticity_mean_median_of_qboxes                        4
# elasticity_mean_standard_deviation_of_qboxes            4
# elasticity_mean_mean_of_qboxes                          4
# elasticity_median_minimum_of_qboxes                     4
# elasticity_median_maximum_of_qboxes                     4
# elasticity_median_median_of_qboxes                      4
# elasticity_median_standard_deviation_of_qboxes          4
# elasticity_median_mean_of_qboxes                        4
# velocity_mean_minimum_of_qboxes                         4
# velocity_mean_maximum_of_qboxes                         4
# velocity_mean_median_of_qboxes                          4
# velocity_mean_standard_deviation_of_qboxes              4
# velocity_mean_mean_of_qboxes                            4
# velocity_median_minimum_of_qboxes                       4
# velocity_median_maximum_of_qboxes                       4
# velocity_median_median_of_qboxes                        4
# velocity_median_standard_deviation_of_qboxes            4
# velocity_median_mean_of_qboxes                          4
# viscosity_mean_median_of_qboxes                         4
# viscosity_mean_standard_deviation_of_qboxes             4
# viscosity_mean_mean_of_qboxes                           4
# viscosity_median_median_of_qboxes                       4
# viscosity_median_standard_deviation_of_qboxes           4
# viscosity_median_mean_of_median                         4
# dispersion_mean_median_of_qboxes                        4
# dispersion_mean_standard_deviation_of_qboxes            4
# dispersion_mean_mean_of_qboxes                          4
# dispersion_median_median_of_qboxes                      4
# dispersion_median_standard_deviation_of_qboxes          4
# dispersion_median_mean_of_median                        4
#
#                                                                 feature_set  \
# tabular_field_name
# timezone                                                   liver_ultrasound
# collection_date                                            liver_ultrasound
# collection_timestamp                                       liver_ultrasound
# liver_ultrasound_qbox_depth                                liver_ultrasound
# liver_ultrasound_qbox_diameter                             liver_ultrasound
# liver_ultrasound_stability_index                           liver_ultrasound
# elasticity_qbox_minimum                                    liver_ultrasound
# elasticity_qbox_maximum                                    liver_ultrasound
# elasticity_qbox_median                                     liver_ultrasound
# elasticity_qbox_standard_deviation                         liver_ultrasound
# elasticity_qbox_mean                                       liver_ultrasound
# velocity_qbox_minimum                                      liver_ultrasound
# velocity_qbox_maximum                                      liver_ultrasound
# velocity_qbox_median                                       liver_ultrasound
# velocity_qbox_standard_deviation                           liver_ultrasound
# velocity_qbox_mean                                         liver_ultrasound
# viscosity_qbox_median                                      liver_ultrasound
# viscosity_qbox_standard_deviation                          liver_ultrasound
# viscosity_qbox_mean                                        liver_ultrasound
# dispersion_qbox_median                                     liver_ultrasound
# dispersion_qbox_standard_deviation                         liver_ultrasound
# dispersion_qbox_mean                                       liver_ultrasound
# attenuation_coefficient_qbox                               liver_ultrasound
# speed_of_sound_qbox                                        liver_ultrasound
# elasticity_mean_minimum_of_qboxes               liver_ultrasound_aggregated
# elasticity_mean_maximum_of_qboxes               liver_ultrasound_aggregated
# elasticity_mean_median_of_qboxes                liver_ultrasound_aggregated
# elasticity_mean_standard_deviation_of_qboxes    liver_ultrasound_aggregated
# elasticity_mean_mean_of_qboxes                  liver_ultrasound_aggregated
# elasticity_median_minimum_of_qboxes             liver_ultrasound_aggregated
# elasticity_median_maximum_of_qboxes             liver_ultrasound_aggregated
# elasticity_median_median_of_qboxes              liver_ultrasound_aggregated
# elasticity_median_standard_deviation_of_qboxes  liver_ultrasound_aggregated
# elasticity_median_mean_of_qboxes                liver_ultrasound_aggregated
# velocity_mean_minimum_of_qboxes                 liver_ultrasound_aggregated
# velocity_mean_maximum_of_qboxes                 liver_ultrasound_aggregated
# velocity_mean_median_of_qboxes                  liver_ultrasound_aggregated
# velocity_mean_standard_deviation_of_qboxes      liver_ultrasound_aggregated
# velocity_mean_mean_of_qboxes                    liver_ultrasound_aggregated
# velocity_median_minimum_of_qboxes               liver_ultrasound_aggregated
# velocity_median_maximum_of_qboxes               liver_ultrasound_aggregated
# velocity_median_median_of_qboxes                liver_ultrasound_aggregated
# velocity_median_standard_deviation_of_qboxes    liver_ultrasound_aggregated
# velocity_median_mean_of_qboxes                  liver_ultrasound_aggregated
# viscosity_mean_median_of_qboxes                 liver_ultrasound_aggregated
# viscosity_mean_standard_deviation_of_qboxes     liver_ultrasound_aggregated
# viscosity_mean_mean_of_qboxes                   liver_ultrasound_aggregated
# viscosity_median_median_of_qboxes               liver_ultrasound_aggregated
# viscosity_median_standard_deviation_of_qboxes   liver_ultrasound_aggregated
# viscosity_median_mean_of_median                 liver_ultrasound_aggregated
# dispersion_mean_median_of_qboxes                liver_ultrasound_aggregated
# dispersion_mean_standard_deviation_of_qboxes    liver_ultrasound_aggregated
# dispersion_mean_mean_of_qboxes                  liver_ultrasound_aggregated
# dispersion_median_median_of_qboxes              liver_ultrasound_aggregated
# dispersion_median_standard_deviation_of_qboxes  liver_ultrasound_aggregated
# dispersion_median_mean_of_median                liver_ultrasound_aggregated
#
#                                                           field_type  \
# tabular_field_name
# timezone                                        Categorical (single)
# collection_date                                                 Date
# collection_timestamp                                        Datetime
# liver_ultrasound_qbox_depth                               Continuous
# liver_ultrasound_qbox_diameter                            Continuous
# liver_ultrasound_stability_index                          Continuous
# elasticity_qbox_minimum                                   Continuous
# elasticity_qbox_maximum                                   Continuous
# elasticity_qbox_median                                    Continuous
# elasticity_qbox_standard_deviation                        Continuous
# elasticity_qbox_mean                                      Continuous
# velocity_qbox_minimum                                     Continuous
# velocity_qbox_maximum                                     Continuous
# velocity_qbox_median                                      Continuous
# velocity_qbox_standard_deviation                          Continuous
# velocity_qbox_mean                                        Continuous
# viscosity_qbox_median                                     Continuous
# viscosity_qbox_standard_deviation                         Continuous
# viscosity_qbox_mean                                       Continuous
# dispersion_qbox_median                                    Continuous
# dispersion_qbox_standard_deviation                        Continuous
# dispersion_qbox_mean                                      Continuous
# attenuation_coefficient_qbox                              Continuous
# speed_of_sound_qbox                                       Continuous
# elasticity_mean_minimum_of_qboxes                         Continuous
# elasticity_mean_maximum_of_qboxes                         Continuous
# elasticity_mean_median_of_qboxes                          Continuous
# elasticity_mean_standard_deviation_of_qboxes              Continuous
# elasticity_mean_mean_of_qboxes                            Continuous
# elasticity_median_minimum_of_qboxes                       Continuous
# elasticity_median_maximum_of_qboxes                       Continuous
# elasticity_median_median_of_qboxes                        Continuous
# elasticity_median_standard_deviation_of_qboxes            Continuous
# elasticity_median_mean_of_qboxes                          Continuous
# velocity_mean_minimum_of_qboxes                           Continuous
# velocity_mean_maximum_of_qboxes                           Continuous
# velocity_mean_median_of_qboxes                            Continuous
# velocity_mean_standard_deviation_of_qboxes                Continuous
# velocity_mean_mean_of_qboxes                              Continuous
# velocity_median_minimum_of_qboxes                         Continuous
# velocity_median_maximum_of_qboxes                         Continuous
# velocity_median_median_of_qboxes                          Continuous
# velocity_median_standard_deviation_of_qboxes              Continuous
# velocity_median_mean_of_qboxes                            Continuous
# viscosity_mean_median_of_qboxes                           Continuous
# viscosity_mean_standard_deviation_of_qboxes               Continuous
# viscosity_mean_mean_of_qboxes                             Continuous
# viscosity_median_median_of_qboxes                         Continuous
# viscosity_median_standard_deviation_of_qboxes             Continuous
# viscosity_median_mean_of_median                           Continuous
# dispersion_mean_median_of_qboxes                          Continuous
# dispersion_mean_standard_deviation_of_qboxes              Continuous
# dispersion_mean_mean_of_qboxes                            Continuous
# dispersion_median_median_of_qboxes                        Continuous
# dispersion_median_standard_deviation_of_qboxes            Continuous
# dispersion_median_mean_of_median                          Continuous
#
#                                                          strata data_coding  \
# tabular_field_name
# timezone                                        Collection time      001_03
# collection_date                                 Collection time         NaN
# collection_timestamp                            Collection time         NaN
# liver_ultrasound_qbox_depth                           Auxiliary         NaN
# liver_ultrasound_qbox_diameter                        Auxiliary         NaN
# liver_ultrasound_stability_index                      Auxiliary         NaN
# elasticity_qbox_minimum                                 Primary         NaN
# elasticity_qbox_maximum                                 Primary         NaN
# elasticity_qbox_median                                  Primary         NaN
# elasticity_qbox_standard_deviation                      Primary         NaN
# elasticity_qbox_mean                                    Primary         NaN
# velocity_qbox_minimum                                   Primary         NaN
# velocity_qbox_maximum                                   Primary         NaN
# velocity_qbox_median                                    Primary         NaN
# velocity_qbox_standard_deviation                        Primary         NaN
# velocity_qbox_mean                                      Primary         NaN
# viscosity_qbox_median                                   Primary         NaN
# viscosity_qbox_standard_deviation                       Primary         NaN
# viscosity_qbox_mean                                     Primary         NaN
# dispersion_qbox_median                                  Primary         NaN
# dispersion_qbox_standard_deviation                      Primary         NaN
# dispersion_qbox_mean                                    Primary         NaN
# attenuation_coefficient_qbox                            Primary         NaN
# speed_of_sound_qbox                                     Primary         NaN
# elasticity_mean_minimum_of_qboxes                       Primary         NaN
# elasticity_mean_maximum_of_qboxes                       Primary         NaN
# elasticity_mean_median_of_qboxes                        Primary         NaN
# elasticity_mean_standard_deviation_of_qboxes            Primary         NaN
# elasticity_mean_mean_of_qboxes                          Primary         NaN
# elasticity_median_minimum_of_qboxes                     Primary         NaN
# elasticity_median_maximum_of_qboxes                     Primary         NaN
# elasticity_median_median_of_qboxes                      Primary         NaN
# elasticity_median_standard_deviation_of_qboxes          Primary         NaN
# elasticity_median_mean_of_qboxes                        Primary         NaN
# velocity_mean_minimum_of_qboxes                         Primary         NaN
# velocity_mean_maximum_of_qboxes                         Primary         NaN
# velocity_mean_median_of_qboxes                          Primary         NaN
# velocity_mean_standard_deviation_of_qboxes              Primary         NaN
# velocity_mean_mean_of_qboxes                            Primary         NaN
# velocity_median_minimum_of_qboxes                       Primary         NaN
# velocity_median_maximum_of_qboxes                       Primary         NaN
# velocity_median_median_of_qboxes                        Primary         NaN
# velocity_median_standard_deviation_of_qboxes            Primary         NaN
# velocity_median_mean_of_qboxes                          Primary         NaN
# viscosity_mean_median_of_qboxes                         Primary         NaN
# viscosity_mean_standard_deviation_of_qboxes             Primary         NaN
# viscosity_mean_mean_of_qboxes                           Primary         NaN
# viscosity_median_median_of_qboxes                       Primary         NaN
# viscosity_median_standard_deviation_of_qboxes           Primary         NaN
# viscosity_median_mean_of_median                         Primary         NaN
# dispersion_mean_median_of_qboxes                        Primary         NaN
# dispersion_mean_standard_deviation_of_qboxes            Primary         NaN
# dispersion_mean_mean_of_qboxes                          Primary         NaN
# dispersion_median_median_of_qboxes                      Primary         NaN
# dispersion_median_standard_deviation_of_qboxes          Primary         NaN
# dispersion_median_mean_of_median                        Primary         NaN
#
#                                                    array  \
# tabular_field_name
# timezone                                        Multiple
# collection_date                                 Multiple
# collection_timestamp                            Multiple
# liver_ultrasound_qbox_depth                     Multiple
# liver_ultrasound_qbox_diameter                  Multiple
# liver_ultrasound_stability_index                Multiple
# elasticity_qbox_minimum                         Multiple
# elasticity_qbox_maximum                         Multiple
# elasticity_qbox_median                          Multiple
# elasticity_qbox_standard_deviation              Multiple
# elasticity_qbox_mean                            Multiple
# velocity_qbox_minimum                           Multiple
# velocity_qbox_maximum                           Multiple
# velocity_qbox_median                            Multiple
# velocity_qbox_standard_deviation                Multiple
# velocity_qbox_mean                              Multiple
# viscosity_qbox_median                           Multiple
# viscosity_qbox_standard_deviation               Multiple
# viscosity_qbox_mean                             Multiple
# dispersion_qbox_median                          Multiple
# dispersion_qbox_standard_deviation              Multiple
# dispersion_qbox_mean                            Multiple
# attenuation_coefficient_qbox                    Multiple
# speed_of_sound_qbox                             Multiple
# elasticity_mean_minimum_of_qboxes               Multiple
# elasticity_mean_maximum_of_qboxes               Multiple
# elasticity_mean_median_of_qboxes                Multiple
# elasticity_mean_standard_deviation_of_qboxes    Multiple
# elasticity_mean_mean_of_qboxes                  Multiple
# elasticity_median_minimum_of_qboxes             Multiple
# elasticity_median_maximum_of_qboxes             Multiple
# elasticity_median_median_of_qboxes              Multiple
# elasticity_median_standard_deviation_of_qboxes  Multiple
# elasticity_median_mean_of_qboxes                Multiple
# velocity_mean_minimum_of_qboxes                 Multiple
# velocity_mean_maximum_of_qboxes                 Multiple
# velocity_mean_median_of_qboxes                  Multiple
# velocity_mean_standard_deviation_of_qboxes      Multiple
# velocity_mean_mean_of_qboxes                    Multiple
# velocity_median_minimum_of_qboxes               Multiple
# velocity_median_maximum_of_qboxes               Multiple
# velocity_median_median_of_qboxes                Multiple
# velocity_median_standard_deviation_of_qboxes    Multiple
# velocity_median_mean_of_qboxes                  Multiple
# viscosity_mean_median_of_qboxes                 Multiple
# viscosity_mean_standard_deviation_of_qboxes     Multiple
# viscosity_mean_mean_of_qboxes                   Multiple
# viscosity_median_median_of_qboxes               Multiple
# viscosity_median_standard_deviation_of_qboxes   Multiple
# viscosity_median_mean_of_median                 Multiple
# dispersion_mean_median_of_qboxes                Multiple
# dispersion_mean_standard_deviation_of_qboxes    Multiple
# dispersion_mean_mean_of_qboxes                  Multiple
# dispersion_median_median_of_qboxes              Multiple
# dispersion_median_standard_deviation_of_qboxes  Multiple
# dispersion_median_mean_of_median                Multiple
#
#                                                                   pandas_dtype  \
# tabular_field_name
# timezone                                                              category
# collection_date                                                 datetime64[ns]
# collection_timestamp                            datetime64[ns, Asia/Jerusalem]
# liver_ultrasound_qbox_depth                                              float
# liver_ultrasound_qbox_diameter                                           float
# liver_ultrasound_stability_index                                         float
# elasticity_qbox_minimum                                                  float
# elasticity_qbox_maximum                                                  float
# elasticity_qbox_median                                                   float
# elasticity_qbox_standard_deviation                                       float
# elasticity_qbox_mean                                                     float
# velocity_qbox_minimum                                                    float
# velocity_qbox_maximum                                                    float
# velocity_qbox_median                                                     float
# velocity_qbox_standard_deviation                                         float
# velocity_qbox_mean                                                       float
# viscosity_qbox_median                                                    float
# viscosity_qbox_standard_deviation                                        float
# viscosity_qbox_mean                                                      float
# dispersion_qbox_median                                                   float
# dispersion_qbox_standard_deviation                                       float
# dispersion_qbox_mean                                                     float
# attenuation_coefficient_qbox                                             float
# speed_of_sound_qbox                                                      float
# elasticity_mean_minimum_of_qboxes                                        float
# elasticity_mean_maximum_of_qboxes                                        float
# elasticity_mean_median_of_qboxes                                         float
# elasticity_mean_standard_deviation_of_qboxes                             float
# elasticity_mean_mean_of_qboxes                                           float
# elasticity_median_minimum_of_qboxes                                      float
# elasticity_median_maximum_of_qboxes                                      float
# elasticity_median_median_of_qboxes                                       float
# elasticity_median_standard_deviation_of_qboxes                           float
# elasticity_median_mean_of_qboxes                                         float
# velocity_mean_minimum_of_qboxes                                          float
# velocity_mean_maximum_of_qboxes                                          float
# velocity_mean_median_of_qboxes                                           float
# velocity_mean_standard_deviation_of_qboxes                               float
# velocity_mean_mean_of_qboxes                                             float
# velocity_median_minimum_of_qboxes                                        float
# velocity_median_maximum_of_qboxes                                        float
# velocity_median_median_of_qboxes                                         float
# velocity_median_standard_deviation_of_qboxes                             float
# velocity_median_mean_of_qboxes                                           float
# viscosity_mean_median_of_qboxes                                          float
# viscosity_mean_standard_deviation_of_qboxes                              float
# viscosity_mean_mean_of_qboxes                                            float
# viscosity_median_median_of_qboxes                                        float
# viscosity_median_standard_deviation_of_qboxes                            float
# viscosity_median_mean_of_median                                          float
# dispersion_mean_median_of_qboxes                                         float
# dispersion_mean_standard_deviation_of_qboxes                             float
# dispersion_mean_mean_of_qboxes                                           float
# dispersion_median_median_of_qboxes                                       float
# dispersion_median_standard_deviation_of_qboxes                           float
# dispersion_median_mean_of_median                                         float
#
#                                                 bulk_file_extension  \
# tabular_field_name
# timezone                                                        NaN
# collection_date                                                 NaN
# collection_timestamp                                            NaN
# liver_ultrasound_qbox_depth                                     NaN
# liver_ultrasound_qbox_diameter                                  NaN
# liver_ultrasound_stability_index                                NaN
# elasticity_qbox_minimum                                         NaN
# elasticity_qbox_maximum                                         NaN
# elasticity_qbox_median                                          NaN
# elasticity_qbox_standard_deviation                              NaN
# elasticity_qbox_mean                                            NaN
# velocity_qbox_minimum                                           NaN
# velocity_qbox_maximum                                           NaN
# velocity_qbox_median                                            NaN
# velocity_qbox_standard_deviation                                NaN
# velocity_qbox_mean                                              NaN
# viscosity_qbox_median                                           NaN
# viscosity_qbox_standard_deviation                               NaN
# viscosity_qbox_mean                                             NaN
# dispersion_qbox_median                                          NaN
# dispersion_qbox_standard_deviation                              NaN
# dispersion_qbox_mean                                            NaN
# attenuation_coefficient_qbox                                    NaN
# speed_of_sound_qbox                                             NaN
# elasticity_mean_minimum_of_qboxes                               NaN
# elasticity_mean_maximum_of_qboxes                               NaN
# elasticity_mean_median_of_qboxes                                NaN
# elasticity_mean_standard_deviation_of_qboxes                    NaN
# elasticity_mean_mean_of_qboxes                                  NaN
# elasticity_median_minimum_of_qboxes                             NaN
# elasticity_median_maximum_of_qboxes                             NaN
# elasticity_median_median_of_qboxes                              NaN
# elasticity_median_standard_deviation_of_qboxes                  NaN
# elasticity_median_mean_of_qboxes                                NaN
# velocity_mean_minimum_of_qboxes                                 NaN
# velocity_mean_maximum_of_qboxes                                 NaN
# velocity_mean_median_of_qboxes                                  NaN
# velocity_mean_standard_deviation_of_qboxes                      NaN
# velocity_mean_mean_of_qboxes                                    NaN
# velocity_median_minimum_of_qboxes                               NaN
# velocity_median_maximum_of_qboxes                               NaN
# velocity_median_median_of_qboxes                                NaN
# velocity_median_standard_deviation_of_qboxes                    NaN
# velocity_median_mean_of_qboxes                                  NaN
# viscosity_mean_median_of_qboxes                                 NaN
# viscosity_mean_standard_deviation_of_qboxes                     NaN
# viscosity_mean_mean_of_qboxes                                   NaN
# viscosity_median_median_of_qboxes                               NaN
# viscosity_median_standard_deviation_of_qboxes                   NaN
# viscosity_median_mean_of_median                                 NaN
# dispersion_mean_median_of_qboxes                                NaN
# dispersion_mean_standard_deviation_of_qboxes                    NaN
# dispersion_mean_mean_of_qboxes                                  NaN
# dispersion_median_median_of_qboxes                              NaN
# dispersion_median_standard_deviation_of_qboxes                  NaN
# dispersion_median_mean_of_median                                NaN
#
#                                                                                 relative_location  \
# tabular_field_name
# timezone                                                liver_ultrasound/liver_ultrasound.parquet
# collection_date                                         liver_ultrasound/liver_ultrasound.parquet
# collection_timestamp                                    liver_ultrasound/liver_ultrasound.parquet
# liver_ultrasound_qbox_depth                             liver_ultrasound/liver_ultrasound.parquet
# liver_ultrasound_qbox_diameter                          liver_ultrasound/liver_ultrasound.parquet
# liver_ultrasound_stability_index                        liver_ultrasound/liver_ultrasound.parquet
# elasticity_qbox_minimum                                 liver_ultrasound/liver_ultrasound.parquet
# elasticity_qbox_maximum                                 liver_ultrasound/liver_ultrasound.parquet
# elasticity_qbox_median                                  liver_ultrasound/liver_ultrasound.parquet
# elasticity_qbox_standard_deviation                      liver_ultrasound/liver_ultrasound.parquet
# elasticity_qbox_mean                                    liver_ultrasound/liver_ultrasound.parquet
# velocity_qbox_minimum                                   liver_ultrasound/liver_ultrasound.parquet
# velocity_qbox_maximum                                   liver_ultrasound/liver_ultrasound.parquet
# velocity_qbox_median                                    liver_ultrasound/liver_ultrasound.parquet
# velocity_qbox_standard_deviation                        liver_ultrasound/liver_ultrasound.parquet
# velocity_qbox_mean                                      liver_ultrasound/liver_ultrasound.parquet
# viscosity_qbox_median                                   liver_ultrasound/liver_ultrasound.parquet
# viscosity_qbox_standard_deviation                       liver_ultrasound/liver_ultrasound.parquet
# viscosity_qbox_mean                                     liver_ultrasound/liver_ultrasound.parquet
# dispersion_qbox_median                                  liver_ultrasound/liver_ultrasound.parquet
# dispersion_qbox_standard_deviation                      liver_ultrasound/liver_ultrasound.parquet
# dispersion_qbox_mean                                    liver_ultrasound/liver_ultrasound.parquet
# attenuation_coefficient_qbox                            liver_ultrasound/liver_ultrasound.parquet
# speed_of_sound_qbox                                     liver_ultrasound/liver_ultrasound.parquet
# elasticity_mean_minimum_of_qboxes               liver_ultrasound/liver_ultrasound_aggregated.p...
# elasticity_mean_maximum_of_qboxes               liver_ultrasound/liver_ultrasound_aggregated.p...
# elasticity_mean_median_of_qboxes                liver_ultrasound/liver_ultrasound_aggregated.p...
# elasticity_mean_standard_deviation_of_qboxes    liver_ultrasound/liver_ultrasound_aggregated.p...
# elasticity_mean_mean_of_qboxes                  liver_ultrasound/liver_ultrasound_aggregated.p...
# elasticity_median_minimum_of_qboxes             liver_ultrasound/liver_ultrasound_aggregated.p...
# elasticity_median_maximum_of_qboxes             liver_ultrasound/liver_ultrasound_aggregated.p...
# elasticity_median_median_of_qboxes              liver_ultrasound/liver_ultrasound_aggregated.p...
# elasticity_median_standard_deviation_of_qboxes  liver_ultrasound/liver_ultrasound_aggregated.p...
# elasticity_median_mean_of_qboxes                liver_ultrasound/liver_ultrasound_aggregated.p...
# velocity_mean_minimum_of_qboxes                         liver_ultrasound/liver_ultrasound.parquet
# velocity_mean_maximum_of_qboxes                         liver_ultrasound/liver_ultrasound.parquet
# velocity_mean_median_of_qboxes                          liver_ultrasound/liver_ultrasound.parquet
# velocity_mean_standard_deviation_of_qboxes              liver_ultrasound/liver_ultrasound.parquet
# velocity_mean_mean_of_qboxes                            liver_ultrasound/liver_ultrasound.parquet
# velocity_median_minimum_of_qboxes                       liver_ultrasound/liver_ultrasound.parquet
# velocity_median_maximum_of_qboxes                       liver_ultrasound/liver_ultrasound.parquet
# velocity_median_median_of_qboxes                        liver_ultrasound/liver_ultrasound.parquet
# velocity_median_standard_deviation_of_qboxes            liver_ultrasound/liver_ultrasound.parquet
# velocity_median_mean_of_qboxes                          liver_ultrasound/liver_ultrasound.parquet
# viscosity_mean_median_of_qboxes                         liver_ultrasound/liver_ultrasound.parquet
# viscosity_mean_standard_deviation_of_qboxes             liver_ultrasound/liver_ultrasound.parquet
# viscosity_mean_mean_of_qboxes                           liver_ultrasound/liver_ultrasound.parquet
# viscosity_median_median_of_qboxes                       liver_ultrasound/liver_ultrasound.parquet
# viscosity_median_standard_deviation_of_qboxes           liver_ultrasound/liver_ultrasound.parquet
# viscosity_median_mean_of_median                         liver_ultrasound/liver_ultrasound.parquet
# dispersion_mean_median_of_qboxes                        liver_ultrasound/liver_ultrasound.parquet
# dispersion_mean_standard_deviation_of_qboxes            liver_ultrasound/liver_ultrasound.parquet
# dispersion_mean_mean_of_qboxes                          liver_ultrasound/liver_ultrasound.parquet
# dispersion_median_median_of_qboxes                      liver_ultrasound/liver_ultrasound.parquet
# dispersion_median_standard_deviation_of_qboxes          liver_ultrasound/liver_ultrasound.parquet
# dispersion_median_mean_of_median                        liver_ultrasound/liver_ultrasound.parquet
#
#                                                     units  bulk_dictionary  \
# tabular_field_name
# timezone                                              NaN              NaN
# collection_date                                       NaN              NaN
# collection_timestamp                                  NaN              NaN
# liver_ultrasound_qbox_depth                            cm              NaN
# liver_ultrasound_qbox_diameter                         mm              NaN
# liver_ultrasound_stability_index                      NaN              NaN
# elasticity_qbox_minimum                               kPa              NaN
# elasticity_qbox_maximum                               kPa              NaN
# elasticity_qbox_median                                kPa              NaN
# elasticity_qbox_standard_deviation                    kPa              NaN
# elasticity_qbox_mean                                  kPa              NaN
# velocity_qbox_minimum                                 m/s              NaN
# velocity_qbox_maximum                                 m/s              NaN
# ...
# elasticity_qbox_median                                    NaN             NaN
# elasticity_qbox_standard_deviation                        NaN             NaN
# elasticity_qbox_mean                                      NaN             NaN
# velocity_qbox_minimum                                     NaN             NaN
# velocity_qbox_maximum                                     NaN             NaN
# velocity_qbox_median                                      NaN             NaN
# velocity_qbox_standard_deviation                          NaN             NaN
# velocity_qbox_mean                                        NaN             NaN
# viscosity_qbox_median                                     NaN             NaN
# viscosity_qbox_standard_deviation                         NaN             NaN
# viscosity_qbox_mean                                       NaN             NaN
# dispersion_qbox_median                                    NaN             NaN
# dispersion_qbox_standard_deviation                        NaN             NaN
# dispersion_qbox_mean                                      NaN             NaN
# attenuation_coefficient_qbox                              NaN             NaN
# speed_of_sound_qbox                                       NaN             NaN
# elasticity_mean_minimum_of_qboxes                         NaN             NaN
# elasticity_mean_maximum_of_qboxes                         NaN             NaN
# elasticity_mean_median_of_qboxes                          NaN             NaN
# elasticity_mean_standard_deviation_of_qboxes              NaN             NaN
# elasticity_mean_mean_of_qboxes                            NaN             NaN
# elasticity_median_minimum_of_qboxes                       NaN             NaN
# elasticity_median_maximum_of_qboxes                       NaN             NaN
# elasticity_median_median_of_qboxes                        NaN             NaN
# elasticity_median_standard_deviation_of_qboxes            NaN             NaN
# elasticity_median_mean_of_qboxes                          NaN             NaN
# velocity_mean_minimum_of_qboxes                           NaN             NaN
# velocity_mean_maximum_of_qboxes                           NaN             NaN
# velocity_mean_median_of_qboxes                            NaN             NaN
# velocity_mean_standard_deviation_of_qboxes                NaN             NaN
# velocity_mean_mean_of_qboxes                              NaN             NaN
# velocity_median_minimum_of_qboxes                         NaN             NaN
# velocity_median_maximum_of_qboxes                         NaN             NaN
# velocity_median_median_of_qboxes                          NaN             NaN
# velocity_median_standard_deviation_of_qboxes              NaN             NaN
# velocity_median_mean_of_qboxes                            NaN             NaN
# viscosity_mean_median_of_qboxes                           NaN             NaN
# viscosity_mean_standard_deviation_of_qboxes               NaN             NaN
# viscosity_mean_mean_of_qboxes                             NaN             NaN
# viscosity_median_median_of_qboxes                         NaN             NaN
# viscosity_median_standard_deviation_of_qboxes             NaN             NaN
# viscosity_median_mean_of_median                           NaN             NaN
# dispersion_mean_median_of_qboxes                          NaN             NaN
# dispersion_mean_standard_deviation_of_qboxes              NaN             NaN
# dispersion_mean_mean_of_qboxes                            NaN             NaN
# dispersion_median_median_of_qboxes                        NaN             NaN
# dispersion_median_standard_deviation_of_qboxes            NaN             NaN
# dispersion_median_mean_of_median                          NaN             NaN
#
#                                                 list_of_tags stability  \
# tabular_field_name
# timezone                                                 NaN  Accruing
# collection_date                                          NaN  Accruing
# collection_timestamp                                     NaN  Accruing
# liver_ultrasound_qbox_depth                              NaN  Accruing
# liver_ultrasound_qbox_diameter                           NaN  Accruing
# liver_ultrasound_stability_index                         NaN  Accruing
# elasticity_qbox_minimum                                  NaN  Accruing
# elasticity_qbox_maximum                                  NaN  Accruing
# elasticity_qbox_median                                   NaN  Accruing
# elasticity_qbox_standard_deviation                       NaN  Accruing
# elasticity_qbox_mean                                     NaN  Accruing
# velocity_qbox_minimum                                    NaN  Accruing
# velocity_qbox_maximum                                    NaN  Accruing
# velocity_qbox_median                                     NaN  Accruing
# velocity_qbox_standard_deviation                         NaN  Accruing
# velocity_qbox_mean                                       NaN  Accruing
# viscosity_qbox_median                                    NaN  Accruing
# viscosity_qbox_standard_deviation                        NaN  Accruing
# viscosity_qbox_mean                                      NaN  Accruing
# dispersion_qbox_median                                   NaN  Accruing
# dispersion_qbox_standard_deviation                       NaN  Accruing
# dispersion_qbox_mean                                     NaN  Accruing
# attenuation_coefficient_qbox                             NaN  Accruing
# speed_of_sound_qbox                                      NaN  Accruing
# elasticity_mean_minimum_of_qboxes                        NaN  Accruing
# elasticity_mean_maximum_of_qboxes                        NaN  Accruing
# elasticity_mean_median_of_qboxes                         NaN  Accruing
# elasticity_mean_standard_deviation_of_qboxes             NaN  Accruing
# elasticity_mean_mean_of_qboxes                           NaN  Accruing
# elasticity_median_minimum_of_qboxes                      NaN  Accruing
# elasticity_median_maximum_of_qboxes                      NaN  Accruing
# elasticity_median_median_of_qboxes                       NaN  Accruing
# elasticity_median_standard_deviation_of_qboxes           NaN  Accruing
# elasticity_median_mean_of_qboxes                         NaN  Accruing
# velocity_mean_minimum_of_qboxes                          NaN  Accruing
# velocity_mean_maximum_of_qboxes                          NaN  Accruing
# velocity_mean_median_of_qboxes                           NaN  Accruing
# velocity_mean_standard_deviation_of_qboxes               NaN  Accruing
# velocity_mean_mean_of_qboxes                             NaN  Accruing
# velocity_median_minimum_of_qboxes                        NaN  Accruing
# velocity_median_maximum_of_qboxes                        NaN  Accruing
# velocity_median_median_of_qboxes                         NaN  Accruing
# velocity_median_standard_deviation_of_qboxes             NaN  Accruing
# velocity_median_mean_of_qboxes                           NaN  Accruing
# viscosity_mean_median_of_qboxes                          NaN  Accruing
# viscosity_mean_standard_deviation_of_qboxes              NaN  Accruing
# viscosity_mean_mean_of_qboxes                            NaN  Accruing
# viscosity_median_median_of_qboxes                        NaN  Accruing
# viscosity_median_standard_deviation_of_qboxes            NaN  Accruing
# viscosity_median_mean_of_median                          NaN  Accruing
# dispersion_mean_median_of_qboxes                         NaN  Accruing
# dispersion_mean_standard_deviation_of_qboxes             NaN  Accruing
# dispersion_mean_mean_of_qboxes                           NaN  Accruing
# dispersion_median_median_of_qboxes                       NaN  Accruing
# dispersion_median_standard_deviation_of_qboxes           NaN  Accruing
# dispersion_median_mean_of_median                         NaN  Accruing
#
#                                                      sexed       debut  \
# tabular_field_name
# timezone                                        Both sexes  2021-08-16
# collection_date                                 Both sexes  2021-08-16
# collection_timestamp                            Both sexes  2021-08-16
# liver_ultrasound_qbox_depth                     Both sexes  2021-08-16
# liver_ultrasound_qbox_diameter                  Both sexes  2021-08-16
# liver_ultrasound_stability_index                Both sexes  2021-08-16
# elasticity_qbox_minimum                         Both sexes  2021-08-16
# elasticity_qbox_maximum                         Both sexes  2021-08-16
# elasticity_qbox_median                          Both sexes  2021-08-16
# elasticity_qbox_standard_deviation              Both sexes  2021-08-16
# elasticity_qbox_mean                            Both sexes  2021-08-16
# velocity_qbox_minimum                           Both sexes  2021-08-16
# velocity_qbox_maximum                           Both sexes  2021-08-16
# velocity_qbox_median                            Both sexes  2021-08-16
# velocity_qbox_standard_deviation                Both sexes  2021-08-16
# velocity_qbox_mean                              Both sexes  2021-08-16
# viscosity_qbox_median                           Both sexes  2021-08-16
# viscosity_qbox_standard_deviation               Both sexes  2021-08-16
# viscosity_qbox_mean                             Both sexes  2021-08-16
# dispersion_qbox_median                          Both sexes  2021-08-16
# dispersion_qbox_standard_deviation              Both sexes  2021-08-16
# dispersion_qbox_mean                            Both sexes  2021-08-16
# attenuation_coefficient_qbox                    Both sexes  2021-08-16
# speed_of_sound_qbox                             Both sexes  2021-08-16
# elasticity_mean_minimum_of_qboxes               Both sexes  2021-08-16
# elasticity_mean_maximum_of_qboxes               Both sexes  2021-08-16
# elasticity_mean_median_of_qboxes                Both sexes  2021-08-16
# elasticity_mean_standard_deviation_of_qboxes    Both sexes  2021-08-16
# elasticity_mean_mean_of_qboxes                  Both sexes  2021-08-16
# elasticity_median_minimum_of_qboxes             Both sexes  2021-08-16
# elasticity_median_maximum_of_qboxes             Both sexes  2021-08-16
# elasticity_median_median_of_qboxes              Both sexes  2021-08-16
# elasticity_median_standard_deviation_of_qboxes  Both sexes  2021-08-16
# elasticity_median_mean_of_qboxes                Both sexes  2021-08-16
# velocity_mean_minimum_of_qboxes                 Both sexes  2021-08-16
# velocity_mean_maximum_of_qboxes                 Both sexes  2021-08-16
# velocity_mean_median_of_qboxes                  Both sexes  2021-08-16
# velocity_mean_standard_deviation_of_qboxes      Both sexes  2021-08-16
# velocity_mean_mean_of_qboxes                    Both sexes  2021-08-16
# velocity_median_minimum_of_qboxes               Both sexes  2021-08-16
# velocity_median_maximum_of_qboxes               Both sexes  2021-08-16
# velocity_median_median_of_qboxes                Both sexes  2021-08-16
# velocity_median_standard_deviation_of_qboxes    Both sexes  2021-08-16
# velocity_median_mean_of_qboxes                  Both sexes  2021-08-16
# viscosity_mean_median_of_qboxes                 Both sexes  2021-08-16
# viscosity_mean_standard_deviation_of_qboxes     Both sexes  2021-08-16
# viscosity_mean_mean_of_qboxes                   Both sexes  2021-08-16
# viscosity_median_median_of_qboxes               Both sexes  2021-08-16
# viscosity_median_standard_deviation_of_qboxes   Both sexes  2021-08-16
# viscosity_median_mean_of_median                 Both sexes  2021-08-16
# dispersion_mean_median_of_qboxes                Both sexes  2021-08-16
# dispersion_mean_standard_deviation_of_qboxes    Both sexes  2021-08-16
# dispersion_mean_mean_of_qboxes                  Both sexes  2021-08-16
# dispersion_median_median_of_qboxes              Both sexes  2021-08-16
# dispersion_median_standard_deviation_of_qboxes  Both sexes  2021-08-16
# dispersion_median_mean_of_median                Both sexes  2021-08-16
#
#                                                 completed
# tabular_field_name
# timezone                                              NaN
# collection_date                                       NaN
# collection_timestamp                                  NaN
# liver_ultrasound_qbox_depth                           NaN
# liver_ultrasound_qbox_diameter                        NaN
# liver_ultrasound_stability_index                      NaN
# elasticity_qbox_minimum                               NaN
# elasticity_qbox_maximum                               NaN
# elasticity_qbox_median                                NaN
# elasticity_qbox_standard_deviation                    NaN
# elasticity_qbox_mean                                  NaN
# velocity_qbox_minimum                                 NaN
# velocity_qbox_maximum                                 NaN
# velocity_qbox_median                                  NaN
# velocity_qbox_standard_deviation                      NaN
# velocity_qbox_mean                                    NaN
# viscosity_qbox_median                                 NaN
# viscosity_qbox_standard_deviation                     NaN
# viscosity_qbox_mean                                   NaN
# dispersion_qbox_median                                NaN
# dispersion_qbox_standard_deviation                    NaN
# dispersion_qbox_mean                                  NaN
# attenuation_coefficient_qbox                          NaN
# speed_of_sound_qbox                                   NaN
# elasticity_mean_minimum_of_qboxes                     NaN
# elasticity_mean_maximum_of_qboxes                     NaN
# elasticity_mean_median_of_qboxes                      NaN
# elasticity_mean_standard_deviation_of_qboxes          NaN
# elasticity_mean_mean_of_qboxes                        NaN
# elasticity_median_minimum_of_qboxes                   NaN
# elasticity_median_maximum_of_qboxes                   NaN
# elasticity_median_median_of_qboxes                    NaN
# elasticity_median_standard_deviation_of_qboxes        NaN
# elasticity_median_mean_of_qboxes                      NaN
# velocity_mean_minimum_of_qboxes                       NaN
# velocity_mean_maximum_of_qboxes                       NaN
# velocity_mean_median_of_qboxes                        NaN
# velocity_mean_standard_deviation_of_qboxes            NaN
# velocity_mean_mean_of_qboxes                          NaN
# velocity_median_minimum_of_qboxes                     NaN
# velocity_median_maximum_of_qboxes                     NaN
# velocity_median_median_of_qboxes                      NaN
# velocity_median_standard_deviation_of_qboxes          NaN
# velocity_median_mean_of_qboxes                        NaN
# viscosity_mean_median_of_qboxes                       NaN
# viscosity_mean_standard_deviation_of_qboxes           NaN
# viscosity_mean_mean_of_qboxes                         NaN
# viscosity_median_median_of_qboxes                     NaN
# viscosity_median_standard_deviation_of_qboxes         NaN
# viscosity_median_mean_of_median                       NaN
# dispersion_mean_median_of_qboxes                      NaN
# dispersion_mean_standard_deviation_of_qboxes          NaN
# dispersion_mean_mean_of_qboxes                        NaN
# dispersion_median_median_of_qboxes                    NaN
# dispersion_median_standard_deviation_of_qboxes        NaN
# dispersion_median_mean_of_median                      NaN

# %% [markdown]
# # Plot histogram and ecdf for elasticity_median_median_of_qboxes at baseline visit

# %%
from pheno_utils.basic_plots import hist_ecdf_plots

col = "elasticity_median_median_of_qboxes"
df = pl[[col] + ["age", "sex", "collection_date"]].loc[:,:,"00_00_visit",0,:]

# plot histogram and ecdf
hist_ecdf_plots(df.dropna(subset=[col,"sex", "age"]), col, gender_col="sex")

# stats
display(df[col].describe().to_frame().T)
# Out:
#                                      count      mean       std   min   25%  \
# elasticity_median_median_of_qboxes  6757.0  5.017764  1.190037  2.65  4.24
#
#                                      50%   75%   max
# elasticity_median_median_of_qboxes  4.84  5.56  29.6
