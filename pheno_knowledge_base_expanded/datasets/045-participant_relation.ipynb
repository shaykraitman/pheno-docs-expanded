# %% [raw]
# ---
# output-file: 045-participant_relation.html
# title: Participant Relations
# ---

# %% [markdown]
# ### Description
#
# The Human Phenotype Project conducts comprehensive data collection through online surveys, where participants voluntarily provide information on various aspects influencing their health. This includes information about other participant's they are related to.
#
# ### Introduction
#
# The Human Phenotype Project collects information about family relationships between study participants to enable genetics and family-based research. Understanding familial connections is essential for studying heritability of traits, shared environmental factors, and genetic associations. Participants who have family members also enrolled in the study can indicate these relationships, allowing researchers to analyze data from related individuals while maintaining privacy and confidentiality.
#
# ### Measurement protocol
# <!-- long measurment protocol for the data browser -->
# A short online survey is used to track participants in the study who are related in some way.
#
# ### Data availability
# <!-- for the example notebooks -->
# The information is stored in 1 parquet files: `participant_relation.parquet`.
#
# ### Summary of available data
# <!-- for the data browser -->
# The dataset contains information about familial relationships between study participants, including:
# 1. Relation type: The type of familial relationship (e.g., parent, sibling, child, spouse)
# 2. Relative participant ID: The study ID of the related participant
# 3. This data enables family-based analyses and genetic studies involving related individuals within the cohort
#
# ### Relevant links
#
# * [Pheno Knowledgebase](https://knowledgebase.pheno.ai/datasets/045-participant_relation.html)
# * [Pheno Data Browser](https://pheno-demo-app.vercel.app/folder/45)

# %%
#| echo: false
import pandas as pd
pd.set_option("display.max_rows", 500)

# %%
from pheno_utils import PhenoLoader

# %%
pl = PhenoLoader('participant_relation')
pl
# Out:
# PhenoLoader for participant_relation with
# 7 fields
# 2 tables: ['participant_relation', 'age_sex']

# %% [markdown]
# # Data dictionary

# %%
pl.dict
# Out:
#                          folder_id           feature_set  \
# tabular_field_name
# collection_timestamp            59  participant relation
# collection_date                 59  participant relation
# timezone                        59  participant relation
# relation_type                   59  participant relation
# relative_participant_id         59  participant relation
#
#                                  field_string  bulk_file_extension  \
# tabular_field_name
# collection_timestamp     Collection timestamp                  NaN
# collection_date               Collection date                  NaN
# timezone                             Timezone                  NaN
# relation_type                   relation_type                  NaN
# relative_participant_id  other_participant_id                  NaN
#
#                          bulk_dictionary  \
# tabular_field_name
# collection_timestamp                 NaN
# collection_date                      NaN
# timezone                             NaN
# relation_type                        NaN
# relative_participant_id              NaN
#
#                                             description_string  \
# tabular_field_name
# collection_timestamp      Timestamp of measurements collection
# collection_date                 Date of measurments collection
# timezone                           Timezone of the measurments
# relation_type            Type of relation to other participant
# relative_participant_id                Relative participant id
#
#                                    field_type data_coding units stability  \
# tabular_field_name
# collection_timestamp                 Datetime         NaN  Time  Accruing
# collection_date                          Date         NaN  Time  Accruing
# timezone                                 Text         NaN   NaN  Accruing
# relation_type            Categorical (single)      045_01   NaN  Accruing
# relative_participant_id               Integer         NaN   NaN  Accruing
#
#                          sampling_rate           strata       sexed   array  \
# tabular_field_name
# collection_timestamp               NaN  Collection time  Both sexes  Single
# collection_date                    NaN  Collection time  Both sexes  Single
# timezone                           NaN  Collection time  Both sexes  Single
# relation_type                      NaN          Primary  Both sexes  Single
# relative_participant_id            NaN          Primary  Both sexes  Single
#
#                          list_of_tags       debut  completed  \
# tabular_field_name
# collection_timestamp              NaN  2019-02-05        NaN
# collection_date                   NaN  2019-02-05        NaN
# timezone                          NaN  2019-02-05        NaN
# relation_type                     NaN  2019-02-05        NaN
# relative_participant_id           NaN  2019-02-05        NaN
#
#                                                          relative_location  \
# tabular_field_name
# collection_timestamp     participant_relation/participant_relation.parquet
# collection_date          participant_relation/participant_relation.parquet
# timezone                 participant_relation/participant_relation.parquet
# relation_type            participant_relation/participant_relation.parquet
# relative_participant_id  participant_relation/participant_relation.parquet
#
#                                            pandas_dtype
# tabular_field_name
# collection_timestamp     datetime64[ns, Asia/Jerusalem]
# collection_date                          datetime64[ns]
# timezone                                       category
# relation_type                                       int
# relative_participant_id                             int
