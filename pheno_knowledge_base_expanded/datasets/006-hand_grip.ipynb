# %% [raw]
# ---
# output-file: 006-hand_grip.html
# title: Hand Grip Strength
# ---

# %% [markdown]
# ### Description
#
# Hand grip strength (HGS) is an effective marker of general health in middle age and older adulthood. Grip strength is measured by squeezing a type of muscle strength testing equipment, known as a dynamometer.
#
# ### Introduction
#
# HGS is a measure of the maximum force that an individual can exert with their hand. It is a widely used measure of muscular strength. HGS is an easy and quick measure to obtain.
#
# In a clinical setting, HGS is often used as a measure to assess changes in muscle strength over time. For example, in patients with conditions such as osteoarthritis, rheumatoid arthritis, or sarcopenia. Additionally, HGS can be used to assess the effectiveness of rehabilitation programs, such as those used to recover from a stroke or from other neurological conditions.
#
# HGS is also used in research studies to investigate the relationship between muscle strength and various health outcomes, such as cardiovascular disease (CVD), respiratory function, and mortality. Studies have shown that low HGS is associated with increased risk of these and other health conditions, highlighting the importance of this measure in identifying individuals at risk for these conditions. Low HGS can be a warning sign of frailty, especially in older adults, as well as muscle wasting and weakness. Based on this, HGS can be used as a simple, non-invasive, and inexpensive method to predict physical frailty and disability.
#
# ### Measurement protocol
# <!-- long measurment protocol for the data browser -->
# HGS is measured using a Jamar Hydraulic Hand Dynamometer (see figure below). The measurement is a measure of the static force (without movement) that the hand can exert when squeezing around the dynamometer. The measurement is recorded in pounds initially, and then converted to kilograms.
#
# ![image alt](006-hand_grip/grip_strength_info.png)
#
# The participant is asked to sit upright in a chair with the arm bent at a 90° angle so that their forearm is pointing forward, with their thumb uppermost. The participant is asked to hold the device first in their dominant hand and adjust the handle of the dynamometer as necessary, ensuring the base rests on the first metacarpal and the handle on the middle of the four fingers. The participant is asked to squeeze the handle of the dynamometer for at least 3 seconds. The results are manually recorded, and then the measurement is repeated for the non-dominant hand.
#
#
# ### Data availability
# <!-- for the example notebooks -->
# The information is stored in 1 parquet file: `hand_grip.parquet`
#
# ### Summary of available data
# <!-- for the data browser -->
# 1. Raw data: a data frame containing individual level hand grip strength measurements.
#
# ### Relevant links
#
# * [Pheno Knowledgebase](https://knowledgebase.pheno.ai/datasets/006-hand_grip.html)
# * [Pheno Data Browser](https://pheno-demo-app.vercel.app/folder/6)

# %%
#| echo: false
import pandas as pd
pd.set_option("display.max_rows", 500)

# %%
from pheno_utils import PhenoLoader

# %%
pl = PhenoLoader('hand_grip')
pl
# Out:
# PhenoLoader for hand_grip with
# 10 fields
# 2 tables: ['hand_grip', 'age_sex']

# %% [markdown]
# # Data dictionary

# %%
pl.dict
# Out:
#                                             field_string  \
# tabular_field_name
# collection_date             Collection date (YYYY-MM-DD)
# collection_timestamp                Collection timestamp
# finger_grip_strength_left    Finger grip strength (left)
# finger_grip_strength_right  Finger grip strength (right)
# dominant_hand                              Dominant hand
# hand_grip_strength_left        Hand grip strength (left)
# hand_grip_strength_right      Hand grip strength (right)
# timezone                                        Timezone
#
#                                               description_string  folder_id  \
# tabular_field_name
# collection_date                     Collection date (YYYY-MM-DD)          6
# collection_timestamp                        Collection timestamp          6
# finger_grip_strength_left            Finger grip strength (left)          6
# finger_grip_strength_right          Finger grip strength (right)          6
# dominant_hand               Hand preference for fine motor tasks          6
# hand_grip_strength_left                Hand grip strength (left)          6
# hand_grip_strength_right              Hand grip strength (right)          6
# timezone                                                Timezone          6
#
#                            feature_set            field_type           strata  \
# tabular_field_name
# collection_date              hand_grip                  Date  Collection time
# collection_timestamp         hand_grip              Datetime  Collection time
# finger_grip_strength_left    hand_grip            Continuous          Primary
# finger_grip_strength_right   hand_grip            Continuous          Primary
# dominant_hand                hand_grip  Categorical (single)          Primary
# hand_grip_strength_left      hand_grip            Continuous          Primary
# hand_grip_strength_right     hand_grip            Continuous          Primary
# timezone                     hand_grip  Categorical (single)  Collection time
#
#                            data_coding   array  \
# tabular_field_name
# collection_date                    NaN  Single
# collection_timestamp               NaN  Single
# finger_grip_strength_left          NaN  Single
# finger_grip_strength_right         NaN  Single
# dominant_hand                   007_01  Single
# hand_grip_strength_left            NaN  Single
# hand_grip_strength_right           NaN  Single
# timezone                           NaN  Single
#
#                                               pandas_dtype  \
# tabular_field_name
# collection_date                             datetime64[ns]
# collection_timestamp        datetime64[ns, Asia/Jerusalem]
# finger_grip_strength_left                            float
# finger_grip_strength_right                           float
# dominant_hand                                     category
# hand_grip_strength_left                              float
# hand_grip_strength_right                             float
# timezone                                            string
#
#                             bulk_file_extension            relative_location  \
# tabular_field_name
# collection_date                             NaN  hand_grip/hand_grip.parquet
# collection_timestamp                        NaN  hand_grip/hand_grip.parquet
# finger_grip_strength_left                   NaN  hand_grip/hand_grip.parquet
# finger_grip_strength_right                  NaN  hand_grip/hand_grip.parquet
# dominant_hand                               NaN  hand_grip/hand_grip.parquet
# hand_grip_strength_left                     NaN  hand_grip/hand_grip.parquet
# hand_grip_strength_right                    NaN  hand_grip/hand_grip.parquet
# timezone                                    NaN  hand_grip/hand_grip.parquet
#
#                            units  bulk_dictionary  sampling_rate  \
# tabular_field_name
# collection_date             Time              NaN            NaN
# collection_timestamp        Time              NaN            NaN
# finger_grip_strength_left     kg              NaN            NaN
# finger_grip_strength_right    kg              NaN            NaN
# dominant_hand                NaN              NaN            NaN
# hand_grip_strength_left       kg              NaN            NaN
# hand_grip_strength_right      kg              NaN            NaN
# timezone                     NaN              NaN            NaN
#
#                             transformation  list_of_tags stability  \
# tabular_field_name
# collection_date                        NaN           NaN  Accruing
# collection_timestamp                   NaN           NaN  Accruing
# finger_grip_strength_left              NaN           NaN  Complete
# finger_grip_strength_right             NaN           NaN  Complete
# dominant_hand                          NaN           NaN  Accruing
# hand_grip_strength_left                NaN           NaN  Accruing
# hand_grip_strength_right               NaN           NaN  Accruing
# timezone                               NaN           NaN  Accruing
#
#                                  sexed       debut   completed
# tabular_field_name
# collection_date             Both sexes  2018-10-18         NaN
# collection_timestamp        Both sexes  2018-10-18  2019-11-13
# finger_grip_strength_left   Both sexes  2018-10-18  2019-11-13
# finger_grip_strength_right  Both sexes  2018-10-18         NaN
# dominant_hand               Both sexes  2018-10-18         NaN
# hand_grip_strength_left     Both sexes  2018-10-18         NaN
# hand_grip_strength_right    Both sexes  2018-10-18         NaN
# timezone                    Both sexes  2018-10-18         NaN

# %% [markdown]
# # Plot histogram and ecdf for hand_grip_strength_left at baseline visit

# %%
from pheno_utils.basic_plots import hist_ecdf_plots

col = "hand_grip_strength_left"
df = pl[[col] + ["age", "sex", "collection_date"]].loc[:,:,"00_00_visit",0,:]

# plot histogram and ecdf
hist_ecdf_plots(df.dropna(subset=[col,"sex", "age"]), col, gender_col="sex")

# stats
display(df[col].describe().to_frame().T)
# Out:
#                            count       mean        std       min        25%  \
# hand_grip_strength_left  10336.0  34.177962  11.432727  2.358683  25.083688
#
#                                50%        75%        max
# hand_grip_strength_left  31.638105  43.091326  79.061244
