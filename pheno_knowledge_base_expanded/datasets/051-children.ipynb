# %% [raw]
# ---
# output-file: 051-children.html
# title: Children
# ---

# %% [markdown]
# ### Description
#
# The Children Dataset is a curated collection of self-reported information from participants concerning their children and pregnancy experiences. It includes key variables such as:
#
# * Number of Children: The total count of biological children reported by each participant.
# * Birth Weights: Recorded birth weights of participants' children, offering insights into neonatal health and potential risk factors.
# * Pregnancy Durations: Length of each pregnancy in weeks, indicating whether births were full-term or preterm
#
# ### Introduction
#
# The Human Phenotype Project collects comprehensive data about participants' children and pregnancy experiences, as these factors can provide important insights into maternal and paternal health, genetic influences, and intergenerational health patterns. Birth weight and pregnancy duration are key indicators of fetal development and maternal health during pregnancy, and can be associated with long-term health outcomes for both parents and children. This information also enables research into the heritability of traits and conditions, as well as the impact of parental phenotypes on offspring health. By collecting data on number of pregnancies, genetic testing before pregnancy, and detailed birth outcomes for multiple children, researchers can investigate patterns across families and explore how parental characteristics and environmental factors influence reproductive outcomes.
#
# ### Measurement protocol
# <!-- long measurment protocol for the data browser -->
# Data for the Children Dataset were collected during the registration phase of the Human Phenotype Project through the Initial Medical Survey. Participants completed an online questionnaire designed to capture accurate and comprehensive information
#
# ### Data availability
# <!-- for the example notebooks -->
# The information is stored in 1 parquets file: `children.parquet`
#
# ### Summary of available data
# <!-- for the data browser -->
# The dataset includes detailed information about participants' reproductive history and their children:
#
# **Pregnancy History:**
# - Total number of pregnancies
# - Number of biological children
# - History of genetic testing before pregnancy
#
# **Birth Outcomes (for up to 9 children):**
# - Birth week (gestational age at delivery)
# - Birth weight in kilograms
# - Collection date and timezone
#
# This data enables research into:
# 1. Associations between parental phenotypes and birth outcomes
# 2. Patterns of pregnancy duration and birth weight across multiple children within families
# 3. Intergenerational health relationships
# 4. Reproductive health patterns in the study population
#
# ### Relevant links
#
# * [Pheno Knowledgebase](https://knowledgebase.pheno.ai/datasets/051-children.html)
# * [Pheno Data Browser](https://pheno-demo-app.vercel.app/folder/51)

# %%
#| echo: false
import pandas as pd
pd.set_option("display.max_rows", 500)

# %%
from pheno_utils import PhenoLoader

# %%
pl = PhenoLoader('children')
pl
# Out:
# PhenoLoader for children with
# 26 fields
# 2 tables: ['children', 'age_sex']

# %% [markdown]
# # Data dictionary

# %%
pl.dict
# Out:
#                                folder_id                   field_string  \
# tabular_field_name
# collection_timestamp                  51                Collection time
# collection_date                       51                Collection date
# timezone                              51                       Timezone
# pregnancies_number                    51            Pregnancies number
# pre_pregnancy_genetic_testing         51  Pre pregnancy genetic testing
# number_of_children                    51             Number of children
# pregnancy_end_week_1                  51           Pregnancy end week 1
# birth_weight_1                        51                 Birth weight 1
# pregnancy_end_week_2                  51           Pregnancy end week 2
# birth_weight_2                        51                 Birth weight 2
# pregnancy_end_week_3                  51           Pregnancy end week 3
# birth_weight_3                        51                 Birth weight 3
# pregnancy_end_week_4                  51           Pregnancy end week 4
# birth_weight_4                        51                 Birth weight 4
# pregnancy_end_week_5                  51           Pregnancy end week 5
# birth_weight_5                        51                 Birth weight 5
# pregnancy_end_week_6                  51           Pregnancy end week 6
# birth_weight_6                        51                 Birth weight 6
# pregnancy_end_week_7                  51           Pregnancy end week 7
# birth_weight_7                        51                 Birth weight 7
# pregnancy_end_week_8                  51           Pregnancy end week 8
# birth_weight_8                        51                 Birth weight 8
# pregnancy_end_week_9                  51           Pregnancy end week 9
# birth_weight_9                        51                 Birth weight 9
#
#                                                               description_string  \
# tabular_field_name
# collection_timestamp                                             Collection time
# collection_date                                                  Collection date
# timezone                                                                Timezone
# pregnancies_number                             How often have you been pregnant?
# pre_pregnancy_genetic_testing  Have you done genetic tests before getting pre...
# number_of_children                                    how many kids do you have?
# pregnancy_end_week_1                        What was the 1st child's birth week?
# birth_weight_1                         What was the child's birth weight in KG?
# pregnancy_end_week_2                        What was the 2nd child's birth week?
# birth_weight_2                         What was the child's birth weight in KG?
# pregnancy_end_week_3                        What was the 3rd child's birth week?
# birth_weight_3                         What was the child's birth weight in KG?
# pregnancy_end_week_4                What was the 4th child's child's birth week?
# birth_weight_4                         What was the child's birth weight in KG?
# pregnancy_end_week_5                        What was the 5th child's birth week?
# birth_weight_5                         What was the child's birth weight in KG?
# pregnancy_end_week_6                        What was the 6th child's birth week?
# birth_weight_6                         What was the child's birth weight in KG?
# pregnancy_end_week_7                        What was the 7th child's birth week?
# birth_weight_7                         What was the child's birth weight in KG?
# pregnancy_end_week_8                        What was the 8th child's birth week?
# birth_weight_8                         What was the child's birth weight in KG?
# pregnancy_end_week_9                        What was the 9th child's birth week?
# birth_weight_9                         What was the child's birth weight in KG?
#
#                               feature_set            field_type  \
# tabular_field_name
# collection_timestamp             children              Datetime
# collection_date                  children                  Date
# timezone                         children  Categorical (single)
# pregnancies_number               children               Integer
# pre_pregnancy_genetic_testing    children  Categorical (single)
# number_of_children               children               Integer
# pregnancy_end_week_1             children            Continuous
# birth_weight_1                   children            Continuous
# pregnancy_end_week_2             children            Continuous
# birth_weight_2                   children            Continuous
# pregnancy_end_week_3             children            Continuous
# birth_weight_3                   children            Continuous
# pregnancy_end_week_4             children            Continuous
# birth_weight_4                   children            Continuous
# pregnancy_end_week_5             children            Continuous
# birth_weight_5                   children            Continuous
# pregnancy_end_week_6             children            Continuous
# birth_weight_6                   children            Continuous
# pregnancy_end_week_7             children            Continuous
# birth_weight_7                   children            Continuous
# pregnancy_end_week_8             children            Continuous
# birth_weight_8                   children            Continuous
# pregnancy_end_week_9             children            Continuous
# birth_weight_9                   children            Continuous
#
#                                         strata  data_coding   array  units  \
# tabular_field_name
# collection_timestamp           Collection time          NaN  Single    NaN
# collection_date                Collection time          NaN  Single    NaN
# timezone                       Collection time          NaN  Single    NaN
# pregnancies_number                     Primary          NaN  Single    NaN
# pre_pregnancy_genetic_testing          Primary          7.0  Single    NaN
# number_of_children                     Primary          NaN  Single    NaN
# pregnancy_end_week_1                   Primary          NaN  Single  weeks
# birth_weight_1                         Primary          NaN  Single     kg
# pregnancy_end_week_2                   Primary          NaN  Single  weeks
# birth_weight_2                         Primary          NaN  Single     kg
# pregnancy_end_week_3                   Primary          NaN  Single  weeks
# birth_weight_3                         Primary          NaN  Single     kg
# pregnancy_end_week_4                   Primary          NaN  Single  weeks
# birth_weight_4                         Primary          NaN  Single     kg
# pregnancy_end_week_5                   Primary          NaN  Single  weeks
# birth_weight_5                         Primary          NaN  Single     kg
# pregnancy_end_week_6                   Primary          NaN  Single  weeks
# birth_weight_6                         Primary          NaN  Single     kg
# pregnancy_end_week_7                   Primary          NaN  Single  weeks
# birth_weight_7                         Primary          NaN  Single     kg
# pregnancy_end_week_8                   Primary          NaN  Single  weeks
# birth_weight_8                         Primary          NaN  Single     kg
# pregnancy_end_week_9                   Primary          NaN  Single  weeks
# birth_weight_9                         Primary          NaN  Single     kg
#
#                                       sexed                    pandas_dtype  \
# tabular_field_name
# collection_timestamp                    NaN  datetime64[ns, Asia/Jerusalem]
# collection_date                         NaN                  datetime64[ns]
# timezone                                NaN                        category
# pregnancies_number             Females only                             int
# pre_pregnancy_genetic_testing  Females only                             int
# number_of_children               Males only                             int
# pregnancy_end_week_1             Males only                             int
# birth_weight_1                   Males only                           float
# pregnancy_end_week_2             Males only                             int
# birth_weight_2                   Males only                           float
# pregnancy_end_week_3             Males only                             int
# birth_weight_3                   Males only                           float
# pregnancy_end_week_4             Males only                             int
# birth_weight_4                   Males only                           float
# pregnancy_end_week_5             Males only                             int
# birth_weight_5                   Males only                           float
# pregnancy_end_week_6             Males only                             int
# birth_weight_6                   Males only                           float
# pregnancy_end_week_7             Males only                             int
# birth_weight_7                   Males only                           float
# pregnancy_end_week_8             Males only                             int
# birth_weight_8                   Males only                           float
# pregnancy_end_week_9             Males only                             int
# birth_weight_9                   Males only                           float
#
#                                bulk_file_extension  bulk_dictionary  \
# tabular_field_name
# collection_timestamp                           NaN              NaN
# collection_date                                NaN              NaN
# timezone                                       NaN              NaN
# pregnancies_number                             NaN              NaN
# pre_pregnancy_genetic_testing                  NaN              NaN
# number_of_children                             NaN              NaN
# pregnancy_end_week_1                           NaN              NaN
# birth_weight_1                                 NaN              NaN
# pregnancy_end_week_2                           NaN              NaN
# birth_weight_2                                 NaN              NaN
# pregnancy_end_week_3                           NaN              NaN
# birth_weight_3                                 NaN              NaN
# pregnancy_end_week_4                           NaN              NaN
# birth_weight_4                                 NaN              NaN
# pregnancy_end_week_5                           NaN              NaN
# birth_weight_5                                 NaN              NaN
# pregnancy_end_week_6                           NaN              NaN
# birth_weight_6                                 NaN              NaN
# pregnancy_end_week_7                           NaN              NaN
# birth_weight_7                                 NaN              NaN
# pregnancy_end_week_8                           NaN              NaN
# birth_weight_8                                 NaN              NaN
# pregnancy_end_week_9                           NaN              NaN
# birth_weight_9                                 NaN              NaN
#
#                                        relative_location  sampling_rate  \
# tabular_field_name
# collection_timestamp           children/children.parquet            NaN
# collection_date                children/children.parquet            NaN
# timezone                       children/children.parquet            NaN
# pregnancies_number             children/children.parquet            NaN
# pre_pregnancy_genetic_testing  children/children.parquet            NaN
# number_of_children             children/children.parquet            NaN
# pregnancy_end_week_1           children/children.parquet            NaN
# birth_weight_1                 children/children.parquet            NaN
# pregnancy_end_week_2           children/children.parquet            NaN
# birth_weight_2                 children/children.parquet            NaN
# pregnancy_end_week_3           children/children.parquet            NaN
# birth_weight_3                 children/children.parquet            NaN
# pregnancy_end_week_4           children/children.parquet            NaN
# birth_weight_4                 children/children.parquet            NaN
# pregnancy_end_week_5           children/children.parquet            NaN
# birth_weight_5                 children/children.parquet            NaN
# pregnancy_end_week_6           children/children.parquet            NaN
# birth_weight_6                 children/children.parquet            NaN
# pregnancy_end_week_7           children/children.parquet            NaN
# birth_weight_7                 children/children.parquet            NaN
# pregnancy_end_week_8           children/children.parquet            NaN
# birth_weight_8                 children/children.parquet            NaN
# pregnancy_end_week_9           children/children.parquet            NaN
# birth_weight_9                 children/children.parquet            NaN
#
#                               stability       debut  completed
# tabular_field_name
# collection_timestamp           Accruing  2020-02-26        NaN
# collection_date                Accruing  2020-02-26        NaN
# timezone                       Accruing  2020-02-26        NaN
# pregnancies_number             Accruing  2020-02-26        NaN
# pre_pregnancy_genetic_testing  Accruing  2020-02-26        NaN
# number_of_children             Accruing  2020-02-26        NaN
# pregnancy_end_week_1           Accruing  2020-02-26        NaN
# birth_weight_1                 Accruing  2020-02-26        NaN
# pregnancy_end_week_2           Accruing  2020-02-26        NaN
# birth_weight_2                 Accruing  2020-02-26        NaN
# pregnancy_end_week_3           Accruing  2020-02-26        NaN
# birth_weight_3                 Accruing  2020-02-26        NaN
# pregnancy_end_week_4           Accruing  2020-02-26        NaN
# birth_weight_4                 Accruing  2020-02-26        NaN
# pregnancy_end_week_5           Accruing  2020-02-26        NaN
# birth_weight_5                 Accruing  2020-02-26        NaN
# pregnancy_end_week_6           Accruing  2020-02-26        NaN
# birth_weight_6                 Accruing  2020-02-26        NaN
# pregnancy_end_week_7           Accruing  2020-02-26        NaN
# birth_weight_7                 Accruing  2020-02-26        NaN
# pregnancy_end_week_8           Accruing  2020-02-26        NaN
# birth_weight_8                 Accruing  2020-02-26        NaN
# pregnancy_end_week_9           Accruing  2020-02-26        NaN
# birth_weight_9                 Accruing  2020-02-26        NaN
