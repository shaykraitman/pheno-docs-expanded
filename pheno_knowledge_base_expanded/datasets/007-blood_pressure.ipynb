# %% [raw]
# ---
# output-file: 007-blood_pressure.html
# title: Blood Pressure
# ---

# %% [markdown]
# ### Description
#
# Blood pressure is the measurement of the force exerted against the walls of the arteries as blood flows through them. Blood pressure is recorded as two values: systolic pressure (the maximum arterial pressure during left ventricular contraction) and diastolic pressure (the minimum arterial pressure during left ventricular relaxation).
#
# ### Introduction
#
# Hypertension, or elevated blood pressure, is a significant risk factor for cardiovascular disease and cerebrovascular events, contributing substantially to global mortality and morbidity. Chronic hypertension is characterized by persistently elevated arterial pressure, which increases cardiac workload and can lead to cardiovascular complications. Conversely, hypotension, or abnormally low blood pressure, can be equally detrimental. Severe hypotension may result in inadequate perfusion of vital organs, potentially leading to insufficient oxygen and nutrient delivery, and in extreme cases, progressing to circulatory shock, a life-threatening condition.
#
# Blood pressure measurement can be performed in a variety of settings, including hospitals, clinics, and even at home, using an automated or manual sphygmomanometer. Blood pressure measurement can be used to monitor the effectiveness of treatment interventions, such as lifestyle changes. The goal of treatment is to achieve and maintain target blood pressure levels, which are generally lower for individuals at higher risk for cardiovascular disease.
#
# ### Measurement protocol
# <!-- long measurment protocol for the data browser -->
# Blood pressure is measured using an OMRON Blood Pressure Monitor HEM-RML31 device and an appropriately sized cuff. Multiple blood pressure readings are done during the visit. For each blood pressure reading, three measurements are taken: systolic pressure, diastolic pressure, and average heart rate. The participant is asked to avoid caffeine, exercise and smoking at least 30 minutes before the measurement. The measurement is taken on the left arm if possible. The cuff size is based on the arm circumference.
#
# The participant is seated for 5 minutes, after which the first measurement is taken. Repeat a second measurement after 2 minutes. The participant then lies down for 5 minutes and the lying blood pressure reading is taken. The participant then stands up, slowly. The first standing reading is taken after 1 minute of standing and the next reading after 3 minutes of standing. The participant is asked to report about dizziness on standing up.
#
# ![image alt](blood_pressure_info.png)
#
# ### Data availability
# <!-- for the example notebooks -->
# The information is stored in 1 parquet file: `blood_pressure.parquet`
#
# ### Summary of available data
# <!-- for the data browser -->
# 1. Raw data: a data frame containing individual level blood pressure measurements.
#
# ### Relevant links
#
# * [Pheno Knowledgebase](https://knowledgebase.pheno.ai/datasets/007-blood_pressure.html)
# * [Pheno Data Browser](https://pheno-demo-app.vercel.app/folder/7)

# %%
#| echo: false
import pandas as pd
pd.set_option("display.max_rows", 500)

# %%
from pheno_utils import PhenoLoader

# %%
pl = PhenoLoader('blood_pressure')
pl
# Out:
# PhenoLoader for blood_pressure with
# 22 fields
# 2 tables: ['blood_pressure', 'age_sex']

# %% [markdown]
# # Data dictionary

# %%
pl.dict
# Out:
#                                                                                  field_string  \
# tabular_field_name
# collection_date                                                  Collection date (YYYY-MM-DD)
# collection_timestamp                                                     Collection timestamp
# timezone                                                                             Timezone
# lying_blood_pressure_diastolic                                 Lying diastolic blood pressure
# lying_blood_pressure_pulse_rate                               Lying blood pressure pulse rate
# lying_blood_pressure_systolic                                   Lying systolic blood pressure
# sitting_blood_pressure_diastolic                             Sitting diastolic blood pressure
# sitting_blood_pressure_pulse_rate                           Sitting blood pressure pulse rate
# sitting_blood_pressure_systolic                               Sitting systolic blood pressure
# standing_one_min_blood_pressure_diastolic        Standing one minute diastolic blood pressure
# standing_one_min_blood_pressure_pulse_rate      Standing one minute blood pressure pulse rate
# standing_one_min_blood_pressure_systolic          Standing one minute systolic blood pressure
# standing_three_min_blood_pressure_diastolic    Standing three minute diastolic blood pressure
# standing_three_min_blood_pressure_pulse_rate  Standing three minute blood pressure pulse rate
# standing_three_min_blood_pressure_systolic      Standing three minute systolic blood pressure
# blood_pressure_hand                                                       Blood pressure hand
# sitting_second_blood_pressure_diastolic               Sitting second diastolic blood pressure
# sitting_second_blood_pressure_pulse_rate             Sitting second blood pressure pulse rate
# sitting_second_blood_pressure_systolic                 Sitting second systolic blood pressure
# dizziness                                                             Dizzness after standing
#
#                                                                              description_string  \
# tabular_field_name
# collection_date                                                    Collection date (YYYY-MM-DD)
# collection_timestamp                                                       Collection timestamp
# timezone                                                                               Timezone
# lying_blood_pressure_diastolic                             Lying diastolic blood pressure value
# lying_blood_pressure_pulse_rate                                 Lying blood pressure pulse rate
# lying_blood_pressure_systolic                               Lying systolic blood pressure value
# sitting_blood_pressure_diastolic                         Sitting diastolic blood pressure value
# sitting_blood_pressure_pulse_rate                             Sitting blood pressure pulse rate
# sitting_blood_pressure_systolic                           Sitting systolic blood pressure value
# standing_one_min_blood_pressure_diastolic     Standing one minute diastolic blood pressure v...
# standing_one_min_blood_pressure_pulse_rate        Standing one minute blood pressure pulse rate
# standing_one_min_blood_pressure_systolic      Standing one minute systolic blood pressure value
# standing_three_min_blood_pressure_diastolic   Standing three minute diastolic blood pressure...
# standing_three_min_blood_pressure_pulse_rate    Standing three minute blood pressure pulse rate
# standing_three_min_blood_pressure_systolic    Standing three minute systolic blood pressure ...
# blood_pressure_hand                                  Hand used to peform blood pressure reading
# sitting_second_blood_pressure_diastolic       A second diastolic blood pressure value readin...
# sitting_second_blood_pressure_pulse_rate      Pulse rate of a second blood pressure reading ...
# sitting_second_blood_pressure_systolic        A second systolic blood pressure value reading...
# dizziness                                     Self reported dizziness once a person stands u...
#
#                                               folder_id     feature_set  \
# tabular_field_name
# collection_date                                       7  blood_pressure
# collection_timestamp                                  7  blood_pressure
# timezone                                              7  blood_pressure
# lying_blood_pressure_diastolic                        7  blood_pressure
# lying_blood_pressure_pulse_rate                       7  blood_pressure
# lying_blood_pressure_systolic                         7  blood_pressure
# sitting_blood_pressure_diastolic                      7  blood_pressure
# sitting_blood_pressure_pulse_rate                     7  blood_pressure
# sitting_blood_pressure_systolic                       7  blood_pressure
# standing_one_min_blood_pressure_diastolic             7  blood_pressure
# standing_one_min_blood_pressure_pulse_rate            7  blood_pressure
# standing_one_min_blood_pressure_systolic              7  blood_pressure
# standing_three_min_blood_pressure_diastolic           7  blood_pressure
# standing_three_min_blood_pressure_pulse_rate          7  blood_pressure
# standing_three_min_blood_pressure_systolic            7  blood_pressure
# blood_pressure_hand                                   7  blood_pressure
# sitting_second_blood_pressure_diastolic               7  blood_pressure
# sitting_second_blood_pressure_pulse_rate              7  blood_pressure
# sitting_second_blood_pressure_systolic                7  blood_pressure
# dizziness                                             7  blood_pressure
#
#                                                         field_type  \
# tabular_field_name
# collection_date                                               Date
# collection_timestamp                                      Datetime
# timezone                                                Continuous
# lying_blood_pressure_diastolic                          Continuous
# lying_blood_pressure_pulse_rate                         Continuous
# lying_blood_pressure_systolic                           Continuous
# sitting_blood_pressure_diastolic                        Continuous
# sitting_blood_pressure_pulse_rate                       Continuous
# sitting_blood_pressure_systolic                         Continuous
# standing_one_min_blood_pressure_diastolic               Continuous
# standing_one_min_blood_pressure_pulse_rate              Continuous
# standing_one_min_blood_pressure_systolic                Continuous
# standing_three_min_blood_pressure_diastolic             Continuous
# standing_three_min_blood_pressure_pulse_rate            Continuous
# standing_three_min_blood_pressure_systolic              Continuous
# blood_pressure_hand                           Categorical (single)
# sitting_second_blood_pressure_diastolic                 Continuous
# sitting_second_blood_pressure_pulse_rate                Continuous
# sitting_second_blood_pressure_systolic                  Continuous
# dizziness                                                  Boolean
#
#                                                        strata data_coding  \
# tabular_field_name
# collection_date                               Collection time         NaN
# collection_timestamp                          Collection time         NaN
# timezone                                      Collection time         NaN
# lying_blood_pressure_diastolic                        Primary         NaN
# lying_blood_pressure_pulse_rate                       Primary         NaN
# lying_blood_pressure_systolic                         Primary         NaN
# sitting_blood_pressure_diastolic                      Primary         NaN
# sitting_blood_pressure_pulse_rate                     Primary         NaN
# sitting_blood_pressure_systolic                       Primary         NaN
# standing_one_min_blood_pressure_diastolic             Primary         NaN
# standing_one_min_blood_pressure_pulse_rate            Primary         NaN
# standing_one_min_blood_pressure_systolic              Primary         NaN
# standing_three_min_blood_pressure_diastolic           Primary         NaN
# standing_three_min_blood_pressure_pulse_rate          Primary         NaN
# standing_three_min_blood_pressure_systolic            Primary         NaN
# blood_pressure_hand                                   Primary      007_01
# sitting_second_blood_pressure_diastolic               Primary         NaN
# sitting_second_blood_pressure_pulse_rate              Primary         NaN
# sitting_second_blood_pressure_systolic                Primary         NaN
# dizziness                                             Primary         NaN
#
#                                                array  \
# tabular_field_name
# collection_date                               Single
# collection_timestamp                          Single
# timezone                                      Single
# lying_blood_pressure_diastolic                Single
# lying_blood_pressure_pulse_rate               Single
# lying_blood_pressure_systolic                 Single
# sitting_blood_pressure_diastolic              Single
# sitting_blood_pressure_pulse_rate             Single
# sitting_blood_pressure_systolic               Single
# standing_one_min_blood_pressure_diastolic     Single
# standing_one_min_blood_pressure_pulse_rate    Single
# standing_one_min_blood_pressure_systolic      Single
# standing_three_min_blood_pressure_diastolic   Single
# standing_three_min_blood_pressure_pulse_rate  Single
# standing_three_min_blood_pressure_systolic    Single
# blood_pressure_hand                           Single
# sitting_second_blood_pressure_diastolic       Single
# sitting_second_blood_pressure_pulse_rate      Single
# sitting_second_blood_pressure_systolic        Single
# dizziness                                     Single
#
#                                                                 pandas_dtype  \
# tabular_field_name
# collection_date                                               datetime64[ns]
# collection_timestamp                          datetime64[ns, Asia/Jerusalem]
# timezone                                                              string
# lying_blood_pressure_diastolic                                         float
# lying_blood_pressure_pulse_rate                                        float
# lying_blood_pressure_systolic                                          float
# sitting_blood_pressure_diastolic                                       float
# sitting_blood_pressure_pulse_rate                                      float
# sitting_blood_pressure_systolic                                        float
# standing_one_min_blood_pressure_diastolic                              float
# standing_one_min_blood_pressure_pulse_rate                             float
# standing_one_min_blood_pressure_systolic                               float
# standing_three_min_blood_pressure_diastolic                            float
# standing_three_min_blood_pressure_pulse_rate                           float
# standing_three_min_blood_pressure_systolic                             float
# blood_pressure_hand                                                 category
# sitting_second_blood_pressure_diastolic                                float
# sitting_second_blood_pressure_pulse_rate                               float
# sitting_second_blood_pressure_systolic                                 float
# dizziness                                                           category
#
#                                               bulk_file_extension  \
# tabular_field_name
# collection_date                                               NaN
# collection_timestamp                                          NaN
# timezone                                                      NaN
# lying_blood_pressure_diastolic                                NaN
# lying_blood_pressure_pulse_rate                               NaN
# lying_blood_pressure_systolic                                 NaN
# sitting_blood_pressure_diastolic                              NaN
# sitting_blood_pressure_pulse_rate                             NaN
# sitting_blood_pressure_systolic                               NaN
# standing_one_min_blood_pressure_diastolic                     NaN
# standing_one_min_blood_pressure_pulse_rate                    NaN
# standing_one_min_blood_pressure_systolic                      NaN
# standing_three_min_blood_pressure_diastolic                   NaN
# standing_three_min_blood_pressure_pulse_rate                  NaN
# standing_three_min_blood_pressure_systolic                    NaN
# blood_pressure_hand                                           NaN
# sitting_second_blood_pressure_diastolic                       NaN
# sitting_second_blood_pressure_pulse_rate                      NaN
# sitting_second_blood_pressure_systolic                        NaN
# dizziness                                                     NaN
#
#                                                                   relative_location  \
# tabular_field_name
# collection_date                               blood_pressure/blood_pressure.parquet
# collection_timestamp                          blood_pressure/blood_pressure.parquet
# timezone                                      blood_pressure/blood_pressure.parquet
# lying_blood_pressure_diastolic                blood_pressure/blood_pressure.parquet
# lying_blood_pressure_pulse_rate               blood_pressure/blood_pressure.parquet
# lying_blood_pressure_systolic                 blood_pressure/blood_pressure.parquet
# sitting_blood_pressure_diastolic              blood_pressure/blood_pressure.parquet
# sitting_blood_pressure_pulse_rate             blood_pressure/blood_pressure.parquet
# sitting_blood_pressure_systolic               blood_pressure/blood_pressure.parquet
# standing_one_min_blood_pressure_diastolic     blood_pressure/blood_pressure.parquet
# standing_one_min_blood_pressure_pulse_rate    blood_pressure/blood_pressure.parquet
# standing_one_min_blood_pressure_systolic      blood_pressure/blood_pressure.parquet
# standing_three_min_blood_pressure_diastolic   blood_pressure/blood_pressure.parquet
# standing_three_min_blood_pressure_pulse_rate  blood_pressure/blood_pressure.parquet
# standing_three_min_blood_pressure_systolic    blood_pressure/blood_pressure.parquet
# blood_pressure_hand                           blood_pressure/blood_pressure.parquet
# sitting_second_blood_pressure_diastolic       blood_pressure/blood_pressure.parquet
# sitting_second_blood_pressure_pulse_rate      blood_pressure/blood_pressure.parquet
# sitting_second_blood_pressure_systolic        blood_pressure/blood_pressure.parquet
# dizziness                                     blood_pressure/blood_pressure.parquet
#
#                                              units  bulk_dictionary  \
# tabular_field_name
# collection_date                               Time              NaN
# collection_timestamp                          Time              NaN
# timezone                                       NaN              NaN
# lying_blood_pressure_diastolic                mmHg              NaN
# lying_blood_pressure_pulse_rate                bpm              NaN
# lying_blood_pressure_systolic                 mmHg              NaN
# sitting_blood_pressure_diastolic              mmHg              NaN
# sitting_blood_pressure_pulse_rate              bpm              NaN
# sitting_blood_pressure_systolic               mmHg              NaN
# standing_one_min_blood_pressure_diastolic     mmHg              NaN
# standing_one_min_blood_pressure_pulse_rate     bpm              NaN
# standing_one_min_blood_pressure_systolic      mmHg              NaN
# standing_three_min_blood_pressure_diastolic   mmHg              NaN
# standing_three_min_blood_pressure_pulse_rate   bpm              NaN
# standing_three_min_blood_pressure_systolic    mmHg              NaN
# blood_pressure_hand                            NaN              NaN
# sitting_second_blood_pressure_diastolic       mmHg              NaN
# sitting_second_blood_pressure_pulse_rate       bpm              NaN
# sitting_second_blood_pressure_systolic        mmHg              NaN
# dizziness                                      NaN              NaN
#
#                                               sampling_rate  transformation  \
# tabular_field_name
# collection_date                                         NaN             NaN
# collection_timestamp                                    NaN             NaN
# timezone                                                NaN             NaN
# lying_blood_pressure_diastolic                          NaN             NaN
# lying_blood_pressure_pulse_rate                         NaN             NaN
# lying_blood_pressure_systolic                           NaN             NaN
# sitting_blood_pressure_diastolic                        NaN             NaN
# sitting_blood_pressure_pulse_rate                       NaN             NaN
# sitting_blood_pressure_systolic                         NaN             NaN
# standing_one_min_blood_pressure_diastolic               NaN             NaN
# standing_one_min_blood_pressure_pulse_rate              NaN             NaN
# standing_one_min_blood_pressure_systolic                NaN             NaN
# standing_three_min_blood_pressure_diastolic             NaN             NaN
# standing_three_min_blood_pressure_pulse_rate            NaN             NaN
# standing_three_min_blood_pressure_systolic              NaN             NaN
# blood_pressure_hand                                     NaN             NaN
# sitting_second_blood_pressure_diastolic                 NaN             NaN
# sitting_second_blood_pressure_pulse_rate                NaN             NaN
# sitting_second_blood_pressure_systolic                  NaN             NaN
# dizziness                                               NaN             NaN
#
#                                                                    list_of_tags  \
# tabular_field_name
# collection_date                               Blood pressure, Physical measures
# collection_timestamp                          Blood pressure, Physical measures
# timezone                                      Blood pressure, Physical measures
# lying_blood_pressure_diastolic                Blood pressure, Physical measures
# lying_blood_pressure_pulse_rate               Blood pressure, Physical measures
# lying_blood_pressure_systolic                 Blood pressure, Physical measures
# sitting_blood_pressure_diastolic              Blood pressure, Physical measures
# sitting_blood_pressure_pulse_rate             Blood pressure, Physical measures
# sitting_blood_pressure_systolic               Blood pressure, Physical measures
# standing_one_min_blood_pressure_diastolic     Blood pressure, Physical measures
# standing_one_min_blood_pressure_pulse_rate    Blood pressure, Physical measures
# standing_one_min_blood_pressure_systolic      Blood pressure, Physical measures
# standing_three_min_blood_pressure_diastolic   Blood pressure, Physical measures
# standing_three_min_blood_pressure_pulse_rate  Blood pressure, Physical measures
# standing_three_min_blood_pressure_systolic    Blood pressure, Physical measures
# blood_pressure_hand                           Blood pressure, Physical measures
# sitting_second_blood_pressure_diastolic       Blood pressure, Physical measures
# sitting_second_blood_pressure_pulse_rate      Blood pressure, Physical measures
# sitting_second_blood_pressure_systolic        Blood pressure, Physical measures
# dizziness                                     Blood pressure, Physical measures
#
#                                              stability       sexed  \
# tabular_field_name
# collection_date                               Accruing  Both sexes
# collection_timestamp                          Accruing  Both sexes
# timezone                                      Accruing  Both sexes
# lying_blood_pressure_diastolic                Accruing  Both sexes
# lying_blood_pressure_pulse_rate               Accruing  Both sexes
# lying_blood_pressure_systolic                 Accruing  Both sexes
# sitting_blood_pressure_diastolic              Accruing  Both sexes
# sitting_blood_pressure_pulse_rate             Accruing  Both sexes
# sitting_blood_pressure_systolic               Accruing  Both sexes
# standing_one_min_blood_pressure_diastolic     Accruing  Both sexes
# standing_one_min_blood_pressure_pulse_rate    Accruing  Both sexes
# standing_one_min_blood_pressure_systolic      Accruing  Both sexes
# standing_three_min_blood_pressure_diastolic   Accruing  Both sexes
# standing_three_min_blood_pressure_pulse_rate  Accruing  Both sexes
# standing_three_min_blood_pressure_systolic    Accruing  Both sexes
# blood_pressure_hand                           Accruing  Both sexes
# sitting_second_blood_pressure_diastolic       Accruing  Both sexes
# sitting_second_blood_pressure_pulse_rate      Accruing  Both sexes
# sitting_second_blood_pressure_systolic        Accruing  Both sexes
# dizziness                                     Accruing  Both sexes
#
#                                                    debut  completed
# tabular_field_name
# collection_date                               2019-01-29        NaN
# collection_timestamp                          2019-01-29        NaN
# timezone                                      2019-01-29        NaN
# lying_blood_pressure_diastolic                2019-01-29        NaN
# lying_blood_pressure_pulse_rate               2019-01-29        NaN
# lying_blood_pressure_systolic                 2019-01-29        NaN
# sitting_blood_pressure_diastolic              2019-01-29        NaN
# sitting_blood_pressure_pulse_rate             2019-01-29        NaN
# sitting_blood_pressure_systolic               2019-01-29        NaN
# standing_one_min_blood_pressure_diastolic     2019-01-29        NaN
# standing_one_min_blood_pressure_pulse_rate    2019-01-29        NaN
# standing_one_min_blood_pressure_systolic      2019-01-29        NaN
# standing_three_min_blood_pressure_diastolic   2019-01-29        NaN
# standing_three_min_blood_pressure_pulse_rate  2019-01-29        NaN
# standing_three_min_blood_pressure_systolic    2019-01-29        NaN
# blood_pressure_hand                           2022-06-12        NaN
# sitting_second_blood_pressure_diastolic       2022-06-12        NaN
# sitting_second_blood_pressure_pulse_rate      2022-06-12        NaN
# sitting_second_blood_pressure_systolic        2022-06-12        NaN
# dizziness                                     2019-01-29        NaN
