# %% [raw]
# ---
# output-file: 057-psychological_and_social_health.html
# title: Psychological and Social Health
# ---

# %% [markdown]
# ### Description
#
# Psychological and social health data captures mental well-being, emotional states, social connections, and life satisfaction across multiple domains. This includes measures of mood, anxiety, depression, social support networks, and satisfaction with various life aspects. Understanding psychological and social health is crucial as these factors significantly influence physical health outcomes, disease progression, and overall quality of life.
#
# ### Introduction
#
# The Human Phenotype Project conducts comprehensive data collection through online surveys, where participants voluntarily provide information on various aspects influencing their health. This includes information about psychological and social health factors, captured through two lifestyle surveys.
#
# ### Measurement protocol
# <!-- long measurment protocol for the data browser -->
# These lifestyle surveys are modeled after the UK Biobank's touch screen questionnaire. Participants receive the full version via email to complete on the Zoho platform, either before or after their baseline visit. A shorter, follow-up version of the questionnaire is then filled out by participants during subsequent visits.
#
# ### Data availability
# <!-- for the example notebooks -->
# The information is stored in 1 parquet file: `psychological_and_social_health`
#
# ### Summary of available data
# <!-- for the data browser -->
# The dataset includes comprehensive psychological and social health measures across several domains:
#
# **Social Connections:**
# - Frequency of friend and family visits
# - Participation in leisure and social activities
# - Loneliness and isolation feelings
# - Ability to confide in others
#
# **Mood and Emotional States:**
# - Mood swings
# - Miserableness and fed-up feelings
# - Irritability
# - Happiness levels
# - Sensitivity and hurt feelings
# - Nervous feelings
#
# **Anxiety and Worry:**
# - Worrier/anxious feelings
# - Tense or 'highly strung' feelings
# - Worry duration after embarrassment
# - Suffering from 'nerves'
# - Guilt feelings
#
# **Depression Symptoms:**
# - Frequency of depressed mood in last 2 weeks
# - Frequency of unenthusiasm/disinterest in last 2 weeks
# - Ever depressed for a whole week
# - Longest period of depression
# - Number of depression episodes
# - Ever unenthusiastic/disinterested for a whole week
# - Longest period of unenthusiasm/disinterest
# - Number of unenthusiastic/disinterested episodes
#
# **Manic/Hypomanic Symptoms:**
# - Ever manic/hyper for 2 days
# - Ever highly irritable/argumentative for 2 days
# - Manic/hyper symptoms
# - Length of longest manic/irritable episode
# - Severity of manic/irritable episodes
#
# **Mental Health Care:**
# - Seen doctor (GP) for nerves, anxiety, tension or depression
# - Seen a psychiatrist for nerves, anxiety, tension or depression
#
# **Life Satisfaction:**
# - Work/job satisfaction
# - Health satisfaction
# - Family relationship satisfaction
# - Friendships satisfaction
# - Financial situation satisfaction
#
# **Personality and Behavioral Traits:**
# - Risk-taking behavior
# - Frequency of tenseness/restlessness in last 2 weeks
# - Frequency of tiredness/lethargy in last 2 weeks
#
# **Life Events:**
# - Illness, injury, bereavement, stress
#
# This comprehensive assessment enables research into the relationships between psychological well-being, social factors, and physical health outcomes.
#
# ### Relevant links
#
# * [Pheno Knowledgebase](https://knowledgebase.pheno.ai/datasets/057-psychological_and_social_health.html)
# * [Pheno Data Browser](https://pheno-demo-app.vercel.app/folder/57)

# %%
#| echo: false
import pandas as pd
pd.set_option("display.max_rows", 500)

# %%
from pheno_utils import PhenoLoader

# %%
pl = PhenoLoader('psychological_and_social_health')
pl
# Out:
# PhenoLoader for psychological_and_social_health with
# 46 fields
# 2 tables: ['psychological_and_social_health', 'age_sex']

# %% [markdown]
# # Data dictionary

# %%
pl.dict
# Out:
#                                                     folder_id  \
# tabular_field_name
# activity_social_visit_frequency                            57
# activity_social_weekly                                     57
# health_mental_current_mood_swings_frequency                57
# health_mental_current_miserable                            57
# health_mental_current_irritable                            57
# health_mental_current_sensitive                            57
# health_mental_current_fed_up                               57
# health_mental_current_nervous                              57
# health_mental_current_worrier                              57
# health_mental_current_tense                                57
# health_mental_current_worry_after_embarassment             57
# health_mental_current_nerves                               57
# health_mental_current_lonely                               57
# health_mental_current_guilt                                57
# health_mental_current_risk_taker                           57
# health_mental_current_happiness                            57
# health_mental_current_satisfaction_work                    57
# health_mental_current_satisfaction_health                  57
# health_mental_current_satisfaction_family_relat...         57
# health_mental_current_satisfaction_friends_rela...         57
# health_mental_current_satisfaction_financial               57
# health_mental_past_two_week_depression_frequency           57
# health_mental_past_two_week_disinterest_frequency          57
# health_mental_past_two_week_restless_frequency             57
# health_mental_past_two_week_tired_frequency                57
# health_mental_past_doctor                                  57
# health_mental_past_psychiatrist                            57
# health_mental_past_depression_week                         57
# health_mental_past_depression_longest                      57
# health_mental_past_depression_episodes_number              57
# health_mental_past_disinterest_week                        57
# health_mental_past_disinterest_longest                     57
# health_mental_past_disinterest_episodes_number             57
# health_mental_past_manic_two_days                          57
# health_mental_past_irritable_two_days                      57
# health_mental_past_manic_symptoms                          57
# health_mental_past_manic_irritable_longest                 57
# health_mental_past_manic_irritable_problems                57
# health_mental_current_able_to_confide                      57
# health_mental_past_two_years_event                         57
# collection_timestamp                                       57
# collection_date                                            57
# timezone                                                   57
# data_source                                                57
#
#                                                                         feature_set  \
# tabular_field_name
# activity_social_visit_frequency                     psychological_and_social_health
# activity_social_weekly                              psychological_and_social_health
# health_mental_current_mood_swings_frequency         psychological_and_social_health
# health_mental_current_miserable                     psychological_and_social_health
# health_mental_current_irritable                     psychological_and_social_health
# health_mental_current_sensitive                     psychological_and_social_health
# health_mental_current_fed_up                        psychological_and_social_health
# health_mental_current_nervous                       psychological_and_social_health
# health_mental_current_worrier                       psychological_and_social_health
# health_mental_current_tense                         psychological_and_social_health
# health_mental_current_worry_after_embarassment      psychological_and_social_health
# health_mental_current_nerves                        psychological_and_social_health
# health_mental_current_lonely                        psychological_and_social_health
# health_mental_current_guilt                         psychological_and_social_health
# health_mental_current_risk_taker                    psychological_and_social_health
# health_mental_current_happiness                     psychological_and_social_health
# health_mental_current_satisfaction_work             psychological_and_social_health
# health_mental_current_satisfaction_health           psychological_and_social_health
# health_mental_current_satisfaction_family_relat...  psychological_and_social_health
# health_mental_current_satisfaction_friends_rela...  psychological_and_social_health
# health_mental_current_satisfaction_financial        psychological_and_social_health
# health_mental_past_two_week_depression_frequency    psychological_and_social_health
# health_mental_past_two_week_disinterest_frequency   psychological_and_social_health
# health_mental_past_two_week_restless_frequency      psychological_and_social_health
# health_mental_past_two_week_tired_frequency         psychological_and_social_health
# health_mental_past_doctor                           psychological_and_social_health
# health_mental_past_psychiatrist                     psychological_and_social_health
# health_mental_past_depression_week                  psychological_and_social_health
# health_mental_past_depression_longest               psychological_and_social_health
# health_mental_past_depression_episodes_number       psychological_and_social_health
# health_mental_past_disinterest_week                 psychological_and_social_health
# health_mental_past_disinterest_longest              psychological_and_social_health
# health_mental_past_disinterest_episodes_number      psychological_and_social_health
# health_mental_past_manic_two_days                   psychological_and_social_health
# health_mental_past_irritable_two_days               psychological_and_social_health
# health_mental_past_manic_symptoms                   psychological_and_social_health
# health_mental_past_manic_irritable_longest          psychological_and_social_health
# health_mental_past_manic_irritable_problems         psychological_and_social_health
# health_mental_current_able_to_confide               psychological_and_social_health
# health_mental_past_two_years_event                  psychological_and_social_health
# collection_timestamp                                psychological_and_social_health
# collection_date                                     psychological_and_social_health
# timezone                                            psychological_and_social_health
# data_source                                         psychological_and_social_health
#
#                                                                                          field_string  \
# tabular_field_name
# activity_social_visit_frequency                                     Frequency of friend/family visits
# activity_social_weekly                                                      Leisure/social activities
# health_mental_current_mood_swings_frequency                                               Mood swings
# health_mental_current_miserable                                                         Miserableness
# health_mental_current_irritable                                                          Irritability
# health_mental_current_sensitive                                           Sensitivity / hurt feelings
# health_mental_current_fed_up                                                          Fed-up feelings
# health_mental_current_nervous                                                        Nervous feelings
# health_mental_current_worrier                                              Worrier / anxious feelings
# health_mental_current_tense                                                   Tense / 'highly strung'
# health_mental_current_worry_after_embarassment                     Worry too long after embarrassment
# health_mental_current_nerves                                                     Suffer from 'nerves'
# health_mental_current_lonely                                                    Loneliness, isolation
# health_mental_current_guilt                                                           Guilty feelings
# health_mental_current_risk_taker                                                          Risk taking
# health_mental_current_happiness                                                             Happiness
# health_mental_current_satisfaction_work                                         Work/job satisfaction
# health_mental_current_satisfaction_health                                         Health satisfaction
# health_mental_current_satisfaction_family_relat...                   Family relationship satisfaction
# health_mental_current_satisfaction_friends_rela...                           Friendships satisfaction
# health_mental_current_satisfaction_financial                         Financial situation satisfaction
# health_mental_past_two_week_depression_frequency          Frequency of depressed mood in last 2 weeks
# health_mental_past_two_week_disinterest_frequency   Frequency of unenthusiasm / disinterest in las...
# health_mental_past_two_week_restless_frequency      Frequency of tenseness / restlessness in last ...
# health_mental_past_two_week_tired_frequency         Frequency of tiredness / lethargy in last 2 weeks
# health_mental_past_doctor                           Seen doctor (GP) for nerves, anxiety, tension ...
# health_mental_past_psychiatrist                     Seen a psychiatrist for nerves, anxiety, tensi...
# health_mental_past_depression_week                                    Ever depressed for a whole week
# health_mental_past_depression_longest                                    Longest period of depression
# health_mental_past_depression_episodes_number                           Number of depression episodes
# health_mental_past_disinterest_week                 Ever unenthusiastic/disinterested for a whole ...
# health_mental_past_disinterest_longest                   Longest period of unenthusiasm / disinterest
# health_mental_past_disinterest_episodes_number        Number of unenthusiastic/disinterested episodes
# health_mental_past_manic_two_days                                         Ever manic/hyper for 2 days
# health_mental_past_irritable_two_days                  Ever highly irritable/argumentative for 2 days
# health_mental_past_manic_symptoms                                                Manic/hyper symptoms
# health_mental_past_manic_irritable_longest                  Length of longest manic/irritable episode
# health_mental_past_manic_irritable_problems                      Severity of manic/irritable episodes
# health_mental_current_able_to_confide                                                 Able to confide
# health_mental_past_two_years_event                  Illness, injury, bereavement, stress in last 2...
# collection_timestamp                                                             Collection timestamp
# collection_date                                                                       Collection date
# timezone                                                                                     Timezone
# data_source                                                                               Data source
#
#                                                                                     relative_location  \
# tabular_field_name
# activity_social_visit_frequency                     psychological_and_social_health/psychological_...
# activity_social_weekly                              psychological_and_social_health/psychological_...
# health_mental_current_mood_swings_frequency         psychological_and_social_health/psychological_...
# health_mental_current_miserable                     psychological_and_social_health/psychological_...
# health_mental_current_irritable                     psychological_and_social_health/psychological_...
# health_mental_current_sensitive                     psychological_and_social_health/psychological_...
# health_mental_current_fed_up                        psychological_and_social_health/psychological_...
# health_mental_current_nervous                       psychological_and_social_health/psychological_...
# health_mental_current_worrier                       psychological_and_social_health/psychological_...
# health_mental_current_tense                         psychological_and_social_health/psychological_...
# health_mental_current_worry_after_embarassment      psychological_and_social_health/psychological_...
# health_mental_current_nerves                        psychological_and_social_health/psychological_...
# health_mental_current_lonely                        psychological_and_social_health/psychological_...
# health_mental_current_guilt                         psychological_and_social_health/psychological_...
# health_mental_current_risk_taker                    psychological_and_social_health/psychological_...
# health_mental_current_happiness                     psychological_and_social_health/psychological_...
# health_mental_current_satisfaction_work             psychological_and_social_health/psychological_...
# health_mental_current_satisfaction_health           psychological_and_social_health/psychological_...
# health_mental_current_satisfaction_family_relat...  psychological_and_social_health/psychological_...
# health_mental_current_satisfaction_friends_rela...  psychological_and_social_health/psychological_...
# health_mental_current_satisfaction_financial        psychological_and_social_health/psychological_...
# health_mental_past_two_week_depression_frequency    psychological_and_social_health/psychological_...
# health_mental_past_two_week_disinterest_frequency   psychological_and_social_health/psychological_...
# health_mental_past_two_week_restless_frequency      psychological_and_social_health/psychological_...
# health_mental_past_two_week_tired_frequency         psychological_and_social_health/psychological_...
# health_mental_past_doctor                           psychological_and_social_health/psychological_...
# health_mental_past_psychiatrist                     psychological_and_social_health/psychological_...
# health_mental_past_depression_week                  psychological_and_social_health/psychological_...
# health_mental_past_depression_longest               psychological_and_social_health/psychological_...
# health_mental_past_depression_episodes_number       psychological_and_social_health/psychological_...
# health_mental_past_disinterest_week                 psychological_and_social_health/psychological_...
# health_mental_past_disinterest_longest              psychological_and_social_health/psychological_...
# health_mental_past_disinterest_episodes_number      psychological_and_social_health/psychological_...
# health_mental_past_manic_two_days                   psychological_and_social_health/psychological_...
# health_mental_past_irritable_two_days               psychological_and_social_health/psychological_...
# health_mental_past_manic_symptoms                   psychological_and_social_health/psychological_...
# health_mental_past_manic_irritable_longest          psychological_and_social_health/psychological_...
# health_mental_past_manic_irritable_problems         psychological_and_social_health/psychological_...
# health_mental_current_able_to_confide               psychological_and_social_health/psychological_...
# health_mental_past_two_years_event                  psychological_and_social_health/psychological_...
# collection_timestamp                                psychological_and_social_health/psychological_...
# collection_date                                     psychological_and_social_health/psychological_...
# timezone                                            psychological_and_social_health/psychological_...
# data_source                                         psychological_and_social_health/psychological_...
#
#                                                     bulk_file_extension  \
# tabular_field_name
# activity_social_visit_frequency                                     NaN
# activity_social_weekly                                              NaN
# health_mental_current_mood_swings_frequency                         NaN
# health_mental_current_miserable                                     NaN
# health_mental_current_irritable                                     NaN
# health_mental_current_sensitive                                     NaN
# health_mental_current_fed_up                                        NaN
# health_mental_current_nervous                                       NaN
# health_mental_current_worrier                                       NaN
# health_mental_current_tense                                         NaN
# health_mental_current_worry_after_embarassment                      NaN
# health_mental_current_nerves                                        NaN
# health_mental_current_lonely                                        NaN
# health_mental_current_guilt                                         NaN
# health_mental_current_risk_taker                                    NaN
# health_mental_current_happiness                                     NaN
# health_mental_current_satisfaction_work                             NaN
# health_mental_current_satisfaction_health                           NaN
# health_mental_current_satisfaction_family_relat...                  NaN
# health_mental_current_satisfaction_friends_rela...                  NaN
# health_mental_current_satisfaction_financial                        NaN
# health_mental_past_two_week_depression_frequency                    NaN
# health_mental_past_two_week_disinterest_frequency                   NaN
# health_mental_past_two_week_restless_frequency                      NaN
# health_mental_past_two_week_tired_frequency                         NaN
# health_mental_past_doctor                                           NaN
# health_mental_past_psychiatrist                                     NaN
# health_mental_past_depression_week                                  NaN
# health_mental_past_depression_longest                               NaN
# health_mental_past_depression_episodes_number                       NaN
# health_mental_past_disinterest_week                                 NaN
# health_mental_past_disinterest_longest                              NaN
# health_mental_past_disinterest_episodes_number                      NaN
# health_mental_past_manic_two_days                                   NaN
# health_mental_past_irritable_two_days                               NaN
# health_mental_past_manic_symptoms                                   NaN
# health_mental_past_manic_irritable_longest                          NaN
# health_mental_past_manic_irritable_problems                         NaN
# health_mental_current_able_to_confide                               NaN
# health_mental_past_two_years_event                                  NaN
# collection_timestamp                                                NaN
# collection_date                                                     NaN
# timezone                                                            NaN
# data_source                                                         NaN
#
#                                                     bulk_dictionary  \
# tabular_field_name
# activity_social_visit_frequency                                 NaN
# activity_social_weekly                                          NaN
# health_mental_current_mood_swings_frequency                     NaN
# health_mental_current_miserable                                 NaN
# health_mental_current_irritable                                 NaN
# health_mental_current_sensitive                                 NaN
# health_mental_current_fed_up                                    NaN
# health_mental_current_nervous                                   NaN
# health_mental_current_worrier                                   NaN
# health_mental_current_tense                                     NaN
# health_mental_current_worry_after_embarassment                  NaN
# health_mental_current_nerves                                    NaN
# health_mental_current_lonely                                    NaN
# health_mental_current_guilt                                     NaN
# health_mental_current_risk_taker                                NaN
# health_mental_current_happiness                                 NaN
# health_mental_current_satisfaction_work                         NaN
# health_mental_current_satisfaction_health                       NaN
# health_mental_current_satisfaction_family_relat...              NaN
# health_mental_current_satisfaction_friends_rela...              NaN
# health_mental_current_satisfaction_financial                    NaN
# health_mental_past_two_week_depression_frequency                NaN
# health_mental_past_two_week_disinterest_frequency               NaN
# health_mental_past_two_week_restless_frequency                  NaN
# health_mental_past_two_week_tired_frequency                     NaN
# health_mental_past_doctor                                       NaN
# health_mental_past_psychiatrist                                 NaN
# health_mental_past_depression_week                              NaN
# health_mental_past_depression_longest                           NaN
# health_mental_past_depression_episodes_number                   NaN
# health_mental_past_disinterest_week                             NaN
# health_mental_past_disinterest_longest                          NaN
# health_mental_past_disinterest_episodes_number                  NaN
# health_mental_past_manic_two_days                               NaN
# health_mental_past_irritable_two_days                           NaN
# health_mental_past_manic_symptoms                               NaN
# health_mental_past_manic_irritable_longest                      NaN
# health_mental_past_manic_irritable_problems                     NaN
# health_mental_current_able_to_confide                           NaN
# health_mental_past_two_years_event                              NaN
# collection_timestamp                                            NaN
# collection_date                                                 NaN
# timezone                                                        NaN
# data_source                                                     NaN
#
#                                                                                    description_string  \
# tabular_field_name
# activity_social_visit_frequency                     How often do you visit friends or family or ha...
# activity_social_weekly                              Which of the following do you attend once a we...
# health_mental_current_mood_swings_frequency                      Does your mood often go up and down?
# health_mental_current_miserable                      Do you ever feel 'just miserable' for no reason?
# health_mental_current_irritable                                          Are you an irritable person?
# health_mental_current_sensitive                                        Are your feelings easily hurt?
# health_mental_current_fed_up                                              Do you often feel 'fed-up'?
# health_mental_current_nervous                               Would you call yourself a nervous person?
# health_mental_current_worrier                                                      Are you a worrier?
# health_mental_current_tense                         Would you call yourself tense or 'highly strung'?
# health_mental_current_worry_after_embarassment      Do you worry too long after an embarrassing ex...
# health_mental_current_nerves                                             Do you suffer from 'nerves'?
# health_mental_current_lonely                                                Do you often feel lonely?
# health_mental_current_guilt                              Are you often troubled by feelings of guilt?
# health_mental_current_risk_taker                    Would you describe yourself as someone who tak...
# health_mental_current_happiness                                         In general how happy are you?
# health_mental_current_satisfaction_work             In general how satisfied are you with the WORK...
# health_mental_current_satisfaction_health           In general how satisfied are you with your HEA...
# health_mental_current_satisfaction_family_relat...  In general how satisfied are you with your FAM...
# health_mental_current_satisfaction_friends_rela...  In general how satisfied are you with your FRI...
# health_mental_current_satisfaction_financial        In general how satisfied are you with your FIN...
# health_mental_past_two_week_depression_frequency    Over the past two weeks, how often have you fe...
# health_mental_past_two_week_disinterest_frequency   Over the past two weeks, how often have you ha...
# health_mental_past_two_week_restless_frequency      Over the past two weeks, how often have you fe...
# health_mental_past_two_week_tired_frequency         Over the past two weeks, how often have you fe...
# health_mental_past_doctor                           Have you ever seen a general practitioner (GP)...
# health_mental_past_psychiatrist                     Have you ever seen a psychiatrist for nerves, ...
# health_mental_past_depression_week                  Looking back over your life, have you ever had...
# health_mental_past_depression_longest               How many weeks was the longest period when you...
# health_mental_past_depression_episodes_number       How many periods have you had when you were fe...
# health_mental_past_disinterest_week                 Have you ever had a time when you were uninter...
# health_mental_past_disinterest_longest              How many weeks was the longest period when you...
# health_mental_past_disinterest_episodes_number      How many periods have you had when you were un...
# health_mental_past_manic_two_days                   Have you ever had a period of time lasting at ...
# health_mental_past_irritable_two_days               Have you ever had a period of time lasting at ...
# health_mental_past_manic_symptoms                   Please try to remember a period when you were ...
# health_mental_past_manic_irritable_longest          What is the longest time period that these "hi...
# health_mental_past_manic_irritable_problems         How much of a problem have these "high" or "ir...
# health_mental_current_able_to_confide               How often are you able to confide in someone c...
# health_mental_past_two_years_event                  In the last 2 years have you experienced any o...
# collection_timestamp                                                             Collection timestamp
# collection_date                                                                       Collection date
# timezone                                                                                     Timezone
# data_source                                                        Data source of survey information
#
#                                                                 field_type  \
# tabular_field_name
# activity_social_visit_frequency                       Categorical (single)
# activity_social_weekly                              Categorical (multiple)
# health_mental_current_mood_swings_frequency           Categorical (single)
# health_mental_current_miserable                       Categorical (single)
# health_mental_current_irritable                       Categorical (single)
# health_mental_current_sensitive                       Categorical (single)
# health_mental_current_fed_up                          Categorical (single)
# health_mental_current_nervous                         Categorical (single)
# health_mental_current_worrier                         Categorical (single)
# health_mental_current_tense                           Categorical (single)
# health_mental_current_worry_after_embarassment        Categorical (single)
# health_mental_current_nerves                          Categorical (single)
# health_mental_current_lonely                          Categorical (single)
# health_mental_current_guilt                           Categorical (single)
# health_mental_current_risk_taker                      Categorical (single)
# health_mental_current_happiness                       Categorical (single)
# health_mental_current_satisfaction_work               Categorical (single)
# health_mental_current_satisfaction_health             Categorical (single)
# health_mental_current_satisfaction_family_relat...    Categorical (single)
# health_mental_current_satisfaction_friends_rela...    Categorical (single)
# health_mental_current_satisfaction_financial          Categorical (single)
# health_mental_past_two_week_depression_frequency      Categorical (single)
# health_mental_past_two_week_disinterest_frequency     Categorical (single)
# health_mental_past_two_week_restless_frequency        Categorical (single)
# health_mental_past_two_week_tired_frequency           Categorical (single)
# health_mental_past_doctor                             Categorical (single)
# health_mental_past_psychiatrist                       Categorical (single)
# health_mental_past_depression_week                    Categorical (single)
# health_mental_past_depression_longest                              Integer
# health_mental_past_depression_episodes_number                      Integer
# health_mental_past_disinterest_week                   Categorical (single)
# health_mental_past_disinterest_longest                             Integer
# health_mental_past_disinterest_episodes_number                     Integer
# health_mental_past_manic_two_days                     Categorical (single)
# health_mental_past_irritable_two_days                 Categorical (single)
# health_mental_past_manic_symptoms                     Categorical (single)
# health_mental_past_manic_irritable_longest            Categorical (single)
# health_mental_past_manic_irritable_problems           Categorical (single)
# health_mental_current_able_to_confide                 Categorical (single)
# health_mental_past_two_years_event                  Categorical (multiple)
# collection_timestamp                                              Datetime
# collection_date                                                       Date
# timezone                                              Categorical (single)
# data_source                                                           Text
#
#                                                        array  \
# tabular_field_name
# activity_social_visit_frequency                       Single
# activity_social_weekly                              Multiple
# health_mental_current_mood_swings_frequency           Single
# health_mental_current_miserable                       Single
# health_mental_current_irritable                       Single
# health_mental_current_sensitive                       Single
# health_mental_current_fed_up                          Single
# health_mental_current_nervous                         Single
# health_mental_current_worrier                         Single
# health_mental_current_tense                           Single
# health_mental_current_worry_after_embarassment        Single
# health_mental_current_nerves                          Single
# health_mental_current_lonely                          Single
# health_mental_current_guilt                           Single
# health_mental_current_risk_taker                      Single
# health_mental_current_happiness                       Single
# health_mental_current_satisfaction_work               Single
# health_mental_current_satisfaction_health             Single
# health_mental_current_satisfaction_family_relat...    Single
# health_mental_current_satisfaction_friends_rela...    Single
# health_mental_current_satisfaction_financial          Single
# health_mental_past_two_week_depression_frequency      Single
# health_mental_past_two_week_disinterest_frequency     Single
# health_mental_past_two_week_restless_frequency        Single
# health_mental_past_two_week_tired_frequency           Single
# health_mental_past_doctor                             Single
# health_mental_past_psychiatrist                       Single
# health_mental_past_depression_week                    Single
# health_mental_past_depression_longest                 Single
# health_mental_past_depression_episodes_number         Single
# health_mental_past_disinterest_week                   Single
# health_mental_past_disinterest_longest                Single
# health_mental_past_disinterest_episodes_number        Single
# health_mental_past_manic_two_days                     Single
# health_mental_past_irritable_two_days                 Single
# health_mental_past_manic_symptoms                     Single
# health_mental_past_manic_irritable_longest            Single
# health_mental_past_manic_irritable_problems           Single
# health_mental_current_able_to_confide                 Single
# health_mental_past_two_years_event                  Multiple
# collection_timestamp                                  Single
# collection_date                                       Single
# timezone                                              Single
# data_source                                           Single
#
#                                                                       pandas_dtype  \
# tabular_field_name
# activity_social_visit_frequency                                                int
# activity_social_weekly                                                      object
# health_mental_current_mood_swings_frequency                                    int
# health_mental_current_miserable                                                int
# health_mental_current_irritable                                                int
# health_mental_current_sensitive                                                int
# health_mental_current_fed_up                                                   int
# health_mental_current_nervous                                                  int
# health_mental_current_worrier                                                  int
# health_mental_current_tense                                                    int
# health_mental_current_worry_after_embarassment                                 int
# health_mental_current_nerves                                                   int
# health_mental_current_lonely                                                   int
# health_mental_current_guilt                                                    int
# health_mental_current_risk_taker                                               int
# health_mental_current_happiness                                                int
# health_mental_current_satisfaction_work                                        int
# health_mental_current_satisfaction_health                                      int
# health_mental_current_satisfaction_family_relat...                             int
# health_mental_current_satisfaction_friends_rela...                             int
# health_mental_current_satisfaction_financial                                   int
# health_mental_past_two_week_depression_frequency                               int
# health_mental_past_two_week_disinterest_frequency                              int
# health_mental_past_two_week_restless_frequency                                 int
# health_mental_past_two_week_tired_frequency                                    int
# health_mental_past_doctor                                                      int
# health_mental_past_psychiatrist                                                int
# health_mental_past_depression_week                                             int
# health_mental_past_depression_longest                                          int
# health_mental_past_depression_episodes_number                                  int
# health_mental_past_disinterest_week                                            int
# health_mental_past_disinterest_longest                                         int
# health_mental_past_disinterest_episodes_number                                 int
# health_mental_past_manic_two_days                                              int
# health_mental_past_irritable_two_days                                          int
# health_mental_past_manic_symptoms                                              int
# health_mental_past_manic_irritable_longest                                     int
# health_mental_past_manic_irritable_problems                                    int
# health_mental_current_able_to_confide                                          int
# health_mental_past_two_years_event                                          object
# collection_timestamp                                datetime64[ns, Asia/Jerusalem]
# collection_date                                                     datetime64[ns]
# timezone                                                                  category
# data_source                                                                 string
#
#                                                    stability  units  \
# tabular_field_name
# activity_social_visit_frequency                     Accruing    NaN
# activity_social_weekly                              Accruing    NaN
# health_mental_current_mood_swings_frequency         Accruing    NaN
# health_mental_current_miserable                     Accruing    NaN
# health_mental_current_irritable                     Accruing    NaN
# health_mental_current_sensitive                     Accruing    NaN
# health_mental_current_fed_up                        Accruing    NaN
# health_mental_current_nervous                       Accruing    NaN
# health_mental_current_worrier                       Accruing    NaN
# health_mental_current_tense                         Accruing    NaN
# health_mental_current_worry_after_embarassment      Accruing    NaN
# health_mental_current_nerves                        Accruing    NaN
# health_mental_current_lonely                        Accruing    NaN
# health_mental_current_guilt                         Accruing    NaN
# health_mental_current_risk_taker                    Accruing    NaN
# health_mental_current_happiness                     Accruing    NaN
# health_mental_current_satisfaction_work             Accruing    NaN
# health_mental_current_satisfaction_health           Accruing    NaN
# health_mental_current_satisfaction_family_relat...  Accruing    NaN
# health_mental_current_satisfaction_friends_rela...  Accruing    NaN
# health_mental_current_satisfaction_financial        Accruing    NaN
# health_mental_past_two_week_depression_frequency    Accruing    NaN
# health_mental_past_two_week_disinterest_frequency   Accruing    NaN
# health_mental_past_two_week_restless_frequency      Accruing    NaN
# health_mental_past_two_week_tired_frequency         Accruing    NaN
# health_mental_past_doctor                           Accruing    NaN
# health_mental_past_psychiatrist                     Accruing    NaN
# health_mental_past_depression_week                  Accruing    NaN
# health_mental_past_depression_longest               Accruing    NaN
# health_mental_past_depression_episodes_number       Accruing    NaN
# health_mental_past_disinterest_week                 Accruing    NaN
# health_mental_past_disinterest_longest              Accruing    NaN
# health_mental_past_disinterest_episodes_number      Accruing    NaN
# health_mental_past_manic_two_days                   Accruing    NaN
# health_mental_past_irritable_two_days               Accruing    NaN
# health_mental_past_manic_symptoms                   Accruing    NaN
# health_mental_past_manic_irritable_longest          Accruing    NaN
# health_mental_past_manic_irritable_problems         Accruing    NaN
# health_mental_current_able_to_confide               Accruing    NaN
# health_mental_past_two_years_event                  Accruing    NaN
# collection_timestamp                                Accruing    NaN
# collection_date                                     Accruing    NaN
# timezone                                            Accruing    NaN
# data_source                                         Accruing    NaN
#
#                                                     sampling_rate  \
# tabular_field_name
# activity_social_visit_frequency                               NaN
# activity_social_weekly                                        NaN
# health_mental_current_mood_swings_frequency                   NaN
# health_mental_current_miserable                               NaN
# health_mental_current_irritable                               NaN
# health_mental_current_sensitive                               NaN
# health_mental_current_fed_up                                  NaN
# health_mental_current_nervous                                 NaN
# health_mental_current_worrier                                 NaN
# health_mental_current_tense                                   NaN
# health_mental_current_worry_after_embarassment                NaN
# health_mental_current_nerves                                  NaN
# health_mental_current_lonely                                  NaN
# health_mental_current_guilt                                   NaN
# health_mental_current_risk_taker                              NaN
# health_mental_current_happiness                               NaN
# health_mental_current_satisfaction_work                       NaN
# health_mental_current_satisfaction_health                     NaN
# health_mental_current_satisfaction_family_relat...            NaN
# health_mental_current_satisfaction_friends_rela...            NaN
# health_mental_current_satisfaction_financial                  NaN
# health_mental_past_two_week_depression_frequency              NaN
# health_mental_past_two_week_disinterest_frequency             NaN
# health_mental_past_two_week_restless_frequency                NaN
# health_mental_past_two_week_tired_frequency                   NaN
# health_mental_past_doctor                                     NaN
# health_mental_past_psychiatrist                               NaN
# health_mental_past_depression_week                            NaN
# health_mental_past_depression_longest                         NaN
# health_mental_past_depression_episodes_number                 NaN
# health_mental_past_disinterest_week                           NaN
# health_mental_past_disinterest_longest                        NaN
# health_mental_past_disinterest_episodes_number                NaN
# health_mental_past_manic_two_days                             NaN
# health_mental_past_irritable_two_days                         NaN
# health_mental_past_manic_symptoms                             NaN
# health_mental_past_manic_irritable_longest                    NaN
# health_mental_past_manic_irritable_problems                   NaN
# health_mental_current_able_to_confide                         NaN
# health_mental_past_two_years_event                            NaN
# collection_timestamp                                          NaN
# collection_date                                               NaN
# timezone                                                      NaN
# data_source                                                   NaN
#
#                                                              strata  \
# tabular_field_name
# activity_social_visit_frequency                             Primary
# activity_social_weekly                                      Primary
# health_mental_current_mood_swings_frequency                 Primary
# health_mental_current_miserable                             Primary
# health_mental_current_irritable                             Primary
# health_mental_current_sensitive                             Primary
# health_mental_current_fed_up                                Primary
# health_mental_current_nervous                               Primary
# health_mental_current_worrier                               Primary
# health_mental_current_tense                                 Primary
# health_mental_current_worry_after_embarassment              Primary
# health_mental_current_nerves                                Primary
# health_mental_current_lonely                                Primary
# health_mental_current_guilt                                 Primary
# health_mental_current_risk_taker                            Primary
# health_mental_current_happiness                             Primary
# health_mental_current_satisfaction_work                     Primary
# health_mental_current_satisfaction_health                   Primary
# health_mental_current_satisfaction_family_relat...          Primary
# health_mental_current_satisfaction_friends_rela...          Primary
# health_mental_current_satisfaction_financial                Primary
# health_mental_past_two_week_depression_frequency            Primary
# health_mental_past_two_week_disinterest_frequency           Primary
# health_mental_past_two_week_restless_frequency              Primary
# health_mental_past_two_week_tired_frequency                 Primary
# health_mental_past_doctor                                   Primary
# health_mental_past_psychiatrist                             Primary
# health_mental_past_depression_week                          Primary
# health_mental_past_depression_longest                       Primary
# health_mental_past_depression_episodes_number               Primary
# health_mental_past_disinterest_week                         Primary
# health_mental_past_disinterest_longest                      Primary
# health_mental_past_disinterest_episodes_number              Primary
# health_mental_past_manic_two_days                           Primary
# health_mental_past_irritable_two_days                       Primary
# health_mental_past_manic_symptoms                           Primary
# health_mental_past_manic_irritable_longest                  Primary
# health_mental_past_manic_irritable_problems                 Primary
# health_mental_current_able_to_confide                       Primary
# health_mental_past_two_years_event                          Primary
# collection_timestamp                                Collection time
# collection_date                                     Collection time
# timezone                                            Collection time
# data_source                                               Auxiliary
#
#                                                          sexed     debut  \
# tabular_field_name
# activity_social_visit_frequency                     Both sexes  1/9/2019
# activity_social_weekly                              Both sexes  1/9/2019
# health_mental_current_mood_swings_frequency         Both sexes  1/9/2019
# health_mental_current_miserable                     Both sexes  1/9/2019
# health_mental_current_irritable                     Both sexes  1/9/2019
# health_mental_current_sensitive                     Both sexes  1/9/2019
# health_mental_current_fed_up                        Both sexes  1/9/2019
# health_mental_current_nervous                       Both sexes  1/9/2019
# health_mental_current_worrier                       Both sexes  1/9/2019
# health_mental_current_tense                         Both sexes  1/9/2019
# health_mental_current_worry_after_embarassment      Both sexes  1/9/2019
# health_mental_current_nerves                        Both sexes  1/9/2019
# health_mental_current_lonely                        Both sexes  1/9/2019
# health_mental_current_guilt                         Both sexes  1/9/2019
# health_mental_current_risk_taker                    Both sexes  1/9/2019
# health_mental_current_happiness                     Both sexes  1/9/2019
# health_mental_current_satisfaction_work             Both sexes  1/9/2019
# health_mental_current_satisfaction_health           Both sexes  1/9/2019
# health_mental_current_satisfaction_family_relat...  Both sexes  1/9/2019
# health_mental_current_satisfaction_friends_rela...  Both sexes  1/9/2019
# health_mental_current_satisfaction_financial        Both sexes  1/9/2019
# health_mental_past_two_week_depression_frequency    Both sexes  1/9/2019
# health_mental_past_two_week_disinterest_frequency   Both sexes  1/9/2019
# health_mental_past_two_week_restless_frequency      Both sexes  1/9/2019
# health_mental_past_two_week_tired_frequency         Both sexes  1/9/2019
# health_mental_past_doctor                           Both sexes  1/9/2019
# health_mental_past_psychiatrist                     Both sexes  1/9/2019
# health_mental_past_depression_week                  Both sexes  1/9/2019
# health_mental_past_depression_longest               Both sexes  1/9/2019
# health_mental_past_depression_episodes_number       Both sexes  1/9/2019
# health_mental_past_disinterest_week                 Both sexes  1/9/2019
# health_mental_past_disinterest_longest              Both sexes  1/9/2019
# health_mental_past_disinterest_episodes_number      Both sexes  1/9/2019
# health_mental_past_manic_two_days                   Both sexes  1/9/2019
# health_mental_past_irritable_two_days               Both sexes  1/9/2019
# health_mental_past_manic_symptoms                   Both sexes  1/9/2019
# health_mental_past_manic_irritable_longest          Both sexes  1/9/2019
# health_mental_past_manic_irritable_problems         Both sexes  1/9/2019
# health_mental_current_able_to_confide               Both sexes  1/9/2019
# health_mental_past_two_years_event                  Both sexes  1/9/2019
# collection_timestamp                                Both sexes  1/9/2019
# collection_date                                     Both sexes  1/9/2019
# timezone                                            Both sexes  1/9/2019
# data_source                                         Both sexes  1/9/2019
#
#                                                     completed data_coding
# tabular_field_name
# activity_social_visit_frequency                           NaN      100327
# activity_social_weekly                                    NaN      100328
# health_mental_current_mood_swings_frequency               NaN      100349
# health_mental_current_miserable                           NaN      100349
# health_mental_current_irritable                           NaN      100349
# health_mental_current_sensitive                           NaN      100349
# health_mental_current_fed_up                              NaN      100349
# health_mental_current_nervous                             NaN      100349
# health_mental_current_worrier                             NaN      100349
# health_mental_current_tense                               NaN      100349
# health_mental_current_worry_after_embarassment            NaN      100349
# health_mental_current_nerves                              NaN      100349
# health_mental_current_lonely                              NaN      100349
# health_mental_current_guilt                               NaN      100349
# health_mental_current_risk_taker                          NaN      100349
# health_mental_current_happiness                           NaN     P100478
# health_mental_current_satisfaction_work                   NaN      100479
# health_mental_current_satisfaction_health                 NaN      100478
# health_mental_current_satisfaction_family_relat...        NaN      100478
# health_mental_current_satisfaction_friends_rela...        NaN      100478
# health_mental_current_satisfaction_financial              NaN      100478
# health_mental_past_two_week_depression_frequency          NaN      100484
# health_mental_past_two_week_disinterest_frequency         NaN      100484
# health_mental_past_two_week_restless_frequency            NaN      100484
# health_mental_past_two_week_tired_frequency               NaN      100484
# health_mental_past_doctor                                 NaN      100349
# health_mental_past_psychiatrist                           NaN      100349
# health_mental_past_depression_week                        NaN      100349
# health_mental_past_depression_longest                     NaN         NaN
# health_mental_past_depression_episodes_number             NaN         NaN
# health_mental_past_disinterest_week                       NaN      100349
# health_mental_past_disinterest_longest                    NaN         NaN
# health_mental_past_disinterest_episodes_number            NaN         NaN
# health_mental_past_manic_two_days                         NaN      100349
# health_mental_past_irritable_two_days                     NaN      100349
# health_mental_past_manic_symptoms                         NaN      100498
# health_mental_past_manic_irritable_longest                NaN      100499
# health_mental_past_manic_irritable_problems               NaN      100500
# health_mental_current_able_to_confide                     NaN      100501
# health_mental_past_two_years_event                        NaN      100502
# collection_timestamp                                      NaN         NaN
# collection_date                                           NaN         NaN
# timezone                                                  NaN         NaN
# data_source                                               NaN         NaN
