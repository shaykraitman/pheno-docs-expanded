# %% [raw]
# ---
# output-file: 021-medical_conditions.html
# title: Medical Conditions
# ---

# %% [markdown]
# ### Description
#
# A medical conditions dataset is a collection of information about various health-related issues experienced by people. This data can include symptoms, diagnoses, treatments, and outcomes for different diseases and conditions. The dataset is gathered using various methods, or "modalities," such as electronic health records, surveys, wearable devices, and medical imaging. The purpose of collecting and analyzing this information is to better understand health trends, identify risk factors, and improve medical care for everyone.
#
# ### Introduction
#
# Medical diagnosis in research studies plays a crucial role in the understanding and advancement of medicine. In clinical research, the process of diagnosis is used to identify individuals with specific medical conditions and to determine the prevalence of these conditions within a study population. Diagnosis is also used to identify subgroups of individuals with similar characteristics or outcomes, which can help researchers to better understand the underlying disease mechanisms and to develop risk models, identify biomarkers for early detection of the disease and for monitoring its progress and to develop  new treatments.
#
# Survey data is a valuable resource for understanding various aspects of medical conditions. It involves collecting self-reported information from individuals about their health, symptoms, diagnoses, treatments, and lifestyle factors. This data is tabular, meaning it is organized in rows and columns, which makes it easy to analyze and compare.
#
# Medical conditions data collected through surveys covers diverse body systems, such as the cardiovascular, respiratory, digestive, and nervous systems. It provides insights into disease prevalence, risk factors, and the impact on individuals' lives.
#
# Surveys are an attractive data modality due to their accessibility, cost-effectiveness, and ability to capture patient perspectives. This information helps researchers identify potential risk factors, inform prevention strategies, and shape public health policies, ultimately contributing to better health outcomes for diverse populations.
#
# ### Measurement protocol
# <!-- long measurment protocol for the data browser -->
# Upon registration to the Human Phenotype Project study, participants provide details about their medical conditions in the Initial Medical Survey. Further data is then gathered during an interview at the baseline visit (In-system drop down) and using the Follow-up Medical Survey when participants return for subsequent visits. The data source columns indicate where information was collected.
#
# Questions and self-reported medical diagnoses were mapped to ICD-11 codes. Medical diagnoses at baseline were determined as diagnoses that were reported at the baseline visit or with an onset date prior to the baseline visit.
#
# #### Baseline
# *  Participants fill in medical conditions history in the Initial Medical Survey.
# *  Interviewer asks participant question and fill in a drop down list of different conditions participants have (In-system drop down).
#
# #### Every follow up visit/ call and baseline
# * Follow-up Medical Survey -
#     * Medical questionnaire asks about conditions.
#     * Should fill in the date when new condition was founded .
#
# ### Data availability
# <!-- for the example notebooks -->
# The information is stored in 1 parquet file: `medical_conditions.parquet`
#
# ### Summary of available data
# <!-- for the data browser -->
# 1. Medical conditions of participants at various research stages.
#
# ### Relevant links
#
# * [Pheno Knowledgebase](https://knowledgebase.pheno.ai/datasets/021-medical_conditions.html)
# * [Pheno Data Browser](https://pheno-demo-app.vercel.app/folder/21)

# %%
#| echo: false
import pandas as pd
pd.set_option("display.max_rows", 500)

# %%
from pheno_utils import PhenoLoader

# %%
pl = PhenoLoader('medical_conditions')
pl
# Out:
# PhenoLoader for medical_conditions with
# 12 fields
# 2 tables: ['medical_conditions', 'age_sex']

# %% [markdown]
# # Data dictionary

# %%
pl.dict
# Out:
#                                           field_string  \
# tabular_field_name
# medical_condition               Medical condition name
# icd11_code                                  ICD11 code
# data_source           Data source of medical condition
# start_month                                Start month
# start_year                                  Start year
# end_month                                    End month
# end_year                                    Start year
# collection_timestamp                   Collection time
# collection_date                        Collection date
# timezone                                      Timezone
#
#                                                      description_string  \
# tabular_field_name
# medical_condition                                Medical condition name
# icd11_code            ICD-11 codes are the latest global system for ...
# data_source           Data source the self reporting of medical cond...
# start_month                                                 Start month
# start_year                                                   Start year
# end_month                                                   Start month
# end_year                                                     Start year
# collection_timestamp                                    Collection time
# collection_date                                         Collection date
# timezone                                                       Timezone
#
#                       folder_id         feature_set            field_type  \
# tabular_field_name
# medical_condition            21  medical_conditions                  Text
# icd11_code                   21  medical_conditions                  Text
# data_source                  21  medical_conditions                  Text
# start_month                  21  medical_conditions               Integer
# start_year                   21  medical_conditions               Integer
# end_month                    21  medical_conditions               Integer
# end_year                     21  medical_conditions               Integer
# collection_timestamp         21  medical_conditions              Datetime
# collection_date              21  medical_conditions                  Date
# timezone                     21  medical_conditions  Categorical (single)
#
#                                strata  data_coding     array  \
# tabular_field_name
# medical_condition             Primary          NaN  Multiple
# icd11_code                    Primary          NaN  Multiple
# data_source                   Primary          NaN  Multiple
# start_month                   Primary          NaN  Multiple
# start_year                    Primary          NaN  Multiple
# end_month                     Primary          NaN  Multiple
# end_year                      Primary          NaN  Multiple
# collection_timestamp  Collection time          NaN    Single
# collection_date       Collection time          NaN    Single
# timezone              Collection time          NaN    Single
#
#                                         pandas_dtype  bulk_file_extension  \
# tabular_field_name
# medical_condition                             string                  NaN
# icd11_code                                    string                  NaN
# data_source                                   string                  NaN
# start_month                                      int                  NaN
# start_year                                       int                  NaN
# end_month                                        int                  NaN
# end_year                                         int                  NaN
# collection_timestamp  datetime64[ns, Asia/Jerusalem]                  NaN
# collection_date                       datetime64[ns]                  NaN
# timezone                                    category                  NaN
#
#                                                   relative_location  units  \
# tabular_field_name
# medical_condition     medical_conditions/medical_conditions.parquet    NaN
# icd11_code            medical_conditions/medical_conditions.parquet    NaN
# data_source           medical_conditions/medical_conditions.parquet    NaN
# start_month           medical_conditions/medical_conditions.parquet    NaN
# start_year            medical_conditions/medical_conditions.parquet    NaN
# end_month             medical_conditions/medical_conditions.parquet    NaN
# end_year              medical_conditions/medical_conditions.parquet    NaN
# collection_timestamp  medical_conditions/medical_conditions.parquet    NaN
# collection_date       medical_conditions/medical_conditions.parquet    NaN
# timezone              medical_conditions/medical_conditions.parquet    NaN
#
#                       bulk_dictionary  sampling_rate  transformation  \
# tabular_field_name
# medical_condition                 NaN            NaN             NaN
# icd11_code                        NaN            NaN             NaN
# data_source                       NaN            NaN             NaN
# start_month                       NaN            NaN             NaN
# start_year                        NaN            NaN             NaN
# end_month                         NaN            NaN             NaN
# end_year                          NaN            NaN             NaN
# collection_timestamp              NaN            NaN             NaN
# collection_date                   NaN            NaN             NaN
# timezone                          NaN            NaN             NaN
#
#                       list_of_tags stability       sexed       debut  \
# tabular_field_name
# medical_condition              NaN  Accruing  Both sexes  11/21/2018
# icd11_code                     NaN  Accruing  Both sexes  11/21/2018
# data_source                    NaN  Accruing  Both sexes  11/21/2018
# start_month                    NaN  Accruing  Both sexes  11/21/2018
# start_year                     NaN  Accruing  Both sexes  11/21/2018
# end_month                      NaN  Accruing  Both sexes  11/21/2018
# end_year                       NaN  Accruing  Both sexes  11/21/2018
# collection_timestamp           NaN  Accruing  Both sexes  11/21/2018
# collection_date                NaN  Accruing  Both sexes  11/21/2018
# timezone                       NaN  Accruing  Both sexes  11/21/2018
#
#                       completed
# tabular_field_name
# medical_condition           NaN
# icd11_code                  NaN
# data_source                 NaN
# start_month                 NaN
# start_year                  NaN
# end_month                   NaN
# end_year                    NaN
# collection_timestamp        NaN
# collection_date             NaN
# timezone                    NaN
