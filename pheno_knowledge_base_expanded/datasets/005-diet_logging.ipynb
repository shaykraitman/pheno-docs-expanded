# %% [raw]
# ---
# output-file: 005-diet_logging.html
# title: Diet Logging
# ---

# %% [markdown]
# ### Description
#
# Diet logging using a smartphone app involves collecting data on food and drink consumption through a mobile application. These data include information such as types of food, serving sizes, nutritional information and the times of consumption. The data is used to track dietary habits and can be used in scientific research to gain insights into the dietary habits of a population and to correlate to other temporal measurements and events.
#
# ### Introduction
#
# There is a strong relationship between the development of chronic disease and a person’s diet. Adults who eat a healthy diet are more likely to live longer and are less likely to develop chronic disease or become obese. An unhealthy diet is a major risk factor for type 2 diabetes, cardiovascular disease and certain types of cancer. Consuming a nutrient-dense diet was associated with a low risk of all-cause mortality.
#
# Nutritional epidemiology is a sub-discipline of epidemiology that provides data about the relationship between diet and disease. The data collected is used to define diet–disease associations that are converted into the practice of prevention by public-health nutrition practitioners. To study the associations between diet and disease, there is a need to accurately characterize the dietary habits of individuals. One approach is to use a food diary, which is a daily log of what an individual eats and drinks. Such diaries are used to characterize eating habits in large and small epidemiological studies. Owing to recent technological advancements and the vast availability of smartphones, nutrition-related apps are commonly used to track dietary behavior.
#
# ### Measurement protocol
# <!-- long measurment protocol for the data browser -->
# Participants in the Human Phenotype Project are asked to log their food for a period of at least two weeks following each visit to the assessment center or a followup call. The figure below shows the process of logging a food item through the diet logging app.
#
# ![image alt](005-diet_logging/diet_logging_eng.png)
#
# Participants are asked to download the app and start logging data one day before the visit to the assessment center. Participants are asked to log everything they eat and drink and to include as one “meal” all the items they have consumed within a 30 minute interval. While participants are asked to log their meals for at least 14 days after each visit, the logging app is open for the whole study period and participants are encouraged to document their diets beyond this time.
#
#
# ### Data availability:
# <!-- for the example notebooks -->
# The information is stored in 3 parquet files: `diet_logging.parquet`, `diet_logging_events.parquet`,  `raw_diet_logging_events.parquet `which contains summary information, processed diet logging data and raw diet logging data respectively.
#
# ### Summary of available data
# <!-- for the data browser -->
# 1. Clean Diet Logging Data: A DataFrame with individual-level diet logging records, post-basic preprocessing and filtering.
# 2. Raw Diet Logging Data: A DataFrame containing the raw, unprocessed individual-level diet logging records.
# 3. Nutrients: Nutritional information corresponding to the diet logging records.
# 4. Summary Table: Contains summary statistics of the diet logging data, aggregated per participant per research stage.
#
#
# ### Relevant links
#
# * [Pheno Knowledgebase](https://knowledgebase.pheno.ai/datasets/005-diet_logging.html)
# * [Pheno Data Browser](https://pheno-demo-app.vercel.app/folder/5)

# %%
#| echo: false
import pandas as pd
pd.set_option("display.max_rows", 500)

# %%
from pheno_utils import PhenoLoader

# %%
pl = PhenoLoader('diet_logging')
pl
# Out:
# PhenoLoader for diet_logging with
# 10 fields
# 2 tables: ['diet_logging', 'age_sex']

# %% [markdown]
# # Data dictionary

# %%
pl.dict
# Out:
#                                                  field_string  \
# tabular_field_name
# collection_date                                          Date
# logging_day                       Logging day per participant
# total_logging_days                Total number of days logged
# timezone                                             Timezone
# food_items                                         Food items
# diet_logging_events                       Diet logging events
# raw_diet_logging_events               Raw diet logging events
# usda_sf_legacy_mapping     USDA SF Legacy nutritional mapping
# collection_timestamp                     Collection timestamp
# collection_date                                          Date
# food_id                                               Food ID
# weight_g                                               Weight
# short_food_name                               Short food name
# food_category                                   Food category
# product_name                                    Product name
# calories_kcal                                        Calories
# carbohydrate_g            Carbohydrate intake per food logged
# lipid_g                            Fat intake per food logged
# protein_g                      Protein intake per food logged
# sodium_mg                       Sodium intake per food logged
# alcohol_g                      Alcohol intake per food logged
# dietary_fiber_g          Dietary fiber intake per food logged
# local_timestamp                               Local timestamp
# eaten_in_restaurant            Eaten at restaurant indication
# timezone                                             Timezone
# collection_timestamp                     Collection timestamp
# collection_date                                          Date
# food_id                                               Food ID
# weight_g                                               Weight
# short_food_name                               Short food name
# food_category                                   Food category
# product_name                                    Product name
# calories_kcal                                        Calories
# carbohydrate_g            Carbohydrate intake per food logged
# lipid_g                            Fat intake per food logged
# protein_g                      Protein intake per food logged
# sodium_mg                       Sodium intake per food logged
# alcohol_g                      Alcohol intake per food logged
# dietary_fiber_g          Dietary fiber intake per food logged
# local_timestamp                               Local timestamp
# eaten_in_restaurant            Eaten at restaurant indication
# timezone                                             Timezone
#
#                                                         description_string  \
# tabular_field_name
# collection_date          Datetime column relecting the time food item w...
# logging_day                 Integer indicating which day of logging period
# total_logging_days       Total number of days diet was logged per resea...
# timezone                                                          Timezone
# food_items                       Total number of food items logged per day
# diet_logging_events                       File path to diet logging events
# raw_diet_logging_events               File path to raw diet logging events
# usda_sf_legacy_mapping   Nutritional mapping file to USDA SF-Legacy dat...
# collection_timestamp                                  Collection timestamp
# collection_date          Datetime column relecting the time food item w...
# food_id                  IDs in the diet logging app representing speci...
# weight_g                                        Weight of food item logged
# short_food_name          Classifcation of food item logged into a short...
# food_category            Classifcation of food item logged into a food ...
# product_name                                   Product name of food logged
# calories_kcal                                 Calories of food item logged
# carbohydrate_g                         Carbohydrate intake per food logged
# lipid_g                                         Fat intake per food logged
# protein_g                                   Protein intake per food logged
# sodium_mg                                    Sodium intake per food logged
# alcohol_g                                   Alcohol intake per food logged
# dietary_fiber_g                       Dietary fiber intake per food logged
# local_timestamp                            Local timestamp of food logging
# eaten_in_restaurant      Indication if food was eatn at home or at a re...
# timezone                                                          Timezone
# collection_timestamp                                  Collection timestamp
# collection_date          Datetime column relecting the time food item w...
# food_id                  IDs in the diet logging app representing speci...
# weight_g                                        Weight of food item logged
# short_food_name          Classifcation of food item logged into a short...
# food_category            Classifcation of food item logged into a food ...
# product_name                                   Product name of food logged
# calories_kcal                                 Calories of food item logged
# carbohydrate_g                         Carbohydrate intake per food logged
# lipid_g                                         Fat intake per food logged
# protein_g                                   Protein intake per food logged
# sodium_mg                                    Sodium intake per food logged
# alcohol_g                                   Alcohol intake per food logged
# dietary_fiber_g                       Dietary fiber intake per food logged
# local_timestamp                            Local timestamp of food logging
# eaten_in_restaurant      Indication if food was eatn at home or at a re...
# timezone                                                          Timezone
#
#                          folder_id              feature_set  \
# tabular_field_name
# collection_date                5.0             diet_logging
# logging_day                    5.0      diet_logging_events
# total_logging_days             5.0             diet_logging
# timezone                       5.0             diet_logging
# food_items                     5.0             diet_logging
# diet_logging_events            5.0      diet_logging_events
# raw_diet_logging_events        5.0  raw_diet_logging_events
# usda_sf_legacy_mapping         5.0   diet_logging_auxiliary
# collection_timestamp           NaN                      NaN
# collection_date                NaN                      NaN
# food_id                        NaN                      NaN
# weight_g                       NaN                      NaN
# short_food_name                NaN                      NaN
# food_category                  NaN                      NaN
# product_name                   NaN                      NaN
# calories_kcal                  NaN                      NaN
# carbohydrate_g                 NaN                      NaN
# lipid_g                        NaN                      NaN
# protein_g                      NaN                      NaN
# sodium_mg                      NaN                      NaN
# alcohol_g                      NaN                      NaN
# dietary_fiber_g                NaN                      NaN
# local_timestamp                NaN                      NaN
# eaten_in_restaurant            NaN                      NaN
# timezone                       NaN                      NaN
# collection_timestamp           NaN                      NaN
# collection_date                NaN                      NaN
# food_id                        NaN                      NaN
# weight_g                       NaN                      NaN
# short_food_name                NaN                      NaN
# food_category                  NaN                      NaN
# product_name                   NaN                      NaN
# calories_kcal                  NaN                      NaN
# carbohydrate_g                 NaN                      NaN
# lipid_g                        NaN                      NaN
# protein_g                      NaN                      NaN
# sodium_mg                      NaN                      NaN
# alcohol_g                      NaN                      NaN
# dietary_fiber_g                NaN                      NaN
# local_timestamp                NaN                      NaN
# eaten_in_restaurant            NaN                      NaN
# timezone                       NaN                      NaN
#
#                                        field_type           strata  \
# tabular_field_name
# collection_date                          Datetime  Collection time
# logging_day                               Integer          Primary
# total_logging_days                        Integer          Primary
# timezone                                     Text  Collection time
# food_items                                Integer          Primary
# diet_logging_events      Time series file (group)        Auxiliary
# raw_diet_logging_events  Time series file (group)        Auxiliary
# usda_sf_legacy_mapping      Mapping table (group)        Auxiliary
# collection_timestamp                       column              NaN
# collection_date                            column              NaN
# food_id                                    column              NaN
# weight_g                                   column              NaN
# short_food_name                            column              NaN
# food_category                              column              NaN
# product_name                               column              NaN
# calories_kcal                              column              NaN
# carbohydrate_g                             column              NaN
# lipid_g                                    column              NaN
# protein_g                                  column              NaN
# sodium_mg                                  column              NaN
# alcohol_g                                  column              NaN
# dietary_fiber_g                            column              NaN
# local_timestamp                            column              NaN
# eaten_in_restaurant                        column              NaN
# timezone                                   column              NaN
# collection_timestamp                       column              NaN
# collection_date                            column              NaN
# food_id                                    column              NaN
# weight_g                                   column              NaN
# short_food_name                            column              NaN
# food_category                              column              NaN
# product_name                               column              NaN
# calories_kcal                              column              NaN
# carbohydrate_g                             column              NaN
# lipid_g                                    column              NaN
# protein_g                                  column              NaN
# sodium_mg                                  column              NaN
# alcohol_g                                  column              NaN
# dietary_fiber_g                            column              NaN
# local_timestamp                            column              NaN
# eaten_in_restaurant                        column              NaN
# timezone                                   column              NaN
#
#                          data_coding   array                    pandas_dtype  \
# tabular_field_name
# collection_date                  NaN  Single                  datetime64[ns]
# logging_day                      NaN  Single                             int
# total_logging_days               NaN  Single                             int
# timezone                         NaN  Single                          string
# food_items                       NaN  Single                             int
# diet_logging_events              NaN  Single                          string
# raw_diet_logging_events          NaN  Single                          string
# usda_sf_legacy_mapping           NaN  Single                        category
# collection_timestamp             NaN     NaN  datetime64[ns, Asia/Jerusalem]
# collection_date                  NaN     NaN                  datetime64[ns]
# food_id                          NaN     NaN                             int
# weight_g                         NaN     NaN                           float
# short_food_name                  NaN     NaN                          string
# food_category                    NaN     NaN                          string
# product_name                     NaN     NaN                          string
# calories_kcal                    NaN     NaN                           float
# carbohydrate_g                   NaN     NaN                           float
# lipid_g                          NaN     NaN                           float
# protein_g                        NaN     NaN                           float
# sodium_mg                        NaN     NaN                           float
# alcohol_g                        NaN     NaN                           float
# dietary_fiber_g                  NaN     NaN                           float
# local_timestamp                  NaN     NaN                  datetime64[ns]
# eaten_in_restaurant              NaN     NaN                            bool
# timezone                         NaN     NaN                          string
# collection_timestamp             NaN     NaN  datetime64[ns, Asia/Jerusalem]
# collection_date                  NaN     NaN                  datetime64[ns]
# food_id                          NaN     NaN                             int
# weight_g                         NaN     NaN                           float
# short_food_name                  NaN     NaN                          string
# food_category                    NaN     NaN                          string
# product_name                     NaN     NaN                          string
# calories_kcal                    NaN     NaN                           float
# carbohydrate_g                   NaN     NaN                           float
# lipid_g                          NaN     NaN                           float
# protein_g                        NaN     NaN                           float
# sodium_mg                        NaN     NaN                           float
# alcohol_g                        NaN     NaN                           float
# dietary_fiber_g                  NaN     NaN                           float
# local_timestamp                  NaN     NaN                  datetime64[ns]
# eaten_in_restaurant              NaN     NaN                            bool
# timezone                         NaN     NaN                          string
#
#                         bulk_file_extension  ... stability       sexed  \
# tabular_field_name                           ...
# collection_date                         NaN  ...  Accruing  Both sexes
# logging_day                             NaN  ...  Accruing  Both sexes
# total_logging_days                      NaN  ...  Accruing  Both sexes
# timezone                                NaN  ...  Accruing  Both sexes
# food_items                              NaN  ...  Accruing  Both sexes
# diet_logging_events                 parquet  ...  Accruing  Both sexes
# raw_diet_logging_events             parquet  ...  Accruing  Both sexes
# usda_sf_legacy_mapping                  csv  ...  Accruing  Both sexes
# collection_timestamp                    NaN  ...  Accruing         NaN
# collection_date                         NaN  ...  Accruing         NaN
# food_id                                 NaN  ...  Accruing         NaN
# weight_g                                NaN  ...  Accruing         NaN
# short_food_name                         NaN  ...  Accruing         NaN
# food_category                           NaN  ...  Accruing         NaN
# product_name                            NaN  ...  Accruing         NaN
# calories_kcal                           NaN  ...  Accruing         NaN
# carbohydrate_g                          NaN  ...  Accruing         NaN
# lipid_g                                 NaN  ...  Accruing         NaN
# protein_g                               NaN  ...  Accruing         NaN
# sodium_mg                               NaN  ...  Accruing         NaN
# alcohol_g                               NaN  ...  Accruing         NaN
# dietary_fiber_g                         NaN  ...  Accruing         NaN
# local_timestamp                         NaN  ...  Accruing         NaN
# eaten_in_restaurant                     NaN  ...  Accruing         NaN
# timezone                                NaN  ...  Accruing         NaN
# collection_timestamp                    NaN  ...  Accruing         NaN
# collection_date                         NaN  ...  Accruing         NaN
# food_id                                 NaN  ...  Accruing         NaN
# weight_g                                NaN  ...  Accruing         NaN
# short_food_name                         NaN  ...  Accruing         NaN
# food_category                           NaN  ...  Accruing         NaN
# product_name                            NaN  ...  Accruing         NaN
# calories_kcal                           NaN  ...  Accruing         NaN
# carbohydrate_g                          NaN  ...  Accruing         NaN
# lipid_g                                 NaN  ...  Accruing         NaN
# protein_g                               NaN  ...  Accruing         NaN
# sodium_mg                               NaN  ...  Accruing         NaN
# alcohol_g                               NaN  ...  Accruing         NaN
# dietary_fiber_g                         NaN  ...  Accruing         NaN
# local_timestamp                         NaN  ...  Accruing         NaN
# eaten_in_restaurant                     NaN  ...  Accruing         NaN
# timezone                                NaN  ...  Accruing         NaN
#
#                               debut  completed  min_plausible_value  \
# tabular_field_name
# collection_date          2019-01-29        NaN                  NaN
# logging_day              2019-01-29        NaN                  NaN
# total_logging_days       2019-01-29        NaN                  NaN
# timezone                 2019-01-29        NaN                  NaN
# food_items               2019-01-29        NaN                  NaN
# diet_logging_events      2019-01-29        NaN                  NaN
# raw_diet_logging_events  2019-01-29        NaN                  NaN
# usda_sf_legacy_mapping   2019-01-29        NaN                  NaN
# collection_timestamp     2019-01-29        NaN                  NaN
# collection_date          2019-09-01        NaN                  NaN
# food_id                  2019-09-01        NaN                  NaN
# weight_g                 2019-09-01        NaN                  0.0
# short_food_name          2019-09-01        NaN                  NaN
# food_category            2019-09-01        NaN                  NaN
# product_name             2019-09-01        NaN                  NaN
# calories_kcal            2019-09-01        NaN                  0.0
# carbohydrate_g           2019-09-01        NaN                  NaN
# lipid_g                  2019-09-01        NaN                  NaN
# protein_g                2019-09-01        NaN                  NaN
# sodium_mg                2019-09-01        NaN                  NaN
# alcohol_g                2019-09-01        NaN                  NaN
# dietary_fiber_g          2019-09-01        NaN                  NaN
# local_timestamp          2019-09-01        NaN                  NaN
# eaten_in_restaurant      2019-09-01        NaN                  NaN
# timezone                 2019-09-01        NaN                  NaN
# collection_timestamp     2019-01-29        NaN                  NaN
# collection_date          2019-09-01        NaN                  NaN
# food_id                  2019-09-01        NaN                  NaN
# weight_g                 2019-09-01        NaN                  0.0
# short_food_name          2019-09-01        NaN                  NaN
# food_category            2019-09-01        NaN                  NaN
# product_name             2019-09-01        NaN                  NaN
# calories_kcal            2019-09-01        NaN                  0.0
# carbohydrate_g           2019-09-01        NaN                  NaN
# lipid_g                  2019-09-01        NaN                  NaN
# protein_g                2019-09-01        NaN                  NaN
# sodium_mg                2019-09-01        NaN                  NaN
# alcohol_g                2019-09-01        NaN                  NaN
# dietary_fiber_g          2019-09-01        NaN                  NaN
# local_timestamp          2019-09-01        NaN                  NaN
# eaten_in_restaurant      2019-09-01        NaN                  NaN
# timezone                 2019-09-01        NaN                  NaN
#
#                         max_plausible_value version customer_field dependency  \
# tabular_field_name
# collection_date                         NaN     NaN            NaN        NaN
# logging_day                             NaN     NaN            NaN        NaN
# total_logging_days                      NaN     NaN            NaN        NaN
# timezone                                NaN     NaN            NaN        NaN
# food_items                              NaN     NaN            NaN        NaN
# diet_logging_events                     NaN     NaN            NaN        NaN
# raw_diet_logging_events                 NaN     NaN            NaN        NaN
# usda_sf_legacy_mapping                  NaN     NaN            NaN        NaN
# collection_timestamp                    NaN     NaN          ready        NaN
# collection_date                         NaN     NaN          ready        NaN
# food_id                                 NaN     NaN          ready        NaN
# weight_g                             2000.0     NaN          ready        NaN
# short_food_name                         NaN     NaN          ready        NaN
# food_category                           NaN     NaN          ready        NaN
# product_name                            NaN     NaN          ready        NaN
# calories_kcal                        5000.0     NaN          ready        NaN
# carbohydrate_g                          NaN     NaN          ready        NaN
# lipid_g                                 NaN     NaN          ready        NaN
# protein_g                               NaN     NaN          ready        NaN
# sodium_mg                               NaN     NaN          ready        NaN
# alcohol_g                               NaN     NaN          ready        NaN
# dietary_fiber_g                         NaN     NaN          ready        NaN
# local_timestamp                         NaN     NaN          ready        NaN
# eaten_in_restaurant                     NaN     NaN          ready        NaN
# timezone                                NaN     NaN          ready        NaN
# collection_timestamp                    NaN     NaN          ready        NaN
# collection_date                         NaN     NaN          ready        NaN
# food_id                                 NaN     NaN          ready        NaN
# weight_g                             2000.0     NaN          ready        NaN
# short_food_name                         NaN     NaN          ready        NaN
# food_category                           NaN     NaN          ready        NaN
# product_name                            NaN     NaN          ready        NaN
# calories_kcal                        5000.0     NaN          ready        NaN
# carbohydrate_g                          NaN     NaN          ready        NaN
# lipid_g                                 NaN     NaN          ready        NaN
# protein_g                               NaN     NaN          ready        NaN
# sodium_mg                               NaN     NaN          ready        NaN
# alcohol_g                               NaN     NaN          ready        NaN
# dietary_fiber_g                         NaN     NaN          ready        NaN
# local_timestamp                         NaN     NaN          ready        NaN
# eaten_in_restaurant                     NaN     NaN          ready        NaN
# timezone                                NaN     NaN          ready        NaN
#
#                                 parent_dataframe
# tabular_field_name
# collection_date                              NaN
# logging_day                                  NaN
# total_logging_days                           NaN
# timezone                                     NaN
# food_items                                   NaN
# diet_logging_events                          NaN
# raw_diet_logging_events                      NaN
# usda_sf_legacy_mapping                       NaN
# collection_timestamp         diet_logging_events
# collection_date              diet_logging_events
# food_id                      diet_logging_events
# weight_g                     diet_logging_events
# short_food_name              diet_logging_events
# food_category                diet_logging_events
# product_name                 diet_logging_events
# calories_kcal                diet_logging_events
# carbohydrate_g               diet_logging_events
# lipid_g                      diet_logging_events
# protein_g                    diet_logging_events
# sodium_mg                    diet_logging_events
# alcohol_g                    diet_logging_events
# dietary_fiber_g              diet_logging_events
# local_timestamp              diet_logging_events
# eaten_in_restaurant          diet_logging_events
# timezone                     diet_logging_events
# collection_timestamp     raw_diet_logging_events
# collection_date          raw_diet_logging_events
# food_id                  raw_diet_logging_events
# weight_g                 raw_diet_logging_events
# short_food_name          raw_diet_logging_events
# food_category            raw_diet_logging_events
# product_name             raw_diet_logging_events
# calories_kcal            raw_diet_logging_events
# carbohydrate_g           raw_diet_logging_events
# lipid_g                  raw_diet_logging_events
# protein_g                raw_diet_logging_events
# sodium_mg                raw_diet_logging_events
# alcohol_g                raw_diet_logging_events
# dietary_fiber_g          raw_diet_logging_events
# local_timestamp          raw_diet_logging_events
# eaten_in_restaurant      raw_diet_logging_events
# timezone                 raw_diet_logging_events
#
# [42 rows x 26 columns]
