# %% [raw]
# ---
# output-file: 044-sex_specific_factors.html
# title: Sex-Specific Factors
# ---

# %% [markdown]
# ### Description
#
# Sex-specific factors refer to biological and physiological differences, such as reproductive health, hormonal variations, disease prevalence and aging processes that influence medical health outcomes in males and females.
#
# ### Introduction
#
# The Human Phenotype Project conducts comprehensive data collection through online surveys, where participants voluntarily provide information on various aspects influencing their health. This includes sex-specific factors, captured through multiple surveys.
#
# ### Measurement protocol
# <!-- long measurment protocol for the data browser -->
# The lifestyle surveys (ukbb and follow-up ukbb) are modeled after the UK Biobank's touch screen questionnaire. Participants receive the full version via email to complete on the Zoho platform, either before or after their baseline visit. A shorter, follow-up version of the questionnaire is then filled out by participants during subsequent visits.
#
# ### Data availability
# <!-- for the example notebooks -->
# The information is stored in 5 parquet files: `menstrual_cycle`, `initial_medical.parquet`, `follow_up_medical.parquet`, `ukbb.parquet` and `follow_up_ukbb.parquet` which indicate the different sources where information is collected from.
#
# ### Summary of available data
# <!-- for the data browser -->
# The data consists of 5 data frames relfecting the survey data sources where information related to sex-specific factors was collected from.
#
# ### Relevant links
#
# * [Pheno Knowledgebase](https://knowledgebase.pheno.ai/datasets/044-sex_specific_factors.html)
# * [Pheno Data Browser](https://pheno-demo-app.vercel.app/folder/44)

# %%
#| echo: false
import pandas as pd
pd.set_option("display.max_rows", 500)

# %%
from pheno_utils import PhenoLoader

# %%
pl = PhenoLoader('sex_specific_factors')
pl
# Out:
# PhenoLoader for sex_specific_factors with
# 99 fields
# 6 tables: ['menstrual_cycle_survey', 'initial_medical', 'ukbb', 'follow_up_ukbb', 'follow_up_medical', 'age_sex']

# %% [markdown]
# # Data dictionary

# %%
pl.dict
# Out:
#                                                     folder_id  \
# tabular_field_name
# collection_timestamp                                       44
# collection_date                                            44
# timezone                                                   44
# menstural_cycle_past_3_months                              44
# menstural_cycle_index                                      44
# menstural_cycle_start_date                                 44
# menstural_cycle_start_description                          44
# menstural_cycle_end_date                                   44
# menstural_cycle_end_description                            44
# survey_format                                              44
# collection_timestamp                                       44
# collection_date                                            44
# timezone                                                   44
# menarche_age                                               44
# is_getting_period_ques                                     44
# menopause_age                                              44
# regular_periods_past                                       44
# regular_periods_present                                    44
# menstrual_cycle_average                                    44
# period_duration_days                                       44
# tampons_pads_average_per_day                               44
# Intermenstrual_bleeding                                    44
# period_pain                                                44
# symptoms_of_menstruation                                   44
# contraception_type                                         44
# women_symptoms                                             44
# hot_flashes_age                                            44
# vaginal_dryness_age                                        44
# low_libido_age                                             44
# mood_changes_age                                           44
# dry_skin_age                                               44
# facial_hair_age                                            44
# voice_changes_age                                          44
# sperm_count_test                                           44
# sperm_count_test_results                                   44
# collection_timestamp                                       44
# collection_date                                            44
# timezone                                                   44
# health_male_past_first_facial_hear_age                     44
# health_male_past_voice_break_age                           44
# health_male_current_balding_pattern                        44
# health_male_current_children_number                        44
# health_females_past_mammogram                              44
# health_females_past_mammogram_years                        44
# health_females_past_cervical_smear                         44
# health_females_past_cervical_smear_years                   44
# health_females_past_period_start_age                       44
# health_females_past_pill_used                              44
# health_females_past_pill_start_age                         44
# health_females_past_pill_end_age                           44
# health_females_past_hrt                                    44
# health_females_past_hrt_start_age                          44
# health_females_past_hrt_end_age                            44
# health_females_past_hysterectomy                           44
# health_females_hysterectomy_age                            44
# health_females_bilateral_oophorectomy                      44
# health_females_bilateral_oophorectomy_age                  44
# collection_timestamp                                       44
# collection_date                                            44
# timezone                                                   44
# health_male_current_balding_pattern                        44
# extra_health_females_first_mestural_cycle_age              44
# extra_health_females_current_mestural_cycle                44
# extra_health_females_last_mestural_cycle_age               44
# extra_health_females_past_mestural_cycle_regular           44
# extra_health_females_current_mestural_cycle_reg...         44
# extra_health_females_current_avg_mestural_cycle...         44
# extra_health_females_current_avg_mestural_cycle...         44
# extra_health_females_current_avg_tampons_per_day           44
# extra_health_females_current_bleeding_between_m...         44
# extra_health_females_current_mestural_cycle_pains          44
# extra_health_females_current_mestural_cycle_sym...         44
# extra_health_females_current_birth_control                 44
# extra_health_females_current_birth_control_type            44
# extra_health_females_current_manopause_symptoms            44
# extra_health_females_first_hot_flash_age                   44
# extra_health_females_first_vaginal_dryness_age             44
# extra_health_females_first_dicreased_libido_age            44
# extra_health_females_first_mood_changes_age                44
# extra_health_females_first_skin_dryness_age                44
# extra_health_females_current_hrt                           44
# extra_health_females_past_recurring_uti                    44
# extra_health_females_past_uti_antibiotics                  44
# collection_timestamp                                       44
# collection_date                                            44
# timezone                                                   44
# female_current_menstural_cycle                             44
# female_past_mestural_cycle_regular                         44
# female_last_mestural_cycle_age                             44
# female_symptoms                                            44
# female_other_symptom_description                           44
# female_fertility_treatments                                44
# female_fertility_treatments_number                         44
# female_pregnant_since_recruitment                          44
# female_current_pregnancy                                   44
# female_current_pregnancy_number                            44
# female_current_pregnancy_age_at_conception                 44
# female_current_pregnancy_conception_type                   44
# female_current_pregnancy_conception_type_other_...         44
# female_current_pregnancy_diagnosis                         44
# female_current_pregnancy_gestational_diabetes_t...         44
# female_current_pregnancy_live_birth                        44
# female_current_pregnancy_birth_week                        44
# female_current_pregnancy_birth_type                        44
# female_current_pregnancy_birth_weight                      44
# female_current_pregnancy_breastfeeding                     44
# female_current_pregnancy_breastfeeding_months              44
# female_current_pregnancy_termination_week                  44
# female_current_pregnancy_termination_reason                44
# female_current_pregnancy_termination_reason_oth...         44
#
#                                                                feature_set  \
# tabular_field_name
# collection_timestamp                                menstrual_cycle_survey
# collection_date                                     menstrual_cycle_survey
# timezone                                            menstrual_cycle_survey
# menstural_cycle_past_3_months                       menstrual_cycle_survey
# menstural_cycle_index                               menstrual_cycle_survey
# menstural_cycle_start_date                          menstrual_cycle_survey
# menstural_cycle_start_description                   menstrual_cycle_survey
# menstural_cycle_end_date                            menstrual_cycle_survey
# menstural_cycle_end_description                     menstrual_cycle_survey
# survey_format                                       menstrual_cycle_survey
# collection_timestamp                                       initial_medical
# collection_date                                            initial_medical
# timezone                                                   initial_medical
# menarche_age                                               initial_medical
# is_getting_period_ques                                     initial_medical
# menopause_age                                              initial_medical
# regular_periods_past                                       initial_medical
# regular_periods_present                                    initial_medical
# menstrual_cycle_average                                    initial_medical
# period_duration_days                                       initial_medical
# tampons_pads_average_per_day                               initial_medical
# Intermenstrual_bleeding                                    initial_medical
# period_pain                                                initial_medical
# symptoms_of_menstruation                                   initial_medical
# contraception_type                                         initial_medical
# women_symptoms                                             initial_medical
# hot_flashes_age                                            initial_medical
# vaginal_dryness_age                                        initial_medical
# low_libido_age                                             initial_medical
# mood_changes_age                                           initial_medical
# dry_skin_age                                               initial_medical
# facial_hair_age                                            initial_medical
# voice_changes_age                                          initial_medical
# sperm_count_test                                           initial_medical
# sperm_count_test_results                                   initial_medical
# collection_timestamp                                                  ukbb
# collection_date                                                       ukbb
# timezone                                                              ukbb
# health_male_past_first_facial_hear_age                                ukbb
# health_male_past_voice_break_age                                      ukbb
# health_male_current_balding_pattern                                   ukbb
# health_male_current_children_number                                   ukbb
# health_females_past_mammogram                                         ukbb
# health_females_past_mammogram_years                                   ukbb
# health_females_past_cervical_smear                                    ukbb
# health_females_past_cervical_smear_years                              ukbb
# health_females_past_period_start_age                                  ukbb
# health_females_past_pill_used                                         ukbb
# health_females_past_pill_start_age                                    ukbb
# health_females_past_pill_end_age                                      ukbb
# health_females_past_hrt                                               ukbb
# health_females_past_hrt_start_age                                     ukbb
# health_females_past_hrt_end_age                                       ukbb
# health_females_past_hysterectomy                                      ukbb
# health_females_hysterectomy_age                                       ukbb
# health_females_bilateral_oophorectomy                                 ukbb
# health_females_bilateral_oophorectomy_age                             ukbb
# collection_timestamp                                        follow_up_ukbb
# collection_date                                             follow_up_ukbb
# timezone                                                    follow_up_ukbb
# health_male_current_balding_pattern                         follow_up_ukbb
# extra_health_females_first_mestural_cycle_age               follow_up_ukbb
# extra_health_females_current_mestural_cycle                 follow_up_ukbb
# extra_health_females_last_mestural_cycle_age                follow_up_ukbb
# extra_health_females_past_mestural_cycle_regular            follow_up_ukbb
# extra_health_females_current_mestural_cycle_reg...          follow_up_ukbb
# extra_health_females_current_avg_mestural_cycle...          follow_up_ukbb
# extra_health_females_current_avg_mestural_cycle...          follow_up_ukbb
# extra_health_females_current_avg_tampons_per_day            follow_up_ukbb
# extra_health_females_current_bleeding_between_m...          follow_up_ukbb
# extra_health_females_current_mestural_cycle_pains           follow_up_ukbb
# extra_health_females_current_mestural_cycle_sym...          follow_up_ukbb
# extra_health_females_current_birth_control                  follow_up_ukbb
# extra_health_females_current_birth_control_type             follow_up_ukbb
# extra_health_females_current_manopause_symptoms             follow_up_ukbb
# extra_health_females_first_hot_flash_age                    follow_up_ukbb
# extra_health_females_first_vaginal_dryness_age              follow_up_ukbb
# extra_health_females_first_dicreased_libido_age             follow_up_ukbb
# extra_health_females_first_mood_changes_age                 follow_up_ukbb
# extra_health_females_first_skin_dryness_age                 follow_up_ukbb
# extra_health_females_current_hrt                            follow_up_ukbb
# extra_health_females_past_recurring_uti                     follow_up_ukbb
# extra_health_females_past_uti_antibiotics                   follow_up_ukbb
# collection_timestamp                                     follow_up_medical
# collection_date                                          follow_up_medical
# timezone                                                 follow_up_medical
# female_current_menstural_cycle                           follow_up_medical
# female_past_mestural_cycle_regular                       follow_up_medical
# female_last_mestural_cycle_age                           follow_up_medical
# female_symptoms                                          follow_up_medical
# female_other_symptom_description                         follow_up_medical
# female_fertility_treatments                              follow_up_medical
# female_fertility_treatments_number                       follow_up_medical
# female_pregnant_since_recruitment                        follow_up_medical
# female_current_pregnancy                                 follow_up_medical
# female_current_pregnancy_number                          follow_up_medical
# female_current_pregnancy_age_at_conception               follow_up_medical
# female_current_pregnancy_conception_type                 follow_up_medical
# female_current_pregnancy_conception_type_other_...       follow_up_medical
# female_current_pregnancy_diagnosis                       follow_up_medical
# female_current_pregnancy_gestational_diabetes_t...       follow_up_medical
# female_current_pregnancy_live_birth                      follow_up_medical
# female_current_pregnancy_birth_week                      follow_up_medical
# female_current_pregnancy_birth_type                      follow_up_medical
# female_current_pregnancy_birth_weight                    follow_up_medical
# female_current_pregnancy_breastfeeding                   follow_up_medical
# female_current_pregnancy_breastfeeding_months            follow_up_medical
# female_current_pregnancy_termination_week                follow_up_medical
# female_current_pregnancy_termination_reason              follow_up_medical
# female_current_pregnancy_termination_reason_oth...       follow_up_medical
#
#                                                                                          field_string  \
# tabular_field_name
# collection_timestamp                                                             Collection timestamp
# collection_date                                                                       Collection date
# timezone                                                                                     Timezone
# menstural_cycle_past_3_months                                                  did_menstruation_occur
# menstural_cycle_index                                                                     cycle_index
# menstural_cycle_start_date                                                                 started_at
# menstural_cycle_start_description                                              started_at_description
# menstural_cycle_end_date                                                                     ended_at
# menstural_cycle_end_description                                                  ended_at_description
# survey_format                                                                      questioning_format
# collection_timestamp                                                             Collection timestamp
# collection_date                                                                       Collection date
# timezone                                                                                     Timezone
# menarche_age                                                                             Menarche age
# is_getting_period_ques                                                         Is getting period ques
# menopause_age                                                                           Menopause age
# regular_periods_past                                                             Regular periods past
# regular_periods_present                                                       Regular periods present
# menstrual_cycle_average                                                       Menstrual cycle average
# period_duration_days                                                             Period duration days
# tampons_pads_average_per_day                                             Tampons pads average per day
# Intermenstrual_bleeding                                                       Intermenstrual bleeding
# period_pain                                                                               Period pain
# symptoms_of_menstruation                                                     Symptoms of menstruation
# contraception_type                                                                 Contraception type
# women_symptoms                                                                         Women symptoms
# hot_flashes_age                                                                       Hot flashes age
# vaginal_dryness_age                                                               Vaginal dryness age
# low_libido_age                                                                         Low libido age
# mood_changes_age                                                                     Mood changes age
# dry_skin_age                                                                             Dry skin age
# facial_hair_age                                                                       Facial hair age
# voice_changes_age                                                                   Voice changes age
# sperm_count_test                                                                     Sperm count test
# sperm_count_test_results                                                     Sperm count test results
# collection_timestamp                                                             Collection timestamp
# collection_date                                                                       Collection date
# timezone                                                                                     Timezone
# health_male_past_first_facial_hear_age                              Relative age of first facial hair
# health_male_past_voice_break_age                                             Relative age voice broke
# health_male_current_balding_pattern                                              Hair/balding pattern
# health_male_current_children_number                                       Number of children fathered
# health_females_past_mammogram                            Ever had breast cancer screening / mammogram
# health_females_past_mammogram_years                 Years since last breast cancer screening / mam...
# health_females_past_cervical_smear                                       Ever had cervical smear test
# health_females_past_cervical_smear_years                         Years since last cervical smear test
# health_females_past_period_start_age                              Age when periods started (menarche)
# health_females_past_pill_used                                      Ever taken oral contraceptive pill
# health_females_past_pill_start_age                                Age started oral contraceptive pill
# health_females_past_pill_end_age                           Age when last used oral contraceptive pill
# health_females_past_hrt                                   Ever used hormone-replacement therapy (HRT)
# health_females_past_hrt_start_age                       Age started hormone-replacement therapy (HRT)
# health_females_past_hrt_end_age                       Age last used hormone-replacement therapy (HRT)
# health_females_past_hysterectomy                                 Ever had hysterectomy (womb removed)
# health_females_hysterectomy_age                                                   Age at hysterectomy
# health_females_bilateral_oophorectomy                   Bilateral oophorectomy (both ovaries removed)
# health_females_bilateral_oophorectomy_age           Age at bilateral oophorectomy (both ovaries re...
# collection_timestamp                                                             Collection timestamp
# collection_date                                                                       Collection date
# timezone                                                                                     Timezone
# health_male_current_balding_pattern                                              Hair/balding pattern
# extra_health_females_first_mestural_cycle_age           Extra health females first mestural cycle age
# extra_health_females_current_mestural_cycle               Extra health females current mestural cycle
# extra_health_females_last_mestural_cycle_age             Extra health females last mestural cycle age
# extra_health_females_past_mestural_cycle_regular     Extra health females past mestural cycle regular
# extra_health_females_current_mestural_cycle_reg...  Extra health females current mestural cycle re...
# extra_health_females_current_avg_mestural_cycle...  Extra health females current avg mestural cycl...
# extra_health_females_current_avg_mestural_cycle...  Extra health females current avg mestural cycl...
# extra_health_females_current_avg_tampons_per_day     Extra health females current avg tampons per day
# extra_health_females_current_bleeding_between_m...  Extra health females current bleeding between ...
# extra_health_females_current_mestural_cycle_pains   Extra health females current mestural cycle pains
# extra_health_females_current_mestural_cycle_sym...  Extra health females current mestural cycle sy...
# extra_health_females_current_birth_control                 Extra health females current birth control
# extra_health_females_current_birth_control_type       Extra health females current birth control type
# extra_health_females_current_manopause_symptoms       Extra health females current manopause symptoms
# extra_health_females_first_hot_flash_age                     Extra health females first hot flash age
# extra_health_females_first_vaginal_dryness_age         Extra health females first vaginal dryness age
# extra_health_females_first_dicreased_libido_age       Extra health females first dicreased libido age
# extra_health_females_first_mood_changes_age               Extra health females first mood changes age
# extra_health_females_first_skin_dryness_age               Extra health females first skin dryness age
# extra_health_females_current_hrt                                     Extra health females current hrt
# extra_health_females_past_recurring_uti                       Extra health females past recurring uti
# extra_health_females_past_uti_antibiotics                   Extra health females past uti antibiotics
# collection_timestamp                                                             Collection timestamp
# collection_date                                                                       Collection date
# timezone                                                                                     Timezone
# female_current_menstural_cycle                                         Female current menstural cycle
# female_past_mestural_cycle_regular                                 Female past mestural cycle regular
# female_last_mestural_cycle_age                                         Female last mestural cycle age
# female_symptoms                                                                       Female symptoms
# female_other_symptom_description                                     Female other symptom description
# female_fertility_treatments                                               Female fertility treatments
# female_fertility_treatments_number                                 Female fertility treatments number
# female_pregnant_since_recruitment                                   Female pregnant since recruitment
# female_current_pregnancy                                                     Female current pregnancy
# female_current_pregnancy_number                                       Female current pregnancy number
# female_current_pregnancy_age_at_conception                 Female current pregnancy age at conception
# female_current_pregnancy_conception_type                     Female current pregnancy conception type
# female_current_pregnancy_conception_type_other_...  Female current pregnancy conception type other...
# female_current_pregnancy_diagnosis                                 Female current pregnancy diagnosis
# female_current_pregnancy_gestational_diabetes_t...  Female current pregnancy gestational diabetes ...
# female_current_pregnancy_live_birth                               Female current pregnancy live birth
# female_current_pregnancy_birth_week                               Female current pregnancy birth week
# female_current_pregnancy_birth_type                               Female current pregnancy birth type
# female_current_pregnancy_birth_weight                           Female current pregnancy birth weight
# female_current_pregnancy_breastfeeding                         Female current pregnancy breastfeeding
# female_current_pregnancy_breastfeeding_months           Female current pregnancy breastfeeding months
# female_current_pregnancy_termination_week                   Female current pregnancy termination week
# female_current_pregnancy_termination_reason               Female current pregnancy termination reason
# female_current_pregnancy_termination_reason_oth...  Female current pregnancy termination reason de...
#
#                                                                                     relative_location  \
# tabular_field_name
# collection_timestamp                                sex_specific_factors/menstrual_cycle_survey.pa...
# collection_date                                     sex_specific_factors/menstrual_cycle_survey.pa...
# timezone                                            sex_specific_factors/menstrual_cycle_survey.pa...
# menstural_cycle_past_3_months                       sex_specific_factors/menstrual_cycle_survey.pa...
# menstural_cycle_index                               sex_specific_factors/menstrual_cycle_survey.pa...
# menstural_cycle_start_date                          sex_specific_factors/menstrual_cycle_survey.pa...
# menstural_cycle_start_description                   sex_specific_factors/menstrual_cycle_survey.pa...
# menstural_cycle_end_date                            sex_specific_factors/menstrual_cycle_survey.pa...
# menstural_cycle_end_description                     sex_specific_factors/menstrual_cycle_survey.pa...
# survey_format                                       sex_specific_factors/menstrual_cycle_survey.pa...
# collection_timestamp                                     sex_specific_factors/initial_medical.parquet
# collection_date                                          sex_specific_factors/initial_medical.parquet
# timezone                                                 sex_specific_factors/initial_medical.parquet
# menarche_age                                             sex_specific_factors/initial_medical.parquet
# is_getting_period_ques                                   sex_specific_factors/initial_medical.parquet
# menopause_age                                            sex_specific_factors/initial_medical.parquet
# regular_periods_past                                     sex_specific_factors/initial_medical.parquet
# regular_periods_present                                  sex_specific_factors/initial_medical.parquet
# menstrual_cycle_average                                  sex_specific_factors/initial_medical.parquet
# period_duration_days                                     sex_specific_factors/initial_medical.parquet
# tampons_pads_average_per_day                             sex_specific_factors/initial_medical.parquet
# Intermenstrual_bleeding                                  sex_specific_factors/initial_medical.parquet
# period_pain                                              sex_specific_factors/initial_medical.parquet
# symptoms_of_menstruation                                 sex_specific_factors/initial_medical.parquet
# contraception_type                                       sex_specific_factors/initial_medical.parquet
# women_symptoms                                           sex_specific_factors/initial_medical.parquet
# hot_flashes_age                                          sex_specific_factors/initial_medical.parquet
# vaginal_dryness_age                                      sex_specific_factors/initial_medical.parquet
# low_libido_age                                           sex_specific_factors/initial_medical.parquet
# mood_changes_age                                         sex_specific_factors/initial_medical.parquet
# dry_skin_age                                             sex_specific_factors/initial_medical.parquet
# facial_hair_age                                          sex_specific_factors/initial_medical.parquet
# voice_changes_age                                        sex_specific_factors/initial_medical.parquet
# sperm_count_test                                         sex_specific_factors/initial_medical.parquet
# sperm_count_test_results                                 sex_specific_factors/initial_medical.parquet
# collection_timestamp                                                sex_specific_factors/ukbb.parquet
# collection_date                                                     sex_specific_factors/ukbb.parquet
# timezone                                                            sex_specific_factors/ukbb.parquet
# health_male_past_first_facial_hear_age                              sex_specific_factors/ukbb.parquet
# health_male_past_voice_break_age                                    sex_specific_factors/ukbb.parquet
# health_male_current_balding_pattern                                 sex_specific_factors/ukbb.parquet
# health_male_current_children_number                                 sex_specific_factors/ukbb.parquet
# health_females_past_mammogram                                       sex_specific_factors/ukbb.parquet
# health_females_past_mammogram_years                                 sex_specific_factors/ukbb.parquet
# health_females_past_cervical_smear                                  sex_specific_factors/ukbb.parquet
# health_females_past_cervical_smear_years                            sex_specific_factors/ukbb.parquet
# health_females_past_period_start_age                                sex_specific_factors/ukbb.parquet
# health_females_past_pill_used                                       sex_specific_factors/ukbb.parquet
# health_females_past_pill_start_age                                  sex_specific_factors/ukbb.parquet
# health_females_past_pill_end_age                                    sex_specific_factors/ukbb.parquet
# health_females_past_hrt                                             sex_specific_factors/ukbb.parquet
# health_females_past_hrt_start_age                                   sex_specific_factors/ukbb.parquet
# health_females_past_hrt_end_age                                     sex_specific_factors/ukbb.parquet
# health_females_past_hysterectomy                                    sex_specific_factors/ukbb.parquet
# health_females_hysterectomy_age                                     sex_specific_factors/ukbb.parquet
# health_females_bilateral_oophorectomy                               sex_specific_factors/ukbb.parquet
# health_females_bilateral_oophorectomy_age                           sex_specific_factors/ukbb.parquet
# collection_timestamp                                      sex_specific_factors/follow_up_ukbb.parquet
# collection_date                                           sex_specific_factors/follow_up_ukbb.parquet
# timezone                                                  sex_specific_factors/follow_up_ukbb.parquet
# health_male_current_balding_pattern                       sex_specific_factors/follow_up_ukbb.parquet
# extra_health_females_first_mestural_cycle_age             sex_specific_factors/follow_up_ukbb.parquet
# extra_health_females_current_mestural_cycle               sex_specific_factors/follow_up_ukbb.parquet
# extra_health_females_last_mestural_cycle_age              sex_specific_factors/follow_up_ukbb.parquet
# extra_health_females_past_mestural_cycle_regular          sex_specific_factors/follow_up_ukbb.parquet
# extra_health_females_current_mestural_cycle_reg...        sex_specific_factors/follow_up_ukbb.parquet
# extra_health_females_current_avg_mestural_cycle...        sex_specific_factors/follow_up_ukbb.parquet
# extra_health_females_current_avg_mestural_cycle...        sex_specific_factors/follow_up_ukbb.parquet
# extra_health_females_current_avg_tampons_per_day          sex_specific_factors/follow_up_ukbb.parquet
# extra_health_females_current_bleeding_between_m...        sex_specific_factors/follow_up_ukbb.parquet
# extra_health_females_current_mestural_cycle_pains         sex_specific_factors/follow_up_ukbb.parquet
# extra_health_females_current_mestural_cycle_sym...        sex_specific_factors/follow_up_ukbb.parquet
# extra_health_females_current_birth_control                sex_specific_factors/follow_up_ukbb.parquet
# extra_health_females_current_birth_control_type           sex_specific_factors/follow_up_ukbb.parquet
# extra_health_females_current_manopause_symptoms           sex_specific_factors/follow_up_ukbb.parquet
# extra_health_females_first_hot_flash_age                  sex_specific_factors/follow_up_ukbb.parquet
# extra_health_females_first_vaginal_dryness_age            sex_specific_factors/follow_up_ukbb.parquet
# extra_health_females_first_dicreased_libido_age           sex_specific_factors/follow_up_ukbb.parquet
# extra_health_females_first_mood_changes_age               sex_specific_factors/follow_up_ukbb.parquet
# extra_health_females_first_skin_dryness_age               sex_specific_factors/follow_up_ukbb.parquet
# extra_health_females_current_hrt                          sex_specific_factors/follow_up_ukbb.parquet
# extra_health_females_past_recurring_uti                   sex_specific_factors/follow_up_ukbb.parquet
# extra_health_females_past_uti_antibiotics                 sex_specific_factors/follow_up_ukbb.parquet
# collection_timestamp                                   sex_specific_factors/follow_up_medical.parquet
# collection_date                                        sex_specific_factors/follow_up_medical.parquet
# timezone                                               sex_specific_factors/follow_up_medical.parquet
# female_current_menstural_cycle                         sex_specific_factors/follow_up_medical.parquet
# female_past_mestural_cycle_regular                     sex_specific_factors/follow_up_medical.parquet
# female_last_mestural_cycle_age                         sex_specific_factors/follow_up_medical.parquet
# female_symptoms                                        sex_specific_factors/follow_up_medical.parquet
# female_other_symptom_description                       sex_specific_factors/follow_up_medical.parquet
# female_fertility_treatments                            sex_specific_factors/follow_up_medical.parquet
# female_fertility_treatments_number                     sex_specific_factors/follow_up_medical.parquet
# female_pregnant_since_recruitment                      sex_specific_factors/follow_up_medical.parquet
# female_current_pregnancy                               sex_specific_factors/follow_up_medical.parquet
# female_current_pregnancy_number                        sex_specific_factors/follow_up_medical.parquet
# female_current_pregnancy_age_at_conception             sex_specific_factors/follow_up_medical.parquet
# female_current_pregnancy_conception_type               sex_specific_factors/follow_up_medical.parquet
# female_current_pregnancy_conception_type_other_...     sex_specific_factors/follow_up_medical.parquet
# female_current_pregnancy_diagnosis                     sex_specific_factors/follow_up_medical.parquet
# female_current_pregnancy_gestational_diabetes_t...     sex_specific_factors/follow_up_medical.parquet
# female_current_pregnancy_live_birth                    sex_specific_factors/follow_up_medical.parquet
# female_current_pregnancy_birth_week                    sex_specific_factors/follow_up_medical.parquet
# female_current_pregnancy_birth_type                    sex_specific_factors/follow_up_medical.parquet
# female_current_pregnancy_birth_weight                  sex_specific_factors/follow_up_medical.parquet
# female_current_pregnancy_breastfeeding                 sex_specific_factors/follow_up_medical.parquet
# female_current_pregnancy_breastfeeding_months          sex_specific_factors/follow_up_medical.parquet
# female_current_pregnancy_termination_week              sex_specific_factors/follow_up_medical.parquet
# female_current_pregnancy_termination_reason            sex_specific_factors/follow_up_medical.parquet
# female_current_pregnancy_termination_reason_oth...     sex_specific_factors/follow_up_medical.parquet
#
#                                                     bulk_file_extension  \
# tabular_field_name
# collection_timestamp                                                NaN
# collection_date                                                     NaN
# timezone                                                            NaN
# menstural_cycle_past_3_months                                       NaN
# menstural_cycle_index                                               NaN
# menstural_cycle_start_date                                          NaN
# menstural_cycle_start_description                                   NaN
# menstural_cycle_end_date                                            NaN
# menstural_cycle_end_description                                     NaN
# survey_format                                                       NaN
# collection_timestamp                                                NaN
# collection_date                                                     NaN
# timezone                                                            NaN
# menarche_age                                                        NaN
# is_getting_period_ques                                              NaN
# menopause_age                                                       NaN
# regular_periods_past                                                NaN
# regular_periods_present                                             NaN
# menstrual_cycle_average                                             NaN
# period_duration_days                                                NaN
# tampons_pads_average_per_day                                        NaN
# Intermenstrual_bleeding                                             NaN
# period_pain                                                         NaN
# symptoms_of_menstruation                                            NaN
# contraception_type                                                  NaN
# women_symptoms                                                      NaN
# hot_flashes_age                                                     NaN
# vaginal_dryness_age                                                 NaN
# low_libido_age                                                      NaN
# mood_changes_age                                                    NaN
# dry_skin_age                                                        NaN
# facial_hair_age                                                     NaN
# voice_changes_age                                                   NaN
# sperm_count_test                                                    NaN
# sperm_count_test_results                                            NaN
# collection_timestamp                                                NaN
# collection_date                                                     NaN
# timezone                                                            NaN
# health_male_past_first_facial_hear_age                              NaN
# health_male_past_voice_break_age                                    NaN
# health_male_current_balding_pattern                                 NaN
# health_male_current_children_number                                 NaN
# health_females_past_mammogram                                       NaN
# health_females_past_mammogram_years                                 NaN
# health_females_past_cervical_smear                                  NaN
# health_females_past_cervical_smear_years                            NaN
# health_females_past_period_start_age                                NaN
# health_females_past_pill_used                                       NaN
# health_females_past_pill_start_age                                  NaN
# health_females_past_pill_end_age                                    NaN
# health_females_past_hrt                                             NaN
# health_females_past_hrt_start_age                                   NaN
# health_females_past_hrt_end_age                                     NaN
# health_females_past_hysterectomy                                    NaN
# health_females_hysterectomy_age                                     NaN
# health_females_bilateral_oophorectomy                               NaN
# health_females_bilateral_oophorectomy_age                           NaN
# collection_timestamp                                                NaN
# collection_date                                                     NaN
# timezone                                                            NaN
# health_male_current_balding_pattern                                 NaN
# extra_health_females_first_mestural_cycle_age                       NaN
# extra_health_females_current_mestural_cycle                         NaN
# extra_health_females_last_mestural_cycle_age                        NaN
# extra_health_females_past_mestural_cycle_regular                    NaN
# extra_health_females_current_mestural_cycle_reg...                  NaN
# extra_health_females_current_avg_mestural_cycle...                  NaN
# extra_health_females_current_avg_mestural_cycle...                  NaN
# extra_health_females_current_avg_tampons_per_day                    NaN
# extra_health_females_current_bleeding_between_m...                  NaN
# extra_health_females_current_mestural_cycle_pains                   NaN
# extra_health_females_current_mestural_cycle_sym...                  NaN
# extra_health_females_current_birth_control                          NaN
# extra_health_females_current_birth_control_type                     NaN
# extra_health_females_current_manopause_symptoms                     NaN
# extra_health_females_first_hot_flash_age                            NaN
# extra_health_females_first_vaginal_dryness_age                      NaN
# extra_health_females_first_dicreased_libido_age                     NaN
# extra_health_females_first_mood_changes_age                         NaN
# extra_health_females_first_skin_dryness_age                         NaN
# extra_health_females_current_hrt                                    NaN
# extra_health_females_past_recurring_uti                             NaN
# extra_health_females_past_uti_antibiotics                           NaN
# collection_timestamp                                                NaN
# collection_date                                                     NaN
# timezone                                                            NaN
# female_current_menstural_cycle                                      NaN
# female_past_mestural_cycle_regular                                  NaN
# female_last_mestural_cycle_age                                      NaN
# female_symptoms                                                     NaN
# female_other_symptom_description                                    NaN
# female_fertility_treatments                                         NaN
# female_fertility_treatments_number                                  NaN
# female_pregnant_since_recruitment                                   NaN
# female_current_pregnancy                                            NaN
# female_current_pregnancy_number                                     NaN
# female_current_pregnancy_age_at_conception                          NaN
# female_current_pregnancy_conception_type                            NaN
# female_current_pregnancy_conception_type_other_...                  NaN
# female_current_pregnancy_diagnosis                                  NaN
# female_current_pregnancy_gestational_diabetes_t...                  NaN
# female_current_pregnancy_live_birth                                 NaN
# female_current_pregnancy_birth_week                                 NaN
# female_current_pregnancy_birth_type                                 NaN
# female_current_pregnancy_birth_weight                               NaN
# female_current_pregnancy_breastfeeding                              NaN
# female_current_pregnancy_breastfeeding_months                       NaN
# female_current_pregnancy_termination_week                           NaN
# female_current_pregnancy_termination_reason                         NaN
# female_current_pregnancy_termination_reason_oth...                  NaN
#
# ...
# regular_periods_present                             Females only   2/26/2020
# menstrual_cycle_average                             Females only   2/26/2020
# period_duration_days                                Females only   2/26/2020
# tampons_pads_average_per_day                        Females only   2/26/2020
# Intermenstrual_bleeding                             Females only   2/26/2020
# period_pain                                         Females only   2/26/2020
# symptoms_of_menstruation                            Females only   2/26/2020
# contraception_type                                  Females only   2/26/2020
# women_symptoms                                      Females only   2/26/2020
# hot_flashes_age                                     Females only   2/26/2020
# vaginal_dryness_age                                 Females only   2/26/2020
# low_libido_age                                      Females only   2/26/2020
# mood_changes_age                                    Females only   2/26/2020
# dry_skin_age                                        Females only   2/26/2020
# facial_hair_age                                       Males only   2/26/2020
# voice_changes_age                                     Males only   2/26/2020
# sperm_count_test                                      Males only   2/26/2020
# sperm_count_test_results                              Males only   2/26/2020
# collection_timestamp                                  Both sexes         NaN
# collection_date                                       Both sexes         NaN
# timezone                                              Both sexes         NaN
# health_male_past_first_facial_hear_age                Males only    1/9/2019
# health_male_past_voice_break_age                      Males only    1/9/2019
# health_male_current_balding_pattern                   Males only    1/9/2019
# health_male_current_children_number                   Males only    1/9/2019
# health_females_past_mammogram                       Females only    1/9/2019
# health_females_past_mammogram_years                 Females only    1/9/2019
# health_females_past_cervical_smear                  Females only    1/9/2019
# health_females_past_cervical_smear_years            Females only    1/9/2019
# health_females_past_period_start_age                Females only    1/9/2019
# health_females_past_pill_used                       Females only    1/9/2019
# health_females_past_pill_start_age                  Females only    1/9/2019
# health_females_past_pill_end_age                    Females only    1/9/2019
# health_females_past_hrt                             Females only    1/9/2019
# health_females_past_hrt_start_age                   Females only    1/9/2019
# health_females_past_hrt_end_age                     Females only    1/9/2019
# health_females_past_hysterectomy                    Females only    1/9/2019
# health_females_hysterectomy_age                     Females only    1/9/2019
# health_females_bilateral_oophorectomy               Females only    1/9/2019
# health_females_bilateral_oophorectomy_age           Females only    1/9/2019
# collection_timestamp                                  Both sexes         NaN
# collection_date                                       Both sexes         NaN
# timezone                                              Both sexes         NaN
# health_male_current_balding_pattern                   Males only   2/17/2020
# extra_health_females_first_mestural_cycle_age       Females only   2/17/2020
# extra_health_females_current_mestural_cycle         Females only   2/17/2020
# extra_health_females_last_mestural_cycle_age        Females only   2/17/2020
# extra_health_females_past_mestural_cycle_regular    Females only   2/17/2020
# extra_health_females_current_mestural_cycle_reg...  Females only   2/17/2020
# extra_health_females_current_avg_mestural_cycle...  Females only   2/17/2020
# extra_health_females_current_avg_mestural_cycle...  Females only   2/17/2020
# extra_health_females_current_avg_tampons_per_day    Females only   2/17/2020
# extra_health_females_current_bleeding_between_m...  Females only   2/17/2020
# extra_health_females_current_mestural_cycle_pains   Females only   2/17/2020
# extra_health_females_current_mestural_cycle_sym...  Females only   2/17/2020
# extra_health_females_current_birth_control          Females only   2/17/2020
# extra_health_females_current_birth_control_type     Females only   2/17/2020
# extra_health_females_current_manopause_symptoms     Females only   2/17/2020
# extra_health_females_first_hot_flash_age            Females only   2/17/2020
# extra_health_females_first_vaginal_dryness_age      Females only   2/17/2020
# extra_health_females_first_dicreased_libido_age     Females only   2/17/2020
# extra_health_females_first_mood_changes_age         Females only   2/17/2020
# extra_health_females_first_skin_dryness_age         Females only   2/17/2020
# extra_health_females_current_hrt                    Females only   2/17/2020
# extra_health_females_past_recurring_uti             Females only   2/17/2020
# extra_health_females_past_uti_antibiotics           Females only   2/17/2020
# collection_timestamp                                  Both sexes   4/22/2021
# collection_date                                       Both sexes   4/22/2021
# timezone                                              Both sexes   4/22/2021
# female_current_menstural_cycle                      Females only   4/22/2021
# female_past_mestural_cycle_regular                  Females only   4/22/2021
# female_last_mestural_cycle_age                      Females only   4/22/2021
# female_symptoms                                     Females only   4/22/2021
# female_other_symptom_description                    Females only   4/22/2021
# female_fertility_treatments                         Females only   4/22/2021
# female_fertility_treatments_number                  Females only   4/22/2021
# female_pregnant_since_recruitment                   Females only   4/22/2021
# female_current_pregnancy                            Females only   4/22/2021
# female_current_pregnancy_number                     Females only   4/22/2021
# female_current_pregnancy_age_at_conception          Females only   4/22/2021
# female_current_pregnancy_conception_type            Females only   4/22/2021
# female_current_pregnancy_conception_type_other_...  Females only   4/22/2021
# female_current_pregnancy_diagnosis                  Females only   4/22/2021
# female_current_pregnancy_gestational_diabetes_t...  Females only   4/22/2021
# female_current_pregnancy_live_birth                 Females only   4/22/2021
# female_current_pregnancy_birth_week                 Females only   4/22/2021
# female_current_pregnancy_birth_type                 Females only   4/22/2021
# female_current_pregnancy_birth_weight               Females only   4/22/2021
# female_current_pregnancy_breastfeeding              Females only   4/22/2021
# female_current_pregnancy_breastfeeding_months       Females only   4/22/2021
# female_current_pregnancy_termination_week           Females only   4/22/2021
# female_current_pregnancy_termination_reason         Females only   4/22/2021
# female_current_pregnancy_termination_reason_oth...  Females only   4/22/2021
#
#                                                     completed data_coding
# tabular_field_name
# collection_timestamp                                      NaN         NaN
# collection_date                                           NaN         NaN
# timezone                                                  NaN         NaN
# menstural_cycle_past_3_months                             NaN           7
# menstural_cycle_index                                     NaN         NaN
# menstural_cycle_start_date                                NaN         NaN
# menstural_cycle_start_description                         NaN      044_01
# menstural_cycle_end_date                                  NaN         NaN
# menstural_cycle_end_description                           NaN      044_01
# survey_format                                             NaN         NaN
# collection_timestamp                                      NaN         NaN
# collection_date                                           NaN         NaN
# timezone                                                  NaN         NaN
# menarche_age                                              NaN         NaN
# is_getting_period_ques                                    NaN           7
# menopause_age                                             NaN         NaN
# regular_periods_past                                      NaN          21
# regular_periods_present                                   NaN          21
# menstrual_cycle_average                                   NaN         NaN
# period_duration_days                                      NaN         NaN
# tampons_pads_average_per_day                              NaN         NaN
# Intermenstrual_bleeding                                   NaN          21
# period_pain                                               NaN      040_13
# symptoms_of_menstruation                                  NaN      040_14
# contraception_type                                        NaN      040_15
# women_symptoms                                            NaN      040_16
# hot_flashes_age                                           NaN         NaN
# vaginal_dryness_age                                       NaN         NaN
# low_libido_age                                            NaN         NaN
# mood_changes_age                                          NaN         NaN
# dry_skin_age                                              NaN         NaN
# facial_hair_age                                           NaN         NaN
# voice_changes_age                                         NaN         NaN
# sperm_count_test                                          NaN          21
# sperm_count_test_results                                  NaN      048_01
# collection_timestamp                                      NaN         NaN
# collection_date                                           NaN         NaN
# timezone                                                  NaN         NaN
# health_male_past_first_facial_hear_age                    NaN      100570
# health_male_past_voice_break_age                          NaN      100570
# health_male_current_balding_pattern                       NaN      100572
# health_male_current_children_number                       NaN         NaN
# health_females_past_mammogram                             NaN      100349
# health_females_past_mammogram_years                       NaN         NaN
# health_females_past_cervical_smear                        NaN      100349
# health_females_past_cervical_smear_years                  NaN         NaN
# health_females_past_period_start_age                      NaN         NaN
# health_females_past_pill_used                             NaN      100349
# health_females_past_pill_start_age                        NaN         NaN
# health_females_past_pill_end_age                          NaN         NaN
# health_females_past_hrt                                   NaN      100349
# health_females_past_hrt_start_age                         NaN         NaN
# health_females_past_hrt_end_age                           NaN         NaN
# health_females_past_hysterectomy                          NaN      100349
# health_females_hysterectomy_age                           NaN         NaN
# health_females_bilateral_oophorectomy                     NaN      100349
# health_females_bilateral_oophorectomy_age                 NaN         NaN
# collection_timestamp                                      NaN         NaN
# collection_date                                           NaN         NaN
# timezone                                                  NaN         NaN
# health_male_current_balding_pattern                       NaN      100572
# extra_health_females_first_mestural_cycle_age             NaN         NaN
# extra_health_females_current_mestural_cycle               NaN           7
# extra_health_females_last_mestural_cycle_age              NaN         NaN
# extra_health_females_past_mestural_cycle_regular          NaN      100349
# extra_health_females_current_mestural_cycle_reg...        NaN      100349
# extra_health_females_current_avg_mestural_cycle...        NaN         NaN
# extra_health_females_current_avg_mestural_cycle...        NaN         NaN
# extra_health_females_current_avg_tampons_per_day          NaN         NaN
# extra_health_females_current_bleeding_between_m...        NaN      100349
# extra_health_females_current_mestural_cycle_pains         NaN      040_13
# extra_health_females_current_mestural_cycle_sym...        NaN      040_14
# extra_health_females_current_birth_control                NaN           7
# extra_health_females_current_birth_control_type           NaN      040_15
# extra_health_females_current_manopause_symptoms           NaN      040_16
# extra_health_females_first_hot_flash_age                  NaN         NaN
# extra_health_females_first_vaginal_dryness_age            NaN         NaN
# extra_health_females_first_dicreased_libido_age           NaN         NaN
# extra_health_females_first_mood_changes_age               NaN         NaN
# extra_health_females_first_skin_dryness_age               NaN         NaN
# extra_health_females_current_hrt                          NaN           7
# extra_health_females_past_recurring_uti                   NaN           7
# extra_health_females_past_uti_antibiotics                 NaN           7
# collection_timestamp                                      NaN         NaN
# collection_date                                           NaN         NaN
# timezone                                                  NaN         NaN
# female_current_menstural_cycle                            NaN      100349
# female_past_mestural_cycle_regular                        NaN      100349
# female_last_mestural_cycle_age                            NaN         NaN
# female_symptoms                                           NaN      040_16
# female_other_symptom_description                          NaN         NaN
# female_fertility_treatments                               NaN           7
# female_fertility_treatments_number                        NaN         NaN
# female_pregnant_since_recruitment                         NaN           7
# female_current_pregnancy                                  NaN           7
# female_current_pregnancy_number                           NaN         NaN
# female_current_pregnancy_age_at_conception                NaN         NaN
# female_current_pregnancy_conception_type                  NaN      046_05
# female_current_pregnancy_conception_type_other_...        NaN         NaN
# female_current_pregnancy_diagnosis                        NaN      046_06
# female_current_pregnancy_gestational_diabetes_t...        NaN      046_07
# female_current_pregnancy_live_birth                       NaN           7
# female_current_pregnancy_birth_week                       NaN         NaN
# female_current_pregnancy_birth_type                       NaN      046_08
# female_current_pregnancy_birth_weight                     NaN         NaN
# female_current_pregnancy_breastfeeding                    NaN           7
# female_current_pregnancy_breastfeeding_months             NaN         NaN
# female_current_pregnancy_termination_week                 NaN         NaN
# female_current_pregnancy_termination_reason               NaN      046_09
# female_current_pregnancy_termination_reason_oth...        NaN         NaN
