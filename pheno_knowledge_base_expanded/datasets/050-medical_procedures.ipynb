# %% [raw]
# ---
# output-file: 050-medical_procedures.html
# title: Medical Procedures
# ---

# %% [markdown]
# ### Description
#
# The medical procedures dataset captures comprehensive information about surgical interventions, diagnostic tests, and medical procedures that participants have undergone throughout their lives. This includes the type of procedure performed and the year it occurred, providing a detailed medical intervention history for each participant.
#
# ### Introduction
#
# The Human Phenotype Project study gathers medical data through online surveys where participants self-report their use of medical procedures. This approach relies on individuals to communicate their experiences with medical interventions. Accurate and comprehensive information about the utilization of these procedures is crucial for grasping their actual effects on personal health.
#
# ### Measurement protocol
# <!-- long measurment protocol for the data browser -->
# During the registration phase of the study, participants are required to provide details about their medical procedures in the Initial Medical Survey. Further data is then gathered in the Follow-up Medical Survey when participants return for subsequent visits.
#
# ### Data availability
# <!-- for the example notebooks -->
# The information is stored in 2 parquets file: `initial_medical.parquet`, `follow_up_medical.parquet`
#
# ### Summary of available data
# <!-- for the data browser -->
# The dataset includes comprehensive information about medical procedures categorized into several groups. The following are examples of the types of procedures tracked (many additional procedures are also recorded):
#
# **Surgical Procedures (examples):**
#
# - Appendectomy, cholecystectomy, tonsillectomy, adenoidectomy
#
# - Thyroidectomy (total or partial)
#
# - Hysterectomy, oophorectomy, myomectomy, conization of cervix
#
# - Prostatectomy, varicocele or hydrocele repair, nephrectomy
#
# - FESS (Functional Endoscopic Sinus Surgery)
#
# - Cataract surgery
#
# - Cesarean section
#
# - Endometriosis surgery
#
# - Trauma-related surgery, orthopedic surgery
#
# - Splenectomy
#
# - BCC or SCC resection
#
# - Meningioma resection
#
# - Ablation of atrial fibrillation or flutter
#
# - Plastic surgery
#
# **Diagnostic and Therapeutic Procedures:**
#
# - Resting and stress echocardiography
#
# - Ergometric stress testing
#
# - Myocardial perfusion imaging
#
# - Cardiac catheterization
#
# - Carotid ultrasound
#
# - Cardiac CT and MRI
#
# - Brain imaging (CT or MRI)
#
# - Pulmonary function tests
#
# - Mole biopsy
#
# **Other Medical Interventions:**
#
# - Fertility treatments
#
# - Triple antibiotic treatment
#
# - Hospitalization records (frequency and timing)
#
# Each procedure record includes the year of occurrence, allowing for temporal analysis of medical interventions throughout a participant's life.
#
# ### Relevant links
#
# * [Pheno Knowledgebase](https://knowledgebase.pheno.ai/datasets/050-medical_procedures)
# * [Pheno Data Browser](https://pheno-demo-app.vercel.app/folder/50)

# %%
#| echo: false
import pandas as pd
pd.set_option("display.max_rows", 500)

# %%
from pheno_utils import PhenoLoader

# %%
pl = PhenoLoader('medical_procedures')
pl
# Out:
# PhenoLoader for medical_procedures with
# 95 fields
# 3 tables: ['initial_medical', 'follow_up_medical', 'age_sex']

# %% [markdown]
# # Data dictionary

# %%
pl.dict
# Out:
#                                                  folder_id        feature_set  \
# tabular_field_name
# collection_timestamp                                    50    initial_medical
# collection_date                                         50    initial_medical
# timezone                                                50    initial_medical
# fertility_treatment_final_year                          50    initial_medical
# invasive_procedure                                      50    initial_medical
# invasive_procedure_type                                 50    initial_medical
# total_or_partial_thyroidectomy_year                     50    initial_medical
# appendectomy_year                                       50    initial_medical
# cholecystectomy_year                                    50    initial_medical
# plastic_surgery_year_of_diagnosis                       50    initial_medical
# FESS_year                                               50    initial_medical
# tonsillectomy_year                                      50    initial_medical
# adenoidectomy_year                                      50    initial_medical
# cataract_year                                           50    initial_medical
# prostatectomy_year                                      50    initial_medical
# hysterectomy_year                                       50    initial_medical
# oophorectomy_year                                       50    initial_medical
# myomectomy_year                                         50    initial_medical
# endometriosis_surgery_year                              50    initial_medical
# conization_of_cervix_year                               50    initial_medical
# trauma_related_surgery_year                             50    initial_medical
# orthopedic_surgery_year                                 50    initial_medical
# splenectomy_year                                        50    initial_medical
# BCC_or_SCC_resection_year                               50    initial_medical
# meningioma_resection_year                               50    initial_medical
# cesarean_section_year                                   50    initial_medical
# varicocele_or_hydrocele_repair_year                     50    initial_medical
# nephrectomy_year                                        50    initial_medical
# ablation_of_atrial_fibrillation_or_flutter_year         50    initial_medical
# hospitalization_this_year                               50    initial_medical
# number_of_hospitalization_this_year                     50    initial_medical
# triple_antibiotic_treatment_yn                          50    initial_medical
# mole_biopsy_yn                                          50    initial_medical
# borderline_or_malignant_yn                              50    initial_medical
# performed_tests                                         50    initial_medical
# resting_echo_results                                    50    initial_medical
# stress_echo_results                                     50    initial_medical
# ergometric_stress_testing_results                       50    initial_medical
# myocardial_perfusion_imaging_results                    50    initial_medical
# cardiac_catheterization_results                         50    initial_medical
# carotid_ultrasound_results                              50    initial_medical
# ct_cd_results                                           50    initial_medical
# cardiac_MRI_results                                     50    initial_medical
# spirometry_results                                      50    initial_medical
# fMRI_results                                            50    initial_medical
# polyps_information                                      50    initial_medical
# repeat_colonoscopy_years                                50    initial_medical
# vaccine_childhood                                       50    initial_medical
# vaccine_army                                            50    initial_medical
# vaccine_travel                                          50    initial_medical
# vaccine_flue                                            50    initial_medical
# vaccine_pneumonia                                       50    initial_medical
# vaccine_papilloma                                       50    initial_medical
# sensitivity_bees                                        50    initial_medical
# epipen_carrying                                         50    initial_medical
# periodontal_diseases_diagnosis                          50    initial_medical
# periodontal_diseases_diagnosis_family                   50    initial_medical
# laser_eye_surgery_age                                   50    initial_medical
# ritalin                                                 50    initial_medical
# contraception                                           50    initial_medical
# HRT                                                     50    initial_medical
# uti_treatment_antibiotics                               50    initial_medical
# fertility_treatment_no_pregnancy                        50    initial_medical
# fertility_treatments_number                             50    initial_medical
# collection_timestamp                                    50  follow_up_medical
# collection_date                                         50  follow_up_medical
# timezone                                                50  follow_up_medical
# hospitalization_since_recruitment                       50  follow_up_medical
# hospitalization_since_recruitment_number                50  follow_up_medical
# hospitalization_since_recruitment_reason_1              50  follow_up_medical
# hospitalization_since_recruitment_date_1                50  follow_up_medical
# hospitalization_since_recruitment_reason_2              50  follow_up_medical
# hospitalization_since_recruitment_date_2                50  follow_up_medical
# hospitalization_since_recruitment_reason_3              50  follow_up_medical
# hospitalization_since_recruitment_date_3                50  follow_up_medical
# hospitalization_since_recruitment_reason_4              50  follow_up_medical
# hospitalization_since_recruitment_date_4                50  follow_up_medical
# hospitalization_since_recruitment_reason_5              50  follow_up_medical
# hospitalization_since_recruitment_date_5                50  follow_up_medical
# surgery_since_recruitment                               50  follow_up_medical
# eco_heart_past_year                                     50  follow_up_medical
# eco_heart_in_effort_past_year                           50  follow_up_medical
# ergometry_past_year                                     50  follow_up_medical
# heart_mapping_past_year                                 50  follow_up_medical
# cardiac_catheterization_past_year                       50  follow_up_medical
# doppler_of_the_carotid_arteries_past_year               50  follow_up_medical
# cardiac_ct_past_year                                    50  follow_up_medical
# cardica_mri_past_year                                   50  follow_up_medical
# kidney_artery_doppler_past_year                         50  follow_up_medical
# chest_abdomen_pevlis_head_ct_mri_past_year              50  follow_up_medical
# gender_related_tests_past_year                          50  follow_up_medical
# colonoscopy_past_year_result                            50  follow_up_medical
# mammogram_past_year_result                              50  follow_up_medical
# PSA_test_past_year_result                               50  follow_up_medical
# PAP_test_past_year_result                               50  follow_up_medical
# vaccinations_past_year                                  50  follow_up_medical
#
#                                                                                       field_string  \
# tabular_field_name
# collection_timestamp                                                          Collection timestamp
# collection_date                                                                    Collection date
# timezone                                                                                  Timezone
# fertility_treatment_final_year                                      Fertility treatment final year
# invasive_procedure                                                              Invasive procedure
# invasive_procedure_type                                                    Invasive procedure type
# total_or_partial_thyroidectomy_year                            Total or partial thyroidectomy year
# appendectomy_year                                                                Appendectomy year
# cholecystectomy_year                                                          Cholecystectomy year
# plastic_surgery_year_of_diagnosis                                Plastic surgery year of diagnosis
# FESS_year                                                                                FESS year
# tonsillectomy_year                                                              Tonsillectomy year
# adenoidectomy_year                                                              Adenoidectomy year
# cataract_year                                                                        Cataract year
# prostatectomy_year                                                              Prostatectomy year
# hysterectomy_year                                                                Hysterectomy year
# oophorectomy_year                                                                Oophorectomy year
# myomectomy_year                                                                    Myomectomy year
# endometriosis_surgery_year                                              Endometriosis surgery year
# conization_of_cervix_year                                                Conization of cervix year
# trauma_related_surgery_year                                            Trauma related surgery year
# orthopedic_surgery_year                                                    Orthopedic surgery year
# splenectomy_year                                                                  Splenectomy year
# BCC_or_SCC_resection_year                                                BCC or SCC resection year
# meningioma_resection_year                                                Meningioma resection year
# cesarean_section_year                                                        Cesarean section year
# varicocele_or_hydrocele_repair_year                            Varicocele or hydrocele repair year
# nephrectomy_year                                                                  Nephrectomy year
# ablation_of_atrial_fibrillation_or_flutter_year    Ablation of atrial fibrillation or flutter year
# hospitalization_this_year                                                Hospitalization this year
# number_of_hospitalization_this_year                            Number of hospitalization this year
# triple_antibiotic_treatment_yn                                         Triple antibiotic treatment
# mole_biopsy_yn                                                                         Mole biopsy
# borderline_or_malignant_yn                                                 Borderline or malignant
# performed_tests                                                                    Performed tests
# resting_echo_results                                              Resting echocardiography results
# stress_echo_results                                                Stress echocardiography results
# ergometric_stress_testing_results                                Ergometric stress testing results
# myocardial_perfusion_imaging_results                          Myocardial perfusion imaging results
# cardiac_catheterization_results                                    Cardiac catheterization results
# carotid_ultrasound_results                                              Carotid ultrasound results
# ct_cd_results                                                                   Cardiac ct results
# cardiac_MRI_results                                                            Cardiac MRI results
# spirometry_results                                                 Pulmonary function test results
# fMRI_results                                                     Brain imaging (CT or MRI) results
# polyps_information                                                              Polyps information
# repeat_colonoscopy_years                         Recommendation to repeat colonoscopy in XXX years
# vaccine_childhood                                                                Vaccine childhood
# vaccine_army                                               Vaccines during recruitment to the army
# vaccine_travel                                                                      Vaccine travel
# vaccine_flue                                                                     Vaccine influenza
# vaccine_pneumonia                                                                Vaccine pneumonia
# vaccine_papilloma                                                      Vaccine for papilloma virus
# sensitivity_bees                                                                  Sensitivity bees
# epipen_carrying                                                                    Epipen carrying
# periodontal_diseases_diagnosis                                      Periodontal diseases diagnosis
# periodontal_diseases_diagnosis_family                        Periodontal diseases diagnosis family
# laser_eye_surgery_age                                                    Vision correction surgery
# ritalin                                                                                    Ritalin
# contraception                                                                        Contraception
# HRT                                                                                            HRT
# uti_treatment_antibiotics                        Regular antibiotic use or relating to sexual i...
# fertility_treatment_no_pregnancy                                  Fertility treatment no pregnancy
# fertility_treatments_number                                       Unsuccessful fertility treatment
# collection_timestamp                                                          Collection timestamp
# collection_date                                                                    Collection date
# timezone                                                                                  Timezone
# hospitalization_since_recruitment                                          TImezone of measurement
# hospitalization_since_recruitment_number         Where you hospitalized since you were recruite...
# hospitalization_since_recruitment_reason_1                                          How many times
# hospitalization_since_recruitment_date_1                                Reason for hospitalization
# hospitalization_since_recruitment_reason_2                                 Date of hospitalization
# hospitalization_since_recruitment_date_2                                Reason for hospitalization
# hospitalization_since_recruitment_reason_3                                 Date of hospitalization
# hospitalization_since_recruitment_date_3                                Reason for hospitalization
# hospitalization_since_recruitment_reason_4                                 Date of hospitalization
# hospitalization_since_recruitment_date_4                                Reason for hospitalization
# hospitalization_since_recruitment_reason_5                                 Date of hospitalization
# hospitalization_since_recruitment_date_5                                Reason for hospitalization
# surgery_since_recruitment                                                  Date of hospitalization
# eco_heart_past_year                                                                   What surgery
# eco_heart_in_effort_past_year                                                Stress echocardiogram
# ergometry_past_year                                                        Stress test (ergometry)
# heart_mapping_past_year                                               Myocardial perfusion imaging
# cardiac_catheterization_past_year                                          Cardiac Catheterization
# doppler_of_the_carotid_arteries_past_year                        Carotid artery Doppler ultrasound
# cardiac_ct_past_year                                                                    Cardiac CT
# cardica_mri_past_year                                                                  Cardiac MRI
# kidney_artery_doppler_past_year                                         Renal Doppler [ultrasound]
# chest_abdomen_pevlis_head_ct_mri_past_year       Chest / abdomen / pelvis / head CT / MRI exami...
# gender_related_tests_past_year                                 gender specific tests + colonoscopy
# colonoscopy_past_year_result                            Other test performed past year description
# mammogram_past_year_result                                                      Normal colonoscopy
# PSA_test_past_year_result                                                         Normal mammogram
# PAP_test_past_year_result                                                          Normal PSA test
# vaccinations_past_year                                                             Normal PAP test
#
#                                                                             relative_location  \
# tabular_field_name
# collection_timestamp                               medical_procedures/initial_medical.parquet
# collection_date                                    medical_procedures/initial_medical.parquet
# timezone                                           medical_procedures/initial_medical.parquet
# fertility_treatment_final_year                     medical_procedures/initial_medical.parquet
# invasive_procedure                                 medical_procedures/initial_medical.parquet
# invasive_procedure_type                            medical_procedures/initial_medical.parquet
# total_or_partial_thyroidectomy_year                medical_procedures/initial_medical.parquet
# appendectomy_year                                  medical_procedures/initial_medical.parquet
# cholecystectomy_year                               medical_procedures/initial_medical.parquet
# plastic_surgery_year_of_diagnosis                  medical_procedures/initial_medical.parquet
# FESS_year                                          medical_procedures/initial_medical.parquet
# tonsillectomy_year                                 medical_procedures/initial_medical.parquet
# adenoidectomy_year                                 medical_procedures/initial_medical.parquet
# cataract_year                                      medical_procedures/initial_medical.parquet
# prostatectomy_year                                 medical_procedures/initial_medical.parquet
# hysterectomy_year                                  medical_procedures/initial_medical.parquet
# oophorectomy_year                                  medical_procedures/initial_medical.parquet
# myomectomy_year                                    medical_procedures/initial_medical.parquet
# endometriosis_surgery_year                         medical_procedures/initial_medical.parquet
# conization_of_cervix_year                          medical_procedures/initial_medical.parquet
# trauma_related_surgery_year                        medical_procedures/initial_medical.parquet
# orthopedic_surgery_year                            medical_procedures/initial_medical.parquet
# splenectomy_year                                   medical_procedures/initial_medical.parquet
# BCC_or_SCC_resection_year                          medical_procedures/initial_medical.parquet
# meningioma_resection_year                          medical_procedures/initial_medical.parquet
# cesarean_section_year                              medical_procedures/initial_medical.parquet
# varicocele_or_hydrocele_repair_year                medical_procedures/initial_medical.parquet
# nephrectomy_year                                   medical_procedures/initial_medical.parquet
# ablation_of_atrial_fibrillation_or_flutter_year    medical_procedures/initial_medical.parquet
# hospitalization_this_year                          medical_procedures/initial_medical.parquet
# number_of_hospitalization_this_year                medical_procedures/initial_medical.parquet
# triple_antibiotic_treatment_yn                     medical_procedures/initial_medical.parquet
# mole_biopsy_yn                                     medical_procedures/initial_medical.parquet
# borderline_or_malignant_yn                         medical_procedures/initial_medical.parquet
# performed_tests                                    medical_procedures/initial_medical.parquet
# resting_echo_results                               medical_procedures/initial_medical.parquet
# stress_echo_results                                medical_procedures/initial_medical.parquet
# ergometric_stress_testing_results                  medical_procedures/initial_medical.parquet
# myocardial_perfusion_imaging_results               medical_procedures/initial_medical.parquet
# cardiac_catheterization_results                    medical_procedures/initial_medical.parquet
# carotid_ultrasound_results                         medical_procedures/initial_medical.parquet
# ct_cd_results                                      medical_procedures/initial_medical.parquet
# cardiac_MRI_results                                medical_procedures/initial_medical.parquet
# spirometry_results                                 medical_procedures/initial_medical.parquet
# fMRI_results                                       medical_procedures/initial_medical.parquet
# polyps_information                                 medical_procedures/initial_medical.parquet
# repeat_colonoscopy_years                           medical_procedures/initial_medical.parquet
# vaccine_childhood                                  medical_procedures/initial_medical.parquet
# vaccine_army                                       medical_procedures/initial_medical.parquet
# vaccine_travel                                     medical_procedures/initial_medical.parquet
# vaccine_flue                                       medical_procedures/initial_medical.parquet
# vaccine_pneumonia                                  medical_procedures/initial_medical.parquet
# vaccine_papilloma                                  medical_procedures/initial_medical.parquet
# sensitivity_bees                                   medical_procedures/initial_medical.parquet
# epipen_carrying                                    medical_procedures/initial_medical.parquet
# periodontal_diseases_diagnosis                     medical_procedures/initial_medical.parquet
# periodontal_diseases_diagnosis_family              medical_procedures/initial_medical.parquet
# laser_eye_surgery_age                              medical_procedures/initial_medical.parquet
# ritalin                                            medical_procedures/initial_medical.parquet
# contraception                                      medical_procedures/initial_medical.parquet
# HRT                                                medical_procedures/initial_medical.parquet
# uti_treatment_antibiotics                          medical_procedures/initial_medical.parquet
# fertility_treatment_no_pregnancy                   medical_procedures/initial_medical.parquet
# fertility_treatments_number                        medical_procedures/initial_medical.parquet
# collection_timestamp                             medical_procedures/follow_up_medical.parquet
# collection_date                                  medical_procedures/follow_up_medical.parquet
# timezone                                         medical_procedures/follow_up_medical.parquet
# hospitalization_since_recruitment                medical_procedures/follow_up_medical.parquet
# hospitalization_since_recruitment_number         medical_procedures/follow_up_medical.parquet
# hospitalization_since_recruitment_reason_1       medical_procedures/follow_up_medical.parquet
# hospitalization_since_recruitment_date_1         medical_procedures/follow_up_medical.parquet
# hospitalization_since_recruitment_reason_2       medical_procedures/follow_up_medical.parquet
# hospitalization_since_recruitment_date_2         medical_procedures/follow_up_medical.parquet
# hospitalization_since_recruitment_reason_3       medical_procedures/follow_up_medical.parquet
# hospitalization_since_recruitment_date_3         medical_procedures/follow_up_medical.parquet
# hospitalization_since_recruitment_reason_4       medical_procedures/follow_up_medical.parquet
# hospitalization_since_recruitment_date_4         medical_procedures/follow_up_medical.parquet
# hospitalization_since_recruitment_reason_5       medical_procedures/follow_up_medical.parquet
# hospitalization_since_recruitment_date_5         medical_procedures/follow_up_medical.parquet
# surgery_since_recruitment                        medical_procedures/follow_up_medical.parquet
# eco_heart_past_year                              medical_procedures/follow_up_medical.parquet
# eco_heart_in_effort_past_year                    medical_procedures/follow_up_medical.parquet
# ergometry_past_year                              medical_procedures/follow_up_medical.parquet
# heart_mapping_past_year                          medical_procedures/follow_up_medical.parquet
# cardiac_catheterization_past_year                medical_procedures/follow_up_medical.parquet
# doppler_of_the_carotid_arteries_past_year        medical_procedures/follow_up_medical.parquet
# cardiac_ct_past_year                             medical_procedures/follow_up_medical.parquet
# cardica_mri_past_year                            medical_procedures/follow_up_medical.parquet
# kidney_artery_doppler_past_year                  medical_procedures/follow_up_medical.parquet
# chest_abdomen_pevlis_head_ct_mri_past_year       medical_procedures/follow_up_medical.parquet
# gender_related_tests_past_year                   medical_procedures/follow_up_medical.parquet
# colonoscopy_past_year_result                     medical_procedures/follow_up_medical.parquet
# mammogram_past_year_result                       medical_procedures/follow_up_medical.parquet
# PSA_test_past_year_result                        medical_procedures/follow_up_medical.parquet
# PAP_test_past_year_result                        medical_procedures/follow_up_medical.parquet
# vaccinations_past_year                           medical_procedures/follow_up_medical.parquet
#
#                                                  bulk_file_extension  \
# tabular_field_name
# collection_timestamp                                             NaN
# collection_date                                                  NaN
# timezone                                                         NaN
# fertility_treatment_final_year                                   NaN
# invasive_procedure                                               NaN
# invasive_procedure_type                                          NaN
# total_or_partial_thyroidectomy_year                              NaN
# appendectomy_year                                                NaN
# cholecystectomy_year                                             NaN
# plastic_surgery_year_of_diagnosis                                NaN
# FESS_year                                                        NaN
# tonsillectomy_year                                               NaN
# adenoidectomy_year                                               NaN
# cataract_year                                                    NaN
# prostatectomy_year                                               NaN
# hysterectomy_year                                                NaN
# oophorectomy_year                                                NaN
# myomectomy_year                                                  NaN
# endometriosis_surgery_year                                       NaN
# conization_of_cervix_year                                        NaN
# trauma_related_surgery_year                                      NaN
# orthopedic_surgery_year                                          NaN
# splenectomy_year                                                 NaN
# BCC_or_SCC_resection_year                                        NaN
# meningioma_resection_year                                        NaN
# cesarean_section_year                                            NaN
# varicocele_or_hydrocele_repair_year                              NaN
# nephrectomy_year                                                 NaN
# ablation_of_atrial_fibrillation_or_flutter_year                  NaN
# hospitalization_this_year                                        NaN
# number_of_hospitalization_this_year                              NaN
# triple_antibiotic_treatment_yn                                   NaN
# mole_biopsy_yn                                                   NaN
# borderline_or_malignant_yn                                       NaN
# performed_tests                                                  NaN
# resting_echo_results                                             NaN
# stress_echo_results                                              NaN
# ergometric_stress_testing_results                                NaN
# myocardial_perfusion_imaging_results                             NaN
# cardiac_catheterization_results                                  NaN
# carotid_ultrasound_results                                       NaN
# ct_cd_results                                                    NaN
# cardiac_MRI_results                                              NaN
# spirometry_results                                               NaN
# fMRI_results                                                     NaN
# polyps_information                                               NaN
# repeat_colonoscopy_years                                         NaN
# vaccine_childhood                                                NaN
# vaccine_army                                                     NaN
# vaccine_travel                                                   NaN
# vaccine_flue                                                     NaN
# vaccine_pneumonia                                                NaN
# vaccine_papilloma                                                NaN
# sensitivity_bees                                                 NaN
# epipen_carrying                                                  NaN
# periodontal_diseases_diagnosis                                   NaN
# periodontal_diseases_diagnosis_family                            NaN
# laser_eye_surgery_age                                            NaN
# ritalin                                                          NaN
# contraception                                                    NaN
# HRT                                                              NaN
# uti_treatment_antibiotics                                        NaN
# fertility_treatment_no_pregnancy                                 NaN
# fertility_treatments_number                                      NaN
# collection_timestamp                                             NaN
# collection_date                                                  NaN
# timezone                                                         NaN
# hospitalization_since_recruitment                                NaN
# hospitalization_since_recruitment_number                         NaN
# hospitalization_since_recruitment_reason_1                       NaN
# hospitalization_since_recruitment_date_1                         NaN
# hospitalization_since_recruitment_reason_2                       NaN
# hospitalization_since_recruitment_date_2                         NaN
# hospitalization_since_recruitment_reason_3                       NaN
# hospitalization_since_recruitment_date_3                         NaN
# hospitalization_since_recruitment_reason_4                       NaN
# hospitalization_since_recruitment_date_4                         NaN
# hospitalization_since_recruitment_reason_5                       NaN
# hospitalization_since_recruitment_date_5                         NaN
# surgery_since_recruitment                                        NaN
# eco_heart_past_year                                              NaN
# eco_heart_in_effort_past_year                                    NaN
# ergometry_past_year                                              NaN
# heart_mapping_past_year                                          NaN
# cardiac_catheterization_past_year                                NaN
# doppler_of_the_carotid_arteries_past_year                        NaN
# cardiac_ct_past_year                                             NaN
# cardica_mri_past_year                                            NaN
# kidney_artery_doppler_past_year                                  NaN
# chest_abdomen_pevlis_head_ct_mri_past_year                       NaN
# gender_related_tests_past_year                                   NaN
# colonoscopy_past_year_result                                     NaN
# mammogram_past_year_result                                       NaN
# PSA_test_past_year_result                                        NaN
# PAP_test_past_year_result                                        NaN
# vaccinations_past_year                                           NaN
#
#                                                  bulk_dictionary  \
# tabular_field_name
# collection_timestamp                                         NaN
# collection_date                                              NaN
# timezone                                                     NaN
# fertility_treatment_final_year                               NaN
# invasive_procedure                                           NaN
# invasive_procedure_type                                      NaN
# total_or_partial_thyroidectomy_year                          NaN
# appendectomy_year                                            NaN
# cholecystectomy_year                                         NaN
# plastic_surgery_year_of_diagnosis                            NaN
# FESS_year                                                    NaN
# tonsillectomy_year                                           NaN
# adenoidectomy_year                                           NaN
# cataract_year                                                NaN
# prostatectomy_year                                           NaN
# hysterectomy_year                                            NaN
# oophorectomy_year                                            NaN
# myomectomy_year                                              NaN
# endometriosis_surgery_year                                   NaN
# conization_of_cervix_year                                    NaN
# trauma_related_surgery_year                                  NaN
# orthopedic_surgery_year                                      NaN
# splenectomy_year                                             NaN
# BCC_or_SCC_resection_year                                    NaN
# meningioma_resection_year                                    NaN
# cesarean_section_year                                        NaN
# varicocele_or_hydrocele_repair_year                          NaN
# nephrectomy_year                                             NaN
# ablation_of_atrial_fibrillation_or_flutter_year              NaN
# hospitalization_this_year                                    NaN
# number_of_hospitalization_this_year                          NaN
# triple_antibiotic_treatment_yn                               NaN
# mole_biopsy_yn                                               NaN
# borderline_or_malignant_yn                                   NaN
# performed_tests                                              NaN
# resting_echo_results                                         NaN
# stress_echo_results                                          NaN
# ergometric_stress_testing_results                            NaN
# myocardial_perfusion_imaging_results                         NaN
# cardiac_catheterization_results                              NaN
# carotid_ultrasound_results                                   NaN
# ct_cd_results                                                NaN
# cardiac_MRI_results                                          NaN
# spirometry_results                                           NaN
# fMRI_results                                                 NaN
# polyps_information                                           NaN
# repeat_colonoscopy_years                                     NaN
# vaccine_childhood                                            NaN
# vaccine_army                                                 NaN
# vaccine_travel                                               NaN
# vaccine_flue                                                 NaN
# vaccine_pneumonia                                            NaN
# vaccine_papilloma                                            NaN
# sensitivity_bees                                             NaN
# epipen_carrying                                              NaN
# periodontal_diseases_diagnosis                               NaN
# periodontal_diseases_diagnosis_family                        NaN
# laser_eye_surgery_age                                        NaN
# ritalin                                                      NaN
# contraception                                                NaN
# HRT                                                          NaN
# uti_treatment_antibiotics                                    NaN
# fertility_treatment_no_pregnancy                             NaN
# fertility_treatments_number                                  NaN
# collection_timestamp                                         NaN
# collection_date                                              NaN
# timezone                                                     NaN
# hospitalization_since_recruitment                            NaN
# hospitalization_since_recruitment_number                     NaN
# hospitalization_since_recruitment_reason_1                   NaN
# hospitalization_since_recruitment_date_1                     NaN
# hospitalization_since_recruitment_reason_2                   NaN
# hospitalization_since_recruitment_date_2                     NaN
# hospitalization_since_recruitment_reason_3                   NaN
# hospitalization_since_recruitment_date_3                     NaN
# hospitalization_since_recruitment_reason_4                   NaN
# hospitalization_since_recruitment_date_4                     NaN
# hospitalization_since_recruitment_reason_5                   NaN
# hospitalization_since_recruitment_date_5                     NaN
# surgery_since_recruitment                                    NaN
# eco_heart_past_year                                          NaN
# eco_heart_in_effort_past_year                                NaN
# ergometry_past_year                                          NaN
# heart_mapping_past_year                                      NaN
# cardiac_catheterization_past_year                            NaN
# doppler_of_the_carotid_arteries_past_year                    NaN
# cardiac_ct_past_year                                         NaN
# cardica_mri_past_year                                        NaN
# kidney_artery_doppler_past_year                              NaN
# chest_abdomen_pevlis_head_ct_mri_past_year                   NaN
# gender_related_tests_past_year                               NaN
# colonoscopy_past_year_result                                 NaN
# mammogram_past_year_result                                   NaN
# PSA_test_past_year_result                                    NaN
# PAP_test_past_year_result                                    NaN
# vaccinations_past_year                                       NaN
#
#                                                                                 description_string  \
# tabular_field_name
# collection_timestamp                                          Timestamp of measurements collection
# collection_date                                                     Date of measurments collection
# timezone                                                               Timezone of the measurments
# fertility_treatment_final_year                                      Fertility treatment final year
# invasive_procedure                               Have you previously undergone surgery or an in...
# invasive_procedure_type                          Please select from the following list of invas...
# total_or_partial_thyroidectomy_year              What year did you undergo a full or partial re...
# appendectomy_year                                What year did you undergo appendix resection (...
# cholecystectomy_year                             What year did you  undergo gallbladder resecti...
# plastic_surgery_year_of_diagnosis                       What year did you undergo plastic surgery?
# FESS_year                                                 What year did you undergo sinus surgery?
# tonsillectomy_year                               What year did you undergo tonsils removal (Ton...
# adenoidectomy_year                                        What year did you undergo adenoidectomy?
# cataract_year                                          What year did you undergo cataract surgery?
# prostatectomy_year                                   What year did you undergo prostate resection?
# hysterectomy_year                                        What year did you undergo a hysterectomy?
# oophorectomy_year                                What year did you go through ovaries removal (...
# myomectomy_year                                  What year did you undergo removal of uterine f...
# endometriosis_surgery_year                       What year did you undergo gynecological surger...
# conization_of_cervix_year                        What year did you undergo a cone biopsy (coniz...
# trauma_related_surgery_year                      What year did you undergo surgeries following ...
# orthopedic_surgery_year                          What year did you undergo an orthopedic surger...
# splenectomy_year                                 What year did you undergo a spleen removal (sp...
# BCC_or_SCC_resection_year                        What year did you undergo basal or squamous ce...
# meningioma_resection_year                        What year did you undergo meningioma removal s...
# cesarean_section_year                                  What year did you undergo cesarean section?
# varicocele_or_hydrocele_repair_year              What year did you undergo surgical repair of v...
# nephrectomy_year                                 What year did you undergo kidney removal (neph...
# ablation_of_atrial_fibrillation_or_flutter_year  What year did you undergo ablation procedure f...
# hospitalization_this_year                         Have you been hospitalized during the past year?
# number_of_hospitalization_this_year              Please specify how many times have you been ho...
# triple_antibiotic_treatment_yn                   Did you get antibiotic Triple Therapy to eradi...
# mole_biopsy_yn                                    Was a biopsy taken from a skin mole in the past?
# borderline_or_malignant_yn                       Was the lesion diagnosed as malignant or exhib...
# performed_tests                                         Did you perform any of the following tests
# resting_echo_results                                                Resting Echocardiogram results
# stress_echo_results                                                  Stress echocardiogram results
# ergometric_stress_testing_results                                  Stress test (ergometry) results
# myocardial_perfusion_imaging_results                     Myocardial perfusion imaging scan results
# cardiac_catheterization_results                  Cardiac catheterisation and coronary angiograp...
# carotid_ultrasound_results                               Carotid artery Doppler ultrasound results
# ct_cd_results                                                       Cardiac CT Angiography results
# cardiac_MRI_results                                                            Cardiac MRI results
# spirometry_results                                                 Pulmonary function test results
# fMRI_results                                                       Brain imaging results (CT, MRI)
# polyps_information                                   Please detail any findings as far as you know
# repeat_colonoscopy_years                         What is the follow-up frequency (in years) ass...
# vaccine_childhood                                Vaccines and Sensitations |Does childhood vacc...
# vaccine_army                                     Vaccines and Sensitations |Do you vaccines as ...
# vaccine_travel                                   Vaccines and Sensitations |Did you receive add...
# vaccine_flue                                     Vaccines and Sensitations |Are you annualy vac...
# vaccine_pneumonia                                Vaccines and Sensitations |Do you vaccinate ag...
# vaccine_papilloma                                Vaccines and Sensitations |Do you vaccinate th...
# sensitivity_bees                                 Vaccines and Sensitations |Is there a sensitiv...
# epipen_carrying                                  Vaccines and Sensitations |Is Apiphan subject ...
# periodontal_diseases_diagnosis                                      Periodontal diseases diagnosis
# periodontal_diseases_diagnosis_family                        Periodontal diseases diagnosis family
# laser_eye_surgery_age                              At what age did you undergo vision improvement?
# ritalin                                          Do you take or previously - Ritalin or its der...
# contraception                                                            Do you use contraception?
# HRT                                                       Do you take alternative hormone therapy?
# uti_treatment_antibiotics                        Does antibiotically treat or around having sex...
# fertility_treatment_no_pregnancy                 Did you undergo fertility treatments that did ...
# fertility_treatments_number                      Please detail the total number of fertility tr...
# collection_timestamp                                          Timestamp of measurements collection
# ...
# hospitalization_since_recruitment_number               NaN
# hospitalization_since_recruitment_reason_1             NaN
# hospitalization_since_recruitment_date_1               NaN
# hospitalization_since_recruitment_reason_2             NaN
# hospitalization_since_recruitment_date_2               NaN
# hospitalization_since_recruitment_reason_3             NaN
# hospitalization_since_recruitment_date_3               NaN
# hospitalization_since_recruitment_reason_4             NaN
# hospitalization_since_recruitment_date_4               NaN
# hospitalization_since_recruitment_reason_5             NaN
# hospitalization_since_recruitment_date_5               NaN
# surgery_since_recruitment                              NaN
# eco_heart_past_year                                    NaN
# eco_heart_in_effort_past_year                          NaN
# ergometry_past_year                                    NaN
# heart_mapping_past_year                                NaN
# cardiac_catheterization_past_year                      NaN
# doppler_of_the_carotid_arteries_past_year              NaN
# cardiac_ct_past_year                                   NaN
# cardica_mri_past_year                                  NaN
# kidney_artery_doppler_past_year                        NaN
# chest_abdomen_pevlis_head_ct_mri_past_year             NaN
# gender_related_tests_past_year                         NaN
# colonoscopy_past_year_result                           NaN
# mammogram_past_year_result                             NaN
# PSA_test_past_year_result                              NaN
# PAP_test_past_year_result                              NaN
# vaccinations_past_year                                 NaN
#
#                                                                    pandas_dtype  \
# tabular_field_name
# collection_timestamp                             datetime64[ns, Asia/Jerusalem]
# collection_date                                                  datetime64[ns]
# timezone                                                               category
# fertility_treatment_final_year                                              int
# invasive_procedure                                                          int
# invasive_procedure_type                                                  object
# total_or_partial_thyroidectomy_year                                         int
# appendectomy_year                                                           int
# cholecystectomy_year                                                        int
# plastic_surgery_year_of_diagnosis                                           int
# FESS_year                                                                   int
# tonsillectomy_year                                                          int
# adenoidectomy_year                                                          int
# cataract_year                                                               int
# prostatectomy_year                                                          int
# hysterectomy_year                                                           int
# oophorectomy_year                                                           int
# myomectomy_year                                                             int
# endometriosis_surgery_year                                                  int
# conization_of_cervix_year                                                   int
# trauma_related_surgery_year                                                 int
# orthopedic_surgery_year                                                     int
# splenectomy_year                                                            int
# BCC_or_SCC_resection_year                                                   int
# meningioma_resection_year                                                   int
# cesarean_section_year                                                       int
# varicocele_or_hydrocele_repair_year                                         int
# nephrectomy_year                                                            int
# ablation_of_atrial_fibrillation_or_flutter_year                             int
# hospitalization_this_year                                                   int
# number_of_hospitalization_this_year                                      object
# triple_antibiotic_treatment_yn                                              int
# mole_biopsy_yn                                                              int
# borderline_or_malignant_yn                                                  int
# performed_tests                                                          object
# resting_echo_results                                                        int
# stress_echo_results                                                         int
# ergometric_stress_testing_results                                           int
# myocardial_perfusion_imaging_results                                        int
# cardiac_catheterization_results                                             int
# carotid_ultrasound_results                                                  int
# ct_cd_results                                                               int
# cardiac_MRI_results                                                         int
# spirometry_results                                                          int
# fMRI_results                                                                int
# polyps_information                                                       object
# repeat_colonoscopy_years                                                    int
# vaccine_childhood                                                           int
# vaccine_army                                                                int
# vaccine_travel                                                              int
# vaccine_flue                                                                int
# vaccine_pneumonia                                                           int
# vaccine_papilloma                                                           int
# sensitivity_bees                                                            int
# epipen_carrying                                                             int
# periodontal_diseases_diagnosis                                              int
# periodontal_diseases_diagnosis_family                                       int
# laser_eye_surgery_age                                                       int
# ritalin                                                                     int
# contraception                                                               int
# HRT                                                                         int
# uti_treatment_antibiotics                                                   int
# fertility_treatment_no_pregnancy                                            int
# fertility_treatments_number                                                 int
# collection_timestamp                             datetime64[ns, Asia/Jerusalem]
# collection_date                                                  datetime64[ns]
# timezone                                                                 string
# hospitalization_since_recruitment                                           int
# hospitalization_since_recruitment_number                                    int
# hospitalization_since_recruitment_reason_1                               string
# hospitalization_since_recruitment_date_1         datetime64[ns, Asia/Jerusalem]
# hospitalization_since_recruitment_reason_2                               string
# hospitalization_since_recruitment_date_2         datetime64[ns, Asia/Jerusalem]
# hospitalization_since_recruitment_reason_3                               string
# hospitalization_since_recruitment_date_3         datetime64[ns, Asia/Jerusalem]
# hospitalization_since_recruitment_reason_4                               string
# hospitalization_since_recruitment_date_4         datetime64[ns, Asia/Jerusalem]
# hospitalization_since_recruitment_reason_5                               string
# hospitalization_since_recruitment_date_5         datetime64[ns, Asia/Jerusalem]
# surgery_since_recruitment                                                   int
# eco_heart_past_year                                                      object
# eco_heart_in_effort_past_year                                            object
# ergometry_past_year                                                      object
# heart_mapping_past_year                                                  object
# cardiac_catheterization_past_year                                        object
# doppler_of_the_carotid_arteries_past_year                                object
# cardiac_ct_past_year                                                     object
# cardica_mri_past_year                                                    object
# kidney_artery_doppler_past_year                                          object
# chest_abdomen_pevlis_head_ct_mri_past_year                               object
# gender_related_tests_past_year                                           object
# colonoscopy_past_year_result                                                int
# mammogram_past_year_result                                                  int
# PSA_test_past_year_result                                                   int
# PAP_test_past_year_result                                                   int
# vaccinations_past_year                                                   object
#
#                                                 data_coding
# tabular_field_name
# collection_timestamp                                    NaN
# collection_date                                         NaN
# timezone                                                NaN
# fertility_treatment_final_year                          NaN
# invasive_procedure                                       21
# invasive_procedure_type                              050_01
# total_or_partial_thyroidectomy_year                     NaN
# appendectomy_year                                       NaN
# cholecystectomy_year                                    NaN
# plastic_surgery_year_of_diagnosis                       NaN
# FESS_year                                               NaN
# tonsillectomy_year                                      NaN
# adenoidectomy_year                                      NaN
# cataract_year                                           NaN
# prostatectomy_year                                      NaN
# hysterectomy_year                                       NaN
# oophorectomy_year                                       NaN
# myomectomy_year                                         NaN
# endometriosis_surgery_year                              NaN
# conization_of_cervix_year                               NaN
# trauma_related_surgery_year                             NaN
# orthopedic_surgery_year                                 NaN
# splenectomy_year                                        NaN
# BCC_or_SCC_resection_year                               NaN
# meningioma_resection_year                               NaN
# cesarean_section_year                                   NaN
# varicocele_or_hydrocele_repair_year                     NaN
# nephrectomy_year                                        NaN
# ablation_of_atrial_fibrillation_or_flutter_year         NaN
# hospitalization_this_year                                 7
# number_of_hospitalization_this_year                  050_03
# triple_antibiotic_treatment_yn                           21
# mole_biopsy_yn                                           21
# borderline_or_malignant_yn                               21
# performed_tests                                      050_02
# resting_echo_results                                 050_04
# stress_echo_results                                  050_04
# ergometric_stress_testing_results                    050_04
# myocardial_perfusion_imaging_results                 050_04
# cardiac_catheterization_results                      050_04
# carotid_ultrasound_results                           050_04
# ct_cd_results                                        050_04
# cardiac_MRI_results                                  050_04
# spirometry_results                                   050_04
# fMRI_results                                         050_04
# polyps_information                                   050_05
# repeat_colonoscopy_years                                NaN
# vaccine_childhood                                        21
# vaccine_army                                             21
# vaccine_travel                                           21
# vaccine_flue                                             21
# vaccine_pneumonia                                        21
# vaccine_papilloma                                        21
# sensitivity_bees                                         21
# epipen_carrying                                          21
# periodontal_diseases_diagnosis                       050_06
# periodontal_diseases_diagnosis_family                050_07
# laser_eye_surgery_age                                   NaN
# ritalin                                                   7
# contraception                                             7
# HRT                                                       7
# uti_treatment_antibiotics                                 7
# fertility_treatment_no_pregnancy                          7
# fertility_treatments_number                             NaN
# collection_timestamp                                    NaN
# collection_date                                         NaN
# timezone                                                NaN
# hospitalization_since_recruitment                         7
# hospitalization_since_recruitment_number                NaN
# hospitalization_since_recruitment_reason_1              NaN
# hospitalization_since_recruitment_date_1                NaN
# hospitalization_since_recruitment_reason_2              NaN
# hospitalization_since_recruitment_date_2                NaN
# hospitalization_since_recruitment_reason_3              NaN
# hospitalization_since_recruitment_date_3                NaN
# hospitalization_since_recruitment_reason_4              NaN
# hospitalization_since_recruitment_date_4                NaN
# hospitalization_since_recruitment_reason_5              NaN
# hospitalization_since_recruitment_date_5                NaN
# surgery_since_recruitment                                 7
# eco_heart_past_year                                  046_01
# eco_heart_in_effort_past_year                        046_01
# ergometry_past_year                                  046_01
# heart_mapping_past_year                              046_01
# cardiac_catheterization_past_year                    046_01
# doppler_of_the_carotid_arteries_past_year            046_01
# cardiac_ct_past_year                                 046_01
# cardica_mri_past_year                                046_01
# kidney_artery_doppler_past_year                      046_01
# chest_abdomen_pevlis_head_ct_mri_past_year           046_01
# gender_related_tests_past_year                       046_02
# colonoscopy_past_year_result                         100349
# mammogram_past_year_result                           100349
# PSA_test_past_year_result                            100349
# PAP_test_past_year_result                            100349
# vaccinations_past_year                               046_03
