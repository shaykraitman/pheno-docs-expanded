# %% [raw]
# ---
# output-file: 058-health_and_medical_history.html
# title: Health and Medical History
# ---

# %% [markdown]
# ### Description
#
# Health and medical history data provides comprehensive insights into an individual's past and present medical conditions, treatments, surgeries, and overall health status. This data includes personal health details such as chronic illnesses, medications, hospitalizations, and surgical procedures, which help in assessing risk factors and understanding disease progression over time.
#
# ### Introduction
#
# The Human Phenotype Project conducts comprehensive data collection through online surveys, where participants voluntarily provide information on various aspects influencing their health. This includes information about a participant's health and medical history, captured through two lifestyle surveys.
#
# ### Measurement protocol
# <!-- long measurment protocol for the data browser -->
# These lifestyle surveys are modeled after the UK Biobank's touch screen questionnaire. Participants receive the full version via email to complete on the Zoho platform, either before or after their baseline visit. A shorter, follow-up version of the questionnaire is then filled out by participants during subsequent visits.
#
# ### Data availability
# <!-- for the example notebooks -->
# The information is stored in 2 parquet files: `ukbb.parquet` and `initial_medical.parquet`
#
# ### Summary of available data
# <!-- for the data browser -->
# 1. Initial Medical Survey: A DataFrame containing tabular features representing responses related to personal health and medical history from the initial medical survey.
# 2. Lifestyle Survey: A DataFrame containing tabular features representing responses related to health behaviors and medical history from the lifestyle survey.
#
# ### Relevant links
#
# * [Pheno Knowledgebase](https://knowledgebase.pheno.ai/datasets/058-health_and_medical_history.html)
# * [Pheno Data Browser](https://pheno-demo-app.vercel.app/folder/58)

# %%
#| echo: false
import pandas as pd
pd.set_option("display.max_rows", 500)

# %%
from pheno_utils import PhenoLoader

# %%
pl = PhenoLoader('health_and_medical_history')
pl
# Out:
# PhenoLoader for health_and_medical_history with
# 74 fields
# 3 tables: ['ukbb', 'initial_medical', 'age_sex']

# %% [markdown]
# # Data dictionary

# %%
pl.dict
# Out:
#                                                    folder_id      feature_set  \
# tabular_field_name
# collection_timestamp                                      58             ukbb
# collection_date                                           58             ukbb
# timezone                                                  58             ukbb
# health_general_rating                                     58             ukbb
# health_general_dissability_illness                        58             ukbb
# health_eyes_glasses_contacts                              58             ukbb
# health_eyes_glasses_contacts_start_age                    58             ukbb
# health_eyes_glasses_contacts_reason                       58             ukbb
# health_eyes_short_sight_eye                               58             ukbb
# health_eyes_long_sight_eye                                58             ukbb
# health_eyes_reading_glasses_eye                           58             ukbb
# health_eyes_astigmatism_eye                               58             ukbb
# health_eyes_squint_eye                                    58             ukbb
# health_eyes_amblyopia_eye                                 58             ukbb
# health_eyes_other_condition_eye                           58             ukbb
# health_eyes_other_problems                                58             ukbb
# health_eyes_problems_doctor_diagnosis                     58             ukbb
# health_eyes_diabetes_eye                                  58             ukbb
# health_eyes_diabetes_eye_start_age                        58             ukbb
# health_eyes_glaucoma_eye                                  58             ukbb
# health_eyes_glaucoma_eye_start_age                        58             ukbb
# health_eyes_injury_trauma_eye                             58             ukbb
# health_eyes_injury_trauma_eye_start_age                   58             ukbb
# health_eyes_cataract_eye                                  58             ukbb
# health_eyes_cataract_eye_start_age                        58             ukbb
# health_eyes_macular_degeneration_eye                      58             ukbb
# health_eyes_macular_degeneration_eye_start_age            58             ukbb
# health_eyes_other_serious_condition_eye                   58             ukbb
# health_eyes_other_serious_condition_eye_start_age         58             ukbb
# health_mouth_problems                                     58             ukbb
# health_general_past_year_falling                          58             ukbb
# health_general_past_year_weight_change                    58             ukbb
# health_cancer_past_bowel_screening                        58             ukbb
# health_cancer_past_bowel_screening_years                  58             ukbb
# health_breathing_past_year_wheezing                       58             ukbb
# health_breathing_shortness_breath_walking                 58             ukbb
# health_legs_pain_walking                                  58             ukbb
# health_legs_pain_begin_standing_sitting                   58             ukbb
# health_legs_calfs_pain                                    58             ukbb
# health_legs_pain_walking_uphill                           58             ukbb
# health_legs_pain_walking_normal                           58             ukbb
# health_legs_pain_dissapear_walking                        58             ukbb
# health_legs_pain_action                                   58             ukbb
# health_legs_pain_change_stopping                          58             ukbb
# health_legs_arteries_surgery                              58             ukbb
# health_legs_amputation                                    58             ukbb
# health_pain_types_past_month                              58             ukbb
# health_pain_past_3_months_headache                        58             ukbb
# health_pain_past_3_months_facial                          58             ukbb
# health_pain_past_3_months_neck_shoulders                  58             ukbb
# health_pain_past_3_months_back                            58             ukbb
# health_pain_past_3_months_stomach                         58             ukbb
# health_pain_past_3_months_hip                             58             ukbb
# health_pain_past_3_months_knee                            58             ukbb
# health_pain_past_3_months_general                         58             ukbb
# health_pain_chest                                         58             ukbb
# health_pain_chest_walking_normal                          58             ukbb
# health_pain_chest_walking_uphill                          58             ukbb
# health_pain_chest_dissapear_stopping                      58             ukbb
# health_cancer_past_prostate_screening                     58             ukbb
# health_cancer_past_prostate_screening_years               58             ukbb
# skin_current_sunscreen_use                                58             ukbb
# oralheatlh_bleeding_gums                                  58  initial_medical
# oralheatlh_abscess_or_gingivitis                          58  initial_medical
# oralheatlh_antibiotics_for_gingivitis                     58  initial_medical
# oralheatlh_bad_breath                                     58  initial_medical
# oralheatlh_teeth_mobility_lately                          58  initial_medical
# eye_health_eyeglasses_age                                 58  initial_medical
# eye_health_decreased_eyesight_age                         58  initial_medical
# eye_health_ona_age                                        58  initial_medical
# eye_health_conjunctivitis_age                             58  initial_medical
# eye_health_surgery_improve_vision_age                     58  initial_medical
# collection_timestamp                                      58  initial_medical
# collection_date                                           58  initial_medical
# timezone                                                  58  initial_medical
# data_source                                               58  initial_medical
#
#                                                                                         field_string  \
# tabular_field_name
# collection_timestamp                                                            Collection timestamp
# collection_date                                                                      Collection date
# timezone                                                                                    Timezone
# health_general_rating                                                          Overall health rating
# health_general_dissability_illness                    Long-standing illness, disability or infirmity
# health_eyes_glasses_contacts                                         Wears glasses or contact lenses
# health_eyes_glasses_contacts_start_age                 Age started wearing glasses or contact lenses
# health_eyes_glasses_contacts_reason                                Reason for glasses/contact lenses
# health_eyes_short_sight_eye                            Which eye(s) affected by myopia (short sight)
# health_eyes_long_sight_eye                         Which eye(s) affected by hypermetropia (long s...
# health_eyes_reading_glasses_eye                                  Which eye(s) affected by presbyopia
# health_eyes_astigmatism_eye                                     Which eye(s) affected by astigmatism
# health_eyes_squint_eye                                  Which eye(s) affected by strabismus (squint)
# health_eyes_amblyopia_eye                              Which eye(s) affected by amblyopia (lazy eye)
# health_eyes_other_condition_eye                         Which eye(s) affected by other eye condition
# health_eyes_other_problems                                                        Other eye problems
# health_eyes_problems_doctor_diagnosis                                         Eye problems/disorders
# health_eyes_diabetes_eye                           Which eye(s) affected by diabetes-related eye ...
# health_eyes_diabetes_eye_start_age                   Age when diabetes-related eye disease diagnosed
# health_eyes_glaucoma_eye                                           Which eye(s) affected by glaucoma
# health_eyes_glaucoma_eye_start_age                                            Age glaucoma diagnosed
# health_eyes_injury_trauma_eye                      Which eye(s) affected by injury or trauma resu...
# health_eyes_injury_trauma_eye_start_age            Age when loss of vision due to injury or traum...
# health_eyes_cataract_eye                                       Which eye(s) are affected by cataract
# health_eyes_cataract_eye_start_age                                            Age cataract diagnosed
# health_eyes_macular_degeneration_eye                   Which eye(s) affected by macular degeneration
# health_eyes_macular_degeneration_eye_start_age                    Age macular degeneration diagnosed
# health_eyes_other_serious_condition_eye            Which eye(s) affected by other serious eye con...
# health_eyes_other_serious_condition_eye_start_age          Age other serious eye condition diagnosed
# health_mouth_problems                                                    Mouth/teeth dental problems
# health_general_past_year_falling                                              Falls in the last year
# health_general_past_year_weight_change                        Weight change compared with 1 year ago
# health_cancer_past_bowel_screening                                   Ever had bowel cancer screening
# health_cancer_past_bowel_screening_years                          Most recent bowel cancer screening
# health_breathing_past_year_wheezing                    Wheeze or whistling in the chest in last year
# health_breathing_shortness_breath_walking                Shortness of breath walking on level ground
# health_legs_pain_walking                                                         Leg pain on walking
# health_legs_pain_begin_standing_sitting                      Leg pain when standing still or sitting
# health_legs_calfs_pain                                                       Leg pain in calf/calves
# health_legs_pain_walking_uphill                             Leg pain when walking uphill or hurrying
# health_legs_pain_walking_normal                                       Leg pain when walking normally
# health_legs_pain_dissapear_walking                 Leg pain when walking ever disappears while wa...
# health_legs_pain_action                                           Leg pain on walking : action taken
# health_legs_pain_change_stopping                      Leg pain on walking : effect of standing still
# health_legs_arteries_surgery                       Surgery on leg arteries (other than for varico...
# health_legs_amputation                                              Surgery/amputation of toe or leg
# health_pain_types_past_month                                  Pain type(s) experienced in last month
# health_pain_past_3_months_headache                                           Headaches for 3+ months
# health_pain_past_3_months_facial                                          Facial pains for 3+ months
# health_pain_past_3_months_neck_shoulders                            Neck/shoulder pain for 3+ months
# health_pain_past_3_months_back                                               Back pain for 3+ months
# health_pain_past_3_months_stomach                               Stomach/abdominal pain for 3+ months
# health_pain_past_3_months_hip                                                 Hip pain for 3+ months
# health_pain_past_3_months_knee                                               Knee pain for 3+ months
# health_pain_past_3_months_general                                         General pain for 3+ months
# health_pain_chest                                                           Chest pain or discomfort
# health_pain_chest_walking_normal                           Chest pain or discomfort walking normally
# health_pain_chest_walking_uphill                   Chest pain or discomfort when walking uphill o...
# health_pain_chest_dissapear_stopping               Chest pain due to walking ceases when standing...
# health_cancer_past_prostate_screening                  Ever had prostate specific antigen (PSA) test
# health_cancer_past_prostate_screening_years        Time since last prostate specific antigen (PSA...
# skin_current_sunscreen_use                                                  Use of sun/uv protection
# oralheatlh_bleeding_gums                                                   Oral heatlh bleeding gums
# oralheatlh_abscess_or_gingivitis                       Oral heatlh periodontal abscess or gingivitis
# oralheatlh_antibiotics_for_gingivitis                   Oral heatlh taken antibiotics for gingivitis
# oralheatlh_bad_breath                                                          Oral heatlh halitosis
# oralheatlh_teeth_mobility_lately                                   Oral heatlh teeth mobility lately
# eye_health_eyeglasses_age                                                Age started wearing glasses
# eye_health_decreased_eyesight_age                                        Age when eyesight decreased
# eye_health_ona_age                                                                Eye health AMD age
# eye_health_conjunctivitis_age                                          Eye health conjunctivitis age
# eye_health_surgery_improve_vision_age                                   Eye health LASIK surgery age
# collection_timestamp                                                            Collection timestamp
# collection_date                                                                      Collection date
# timezone                                                                                    Timezone
# data_source                                                                              Data source
#
#                                                                                    relative_location  \
# tabular_field_name
# collection_timestamp                                         health_and_medical_history/ukbb.parquet
# collection_date                                              health_and_medical_history/ukbb.parquet
# timezone                                                     health_and_medical_history/ukbb.parquet
# health_general_rating                                        health_and_medical_history/ukbb.parquet
# health_general_dissability_illness                           health_and_medical_history/ukbb.parquet
# health_eyes_glasses_contacts                                 health_and_medical_history/ukbb.parquet
# health_eyes_glasses_contacts_start_age                       health_and_medical_history/ukbb.parquet
# health_eyes_glasses_contacts_reason                          health_and_medical_history/ukbb.parquet
# health_eyes_short_sight_eye                                  health_and_medical_history/ukbb.parquet
# health_eyes_long_sight_eye                                   health_and_medical_history/ukbb.parquet
# health_eyes_reading_glasses_eye                              health_and_medical_history/ukbb.parquet
# health_eyes_astigmatism_eye                                  health_and_medical_history/ukbb.parquet
# health_eyes_squint_eye                                       health_and_medical_history/ukbb.parquet
# health_eyes_amblyopia_eye                                    health_and_medical_history/ukbb.parquet
# health_eyes_other_condition_eye                              health_and_medical_history/ukbb.parquet
# health_eyes_other_problems                                   health_and_medical_history/ukbb.parquet
# health_eyes_problems_doctor_diagnosis                        health_and_medical_history/ukbb.parquet
# health_eyes_diabetes_eye                                     health_and_medical_history/ukbb.parquet
# health_eyes_diabetes_eye_start_age                           health_and_medical_history/ukbb.parquet
# health_eyes_glaucoma_eye                                     health_and_medical_history/ukbb.parquet
# health_eyes_glaucoma_eye_start_age                           health_and_medical_history/ukbb.parquet
# health_eyes_injury_trauma_eye                                health_and_medical_history/ukbb.parquet
# health_eyes_injury_trauma_eye_start_age                      health_and_medical_history/ukbb.parquet
# health_eyes_cataract_eye                                     health_and_medical_history/ukbb.parquet
# health_eyes_cataract_eye_start_age                           health_and_medical_history/ukbb.parquet
# health_eyes_macular_degeneration_eye                         health_and_medical_history/ukbb.parquet
# health_eyes_macular_degeneration_eye_start_age               health_and_medical_history/ukbb.parquet
# health_eyes_other_serious_condition_eye                      health_and_medical_history/ukbb.parquet
# health_eyes_other_serious_condition_eye_start_age            health_and_medical_history/ukbb.parquet
# health_mouth_problems                                        health_and_medical_history/ukbb.parquet
# health_general_past_year_falling                             health_and_medical_history/ukbb.parquet
# health_general_past_year_weight_change                       health_and_medical_history/ukbb.parquet
# health_cancer_past_bowel_screening                           health_and_medical_history/ukbb.parquet
# health_cancer_past_bowel_screening_years                     health_and_medical_history/ukbb.parquet
# health_breathing_past_year_wheezing                          health_and_medical_history/ukbb.parquet
# health_breathing_shortness_breath_walking                    health_and_medical_history/ukbb.parquet
# health_legs_pain_walking                                     health_and_medical_history/ukbb.parquet
# health_legs_pain_begin_standing_sitting                      health_and_medical_history/ukbb.parquet
# health_legs_calfs_pain                                       health_and_medical_history/ukbb.parquet
# health_legs_pain_walking_uphill                              health_and_medical_history/ukbb.parquet
# health_legs_pain_walking_normal                              health_and_medical_history/ukbb.parquet
# health_legs_pain_dissapear_walking                           health_and_medical_history/ukbb.parquet
# health_legs_pain_action                                      health_and_medical_history/ukbb.parquet
# health_legs_pain_change_stopping                             health_and_medical_history/ukbb.parquet
# health_legs_arteries_surgery                                 health_and_medical_history/ukbb.parquet
# health_legs_amputation                                       health_and_medical_history/ukbb.parquet
# health_pain_types_past_month                                 health_and_medical_history/ukbb.parquet
# health_pain_past_3_months_headache                           health_and_medical_history/ukbb.parquet
# health_pain_past_3_months_facial                             health_and_medical_history/ukbb.parquet
# health_pain_past_3_months_neck_shoulders                     health_and_medical_history/ukbb.parquet
# health_pain_past_3_months_back                               health_and_medical_history/ukbb.parquet
# health_pain_past_3_months_stomach                            health_and_medical_history/ukbb.parquet
# health_pain_past_3_months_hip                                health_and_medical_history/ukbb.parquet
# health_pain_past_3_months_knee                               health_and_medical_history/ukbb.parquet
# health_pain_past_3_months_general                            health_and_medical_history/ukbb.parquet
# health_pain_chest                                            health_and_medical_history/ukbb.parquet
# health_pain_chest_walking_normal                             health_and_medical_history/ukbb.parquet
# health_pain_chest_walking_uphill                             health_and_medical_history/ukbb.parquet
# health_pain_chest_dissapear_stopping                         health_and_medical_history/ukbb.parquet
# health_cancer_past_prostate_screening                        health_and_medical_history/ukbb.parquet
# health_cancer_past_prostate_screening_years                  health_and_medical_history/ukbb.parquet
# skin_current_sunscreen_use                                   health_and_medical_history/ukbb.parquet
# oralheatlh_bleeding_gums                           health_and_medical_history/initial_medical.par...
# oralheatlh_abscess_or_gingivitis                   health_and_medical_history/initial_medical.par...
# oralheatlh_antibiotics_for_gingivitis              health_and_medical_history/initial_medical.par...
# oralheatlh_bad_breath                              health_and_medical_history/initial_medical.par...
# oralheatlh_teeth_mobility_lately                   health_and_medical_history/initial_medical.par...
# eye_health_eyeglasses_age                          health_and_medical_history/initial_medical.par...
# eye_health_decreased_eyesight_age                  health_and_medical_history/initial_medical.par...
# eye_health_ona_age                                 health_and_medical_history/initial_medical.par...
# eye_health_conjunctivitis_age                      health_and_medical_history/initial_medical.par...
# eye_health_surgery_improve_vision_age              health_and_medical_history/initial_medical.par...
# collection_timestamp                               health_and_medical_history/initial_medical.par...
# collection_date                                    health_and_medical_history/initial_medical.par...
# timezone                                           health_and_medical_history/initial_medical.par...
# data_source                                        health_and_medical_history/initial_medical.par...
#
#                                                    bulk_file_extension  \
# tabular_field_name
# collection_timestamp                                               NaN
# collection_date                                                    NaN
# timezone                                                           NaN
# health_general_rating                                              NaN
# health_general_dissability_illness                                 NaN
# health_eyes_glasses_contacts                                       NaN
# health_eyes_glasses_contacts_start_age                             NaN
# health_eyes_glasses_contacts_reason                                NaN
# health_eyes_short_sight_eye                                        NaN
# health_eyes_long_sight_eye                                         NaN
# health_eyes_reading_glasses_eye                                    NaN
# health_eyes_astigmatism_eye                                        NaN
# health_eyes_squint_eye                                             NaN
# health_eyes_amblyopia_eye                                          NaN
# health_eyes_other_condition_eye                                    NaN
# health_eyes_other_problems                                         NaN
# health_eyes_problems_doctor_diagnosis                              NaN
# health_eyes_diabetes_eye                                           NaN
# health_eyes_diabetes_eye_start_age                                 NaN
# health_eyes_glaucoma_eye                                           NaN
# health_eyes_glaucoma_eye_start_age                                 NaN
# health_eyes_injury_trauma_eye                                      NaN
# health_eyes_injury_trauma_eye_start_age                            NaN
# health_eyes_cataract_eye                                           NaN
# health_eyes_cataract_eye_start_age                                 NaN
# health_eyes_macular_degeneration_eye                               NaN
# health_eyes_macular_degeneration_eye_start_age                     NaN
# health_eyes_other_serious_condition_eye                            NaN
# health_eyes_other_serious_condition_eye_start_age                  NaN
# health_mouth_problems                                              NaN
# health_general_past_year_falling                                   NaN
# health_general_past_year_weight_change                             NaN
# health_cancer_past_bowel_screening                                 NaN
# health_cancer_past_bowel_screening_years                           NaN
# health_breathing_past_year_wheezing                                NaN
# health_breathing_shortness_breath_walking                          NaN
# health_legs_pain_walking                                           NaN
# health_legs_pain_begin_standing_sitting                            NaN
# health_legs_calfs_pain                                             NaN
# health_legs_pain_walking_uphill                                    NaN
# health_legs_pain_walking_normal                                    NaN
# health_legs_pain_dissapear_walking                                 NaN
# health_legs_pain_action                                            NaN
# health_legs_pain_change_stopping                                   NaN
# health_legs_arteries_surgery                                       NaN
# health_legs_amputation                                             NaN
# health_pain_types_past_month                                       NaN
# health_pain_past_3_months_headache                                 NaN
# health_pain_past_3_months_facial                                   NaN
# health_pain_past_3_months_neck_shoulders                           NaN
# health_pain_past_3_months_back                                     NaN
# health_pain_past_3_months_stomach                                  NaN
# health_pain_past_3_months_hip                                      NaN
# health_pain_past_3_months_knee                                     NaN
# health_pain_past_3_months_general                                  NaN
# health_pain_chest                                                  NaN
# health_pain_chest_walking_normal                                   NaN
# health_pain_chest_walking_uphill                                   NaN
# health_pain_chest_dissapear_stopping                               NaN
# health_cancer_past_prostate_screening                              NaN
# health_cancer_past_prostate_screening_years                        NaN
# skin_current_sunscreen_use                                         NaN
# oralheatlh_bleeding_gums                                           NaN
# oralheatlh_abscess_or_gingivitis                                   NaN
# oralheatlh_antibiotics_for_gingivitis                              NaN
# oralheatlh_bad_breath                                              NaN
# oralheatlh_teeth_mobility_lately                                   NaN
# eye_health_eyeglasses_age                                          NaN
# eye_health_decreased_eyesight_age                                  NaN
# eye_health_ona_age                                                 NaN
# eye_health_conjunctivitis_age                                      NaN
# eye_health_surgery_improve_vision_age                              NaN
# collection_timestamp                                               NaN
# collection_date                                                    NaN
# timezone                                                           NaN
# data_source                                                        NaN
#
#                                                    bulk_dictionary  \
# tabular_field_name
# collection_timestamp                                           NaN
# collection_date                                                NaN
# timezone                                                       NaN
# health_general_rating                                          NaN
# health_general_dissability_illness                             NaN
# health_eyes_glasses_contacts                                   NaN
# health_eyes_glasses_contacts_start_age                         NaN
# health_eyes_glasses_contacts_reason                            NaN
# health_eyes_short_sight_eye                                    NaN
# health_eyes_long_sight_eye                                     NaN
# health_eyes_reading_glasses_eye                                NaN
# health_eyes_astigmatism_eye                                    NaN
# health_eyes_squint_eye                                         NaN
# health_eyes_amblyopia_eye                                      NaN
# health_eyes_other_condition_eye                                NaN
# health_eyes_other_problems                                     NaN
# health_eyes_problems_doctor_diagnosis                          NaN
# health_eyes_diabetes_eye                                       NaN
# health_eyes_diabetes_eye_start_age                             NaN
# health_eyes_glaucoma_eye                                       NaN
# health_eyes_glaucoma_eye_start_age                             NaN
# health_eyes_injury_trauma_eye                                  NaN
# health_eyes_injury_trauma_eye_start_age                        NaN
# health_eyes_cataract_eye                                       NaN
# health_eyes_cataract_eye_start_age                             NaN
# health_eyes_macular_degeneration_eye                           NaN
# health_eyes_macular_degeneration_eye_start_age                 NaN
# health_eyes_other_serious_condition_eye                        NaN
# health_eyes_other_serious_condition_eye_start_age              NaN
# health_mouth_problems                                          NaN
# health_general_past_year_falling                               NaN
# health_general_past_year_weight_change                         NaN
# health_cancer_past_bowel_screening                             NaN
# health_cancer_past_bowel_screening_years                       NaN
# health_breathing_past_year_wheezing                            NaN
# health_breathing_shortness_breath_walking                      NaN
# health_legs_pain_walking                                       NaN
# health_legs_pain_begin_standing_sitting                        NaN
# health_legs_calfs_pain                                         NaN
# health_legs_pain_walking_uphill                                NaN
# health_legs_pain_walking_normal                                NaN
# health_legs_pain_dissapear_walking                             NaN
# health_legs_pain_action                                        NaN
# health_legs_pain_change_stopping                               NaN
# health_legs_arteries_surgery                                   NaN
# health_legs_amputation                                         NaN
# health_pain_types_past_month                                   NaN
# health_pain_past_3_months_headache                             NaN
# health_pain_past_3_months_facial                               NaN
# health_pain_past_3_months_neck_shoulders                       NaN
# health_pain_past_3_months_back                                 NaN
# health_pain_past_3_months_stomach                              NaN
# health_pain_past_3_months_hip                                  NaN
# health_pain_past_3_months_knee                                 NaN
# health_pain_past_3_months_general                              NaN
# health_pain_chest                                              NaN
# health_pain_chest_walking_normal                               NaN
# health_pain_chest_walking_uphill                               NaN
# health_pain_chest_dissapear_stopping                           NaN
# health_cancer_past_prostate_screening                          NaN
# health_cancer_past_prostate_screening_years                    NaN
# skin_current_sunscreen_use                                     NaN
# oralheatlh_bleeding_gums                                       NaN
# oralheatlh_abscess_or_gingivitis                               NaN
# oralheatlh_antibiotics_for_gingivitis                          NaN
# oralheatlh_bad_breath                                          NaN
# oralheatlh_teeth_mobility_lately                               NaN
# eye_health_eyeglasses_age                                      NaN
# eye_health_decreased_eyesight_age                              NaN
# eye_health_ona_age                                             NaN
# eye_health_conjunctivitis_age                                  NaN
# eye_health_surgery_improve_vision_age                          NaN
# collection_timestamp                                           NaN
# collection_date                                                NaN
# timezone                                                       NaN
# data_source                                                    NaN
#
#                                                                                   description_string  \
# tabular_field_name
# collection_timestamp                                                            Collection timestamp
# collection_date                                                                      Collection date
# timezone                                                                                    Timezone
# health_general_rating                              In general how would you rate your overall hea...
# health_general_dissability_illness                 Do you have any long-standing illness, disabil...
# health_eyes_glasses_contacts                       Do you wear glasses or contact lenses to corre...
# health_eyes_glasses_contacts_start_age             What age did you first start to wear glasses o...
# health_eyes_glasses_contacts_reason                Why were you prescribed glasses/contacts? (You...
# health_eyes_short_sight_eye                        Which eye(s) are affected by myopia (short sig...
# health_eyes_long_sight_eye                         Which eye(s) are affected by hypermetropia (lo...
# health_eyes_reading_glasses_eye                             Which eye(s) are affected by presbyopia?
# health_eyes_astigmatism_eye                                Which eye(s) are affected by astigmatism?
# health_eyes_squint_eye                             Which eye(s) are affected by strabismus (squint)?
# health_eyes_amblyopia_eye                          Which eye(s) are affected by amblyopia (lazy e...
# health_eyes_other_condition_eye                    Which eye(s) are affected by your other eye co...
# health_eyes_other_problems                         Do you have any other problems with your eyes ...
# health_eyes_problems_doctor_diagnosis              Has a doctor told you that you have any of the...
# health_eyes_diabetes_eye                           Which eye(s) are affected by diabetes related ...
# health_eyes_diabetes_eye_start_age                 What was your age when diabetes related eye di...
# health_eyes_glaucoma_eye                                      Which eye(s) are affected by glaucoma?
# health_eyes_glaucoma_eye_start_age                 What was your age when glaucoma was first diag...
# health_eyes_injury_trauma_eye                      Which eye(s) are affected by injury or trauma ...
# health_eyes_injury_trauma_eye_start_age            What was your age when injury or trauma result...
# health_eyes_cataract_eye                                    Which eye(s) are affected by a cataract?
# health_eyes_cataract_eye_start_age                 What was your age when a cataract was first di...
# health_eyes_macular_degeneration_eye               Which eye(s) are affected by macular degenerat...
# health_eyes_macular_degeneration_eye_start_age     What was your age when macular degeneration wa...
# health_eyes_other_serious_condition_eye            Which eye(s) are affected by the other serious...
# health_eyes_other_serious_condition_eye_start_age  What was your age when the other serious eye c...
# health_mouth_problems                              Do you have any of the following? (You can sel...
# health_general_past_year_falling                            In the last year have you had any falls?
# health_general_past_year_weight_change             Compared with one year ago, has your weight ch...
# health_cancer_past_bowel_screening                 Have you ever had a screening test for bowel (...
# health_cancer_past_bowel_screening_years           How many years ago was the most recent one of ...
# health_breathing_past_year_wheezing                In the last year have you ever had wheeze or w...
# health_breathing_shortness_breath_walking          Do you get short of breath walking with people...
# health_legs_pain_walking                                 Do you get a pain in either leg on walking?
# health_legs_pain_begin_standing_sitting            Does this pain ever begin when you are standin...
# health_legs_calfs_pain                                   Do you get this pain in your calf (calves)?
# health_legs_pain_walking_uphill                       Do you get pain when you walk uphill or hurry?
# health_legs_pain_walking_normal                    Do you get pain when you walk at an ordinary p...
# health_legs_pain_dissapear_walking                 Does the pain you get while walking ever disap...
# health_legs_pain_action                            What do you do if you get pain when you are wa...
# health_legs_pain_change_stopping                   What happens to the pain you get while walking...
# health_legs_arteries_surgery                       Have you ever had surgery on the arteries of y...
# health_legs_amputation                             Have you ever had surgery to remove any of the...
# health_pain_types_past_month                       In the last month have you experienced any of ...
# health_pain_past_3_months_headache                    Have you had headaches for more than 3 months?
# health_pain_past_3_months_facial                   Have you had facial pains for more than 3 months?
# health_pain_past_3_months_neck_shoulders           Have you had neck or shoulder pains for more t...
# health_pain_past_3_months_back                       Have you had back pains for more than 3 months?
# health_pain_past_3_months_stomach                  Have you had stomach or abdominal pains for mo...
# health_pain_past_3_months_hip                         Have you had hip pains for more than 3 months?
# health_pain_past_3_months_knee                       Have you had knee pains for more than 3 months?
# health_pain_past_3_months_general                  Have you had pains all over the body for more ...
# health_pain_chest                                  Do you ever have any pain or discomfort in you...
# health_pain_chest_walking_normal                   Do you get this pain or discomfort when you wa...
# health_pain_chest_walking_uphill                   Do you get this pain or discomfort when you wa...
# health_pain_chest_dissapear_stopping               Does this chest pain go away when you stand st...
# health_cancer_past_prostate_screening              Have you ever had a blood test for prostate ca...
# health_cancer_past_prostate_screening_years                   How many years ago was your last test?
# skin_current_sunscreen_use                         Do you wear sun protection (e.g. sunscreen lot...
# oralheatlh_bleeding_gums                                                   Oral heatlh bleeding gums
# oralheatlh_abscess_or_gingivitis                       Oral heatlh periodontal abscess or gingivitis
# oralheatlh_antibiotics_for_gingivitis                   Oral heatlh taken antibiotics for gingivitis
# oralheatlh_bad_breath                                                          Oral heatlh halitosis
# oralheatlh_teeth_mobility_lately                                   Oral heatlh teeth mobility lately
# eye_health_eyeglasses_age                                                Age started wearing glasses
# eye_health_decreased_eyesight_age                                        Age when eyesight decreased
# eye_health_ona_age                                                                Eye health AMD age
# eye_health_conjunctivitis_age                                          Eye health conjunctivitis age
# eye_health_surgery_improve_vision_age                                   Eye health LASIK surgery age
# collection_timestamp                                                            Collection timestamp
# collection_date                                                                      Collection date
# timezone                                                                                    Timezone
# data_source                                                        Data source of survey information
#
#                                                                field_type  \
# tabular_field_name
# collection_timestamp                                             Datetime
# collection_date                                                      Date
# timezone                                                             Text
# health_general_rating                                Categorical (single)
# health_general_dissability_illness                   Categorical (single)
# health_eyes_glasses_contacts                         Categorical (single)
# health_eyes_glasses_contacts_start_age                            Integer
# health_eyes_glasses_contacts_reason                Categorical (multiple)
# health_eyes_short_sight_eye                          Categorical (single)
# health_eyes_long_sight_eye                           Categorical (single)
# health_eyes_reading_glasses_eye                      Categorical (single)
# health_eyes_astigmatism_eye                          Categorical (single)
# health_eyes_squint_eye                               Categorical (single)
# health_eyes_amblyopia_eye                            Categorical (single)
# health_eyes_other_condition_eye                      Categorical (single)
# health_eyes_other_problems                           Categorical (single)
# health_eyes_problems_doctor_diagnosis              Categorical (multiple)
# health_eyes_diabetes_eye                             Categorical (single)
# health_eyes_diabetes_eye_start_age                                Integer
# health_eyes_glaucoma_eye                             Categorical (single)
# health_eyes_glaucoma_eye_start_age                                Integer
# health_eyes_injury_trauma_eye                        Categorical (single)
# health_eyes_injury_trauma_eye_start_age                           Integer
# health_eyes_cataract_eye                             Categorical (single)
# health_eyes_cataract_eye_start_age                                Integer
# health_eyes_macular_degeneration_eye                 Categorical (single)
# health_eyes_macular_degeneration_eye_start_age                    Integer
# health_eyes_other_serious_condition_eye              Categorical (single)
# health_eyes_other_serious_condition_eye_start_age                 Integer
# health_mouth_problems                              Categorical (multiple)
# health_general_past_year_falling                     Categorical (single)
# health_general_past_year_weight_change               Categorical (single)
# health_cancer_past_bowel_screening                   Categorical (single)
# health_cancer_past_bowel_screening_years                          Integer
# health_breathing_past_year_wheezing                  Categorical (single)
# health_breathing_shortness_breath_walking            Categorical (single)
# health_legs_pain_walking                             Categorical (single)
# health_legs_pain_begin_standing_sitting              Categorical (single)
# health_legs_calfs_pain                               Categorical (single)
# health_legs_pain_walking_uphill                      Categorical (single)
# health_legs_pain_walking_normal                      Categorical (single)
# health_legs_pain_dissapear_walking                   Categorical (single)
# health_legs_pain_action                              Categorical (single)
# health_legs_pain_change_stopping                     Categorical (single)
# health_legs_arteries_surgery                         Categorical (single)
# health_legs_amputation                               Categorical (single)
# health_pain_types_past_month                       Categorical (multiple)
# health_pain_past_3_months_headache                   Categorical (single)
# health_pain_past_3_months_facial                     Categorical (single)
# health_pain_past_3_months_neck_shoulders             Categorical (single)
# health_pain_past_3_months_back                       Categorical (single)
# health_pain_past_3_months_stomach                    Categorical (single)
# health_pain_past_3_months_hip                        Categorical (single)
# health_pain_past_3_months_knee                       Categorical (single)
# health_pain_past_3_months_general                    Categorical (single)
# health_pain_chest                                    Categorical (single)
# health_pain_chest_walking_normal                     Categorical (single)
# health_pain_chest_walking_uphill                     Categorical (single)
# health_pain_chest_dissapear_stopping                 Categorical (single)
# health_cancer_past_prostate_screening                Categorical (single)
# health_cancer_past_prostate_screening_years                       Integer
# skin_current_sunscreen_use                           Categorical (single)
# oralheatlh_bleeding_gums                             Categorical (single)
# oralheatlh_abscess_or_gingivitis                     Categorical (single)
# oralheatlh_antibiotics_for_gingivitis                Categorical (single)
# oralheatlh_bad_breath                                Categorical (single)
# oralheatlh_teeth_mobility_lately                     Categorical (single)
# eye_health_eyeglasses_age                                         Integer
# eye_health_decreased_eyesight_age                                 Integer
# eye_health_ona_age                                                Integer
# eye_health_conjunctivitis_age                                     Integer
# eye_health_surgery_improve_vision_age                             Integer
# collection_timestamp                                             Datetime
# collection_date                                                      Date
# timezone                                                             Text
# data_source                                                          Text
#
#                                                       array  \
# ...
# health_eyes_diabetes_eye                                   Primary
# health_eyes_diabetes_eye_start_age                         Primary
# health_eyes_glaucoma_eye                                   Primary
# health_eyes_glaucoma_eye_start_age                         Primary
# health_eyes_injury_trauma_eye                              Primary
# health_eyes_injury_trauma_eye_start_age                    Primary
# health_eyes_cataract_eye                                   Primary
# health_eyes_cataract_eye_start_age                         Primary
# health_eyes_macular_degeneration_eye                       Primary
# health_eyes_macular_degeneration_eye_start_age             Primary
# health_eyes_other_serious_condition_eye                    Primary
# health_eyes_other_serious_condition_eye_start_age          Primary
# health_mouth_problems                                      Primary
# health_general_past_year_falling                           Primary
# health_general_past_year_weight_change                     Primary
# health_cancer_past_bowel_screening                         Primary
# health_cancer_past_bowel_screening_years                   Primary
# health_breathing_past_year_wheezing                        Primary
# health_breathing_shortness_breath_walking                  Primary
# health_legs_pain_walking                                   Primary
# health_legs_pain_begin_standing_sitting                    Primary
# health_legs_calfs_pain                                     Primary
# health_legs_pain_walking_uphill                            Primary
# health_legs_pain_walking_normal                            Primary
# health_legs_pain_dissapear_walking                         Primary
# health_legs_pain_action                                    Primary
# health_legs_pain_change_stopping                           Primary
# health_legs_arteries_surgery                               Primary
# health_legs_amputation                                     Primary
# health_pain_types_past_month                               Primary
# health_pain_past_3_months_headache                         Primary
# health_pain_past_3_months_facial                           Primary
# health_pain_past_3_months_neck_shoulders                   Primary
# health_pain_past_3_months_back                             Primary
# health_pain_past_3_months_stomach                          Primary
# health_pain_past_3_months_hip                              Primary
# health_pain_past_3_months_knee                             Primary
# health_pain_past_3_months_general                          Primary
# health_pain_chest                                          Primary
# health_pain_chest_walking_normal                           Primary
# health_pain_chest_walking_uphill                           Primary
# health_pain_chest_dissapear_stopping                       Primary
# health_cancer_past_prostate_screening                      Primary
# health_cancer_past_prostate_screening_years                Primary
# skin_current_sunscreen_use                                 Primary
# oralheatlh_bleeding_gums                                   Primary
# oralheatlh_abscess_or_gingivitis                           Primary
# oralheatlh_antibiotics_for_gingivitis                      Primary
# oralheatlh_bad_breath                                      Primary
# oralheatlh_teeth_mobility_lately                           Primary
# eye_health_eyeglasses_age                                  Primary
# eye_health_decreased_eyesight_age                          Primary
# eye_health_ona_age                                         Primary
# eye_health_conjunctivitis_age                              Primary
# eye_health_surgery_improve_vision_age                      Primary
# collection_timestamp                               Collection time
# collection_date                                    Collection time
# timezone                                           Collection time
# data_source                                              Auxiliary
#
#                                                         sexed       debut  \
# tabular_field_name
# collection_timestamp                               Both sexes    1/9/2019
# collection_date                                    Both sexes    1/9/2019
# timezone                                           Both sexes    1/9/2019
# health_general_rating                              Both sexes    1/9/2019
# health_general_dissability_illness                 Both sexes    1/9/2019
# health_eyes_glasses_contacts                       Both sexes    1/9/2019
# health_eyes_glasses_contacts_start_age             Both sexes    1/9/2019
# health_eyes_glasses_contacts_reason                Both sexes    1/9/2019
# health_eyes_short_sight_eye                        Both sexes    1/9/2019
# health_eyes_long_sight_eye                         Both sexes    1/9/2019
# health_eyes_reading_glasses_eye                    Both sexes    1/9/2019
# health_eyes_astigmatism_eye                        Both sexes    1/9/2019
# health_eyes_squint_eye                             Both sexes    1/9/2019
# health_eyes_amblyopia_eye                          Both sexes    1/9/2019
# health_eyes_other_condition_eye                    Both sexes    1/9/2019
# health_eyes_other_problems                         Both sexes    1/9/2019
# health_eyes_problems_doctor_diagnosis              Both sexes    1/9/2019
# health_eyes_diabetes_eye                           Both sexes    1/9/2019
# health_eyes_diabetes_eye_start_age                 Both sexes    1/9/2019
# health_eyes_glaucoma_eye                           Both sexes    1/9/2019
# health_eyes_glaucoma_eye_start_age                 Both sexes    1/9/2019
# health_eyes_injury_trauma_eye                      Both sexes    1/9/2019
# health_eyes_injury_trauma_eye_start_age            Both sexes    1/9/2019
# health_eyes_cataract_eye                           Both sexes    1/9/2019
# health_eyes_cataract_eye_start_age                 Both sexes    1/9/2019
# health_eyes_macular_degeneration_eye               Both sexes    1/9/2019
# health_eyes_macular_degeneration_eye_start_age     Both sexes    1/9/2019
# health_eyes_other_serious_condition_eye            Both sexes    1/9/2019
# health_eyes_other_serious_condition_eye_start_age  Both sexes    1/9/2019
# health_mouth_problems                              Both sexes    1/9/2019
# health_general_past_year_falling                   Both sexes    1/9/2019
# health_general_past_year_weight_change             Both sexes    1/9/2019
# health_cancer_past_bowel_screening                 Both sexes    1/9/2019
# health_cancer_past_bowel_screening_years           Both sexes    1/9/2019
# health_breathing_past_year_wheezing                Both sexes    1/9/2019
# health_breathing_shortness_breath_walking          Both sexes    1/9/2019
# health_legs_pain_walking                           Both sexes    1/9/2019
# health_legs_pain_begin_standing_sitting            Both sexes    1/9/2019
# health_legs_calfs_pain                             Both sexes    1/9/2019
# health_legs_pain_walking_uphill                    Both sexes    1/9/2019
# health_legs_pain_walking_normal                    Both sexes    1/9/2019
# health_legs_pain_dissapear_walking                 Both sexes    1/9/2019
# health_legs_pain_action                            Both sexes    1/9/2019
# health_legs_pain_change_stopping                   Both sexes    1/9/2019
# health_legs_arteries_surgery                       Both sexes    1/9/2019
# health_legs_amputation                             Both sexes    1/9/2019
# health_pain_types_past_month                       Both sexes    1/9/2019
# health_pain_past_3_months_headache                 Both sexes    1/9/2019
# health_pain_past_3_months_facial                   Both sexes    1/9/2019
# health_pain_past_3_months_neck_shoulders           Both sexes    1/9/2019
# health_pain_past_3_months_back                     Both sexes    1/9/2019
# health_pain_past_3_months_stomach                  Both sexes    1/9/2019
# health_pain_past_3_months_hip                      Both sexes    1/9/2019
# health_pain_past_3_months_knee                     Both sexes    1/9/2019
# health_pain_past_3_months_general                  Both sexes    1/9/2019
# health_pain_chest                                  Both sexes    1/9/2019
# health_pain_chest_walking_normal                   Both sexes    1/9/2019
# health_pain_chest_walking_uphill                   Both sexes    1/9/2019
# health_pain_chest_dissapear_stopping               Both sexes    1/9/2019
# health_cancer_past_prostate_screening              Both sexes    1/9/2019
# health_cancer_past_prostate_screening_years        Both sexes    1/9/2019
# skin_current_sunscreen_use                         Both sexes   2/17/2020
# oralheatlh_bleeding_gums                           Both sexes  2018-11-21
# oralheatlh_abscess_or_gingivitis                   Both sexes  2018-11-21
# oralheatlh_antibiotics_for_gingivitis              Both sexes  2018-11-21
# oralheatlh_bad_breath                              Both sexes  2018-11-21
# oralheatlh_teeth_mobility_lately                   Both sexes  2018-11-21
# eye_health_eyeglasses_age                          Both sexes  2018-11-21
# eye_health_decreased_eyesight_age                  Both sexes  2018-11-21
# eye_health_ona_age                                 Both sexes  2018-11-21
# eye_health_conjunctivitis_age                      Both sexes  2018-11-21
# eye_health_surgery_improve_vision_age              Both sexes  2018-11-21
# collection_timestamp                               Both sexes  2018-11-21
# collection_date                                    Both sexes  2018-11-21
# timezone                                           Both sexes  2018-11-21
# data_source                                        Both sexes  2018-11-21
#
#                                                    completed data_coding
# tabular_field_name
# collection_timestamp                                     NaN         NaN
# collection_date                                          NaN         NaN
# timezone                                                 NaN         NaN
# health_general_rating                                    NaN      100508
# health_general_dissability_illness                       NaN      100349
# health_eyes_glasses_contacts                             NaN      100349
# health_eyes_glasses_contacts_start_age                   NaN         NaN
# health_eyes_glasses_contacts_reason                      NaN      100514
# health_eyes_short_sight_eye                              NaN      100515
# health_eyes_long_sight_eye                               NaN      100515
# health_eyes_reading_glasses_eye                          NaN      100515
# health_eyes_astigmatism_eye                              NaN      100515
# health_eyes_squint_eye                                   NaN      100515
# health_eyes_amblyopia_eye                                NaN      100515
# health_eyes_other_condition_eye                          NaN      100515
# health_eyes_other_problems                               NaN      100352
# health_eyes_problems_doctor_diagnosis                    NaN      100523
# health_eyes_diabetes_eye                                 NaN      100515
# health_eyes_diabetes_eye_start_age                       NaN         NaN
# health_eyes_glaucoma_eye                                 NaN      100515
# health_eyes_glaucoma_eye_start_age                       NaN         NaN
# health_eyes_injury_trauma_eye                            NaN      100515
# health_eyes_injury_trauma_eye_start_age                  NaN         NaN
# health_eyes_cataract_eye                                 NaN      100515
# health_eyes_cataract_eye_start_age                       NaN         NaN
# health_eyes_macular_degeneration_eye                     NaN      100515
# health_eyes_macular_degeneration_eye_start_age           NaN         NaN
# health_eyes_other_serious_condition_eye                  NaN      100515
# health_eyes_other_serious_condition_eye_start_age        NaN         NaN
# health_mouth_problems                                    NaN      100538
# health_general_past_year_falling                         NaN      100539
# health_general_past_year_weight_change                   NaN      100540
# health_cancer_past_bowel_screening                       NaN      100349
# health_cancer_past_bowel_screening_years                 NaN         NaN
# health_breathing_past_year_wheezing                      NaN      100349
# health_breathing_shortness_breath_walking                NaN      100349
# health_legs_pain_walking                                 NaN      100349
# health_legs_pain_begin_standing_sitting                  NaN      100349
# health_legs_calfs_pain                                   NaN      100349
# health_legs_pain_walking_uphill                          NaN      100349
# health_legs_pain_walking_normal                          NaN      100349
# health_legs_pain_dissapear_walking                       NaN      100349
# health_legs_pain_action                                  NaN      100549
# health_legs_pain_change_stopping                         NaN      100550
# health_legs_arteries_surgery                             NaN      100349
# health_legs_amputation                                   NaN      100552
# health_pain_types_past_month                             NaN      100553
# health_pain_past_3_months_headache                       NaN      100349
# health_pain_past_3_months_facial                         NaN      100349
# health_pain_past_3_months_neck_shoulders                 NaN      100349
# health_pain_past_3_months_back                           NaN      100349
# health_pain_past_3_months_stomach                        NaN      100349
# health_pain_past_3_months_hip                            NaN      100349
# health_pain_past_3_months_knee                           NaN      100349
# health_pain_past_3_months_general                        NaN      100349
# health_pain_chest                                        NaN      100349
# health_pain_chest_walking_normal                         NaN      100563
# health_pain_chest_walking_uphill                         NaN      100564
# health_pain_chest_dissapear_stopping                     NaN      100349
# health_cancer_past_prostate_screening                    NaN      100349
# health_cancer_past_prostate_screening_years              NaN         NaN
# skin_current_sunscreen_use                               NaN      100536
# oralheatlh_bleeding_gums                                 NaN      021_01
# oralheatlh_abscess_or_gingivitis                         NaN      021_02
# oralheatlh_antibiotics_for_gingivitis                    NaN      021_02
# oralheatlh_bad_breath                                    NaN      021_03
# oralheatlh_teeth_mobility_lately                         NaN      021_04
# eye_health_eyeglasses_age                                NaN         NaN
# eye_health_decreased_eyesight_age                        NaN         NaN
# eye_health_ona_age                                       NaN         NaN
# eye_health_conjunctivitis_age                            NaN         NaN
# eye_health_surgery_improve_vision_age                    NaN         NaN
# collection_timestamp                                     NaN         NaN
# collection_date                                          NaN         NaN
# timezone                                                 NaN         NaN
# data_source                                              NaN         NaN
