# %% [raw]
# ---
# output-file: 070-oral_microbiome.html
# title: Oral Microbiome
# ---

# %% [markdown]
# ### Description
#
# The collection of buccal swabs for human genetic sequencing presents an advantageous opportunity to simultaneously explore the oral microbiome using the non-human DNA sequences found. This metagenomic analysis provides insight into the diverse microbial community within the buccal mucosa. The obtained data not only enriches our genetic understanding but also broadens our knowledge on the microorganisms residing in the oral cavity, their interactions, and potential implications for oral and systemic health. This dual analysis underscores the utility of buccal swabs as a resourceful means for both genetic and microbial investigations.
#
#
# ### Introduction
#
# The primary intent behind collecting buccal swabs was to explore human genetics. Concurrently, it yielded metagenomic data, unveiling the microbial community within the oral cavity.
#
# This data illuminates the diversity and interactions of microorganisms, specifically in the buccal mucosa. Delving into the oral microbiome presents an opportunity to understand its linkage to health conditions. For instance, an imbalanced oral microbiome can lead to periodontal disease, associated with an increased risk of cardiovascular diseases. Moreover, alterations in the oral microbiome have been observed in oral cancers, hinting at its potential role in their onset and progression​ [The oral microbiome: diversity, biogeography and human health](https://www.nature.com/articles/s41579-023-00963-6)​.
#
# Through this data, the exploration into possible connections between oral microbial composition and various health conditions is facilitated, marking a step towards understanding the broader health implications.
#
# ### Measurement protocol
# <!-- long measurment protocol for the data browser -->
# This dataset is a derivative of the human genome dataset (that has been collected via buccal swabs) - ergo the measurement protocol can be found at the Human genetics dataset.
#
#
# ### Data availability
# <!-- for the example notebooks -->
# The information is stored in multiple parquet files:
#
# - `oral_microbiome.parquet`: Sequencing and QC statistics.
# - `metaphlan_*`: 8 tables with MetaPhlAn 4 vJan21 relative abundances, separated by taxonomic levels.
# - `humann_aggregated_*`: arrow files of either gene level abundances or pathway level abundances+coverage from HumanN 3.6 given MetaPhlAn 4 vJan21 outputs
#
# ```{mermaid}
# graph LR;
#     A(Human Aligned<br>BAM) --> |Filter and convert| B(Non Human Reads<br>FASTQ)
#     B --> |Trimmomatic| C(Clean FASTQ File)
#     C --> |MetaPhlAn| D(MetaPhlAn 4 /<br>vJan21 Abundances<br>Tabular)
#     C --> |HumanN| E(HumanN 3.6 genes abundance)
#     C --> |HumanN| F(HumanN 3.6 Pathways abundance)
#     C --> |HumanN| G(HumanN 3.6 Pathways coverage)
#     C --> |FastQC| H(Reads QC report - after)
#     B ---> |FastQC| I(Reads QC report - before)
# ```
#
# ### Summary of available data
# <!-- for the data browser -->
# - DNA Sequencing files
#     - Non human FASTQ file
#     - Trimmed Non human FASTQ file
# - QC
#     - FASTQC files
# - Bacterial
#     - HumanN (3.6) output
#     - MetaPhlAn4 (vJan21) output
#
# ![available data](oralmb_data.png)
#
# ### Relevant links
#
# * [Pheno Knowledgebase](https://knowledgebase.pheno.ai/datasets/070-oral_microbiome.html)
# * [Pheno Data Browser](https://pheno-demo-app.vercel.app/folder/70)

# %%
#| echo: false
import pandas as pd
pd.set_option("display.max_rows", 500)

# %%
from pheno_utils import PhenoLoader

# %%
pl = PhenoLoader('oral_microbiome')
pl
# Out:
# PhenoLoader for oral_microbiome with
# 39 fields
# 2 tables: ['oral_microbiome', 'age_sex']

# %% [markdown]
# # Data dictionary

# %%
pl.dict
# Out:
#                                                     folder_id  \
# tabular_field_name
# collection_date                                           NaN
# metaphlan_abundance_kingdom_parquet                       NaN
# metaphlan_abundance_phylum_parquet                        NaN
# metaphlan_abundance_class_parquet                         NaN
# metaphlan_abundance_order_parquet                         NaN
# metaphlan_abundance_family_parquet                        NaN
# metaphlan_abundance_genus_parquet                         NaN
# metaphlan_abundance_species_parquet                       NaN
# metaphlan_abundance_strain_parquet                        NaN
# raw_fastq                                                 NaN
# trimmed_fastq                                             NaN
# fastqc_raw_html                                           NaN
# fastqc_raw_zip                                            NaN
# fastqc_trimmed_html                                       NaN
# fastqc_trimmed_zip                                        NaN
# metaphlan4_results_tsv                                    NaN
# raw_read_count                                            NaN
# non_human_read_count                                      NaN
# trimmed_non_human_read_count                              NaN
# metaphlan4_aligned_read_count                             NaN
# gene_aligned_read_count                                   NaN
# humann_gene_families_tsv                                  NaN
# humann_gene_familites_gene_level_parquet                  NaN
# humann_gene_familites_microbe_level_parquet               NaN
# humann_pathway_abundance_tsv                              NaN
# humann_pathway_abundance_pathway_level_parquet            NaN
# humann_pathway_abundance_microbe_level_parquet            NaN
# humann_pathway_coverage_tsv                               NaN
# humann_pathway_coverage_pathway_level_parquet             NaN
# humann_pathway_coverage_microbe_level_parquet             NaN
# humann_intermediate_files_tar                             NaN
# humann_aggregated_gene_familites_gene_level_arrow         NaN
# humann_aggregated_gene_familites_microbiome_lev...        NaN
# humann_aggregated_pathway_abundance_pathway_lev...        NaN
# humann_aggregated_pathway_abundance_microbiome_...        NaN
# humann_aggregated_pathway_coverage_pathway_leve...        NaN
# humann_aggregated_pathway_coverage_microbiome_l...        NaN
#
#                                                              feature_set  \
# tabular_field_name
# collection_date                                          oral_microbiome
# metaphlan_abundance_kingdom_parquet                 metaphlan_aggregated
# metaphlan_abundance_phylum_parquet                  metaphlan_aggregated
# metaphlan_abundance_class_parquet                   metaphlan_aggregated
# metaphlan_abundance_order_parquet                   metaphlan_aggregated
# metaphlan_abundance_family_parquet                  metaphlan_aggregated
# metaphlan_abundance_genus_parquet                   metaphlan_aggregated
# metaphlan_abundance_species_parquet                 metaphlan_aggregated
# metaphlan_abundance_strain_parquet                  metaphlan_aggregated
# raw_fastq                                                      raw_fastq
# trimmed_fastq                                              trimmed_fastq
# fastqc_raw_html                                                   fastqc
# fastqc_raw_zip                                                    fastqc
# fastqc_trimmed_html                                               fastqc
# fastqc_trimmed_zip                                                fastqc
# metaphlan4_results_tsv                                         metaphlan
# raw_read_count                                           oral_microbiome
# non_human_read_count                                     oral_microbiome
# trimmed_non_human_read_count                             oral_microbiome
# metaphlan4_aligned_read_count                            oral_microbiome
# gene_aligned_read_count                                  oral_microbiome
# humann_gene_families_tsv                                          humann
# humann_gene_familites_gene_level_parquet                          humann
# humann_gene_familites_microbe_level_parquet                       humann
# humann_pathway_abundance_tsv                                      humann
# humann_pathway_abundance_pathway_level_parquet                    humann
# humann_pathway_abundance_microbe_level_parquet                    humann
# humann_pathway_coverage_tsv                                       humann
# humann_pathway_coverage_pathway_level_parquet                     humann
# humann_pathway_coverage_microbe_level_parquet                     humann
# humann_intermediate_files_tar                                     humann
# humann_aggregated_gene_familites_gene_level_arrow      humann_aggregated
# humann_aggregated_gene_familites_microbiome_lev...     humann_aggregated
# humann_aggregated_pathway_abundance_pathway_lev...     humann_aggregated
# humann_aggregated_pathway_abundance_microbiome_...     humann_aggregated
# humann_aggregated_pathway_coverage_pathway_leve...     humann_aggregated
# humann_aggregated_pathway_coverage_microbiome_l...     humann_aggregated
#
#                                                                  field_type  \
# tabular_field_name
# collection_date                                                    Datetime
# metaphlan_abundance_kingdom_parquet                   Mapping table (group)
# metaphlan_abundance_phylum_parquet                    Mapping table (group)
# metaphlan_abundance_class_parquet                     Mapping table (group)
# metaphlan_abundance_order_parquet                     Mapping table (group)
# metaphlan_abundance_family_parquet                    Mapping table (group)
# metaphlan_abundance_genus_parquet                     Mapping table (group)
# metaphlan_abundance_species_parquet                   Mapping table (group)
# metaphlan_abundance_strain_parquet                    Mapping table (group)
# raw_fastq                                           Fastq file (individual)
# trimmed_fastq                                       Fastq file (individual)
# fastqc_raw_html                                      Bulk file (individual)
# fastqc_raw_zip                                       Bulk file (individual)
# fastqc_trimmed_html                                  Bulk file (individual)
# fastqc_trimmed_zip                                   Bulk file (individual)
# metaphlan4_results_tsv                               Bulk file (individual)
# raw_read_count                                                      Integer
# non_human_read_count                                                Integer
# trimmed_non_human_read_count                                        Integer
# metaphlan4_aligned_read_count                                       Integer
# gene_aligned_read_count                                             Integer
# humann_gene_families_tsv                             Bulk file (individual)
# humann_gene_familites_gene_level_parquet             Bulk file (individual)
# humann_gene_familites_microbe_level_parquet          Bulk file (individual)
# humann_pathway_abundance_tsv                         Bulk file (individual)
# humann_pathway_abundance_pathway_level_parquet       Bulk file (individual)
# humann_pathway_abundance_microbe_level_parquet       Bulk file (individual)
# humann_pathway_coverage_tsv                          Bulk file (individual)
# humann_pathway_coverage_pathway_level_parquet        Bulk file (individual)
# humann_pathway_coverage_microbe_level_parquet        Bulk file (individual)
# humann_intermediate_files_tar                        Bulk file (individual)
# humann_aggregated_gene_familites_gene_level_arrow     Mapping table (group)
# humann_aggregated_gene_familites_microbiome_lev...    Mapping table (group)
# humann_aggregated_pathway_abundance_pathway_lev...    Mapping table (group)
# humann_aggregated_pathway_abundance_microbiome_...    Mapping table (group)
# humann_aggregated_pathway_coverage_pathway_leve...    Mapping table (group)
# humann_aggregated_pathway_coverage_microbiome_l...    Mapping table (group)
#
#                                                                                          field_string  \
# tabular_field_name
# collection_date                                                                          Sampled date
# metaphlan_abundance_kingdom_parquet                                   MetaPhlAn 4 abundance (kingdom)
# metaphlan_abundance_phylum_parquet                                     MetaPhlAn 4 abundance (phylum)
# metaphlan_abundance_class_parquet                                       MetaPhlAn 4 abundance (class)
# metaphlan_abundance_order_parquet                                       MetaPhlAn 4 abundance (order)
# metaphlan_abundance_family_parquet                                    MetaPhlAn 4 abundance (famiily)
# metaphlan_abundance_genus_parquet                                       MetaPhlAn 4 abundance (genus)
# metaphlan_abundance_species_parquet                                   MetaPhlAn 4 abundance (species)
# metaphlan_abundance_strain_parquet                                     MetaPhlAn 4 abundance (strain)
# raw_fastq                                                         Raw FASTQ path (Post human removal)
# trimmed_fastq                                                                      Post QC FASTQ path
# fastqc_raw_html                                                             FASTQC HTML path Raw data
# fastqc_raw_zip                                                               FASTQC zip path Raw data
# fastqc_trimmed_html                                                     FASTQC HTML path Trimmed data
# fastqc_trimmed_zip                                                       FASTQC zip path Trimmed data
# metaphlan4_results_tsv                                                     MetaPhlAn 4 abundance path
# raw_read_count                                                                        Raw reads count
# non_human_read_count                                                            Non-human reads count
# trimmed_non_human_read_count                                            Post QC Non-human reads count
# metaphlan4_aligned_read_count                             Jan21 MetaPhlAn4 unique aligned reads count
# gene_aligned_read_count                                  HumanN 3.6 diamond aligned unique read count
# humann_gene_families_tsv                                  HumanN 3.6 - Gene families in original .tsv
# humann_gene_familites_gene_level_parquet            HumanN 3.6 - Gene families, in gene only level...
# humann_gene_familites_microbe_level_parquet         HumanN 3.6 - Gene families, microbiome level, ...
# humann_pathway_abundance_tsv                          HumanN 3.6 - Pathway abundance in original .tsv
# humann_pathway_abundance_pathway_level_parquet      HumanN 3.6 - Pathway abundance, in gene only l...
# humann_pathway_abundance_microbe_level_parquet      HumanN 3.6 - Pathway abundance, microbiome lev...
# humann_pathway_coverage_tsv                            HumanN 3.6 - Pathway coverage in original .tsv
# humann_pathway_coverage_pathway_level_parquet       HumanN 3.6 - Pathway coverage, in gene only le...
# humann_pathway_coverage_microbe_level_parquet       HumanN 3.6 - Pathway coverage, microbiome leve...
# humann_intermediate_files_tar                                         HumanN 3.6 - Intermidiate files
# humann_aggregated_gene_familites_gene_level_arrow   Aggregated HumanN 3.6 - Gene families (gene le...
# humann_aggregated_gene_familites_microbiome_lev...  Aggregated HumanN 3.6 - Gene families (microbe...
# humann_aggregated_pathway_abundance_pathway_lev...  Aggregated HumanN 3.6 - Pathways abundances (p...
# humann_aggregated_pathway_abundance_microbiome_...  Aggregated HumanN 3.6 - Pathways abundances (m...
# humann_aggregated_pathway_coverage_pathway_leve...  Aggregated HumanN 3.6 - Pathways coverage (pat...
# humann_aggregated_pathway_coverage_microbiome_l...  Aggregated HumanN 3.6 - Pathways coverage (mic...
#
#                                                                                    description_string  \
# tabular_field_name
# collection_date                                                                 Date sample was given
# metaphlan_abundance_kingdom_parquet                 Aggregated abundance (MetaPhlAn 4) at the king...
# metaphlan_abundance_phylum_parquet                  Aggregated abundance (MetaPhlAn 4) at the phyl...
# metaphlan_abundance_class_parquet                   Aggregated abundance (MetaPhlAn 4) at the clas...
# metaphlan_abundance_order_parquet                   Aggregated abundance (MetaPhlAn 4) at the orde...
# metaphlan_abundance_family_parquet                  Aggregated abundance (MetaPhlAn 4) at the fami...
# metaphlan_abundance_genus_parquet                   Aggregated abundance (MetaPhlAn 4) at the genu...
# metaphlan_abundance_species_parquet                 Aggregated abundance (MetaPhlAn 4) at the spec...
# metaphlan_abundance_strain_parquet                  Aggregated abundance (MetaPhlAn 4) at the stra...
# raw_fastq                                                                     The original FASTQ file
# trimmed_fastq                                       FASTQ file post Trimmomatic (removing adaptors...
# fastqc_raw_html                                                    FASTQC Output for Raw FASTQ - HTML
# fastqc_raw_zip                                                      FASTQC Output for Raw FASTQ - Zip
# fastqc_trimmed_html                                            FASTQC Output for Post QC FASTQ - HTML
# fastqc_trimmed_zip                                              FASTQC Output for Post QC FASTQ - Zip
# metaphlan4_results_tsv                                                 MetaPhlAn4 relative abundances
# raw_read_count                                          # Reads in the original bam file from gencove
# non_human_read_count                                    # Reads with no alignment to the human genome
# trimmed_non_human_read_count                                               # Non human Reads After QC
# metaphlan4_aligned_read_count                            # Reads after QC aligned to bacteria genomes
# gene_aligned_read_count                                          # Reads after QC aligned to Uniref90
# humann_gene_families_tsv                            HumanN 3.6 output of Microbial reads protein a...
# humann_gene_familites_gene_level_parquet            HumanN 3.6 output of Microbial reads protein a...
# humann_gene_familites_microbe_level_parquet         HumanN 3.6 + MetaPhlAn 4 output of Microbial r...
# humann_pathway_abundance_tsv                        HumanN 3.6 output of Oral microbime metaboliti...
# humann_pathway_abundance_pathway_level_parquet      HumanN 3.6 output of Oral microbime metaboliti...
# humann_pathway_abundance_microbe_level_parquet      HumanN 3.6 + MetaPhlAn 4 output of Oral microb...
# humann_pathway_coverage_tsv                         HumanN 3.6 output of Oral microbime metaboliti...
# humann_pathway_coverage_pathway_level_parquet       HumanN 3.6 output of Oral microbime metaboliti...
# humann_pathway_coverage_microbe_level_parquet       HumanN 3.6 + MetaPhlAn 4 output of Oral microb...
# humann_intermediate_files_tar                       All of the HumanN 3.6 + MetaPhlAn 4 intermidia...
# humann_aggregated_gene_familites_gene_level_arrow   Aggregated HumanN 3.6 output of Microbial read...
# humann_aggregated_gene_familites_microbiome_lev...  Aggregated HumanN 3.6 output of Microbial read...
# humann_aggregated_pathway_abundance_pathway_lev...  Aggregated HumanN 3.6 output of Oral microbime...
# humann_aggregated_pathway_abundance_microbiome_...  Aggregated HumanN 3.6 output of Oral microbime...
# humann_aggregated_pathway_coverage_pathway_leve...  Aggregated HumanN 3.6 output of Oral microbime...
# humann_aggregated_pathway_coverage_microbiome_l...  Aggregated HumanN 3.6 output of Oral microbime...
#
#                                                                           relative_location  \
# tabular_field_name
# collection_date                                     oral_microbiome/oral_microbiome.parquet
# metaphlan_abundance_kingdom_parquet                 oral_microbiome/oral_microbiome.parquet
# metaphlan_abundance_phylum_parquet                  oral_microbiome/oral_microbiome.parquet
# metaphlan_abundance_class_parquet                   oral_microbiome/oral_microbiome.parquet
# metaphlan_abundance_order_parquet                   oral_microbiome/oral_microbiome.parquet
# metaphlan_abundance_family_parquet                  oral_microbiome/oral_microbiome.parquet
# metaphlan_abundance_genus_parquet                   oral_microbiome/oral_microbiome.parquet
# metaphlan_abundance_species_parquet                 oral_microbiome/oral_microbiome.parquet
# metaphlan_abundance_strain_parquet                  oral_microbiome/oral_microbiome.parquet
# raw_fastq                                           oral_microbiome/oral_microbiome.parquet
# trimmed_fastq                                       oral_microbiome/oral_microbiome.parquet
# fastqc_raw_html                                     oral_microbiome/oral_microbiome.parquet
# fastqc_raw_zip                                      oral_microbiome/oral_microbiome.parquet
# fastqc_trimmed_html                                 oral_microbiome/oral_microbiome.parquet
# fastqc_trimmed_zip                                  oral_microbiome/oral_microbiome.parquet
# metaphlan4_results_tsv                              oral_microbiome/oral_microbiome.parquet
# raw_read_count                                      oral_microbiome/oral_microbiome.parquet
# non_human_read_count                                oral_microbiome/oral_microbiome.parquet
# trimmed_non_human_read_count                        oral_microbiome/oral_microbiome.parquet
# metaphlan4_aligned_read_count                       oral_microbiome/oral_microbiome.parquet
# gene_aligned_read_count                             oral_microbiome/oral_microbiome.parquet
# humann_gene_families_tsv                            oral_microbiome/oral_microbiome.parquet
# humann_gene_familites_gene_level_parquet            oral_microbiome/oral_microbiome.parquet
# humann_gene_familites_microbe_level_parquet         oral_microbiome/oral_microbiome.parquet
# humann_pathway_abundance_tsv                        oral_microbiome/oral_microbiome.parquet
# humann_pathway_abundance_pathway_level_parquet      oral_microbiome/oral_microbiome.parquet
# humann_pathway_abundance_microbe_level_parquet      oral_microbiome/oral_microbiome.parquet
# humann_pathway_coverage_tsv                         oral_microbiome/oral_microbiome.parquet
# humann_pathway_coverage_pathway_level_parquet       oral_microbiome/oral_microbiome.parquet
# humann_pathway_coverage_microbe_level_parquet       oral_microbiome/oral_microbiome.parquet
# humann_intermediate_files_tar                       oral_microbiome/oral_microbiome.parquet
# humann_aggregated_gene_familites_gene_level_arrow   oral_microbiome/oral_microbiome.parquet
# humann_aggregated_gene_familites_microbiome_lev...  oral_microbiome/oral_microbiome.parquet
# humann_aggregated_pathway_abundance_pathway_lev...  oral_microbiome/oral_microbiome.parquet
# humann_aggregated_pathway_abundance_microbiome_...  oral_microbiome/oral_microbiome.parquet
# humann_aggregated_pathway_coverage_pathway_leve...  oral_microbiome/oral_microbiome.parquet
# humann_aggregated_pathway_coverage_microbiome_l...  oral_microbiome/oral_microbiome.parquet
#
#                                                     data_coding stability  \
# tabular_field_name
# collection_date                                             NaN  Complete
# metaphlan_abundance_kingdom_parquet                         NaN  Complete
# metaphlan_abundance_phylum_parquet                          NaN  Complete
# metaphlan_abundance_class_parquet                           NaN  Complete
# metaphlan_abundance_order_parquet                           NaN  Complete
# metaphlan_abundance_family_parquet                          NaN  Complete
# metaphlan_abundance_genus_parquet                           NaN  Complete
# metaphlan_abundance_species_parquet                         NaN  Complete
# metaphlan_abundance_strain_parquet                          NaN  Complete
# raw_fastq                                                   NaN  Complete
# trimmed_fastq                                               NaN  Complete
# fastqc_raw_html                                             NaN  Complete
# fastqc_raw_zip                                              NaN  Complete
# fastqc_trimmed_html                                         NaN  Complete
# fastqc_trimmed_zip                                          NaN  Complete
# metaphlan4_results_tsv                                      NaN  Complete
# raw_read_count                                              NaN  Complete
# non_human_read_count                                        NaN  Complete
# trimmed_non_human_read_count                                NaN  Complete
# metaphlan4_aligned_read_count                               NaN  Complete
# gene_aligned_read_count                                     NaN  Complete
# humann_gene_families_tsv                                    NaN  Complete
# humann_gene_familites_gene_level_parquet                    NaN  Complete
# humann_gene_familites_microbe_level_parquet                 NaN  Complete
# humann_pathway_abundance_tsv                                NaN  Complete
# humann_pathway_abundance_pathway_level_parquet              NaN  Complete
# humann_pathway_abundance_microbe_level_parquet              NaN  Complete
# humann_pathway_coverage_tsv                                 NaN  Complete
# humann_pathway_coverage_pathway_level_parquet               NaN  Complete
# humann_pathway_coverage_microbe_level_parquet               NaN  Complete
# humann_intermediate_files_tar                               NaN  Complete
# humann_aggregated_gene_familites_gene_level_arrow           NaN  Complete
# humann_aggregated_gene_familites_microbiome_lev...          NaN  Complete
# humann_aggregated_pathway_abundance_pathway_lev...          NaN  Complete
# humann_aggregated_pathway_abundance_microbiome_...          NaN  Complete
# humann_aggregated_pathway_coverage_pathway_leve...          NaN  Complete
# humann_aggregated_pathway_coverage_microbiome_l...          NaN  Complete
#
#                                                    units  sampling_rate  \
# tabular_field_name
# collection_date                                     Time            NaN
# metaphlan_abundance_kingdom_parquet                  NaN            NaN
# metaphlan_abundance_phylum_parquet                   NaN            NaN
# metaphlan_abundance_class_parquet                    NaN            NaN
# metaphlan_abundance_order_parquet                    NaN            NaN
# metaphlan_abundance_family_parquet                   NaN            NaN
# metaphlan_abundance_genus_parquet                    NaN            NaN
# metaphlan_abundance_species_parquet                  NaN            NaN
# metaphlan_abundance_strain_parquet                   NaN            NaN
# raw_fastq                                            NaN            NaN
# trimmed_fastq                                        NaN            NaN
# fastqc_raw_html                                      NaN            NaN
# fastqc_raw_zip                                       NaN            NaN
# fastqc_trimmed_html                                  NaN            NaN
# fastqc_trimmed_zip                                   NaN            NaN
# metaphlan4_results_tsv                               NaN            NaN
# raw_read_count                                       NaN            NaN
# non_human_read_count                                 NaN            NaN
# trimmed_non_human_read_count                         NaN            NaN
# metaphlan4_aligned_read_count                        NaN            NaN
# gene_aligned_read_count                              NaN            NaN
# humann_gene_families_tsv                             NaN            NaN
# humann_gene_familites_gene_level_parquet             NaN            NaN
# humann_gene_familites_microbe_level_parquet          NaN            NaN
# humann_pathway_abundance_tsv                         NaN            NaN
# humann_pathway_abundance_pathway_level_parquet       NaN            NaN
# humann_pathway_abundance_microbe_level_parquet       NaN            NaN
# humann_pathway_coverage_tsv                          NaN            NaN
# humann_pathway_coverage_pathway_level_parquet        NaN            NaN
# humann_pathway_coverage_microbe_level_parquet        NaN            NaN
# humann_intermediate_files_tar                        NaN            NaN
# humann_aggregated_gene_familites_gene_level_arrow    NaN            NaN
# humann_aggregated_gene_familites_microbiome_lev...   NaN            NaN
# humann_aggregated_pathway_abundance_pathway_lev...   NaN            NaN
# humann_aggregated_pathway_abundance_microbiome_...   NaN            NaN
# humann_aggregated_pathway_coverage_pathway_leve...   NaN            NaN
# humann_aggregated_pathway_coverage_microbiome_l...   NaN            NaN
#
#                                                    bulk_file_extension  \
# tabular_field_name
# collection_date                                                    NaN
# metaphlan_abundance_kingdom_parquet                            parquet
# metaphlan_abundance_phylum_parquet                             parquet
# metaphlan_abundance_class_parquet                              parquet
# metaphlan_abundance_order_parquet                              parquet
# metaphlan_abundance_family_parquet                             parquet
# metaphlan_abundance_genus_parquet                              parquet
# metaphlan_abundance_species_parquet                            parquet
# metaphlan_abundance_strain_parquet                             parquet
# raw_fastq                                                     fastq.gz
# trimmed_fastq                                                 fastq.gz
# fastqc_raw_html                                                   html
# fastqc_raw_zip                                                     zip
# fastqc_trimmed_html                                               html
# fastqc_trimmed_zip                                                 zip
# metaphlan4_results_tsv                                             tsv
# raw_read_count                                                     NaN
# non_human_read_count                                               NaN
# trimmed_non_human_read_count                                       NaN
# metaphlan4_aligned_read_count                                      NaN
# gene_aligned_read_count                                            NaN
# humann_gene_families_tsv                                           tsv
# humann_gene_familites_gene_level_parquet                       parquet
# humann_gene_familites_microbe_level_parquet                    parquet
# humann_pathway_abundance_tsv                                       tsv
# humann_pathway_abundance_pathway_level_parquet                 parquet
# humann_pathway_abundance_microbe_level_parquet                 parquet
# humann_pathway_coverage_tsv                                        tsv
# humann_pathway_coverage_pathway_level_parquet                  parquet
# humann_pathway_coverage_microbe_level_parquet                  parquet
# humann_intermediate_files_tar                                   tar.gz
# humann_aggregated_gene_familites_gene_level_arrow                arrow
# humann_aggregated_gene_familites_microbiome_lev...               arrow
# humann_aggregated_pathway_abundance_pathway_lev...               arrow
# humann_aggregated_pathway_abundance_microbiome_...               arrow
# humann_aggregated_pathway_coverage_pathway_leve...               arrow
# humann_aggregated_pathway_coverage_microbiome_l...               arrow
#
#                                                     bulk_dictionary  \
# tabular_field_name
# collection_date                                                 NaN
# metaphlan_abundance_kingdom_parquet                             NaN
# metaphlan_abundance_phylum_parquet                              NaN
# metaphlan_abundance_class_parquet                               NaN
# metaphlan_abundance_order_parquet                               NaN
# metaphlan_abundance_family_parquet                              NaN
# metaphlan_abundance_genus_parquet                               NaN
# metaphlan_abundance_species_parquet                             NaN
# metaphlan_abundance_strain_parquet                              NaN
# raw_fastq                                                       NaN
# trimmed_fastq                                                   NaN
# fastqc_raw_html                                                 NaN
# fastqc_raw_zip                                                  NaN
# fastqc_trimmed_html                                             NaN
# fastqc_trimmed_zip                                              NaN
# metaphlan4_results_tsv                                          NaN
# raw_read_count                                                  NaN
# non_human_read_count                                            NaN
# trimmed_non_human_read_count                                    NaN
# metaphlan4_aligned_read_count                                   NaN
# gene_aligned_read_count                                         NaN
# humann_gene_families_tsv                                        NaN
# humann_gene_familites_gene_level_parquet                        NaN
# humann_gene_familites_microbe_level_parquet                     NaN
# humann_pathway_abundance_tsv                                    NaN
# humann_pathway_abundance_pathway_level_parquet                  NaN
# humann_pathway_abundance_microbe_level_parquet                  NaN
# humann_pathway_coverage_tsv                                     NaN
# humann_pathway_coverage_pathway_level_parquet                   NaN
# humann_pathway_coverage_microbe_level_parquet                   NaN
# humann_intermediate_files_tar                                   NaN
# humann_aggregated_gene_familites_gene_level_arrow               NaN
# humann_aggregated_gene_familites_microbiome_lev...              NaN
# humann_aggregated_pathway_abundance_pathway_lev...              NaN
# humann_aggregated_pathway_abundance_microbiome_...              NaN
# humann_aggregated_pathway_coverage_pathway_leve...              NaN
# humann_aggregated_pathway_coverage_microbiome_l...              NaN
#
#                                                         strata       sexed  \
# tabular_field_name
# collection_date                                        Primary  Both sexes
# metaphlan_abundance_kingdom_parquet                    Primary  Both sexes
# metaphlan_abundance_phylum_parquet                     Primary  Both sexes
# metaphlan_abundance_class_parquet                      Primary  Both sexes
# metaphlan_abundance_order_parquet                      Primary  Both sexes
# metaphlan_abundance_family_parquet                     Primary  Both sexes
# metaphlan_abundance_genus_parquet                      Primary  Both sexes
# metaphlan_abundance_species_parquet                    Primary  Both sexes
# metaphlan_abundance_strain_parquet                     Primary  Both sexes
# raw_fastq                                              Primary  Both sexes
# trimmed_fastq                                          Primary  Both sexes
# fastqc_raw_html                                     Supporting  Both sexes
# fastqc_raw_zip                                      Supporting  Both sexes
# fastqc_trimmed_html                                 Supporting  Both sexes
# fastqc_trimmed_zip                                  Supporting  Both sexes
# metaphlan4_results_tsv                              Supporting  Both sexes
# raw_read_count                                         Primary  Both sexes
# non_human_read_count                                   Primary  Both sexes
# trimmed_non_human_read_count                           Primary  Both sexes
# metaphlan4_aligned_read_count                          Primary  Both sexes
# gene_aligned_read_count                                Primary  Both sexes
# humann_gene_families_tsv                            Supporting  Both sexes
# humann_gene_familites_gene_level_parquet            Supporting  Both sexes
# humann_gene_familites_microbe_level_parquet         Supporting  Both sexes
# humann_pathway_abundance_tsv                        Supporting  Both sexes
# humann_pathway_abundance_pathway_level_parquet      Supporting  Both sexes
# humann_pathway_abundance_microbe_level_parquet      Supporting  Both sexes
# humann_pathway_coverage_tsv                         Supporting  Both sexes
# humann_pathway_coverage_pathway_level_parquet       Supporting  Both sexes
# humann_pathway_coverage_microbe_level_parquet       Supporting  Both sexes
# humann_intermediate_files_tar                       Supporting  Both sexes
# humann_aggregated_gene_familites_gene_level_arrow      Primary  Both sexes
# humann_aggregated_gene_familites_microbiome_lev...     Primary  Both sexes
# humann_aggregated_pathway_abundance_pathway_lev...     Primary  Both sexes
# humann_aggregated_pathway_abundance_microbiome_...     Primary  Both sexes
# humann_aggregated_pathway_coverage_pathway_leve...     Primary  Both sexes
# humann_aggregated_pathway_coverage_microbiome_l...     Primary  Both sexes
#
#                                                      array  debut  completed  \
# tabular_field_name
# collection_date                                     Single    NaN        NaN
# metaphlan_abundance_kingdom_parquet                 Single    NaN        NaN
# metaphlan_abundance_phylum_parquet                  Single    NaN        NaN
# metaphlan_abundance_class_parquet                   Single    NaN        NaN
# metaphlan_abundance_order_parquet                   Single    NaN        NaN
# metaphlan_abundance_family_parquet                  Single    NaN        NaN
# metaphlan_abundance_genus_parquet                   Single    NaN        NaN
# metaphlan_abundance_species_parquet                 Single    NaN        NaN
# metaphlan_abundance_strain_parquet                  Single    NaN        NaN
# raw_fastq                                           Single    NaN        NaN
# trimmed_fastq                                       Single    NaN        NaN
# fastqc_raw_html                                     Single    NaN        NaN
# fastqc_raw_zip                                      Single    NaN        NaN
# fastqc_trimmed_html                                 Single    NaN        NaN
# fastqc_trimmed_zip                                  Single    NaN        NaN
# metaphlan4_results_tsv                              Single    NaN        NaN
# raw_read_count                                      Single    NaN        NaN
# non_human_read_count                                Single    NaN        NaN
# trimmed_non_human_read_count                        Single    NaN        NaN
# metaphlan4_aligned_read_count                       Single    NaN        NaN
# gene_aligned_read_count                             Single    NaN        NaN
# humann_gene_families_tsv                            Single    NaN        NaN
# humann_gene_familites_gene_level_parquet            Single    NaN        NaN
# humann_gene_familites_microbe_level_parquet         Single    NaN        NaN
# humann_pathway_abundance_tsv                        Single    NaN        NaN
# humann_pathway_abundance_pathway_level_parquet      Single    NaN        NaN
# humann_pathway_abundance_microbe_level_parquet      Single    NaN        NaN
# humann_pathway_coverage_tsv                         Single    NaN        NaN
# humann_pathway_coverage_pathway_level_parquet       Single    NaN        NaN
# humann_pathway_coverage_microbe_level_parquet       Single    NaN        NaN
# humann_intermediate_files_tar                       Single    NaN        NaN
# humann_aggregated_gene_familites_gene_level_arrow   Single    NaN        NaN
# humann_aggregated_gene_familites_microbiome_lev...  Single    NaN        NaN
# humann_aggregated_pathway_abundance_pathway_lev...  Single    NaN        NaN
# humann_aggregated_pathway_abundance_microbiome_...  Single    NaN        NaN
# humann_aggregated_pathway_coverage_pathway_leve...  Single    NaN        NaN
# humann_aggregated_pathway_coverage_microbiome_l...  Single    NaN        NaN
#
#                                                     transformation  \
# tabular_field_name
# collection_date                                                NaN
# metaphlan_abundance_kingdom_parquet                            NaN
# metaphlan_abundance_phylum_parquet                             NaN
# metaphlan_abundance_class_parquet                              NaN
# metaphlan_abundance_order_parquet                              NaN
# metaphlan_abundance_family_parquet                             NaN
# metaphlan_abundance_genus_parquet                              NaN
# metaphlan_abundance_species_parquet                            NaN
# metaphlan_abundance_strain_parquet                             NaN
# raw_fastq                                                      NaN
# trimmed_fastq                                                  NaN
# fastqc_raw_html                                                NaN
# fastqc_raw_zip                                                 NaN
# fastqc_trimmed_html                                            NaN
# fastqc_trimmed_zip                                             NaN
# metaphlan4_results_tsv                                         NaN
# raw_read_count                                                 NaN
# non_human_read_count                                           NaN
# trimmed_non_human_read_count                                   NaN
# metaphlan4_aligned_read_count                                  NaN
# gene_aligned_read_count                                        NaN
# humann_gene_families_tsv                                       NaN
# humann_gene_familites_gene_level_parquet                       NaN
# humann_gene_familites_microbe_level_parquet                    NaN
# humann_pathway_abundance_tsv                                   NaN
# humann_pathway_abundance_pathway_level_parquet                 NaN
# humann_pathway_abundance_microbe_level_parquet                 NaN
# humann_pathway_coverage_tsv                                    NaN
# humann_pathway_coverage_pathway_level_parquet                  NaN
# humann_pathway_coverage_microbe_level_parquet                  NaN
# humann_intermediate_files_tar                                  NaN
# humann_aggregated_gene_familites_gene_level_arrow              NaN
# humann_aggregated_gene_familites_microbiome_lev...             NaN
# humann_aggregated_pathway_abundance_pathway_lev...             NaN
# humann_aggregated_pathway_abundance_microbiome_...             NaN
# humann_aggregated_pathway_coverage_pathway_leve...             NaN
# humann_aggregated_pathway_coverage_microbiome_l...             NaN
#
#                                                        list_of_tags  \
# tabular_field_name
# collection_date                                     Oral Microbiome
# metaphlan_abundance_kingdom_parquet                 Oral Microbiome
# metaphlan_abundance_phylum_parquet                  Oral Microbiome
# metaphlan_abundance_class_parquet                   Oral Microbiome
# metaphlan_abundance_order_parquet                   Oral Microbiome
# metaphlan_abundance_family_parquet                  Oral Microbiome
# metaphlan_abundance_genus_parquet                   Oral Microbiome
# metaphlan_abundance_species_parquet                 Oral Microbiome
# metaphlan_abundance_strain_parquet                  Oral Microbiome
# raw_fastq                                           Oral Microbiome
# trimmed_fastq                                       Oral Microbiome
# fastqc_raw_html                                     Oral Microbiome
# fastqc_raw_zip                                      Oral Microbiome
# fastqc_trimmed_html                                 Oral Microbiome
# fastqc_trimmed_zip                                  Oral Microbiome
# metaphlan4_results_tsv                              Oral Microbiome
# raw_read_count                                      Oral Microbiome
# non_human_read_count                                Oral Microbiome
# trimmed_non_human_read_count                        Oral Microbiome
# metaphlan4_aligned_read_count                       Oral Microbiome
# gene_aligned_read_count                             Oral Microbiome
# humann_gene_families_tsv                            Oral Microbiome
# humann_gene_familites_gene_level_parquet            Oral Microbiome
# humann_gene_familites_microbe_level_parquet         Oral Microbiome
# humann_pathway_abundance_tsv                        Oral Microbiome
# humann_pathway_abundance_pathway_level_parquet      Oral Microbiome
# humann_pathway_abundance_microbe_level_parquet      Oral Microbiome
# humann_pathway_coverage_tsv                         Oral Microbiome
# humann_pathway_coverage_pathway_level_parquet       Oral Microbiome
# humann_pathway_coverage_microbe_level_parquet       Oral Microbiome
# humann_intermediate_files_tar                       Oral Microbiome
# humann_aggregated_gene_familites_gene_level_arrow   Oral Microbiome
# humann_aggregated_gene_familites_microbiome_lev...  Oral Microbiome
# humann_aggregated_pathway_abundance_pathway_lev...  Oral Microbiome
# humann_aggregated_pathway_abundance_microbiome_...  Oral Microbiome
# humann_aggregated_pathway_coverage_pathway_leve...  Oral Microbiome
# humann_aggregated_pathway_coverage_microbiome_l...  Oral Microbiome
#
#                                                       pandas_dtype
# tabular_field_name
# collection_date                                     datetime64[ns]
# metaphlan_abundance_kingdom_parquet                         string
# metaphlan_abundance_phylum_parquet                          string
# metaphlan_abundance_class_parquet                           string
# metaphlan_abundance_order_parquet                           string
# metaphlan_abundance_family_parquet                          string
# metaphlan_abundance_genus_parquet                           string
# metaphlan_abundance_species_parquet                         string
# metaphlan_abundance_strain_parquet                          string
# raw_fastq                                                   string
# trimmed_fastq                                               string
# fastqc_raw_html                                             string
# fastqc_raw_zip                                              string
# fastqc_trimmed_html                                         string
# fastqc_trimmed_zip                                          string
# metaphlan4_results_tsv                                      string
# raw_read_count                                                 int
# non_human_read_count                                           int
# trimmed_non_human_read_count                                   int
# metaphlan4_aligned_read_count                                  int
# gene_aligned_read_count                                        int
# humann_gene_families_tsv                                    string
# humann_gene_familites_gene_level_parquet                    string
# humann_gene_familites_microbe_level_parquet                 string
# humann_pathway_abundance_tsv                                string
# humann_pathway_abundance_pathway_level_parquet              string
# humann_pathway_abundance_microbe_level_parquet              string
# humann_pathway_coverage_tsv                                 string
# humann_pathway_coverage_pathway_level_parquet               string
# humann_pathway_coverage_microbe_level_parquet               string
# humann_intermediate_files_tar                               string
# humann_aggregated_gene_familites_gene_level_arrow           string
# humann_aggregated_gene_familites_microbiome_lev...          string
# humann_aggregated_pathway_abundance_pathway_lev...          string
# humann_aggregated_pathway_abundance_microbiome_...          string
# humann_aggregated_pathway_coverage_pathway_leve...          string
# humann_aggregated_pathway_coverage_microbiome_l...          string

# %% [markdown]
# # Plot histogram and ecdf for raw_read_count at baseline visit

# %%
from pheno_utils.basic_plots import hist_ecdf_plots

col = "raw_read_count"
df = pl[[col] + ["age", "sex", "collection_date"]].loc[:,:,"00_00_visit",0,:]

# plot histogram and ecdf
hist_ecdf_plots(df.dropna(subset=[col,"sex", "age"]), col, gender_col="sex")

# stats
display(df[col].describe().to_frame().T)
# Out:
#                  count             mean             std        min  \
# raw_read_count  8294.0  19529470.245479  7338498.393217  8805038.0
#
#                        25%         50%         75%          max
# raw_read_count  15039265.5  18221025.5  21923790.0  127497332.0
