# %% [raw]
# ---
# output-file: 014-human_genetics.html
# title: Human Genetics
# ---

# %% [markdown]
# ### Description
#
# The Human Phenotype Project collects genomic variation data on all its participants. The genomic data together with the Human Phenotype Project  deep-phenotypes allows to investigate the progression of disease, and to explore personalized treatments. We genotype millions of positions by low-pass sequencing combined with imputation using gencove platform technologies. Genotype imputation is a process of statistically inferring unobserved genotypes using known haplotypes in a population. The performance of Gencove genotype imputation is very high ( accuracy > 98% ) ([Wasik et al. 2021](https://link.springer.com/article/10.1186/s12864-021-07508-2?utm_campaign=2022.01%20Publications&utm_source=LP%20for%20Pharmacogenomics)).
#
# ### Introduction
#
# Genomic variation refers to DNA sequence differences between individuals. Some genetic variants can influence biological function (such as a mutation that causes a genetic disease), while others have no known effects. The genomic data together with the Human Phenotype Project rich variety of phenotypic data enables investigation of how genetics impact the progression of disease, and exploration of personalized prevention strategies and  treatments.
#
# The Human Phenotype Project uses low-pass sequencing combined with [imputation](https://en.wikipedia.org/wiki/Imputation_(genetics)) to obtain genomic variation, using [genocve](https://gencove.com) platform technologies. We do not target specific regions by sequencing, but rather sample the entire genome with low average depth of coverage, and impute the sequence data to the haplotype reference panel which includes a large set of known genetic variants. Briefly, the model approach is to identify haplotypes shared between a study sample and a reference panel based on the study sample observed genotypes. Next, the unobserved genotypes are extrapolated according to the large reference data as illustrated in Figure 1. Imputation is performed for single nucleotide polymorphisms (SNPs) and short insertion–deletion variants (indels), structural variation are currently not included. The overall accuracy of gencove imputed genotypes is 98.22% (Wasik et al. 2021). We also validated the accuracy of the imputation using two hundred Human Phenotype Project participants from several ancestries which had both low-pass sequencing done and Illumina genotyping array data. We obtained high concordance rates, greater than 96%.
#
# ![study sample](study_sample.png)
#
# Figure 1: taken from [Li et al. 2013](https://www.ncbi.nlm.nih.gov/pmc/articles/PMC2925172/).
# Panel A illustrates the observed data which consists of genotypes at a modest number of genetic markers in each sample being studied and of detailed information on genotypes (or haplotypes) for a reference sample. Panel B illustrates the process of identifying regions of chromosomes shared between a study sample and individuals in the reference panel. In Panel C, observed genotypes and haplotype sharing information have been combined to fill in a series of unobserved genotypes in the study sample.*
#
# ### Measurement protocol
# <!-- long measurment protocol for the data browser -->
# #### Genotyping Procedure
# DNA is collected from Human Phenotype Project participants using a buccal swab during their baseline visit. DNA is collected only once as germline DNA is considered constant. The buccal swabs are shipped to Gencove laboratories. The entire sequencing and genotyping workflow is performed by Gencove technologies. The Detailed information about the Gencove algorithms and quality control protocols are available in Wasik et al. 2021,  we briefly describe the key steps here.
#
# Gencove’s workflow contains three steps: DNA extraction and library preparation, low-pass whole genome sequencing, and imputation analysis. Sequencing is performed at Neogen GeneSeek Laboratories using Illumina Novaseq at low-pass, targeting coverage levels of 0.5× and 1×. Whole-genome coverage is defined as the number of mapped DNA bases divided by the size of the genome (∼3 billion base pairs). We perform paired-end sequencing at length of 150-bp resulting in two FASTQ files (R1 and R2). Sequencing at paired-end mode significantly improves alignment to the genome. Next, the FASTQ files are aligned to the hs37-1kg reference genome, resulting in a BAM (Binary Alignment Map) file. In the sequence alignment procedure the DNA reads are mapped (in-pair) to the human genome reference sequence by similarity between the sequences. Lastly, loimpute-v0.1.0, Gencove’s imputation procedure, is used over the aligned reads. Imputation is done for the autosomal chromosomes (1-22) using The 1000 Genomes phase 3 haplotypes (1KGP3) as a reference panel, resulting in a VCF (Variant Call Format) file. The VCF contains the most likely genotype (GT) at 37,559,140 positions and their corresponding genotype probabilities (GP). Finally, Gencove employs quality control procedures to exclude samples with poor sequencing and genotyping results.
#
# ### Data availability
# <!-- for the example notebooks -->
# The information is stored in a number of statistics parquet files:<br>
# - `human_genetics.parquet`: sample metadata, including QC statistics, paths to PLINK variant files (raw and post-QC), and principal components (PCs).<br>
# - `variants_qc.parquet`: variant QC statistics.<br>
# - `relationship/relationship_ibs.txt`: IBS calculated by PLINK for pairs of participants.<br>
# - `relationship/relationship_king.tsv`: King kinship coefficients for pairs of participants.<br>
# - `pca/pca.parquet`: a PLINK file containing  principal components.<br>
# - `pca/pca_loadings.tsv`: a PLINK file containing principal component loadings calculated.<br>
#
# ```{mermaid}
# graph LR;
#     D[DNA extraction] -->|sequencing| F(FASTQ) -->|alignment| B(BAM) -->|imputation| V(VCF)
#     H[REFERENCE HAPLOTYPES] -->|imputation| V -->|"sample<br>aggregation"| R(BED<br>raw) -->|QC| Q(BED<br>post-qc)
#     Q --> PCA(PCA)
#     Q --> IBS(PLINK IBS<br>relationships)
#     Q --> KING(KING<br>relationships)
# ```
#
# ### Summary of available data
# <!-- for the data browser -->
# #### Raw DNA data
# Pheno provides per each sample all of the raw sequencing and genotyping workflow data, including FASTQ, BAM, VCF, and QC files.
#
# - FASTQ files are the sequencing machine outputs. They are text files that store the DNA sequences and their corresponding quality scores. We perform the sequencing at paired-end mode, meaning that each DNA molecule is sequenced from both sides, therefore there are two FASTQ files (R1 and R2).
# - Binary Alignment Map (BAM) files are a binary and indexed representation of sequence alignment results. The BAM file stores the position of the DNA reads in the reference genome and the corresponding mapping quality. Indexing is provided in the bam.bai file, and allows to retrieve alignments that overlap a specific location quickly.
# - Variant Call Format (VCF) file is a text file used for storing genetic variations. VCF consists of a header and a table. The header provides metadata describing the table fields and their values. The FILTER field holds a flag indicating whether the variant has failed or successfully passed filters. The raw genotype data includes all 37M positions regardless of their FILTER flag status. Genotypes are flagged as ‘LOWCONF’ at the FILTER field if their maximum GP is less than 0.9, and otherwise flagged as ‘PASS’ quality check. The following FORMAT fields are provided in the VCF - GT:RC:AC:GP:DS ([VCF specification](https://samtools.github.io/hts-specs/VCFv4.3.pdf)). Please note that the data is unphased.
# - PLINK binary biallelic genotype file - In addition to the single sample VCFs we also provide the raw genotype data of all samples jointly in PLINK bed format. Because of the large number of variants, we split the data to chromosomes  (22 PLINK bed/bim/bam files). PLINK bed file is a compacted binary representation of genotypes at bi-allelic variants. It is accompanied by .bim and .fam files, which are the metadata files for variants and samples, respectively ([PLINK specification](https://www.cog-genomics.org/plink/1.9/formats#bed)).
# - Gencove QC file - Gencove performs quality control to exclude samples with poor sequencing and genotyping results. Gencove’s quality control matrices are included in the sample metadata.
#
# The raw genotype data includes 34,580,532 SNPs and 2,978,606 short indels, 37,494,604 of the variants are bi-alleleic and 30,990 are multi-allelic. Multi-allelic variants are represented in variant normalization format, meaning each alternate allele is listed in a separate line, in both the VCFs and PLINK.
#
# Notably, we do not provide the raw data of samples who failed Gencove QC or for which we identify a possibility of DNA contamination or of mislabelling (i.e. DNA samples are associated with the wrong individual), as explained in section ‘Sample evaluation’.
#
# #### Post-genotyping QC data
# - We provide the QC genotyped data in PLINK format as explained above. The post-genotyping QC procedure resulted in genotypes for ~99.98% of total samples, and 5,770,633 variants that passed variant QC (~15.36% of the total variants).
# - In addition to the genotype data we provide auxiliary tabulated datasets such as : variants and sample QC metrics, principal component projection, and familial relationships estimates.
#
# ![availbale data](genetics_data.png)
#
# ### Relevant links
#
# * [Pheno Knowledgebase](https://knowledgebase.pheno.ai/datasets/014-human_genetics.html)
# * [Pheno Data Browser](https://pheno-demo-app.vercel.app/folder/14)

# %%
#| echo: false
import pandas as pd
pd.set_option("display.max_rows", 500)

# %%
from pheno_utils import PhenoLoader

# %%
pl = PhenoLoader('human_genetics')
pl
# Out:
# PhenoLoader for human_genetics with
# 189 fields
# 3 tables: ['human_genetics', 'pca', 'age_sex']

# %% [markdown]
# # Data dictionary

# %%
pl.dict
# Out:
#                                           folder_id       feature_set  \
# tabular_field_name
# collection_date                                  14    human_genetics
# version                                          14    human_genetics
# gencove_fastq_r1                                 14         fastq_bam
# gencove_fastq_r2                                 14         fastq_bam
# gencove_bam                                      14         fastq_bam
# gencove_bai                                      14         fastq_bam
# gencove_vcf                                      14         fastq_bam
# genecov_qc_bases                                 14    human_genetics
# genecov_qc_bases_dedup                           14    human_genetics
# gencove_qc_bases_dedup_mapped                    14    human_genetics
# genecov_qc_effective_coverage                    14    human_genetics
# genecov_qc_fraction_contamination                14    human_genetics
# genecov_qc_snps                                  14    human_genetics
# genecov_qc_format_passed                         14    human_genetics
# genecov_qc_r1_eq_r2_passed                       14    human_genetics
# genecov_qc_r1_r2_ids_match_passed                14    human_genetics
# genecov_qc_bases_passed                          14    human_genetics
# genecov_qc_bases_dedup_passed                    14    human_genetics
# genecov_qc_bases_dedup_mapped_passed             14    human_genetics
# genecov_qc_effective_coverage_passed             14    human_genetics
# genecov_qc_fraction_contamination_passed         14    human_genetics
# genecov_qc_snps_passed                           14    human_genetics
# heterozygosity_proportion                        14    human_genetics
# pass_het_check                                   14    human_genetics
# sample_qc_gp_pass_rate                           14    human_genetics
# sample_qc_gp_pass_check                          14    human_genetics
# genetic_sex                                      14    human_genetics
# chr_x_proportion                                 14    human_genetics
# chr_y_proportion                                 14    human_genetics
# sample_qc_gender_match_check                     14    human_genetics
# variants_qc_parquet                              14       variants_qc
# relatives                                        14      relationship
# relationship_king_tsv                            14      relationship
# relationship_ibs_txt                             14      relationship
# chr_1_raw_bed                                    14     genotypes_raw
# chr_1_raw_fam                                    14     genotypes_raw
# chr_1_raw_bim                                    14     genotypes_raw
# chr_2_raw_bed                                    14     genotypes_raw
# chr_2_raw_fam                                    14     genotypes_raw
# chr_2_raw_bim                                    14     genotypes_raw
# chr_3_raw_bed                                    14     genotypes_raw
# chr_3_raw_fam                                    14     genotypes_raw
# chr_3_raw_bim                                    14     genotypes_raw
# chr_4_raw_bed                                    14     genotypes_raw
# chr_4_raw_fam                                    14     genotypes_raw
# chr_4_raw_bim                                    14     genotypes_raw
# chr_5_raw_bed                                    14     genotypes_raw
# chr_5_raw_fam                                    14     genotypes_raw
# chr_5_raw_bim                                    14     genotypes_raw
# chr_6_raw_bed                                    14     genotypes_raw
# chr_6_raw_fam                                    14     genotypes_raw
# chr_6_raw_bim                                    14     genotypes_raw
# chr_7_raw_bed                                    14     genotypes_raw
# chr_7_raw_fam                                    14     genotypes_raw
# chr_7_raw_bim                                    14     genotypes_raw
# chr_8_raw_bed                                    14     genotypes_raw
# chr_8_raw_fam                                    14     genotypes_raw
# chr_8_raw_bim                                    14     genotypes_raw
# chr_9_raw_bed                                    14     genotypes_raw
# chr_9_raw_fam                                    14     genotypes_raw
# chr_9_raw_bim                                    14     genotypes_raw
# chr_10_raw_bed                                   14     genotypes_raw
# chr_10_raw_fam                                   14     genotypes_raw
# chr_10_raw_bim                                   14     genotypes_raw
# chr_11_raw_bed                                   14     genotypes_raw
# chr_11_raw_fam                                   14     genotypes_raw
# chr_11_raw_bim                                   14     genotypes_raw
# chr_12_raw_bed                                   14     genotypes_raw
# chr_12_raw_fam                                   14     genotypes_raw
# chr_12_raw_bim                                   14     genotypes_raw
# chr_13_raw_bed                                   14     genotypes_raw
# chr_13_raw_fam                                   14     genotypes_raw
# chr_13_raw_bim                                   14     genotypes_raw
# chr_14_raw_bed                                   14     genotypes_raw
# chr_14_raw_fam                                   14     genotypes_raw
# chr_14_raw_bim                                   14     genotypes_raw
# chr_15_raw_bed                                   14     genotypes_raw
# chr_15_raw_fam                                   14     genotypes_raw
# chr_15_raw_bim                                   14     genotypes_raw
# chr_16_raw_bed                                   14     genotypes_raw
# chr_16_raw_fam                                   14     genotypes_raw
# chr_16_raw_bim                                   14     genotypes_raw
# chr_17_raw_bed                                   14     genotypes_raw
# chr_17_raw_fam                                   14     genotypes_raw
# chr_17_raw_bim                                   14     genotypes_raw
# chr_18_raw_bed                                   14     genotypes_raw
# chr_18_raw_fam                                   14     genotypes_raw
# chr_18_raw_bim                                   14     genotypes_raw
# chr_19_raw_bed                                   14     genotypes_raw
# chr_19_raw_fam                                   14     genotypes_raw
# chr_19_raw_bim                                   14     genotypes_raw
# chr_20_raw_bed                                   14     genotypes_raw
# chr_20_raw_fam                                   14     genotypes_raw
# chr_20_raw_bim                                   14     genotypes_raw
# chr_21_raw_bed                                   14     genotypes_raw
# chr_21_raw_fam                                   14     genotypes_raw
# chr_21_raw_bim                                   14     genotypes_raw
# chr_22_raw_bed                                   14     genotypes_raw
# chr_22_raw_fam                                   14     genotypes_raw
# chr_22_raw_bim                                   14     genotypes_raw
# chr_1_postqc_bed                                 14  genotypes_postqc
# chr_1_postqc_fam                                 14  genotypes_postqc
# chr_1_postqc_bim                                 14  genotypes_postqc
# chr_2_postqc_bed                                 14  genotypes_postqc
# chr_2_postqc_fam                                 14  genotypes_postqc
# chr_2_postqc_bim                                 14  genotypes_postqc
# chr_3_postqc_bed                                 14  genotypes_postqc
# chr_3_postqc_fam                                 14  genotypes_postqc
# chr_3_postqc_bim                                 14  genotypes_postqc
# chr_4_postqc_bed                                 14  genotypes_postqc
# chr_4_postqc_fam                                 14  genotypes_postqc
# chr_4_postqc_bim                                 14  genotypes_postqc
# chr_5_postqc_bed                                 14  genotypes_postqc
# chr_5_postqc_fam                                 14  genotypes_postqc
# chr_5_postqc_bim                                 14  genotypes_postqc
# chr_6_postqc_bed                                 14  genotypes_postqc
# chr_6_postqc_fam                                 14  genotypes_postqc
# chr_6_postqc_bim                                 14  genotypes_postqc
# chr_7_postqc_bed                                 14  genotypes_postqc
# chr_7_postqc_fam                                 14  genotypes_postqc
# chr_7_postqc_bim                                 14  genotypes_postqc
# chr_8_postqc_bed                                 14  genotypes_postqc
# chr_8_postqc_fam                                 14  genotypes_postqc
# chr_8_postqc_bim                                 14  genotypes_postqc
# chr_9_postqc_bed                                 14  genotypes_postqc
# chr_9_postqc_fam                                 14  genotypes_postqc
# chr_9_postqc_bim                                 14  genotypes_postqc
# chr_10_postqc_bed                                14  genotypes_postqc
# chr_10_postqc_fam                                14  genotypes_postqc
# chr_10_postqc_bim                                14  genotypes_postqc
# chr_11_postqc_bed                                14  genotypes_postqc
# chr_11_postqc_fam                                14  genotypes_postqc
# chr_11_postqc_bim                                14  genotypes_postqc
# chr_12_postqc_bed                                14  genotypes_postqc
# chr_12_postqc_fam                                14  genotypes_postqc
# chr_12_postqc_bim                                14  genotypes_postqc
# chr_13_postqc_bed                                14  genotypes_postqc
# chr_13_postqc_fam                                14  genotypes_postqc
# chr_13_postqc_bim                                14  genotypes_postqc
# chr_14_postqc_bed                                14  genotypes_postqc
# chr_14_postqc_fam                                14  genotypes_postqc
# chr_14_postqc_bim                                14  genotypes_postqc
# chr_15_postqc_bed                                14  genotypes_postqc
# chr_15_postqc_fam                                14  genotypes_postqc
# chr_15_postqc_bim                                14  genotypes_postqc
# chr_16_postqc_bed                                14  genotypes_postqc
# chr_16_postqc_fam                                14  genotypes_postqc
# chr_16_postqc_bim                                14  genotypes_postqc
# chr_17_postqc_bed                                14  genotypes_postqc
# chr_17_postqc_fam                                14  genotypes_postqc
# chr_17_postqc_bim                                14  genotypes_postqc
# chr_18_postqc_bed                                14  genotypes_postqc
# chr_18_postqc_fam                                14  genotypes_postqc
# chr_18_postqc_bim                                14  genotypes_postqc
# chr_19_postqc_bed                                14  genotypes_postqc
# chr_19_postqc_fam                                14  genotypes_postqc
# chr_19_postqc_bim                                14  genotypes_postqc
# chr_20_postqc_bed                                14  genotypes_postqc
# chr_20_postqc_fam                                14  genotypes_postqc
# chr_20_postqc_bim                                14  genotypes_postqc
# chr_21_postqc_bed                                14  genotypes_postqc
# chr_21_postqc_fam                                14  genotypes_postqc
# chr_21_postqc_bim                                14  genotypes_postqc
# chr_22_postqc_bed                                14  genotypes_postqc
# chr_22_postqc_fam                                14  genotypes_postqc
# chr_22_postqc_bim                                14  genotypes_postqc
# pc1                                              14               pca
# pc2                                              14               pca
# pc3                                              14               pca
# pc4                                              14               pca
# pc5                                              14               pca
# pc6                                              14               pca
# pc7                                              14               pca
# pc8                                              14               pca
# pc9                                              14               pca
# pc10                                             14               pca
# pc11                                             14               pca
# pc12                                             14               pca
# pc13                                             14               pca
# pc14                                             14               pca
# pc15                                             14               pca
# pc16                                             14               pca
# pc17                                             14               pca
# pc18                                             14               pca
# pc19                                             14               pca
# pc20                                             14               pca
# used_in_pca_calculation                          14               pca
# pca_loadings_tsv                                 14               pca
#
#                                                                                field_string  \
# tabular_field_name
# collection_date                                                             Collection date
# version                                                                     Gencove version
# gencove_fastq_r1                                                                   R1_FASTQ
# gencove_fastq_r2                                                                   R2_FASTQ
# gencove_bam                                                                             BAM
# gencove_bai                                                                     BAM indices
# gencove_vcf                                            Imputation Variant Call Format (VCF)
# genecov_qc_bases                                                            Bases sequenced
# genecov_qc_bases_dedup                                                   Deduplicated bases
# gencove_qc_bases_dedup_mapped                                    Deduplicated bases aligned
# genecov_qc_effective_coverage                                            Effective coverage
# genecov_qc_fraction_contamination                                         DNA contamination
# genecov_qc_snps                                                                SNPs covered
# genecov_qc_format_passed                                       Passed FASTQ format validity
# genecov_qc_r1_eq_r2_passed                                          Passed paired-end count
# genecov_qc_r1_r2_ids_match_passed                                   Passed paired-end match
# genecov_qc_bases_passed                                              Passed Bases sequenced
# genecov_qc_bases_dedup_passed                                     Passed Deduplicated bases
# genecov_qc_bases_dedup_mapped_passed                      Passed Deduplicated bases aligned
# genecov_qc_effective_coverage_passed                              Passed Effective coverage
# genecov_qc_fraction_contamination_passed                           Passed DNA contamination
# genecov_qc_snps_passed                                                  Passed SNPs covered
# heterozygosity_proportion                                         Heterozygosity proportion
# pass_het_check                                             Passed Heterozygosity proportion
# sample_qc_gp_pass_rate                                     Genotype Probabilities pass rate
# sample_qc_gp_pass_check                                       Passed Genotype Probabilities
# genetic_sex                                                                         DNA sex
# chr_x_proportion                                    Proportion of alignment to chromosome X
# chr_y_proportion                                    Proportion of alignment to chromosome Y
# sample_qc_gender_match_check                                            Passed gender check
# variants_qc_parquet                                                      Variants QC report
# relatives                                                 Relatives based on IBD estimation
# relationship_king_tsv                                                    KING kingship file
# relationship_ibs_txt                                                         PLINK IBS file
# chr_1_raw_bed                             PLINK BED file for the Raw genotype data for chr1
# chr_1_raw_fam                                 PLINK FAM file accompanying Raw .bed for chr1
# chr_1_raw_bim                             PLINK BIM file for the Raw genotype data for chr1
# chr_2_raw_bed                             PLINK BED file for the Raw genotype data for chr2
# chr_2_raw_fam                                 PLINK FAM file accompanying Raw .bed for chr2
# chr_2_raw_bim                             PLINK BIM file for the Raw genotype data for chr2
# chr_3_raw_bed                             PLINK BED file for the Raw genotype data for chr3
# chr_3_raw_fam                                 PLINK FAM file accompanying Raw .bed for chr3
# chr_3_raw_bim                             PLINK BIM file for the Raw genotype data for chr3
# chr_4_raw_bed                             PLINK BED file for the Raw genotype data for chr4
# chr_4_raw_fam                                 PLINK FAM file accompanying Raw .bed for chr4
# chr_4_raw_bim                             PLINK BIM file for the Raw genotype data for chr4
# chr_5_raw_bed                             PLINK BED file for the Raw genotype data for chr5
# chr_5_raw_fam                                 PLINK FAM file accompanying Raw .bed for chr5
# chr_5_raw_bim                             PLINK BIM file for the Raw genotype data for chr5
# chr_6_raw_bed                             PLINK BED file for the Raw genotype data for chr6
# chr_6_raw_fam                                 PLINK FAM file accompanying Raw .bed for chr6
# chr_6_raw_bim                             PLINK BIM file for the Raw genotype data for chr6
# chr_7_raw_bed                             PLINK BED file for the Raw genotype data for chr7
# chr_7_raw_fam                                 PLINK FAM file accompanying Raw .bed for chr7
# chr_7_raw_bim                             PLINK BIM file for the Raw genotype data for chr7
# chr_8_raw_bed                             PLINK BED file for the Raw genotype data for chr8
# chr_8_raw_fam                                 PLINK FAM file accompanying Raw .bed for chr8
# chr_8_raw_bim                             PLINK BIM file for the Raw genotype data for chr8
# chr_9_raw_bed                             PLINK BED file for the Raw genotype data for chr9
# chr_9_raw_fam                                 PLINK FAM file accompanying Raw .bed for chr9
# chr_9_raw_bim                             PLINK BIM file for the Raw genotype data for chr9
# chr_10_raw_bed                            PLINK BED file for the Raw genotype data for c...
# chr_10_raw_fam                               PLINK FAM file accompanying Raw .bed for chr10
# chr_10_raw_bim                            PLINK BIM file for the Raw genotype data for c...
# chr_11_raw_bed                            PLINK BED file for the Raw genotype data for c...
# chr_11_raw_fam                               PLINK FAM file accompanying Raw .bed for chr11
# chr_11_raw_bim                            PLINK BIM file for the Raw genotype data for c...
# chr_12_raw_bed                            PLINK BED file for the Raw genotype data for c...
# chr_12_raw_fam                               PLINK FAM file accompanying Raw .bed for chr12
# chr_12_raw_bim                            PLINK BIM file for the Raw genotype data for c...
# chr_13_raw_bed                            PLINK BED file for the Raw genotype data for c...
# chr_13_raw_fam                               PLINK FAM file accompanying Raw .bed for chr13
# chr_13_raw_bim                            PLINK BIM file for the Raw genotype data for c...
# chr_14_raw_bed                            PLINK BED file for the Raw genotype data for c...
# chr_14_raw_fam                               PLINK FAM file accompanying Raw .bed for chr14
# chr_14_raw_bim                            PLINK BIM file for the Raw genotype data for c...
# chr_15_raw_bed                            PLINK BED file for the Raw genotype data for c...
# chr_15_raw_fam                               PLINK FAM file accompanying Raw .bed for chr15
# chr_15_raw_bim                            PLINK BIM file for the Raw genotype data for c...
# chr_16_raw_bed                            PLINK BED file for the Raw genotype data for c...
# chr_16_raw_fam                               PLINK FAM file accompanying Raw .bed for chr16
# chr_16_raw_bim                            PLINK BIM file for the Raw genotype data for c...
# chr_17_raw_bed                            PLINK BED file for the Raw genotype data for c...
# chr_17_raw_fam                               PLINK FAM file accompanying Raw .bed for chr17
# chr_17_raw_bim                            PLINK BIM file for the Raw genotype data for c...
# chr_18_raw_bed                            PLINK BED file for the Raw genotype data for c...
# chr_18_raw_fam                               PLINK FAM file accompanying Raw .bed for chr18
# chr_18_raw_bim                            PLINK BIM file for the Raw genotype data for c...
# chr_19_raw_bed                            PLINK BED file for the Raw genotype data for c...
# chr_19_raw_fam                               PLINK FAM file accompanying Raw .bed for chr19
# chr_19_raw_bim                            PLINK BIM file for the Raw genotype data for c...
# chr_20_raw_bed                            PLINK BED file for the Raw genotype data for c...
# chr_20_raw_fam                               PLINK FAM file accompanying Raw .bed for chr20
# chr_20_raw_bim                            PLINK BIM file for the Raw genotype data for c...
# chr_21_raw_bed                            PLINK BED file for the Raw genotype data for c...
# chr_21_raw_fam                               PLINK FAM file accompanying Raw .bed for chr21
# chr_21_raw_bim                            PLINK BIM file for the Raw genotype data for c...
# chr_22_raw_bed                            PLINK BED file for the Raw genotype data for c...
# chr_22_raw_fam                               PLINK FAM file accompanying Raw .bed for chr22
# chr_22_raw_bim                            PLINK BIM file for the Raw genotype data for c...
# chr_1_postqc_bed                          PLINK BED file for post QC genotype data for chr1
# chr_1_postqc_fam                               PLINK FAM file accompanying QC .bed for chr1
# chr_1_postqc_bim                          PLINK BIM file for the post QC genotype data f...
# chr_2_postqc_bed                          PLINK BED file for post QC genotype data for chr2
# chr_2_postqc_fam                               PLINK FAM file accompanying QC .bed for chr2
# chr_2_postqc_bim                          PLINK BIM file for the post QC genotype data f...
# chr_3_postqc_bed                          PLINK BED file for post QC genotype data for chr3
# chr_3_postqc_fam                               PLINK FAM file accompanying QC .bed for chr3
# chr_3_postqc_bim                          PLINK BIM file for the post QC genotype data f...
# chr_4_postqc_bed                          PLINK BED file for post QC genotype data for chr4
# chr_4_postqc_fam                               PLINK FAM file accompanying QC .bed for chr4
# chr_4_postqc_bim                          PLINK BIM file for the post QC genotype data f...
# chr_5_postqc_bed                          PLINK BED file for post QC genotype data for chr5
# chr_5_postqc_fam                               PLINK FAM file accompanying QC .bed for chr5
# chr_5_postqc_bim                          PLINK BIM file for the post QC genotype data f...
# chr_6_postqc_bed                          PLINK BED file for post QC genotype data for chr6
# chr_6_postqc_fam                               PLINK FAM file accompanying QC .bed for chr6
# chr_6_postqc_bim                          PLINK BIM file for the post QC genotype data f...
# chr_7_postqc_bed                          PLINK BED file for post QC genotype data for chr7
# chr_7_postqc_fam                               PLINK FAM file accompanying QC .bed for chr7
# chr_7_postqc_bim                          PLINK BIM file for the post QC genotype data f...
# chr_8_postqc_bed                          PLINK BED file for post QC genotype data for chr8
# chr_8_postqc_fam                               PLINK FAM file accompanying QC .bed for chr8
# chr_8_postqc_bim                          PLINK BIM file for the post QC genotype data f...
# chr_9_postqc_bed                          PLINK BED file for post QC genotype data for chr9
# chr_9_postqc_fam                               PLINK FAM file accompanying QC .bed for chr9
# chr_9_postqc_bim                          PLINK BIM file for the post QC genotype data f...
# chr_10_postqc_bed                         PLINK BED file for post QC genotype data for c...
# chr_10_postqc_fam                             PLINK FAM file accompanying QC .bed for chr10
# chr_10_postqc_bim                         PLINK BIM file for the post QC genotype data f...
# chr_11_postqc_bed                         PLINK BED file for post QC genotype data for c...
# chr_11_postqc_fam                             PLINK FAM file accompanying QC .bed for chr11
# chr_11_postqc_bim                         PLINK BIM file for the post QC genotype data f...
# chr_12_postqc_bed                         PLINK BED file for post QC genotype data for c...
# chr_12_postqc_fam                             PLINK FAM file accompanying QC .bed for chr12
# chr_12_postqc_bim                         PLINK BIM file for the post QC genotype data f...
# chr_13_postqc_bed                         PLINK BED file for post QC genotype data for c...
# chr_13_postqc_fam                             PLINK FAM file accompanying QC .bed for chr13
# chr_13_postqc_bim                         PLINK BIM file for the post QC genotype data f...
# chr_14_postqc_bed                         PLINK BED file for post QC genotype data for c...
# chr_14_postqc_fam                             PLINK FAM file accompanying QC .bed for chr14
# chr_14_postqc_bim                         PLINK BIM file for the post QC genotype data f...
# chr_15_postqc_bed                         PLINK BED file for post QC genotype data for c...
# chr_15_postqc_fam                             PLINK FAM file accompanying QC .bed for chr15
# chr_15_postqc_bim                         PLINK BIM file for the post QC genotype data f...
# chr_16_postqc_bed                         PLINK BED file for post QC genotype data for c...
# chr_16_postqc_fam                             PLINK FAM file accompanying QC .bed for chr16
# chr_16_postqc_bim                         PLINK BIM file for the post QC genotype data f...
# chr_17_postqc_bed                         PLINK BED file for post QC genotype data for c...
# chr_17_postqc_fam                             PLINK FAM file accompanying QC .bed for chr17
# chr_17_postqc_bim                         PLINK BIM file for the post QC genotype data f...
# chr_18_postqc_bed                         PLINK BED file for post QC genotype data for c...
# chr_18_postqc_fam                             PLINK FAM file accompanying QC .bed for chr18
# chr_18_postqc_bim                         PLINK BIM file for the post QC genotype data f...
# chr_19_postqc_bed                         PLINK BED file for post QC genotype data for c...
# chr_19_postqc_fam                             PLINK FAM file accompanying QC .bed for chr19
# chr_19_postqc_bim                         PLINK BIM file for the post QC genotype data f...
# chr_20_postqc_bed                         PLINK BED file for post QC genotype data for c...
# chr_20_postqc_fam                             PLINK FAM file accompanying QC .bed for chr20
# chr_20_postqc_bim                         PLINK BIM file for the post QC genotype data f...
# chr_21_postqc_bed                         PLINK BED file for post QC genotype data for c...
# chr_21_postqc_fam                             PLINK FAM file accompanying QC .bed for chr21
# chr_21_postqc_bim                         PLINK BIM file for the post QC genotype data f...
# chr_22_postqc_bed                         PLINK BED file for post QC genotype data for c...
# chr_22_postqc_fam                             PLINK FAM file accompanying QC .bed for chr22
# chr_22_postqc_bim                         PLINK BIM file for the post QC genotype data f...
# pc1                                                                   Principal component 1
# pc2                                                                   Principal component 2
# pc3                                                                   Principal component 3
# pc4                                                                   Principal component 4
# pc5                                                                   Principal component 5
# pc6                                                                   Principal component 6
# pc7                                                                   Principal component 7
# pc8                                                                   Principal component 8
# pc9                                                                   Principal component 9
# pc10                                                                 Principal component 10
# pc11                                                                 Principal component 11
# pc12                                                                 Principal component 12
# pc13                                                                 Principal component 13
# pc14                                                                 Principal component 14
# pc15                                                                 Principal component 15
# pc16                                                                 Principal component 16
# pc17                                                                 Principal component 17
# pc18                                                                 Principal component 18
# pc19                                                                 Principal component 19
# pc20                                                                 Principal component 20
# used_in_pca_calculation                            Included in principal component analysis
# pca_loadings_tsv                                           Principal component loading file
#
#                                                                          description_string  \
# tabular_field_name
# collection_date                           The date of downloading Gencove results from t...
# version                                                          Gencove API version 1 or 2
# gencove_fastq_r1                          Per sample FASTQ file, a text file that contai...
# gencove_fastq_r2                          Per sample FASTQ file, a text file that contai...
# gencove_bam                               Per sample Binary Alignment Map (BAM) file for...
# gencove_bai                                                 Per sample indices for BAM file
# gencove_vcf                               Per sample VCF, a text file storing imputed ge...
# genecov_qc_bases                          number of total bases sequenced. from genecov ...
# genecov_qc_bases_dedup                    number of deduplicated bases. from genecov qc ...
# gencove_qc_bases_dedup_mapped             number of deduplicated bases that have aligned...
# genecov_qc_effective_coverage                      effective coverage. from genecov qc file
# genecov_qc_fraction_contamination         contamination by DNA from another sample of th...
# genecov_qc_snps                           number of variants in reference panel that are...
# genecov_qc_format_passed                  Indicates proper formatting of the input FASTQ...
# genecov_qc_r1_eq_r2_passed                Indicates number of bases in R1 file equal to ...
# genecov_qc_r1_r2_ids_match_passed         Indicates R1 read identifiers match R2 read id...
# genecov_qc_bases_passed                   Indicates number of total bases sequenced grea...
# genecov_qc_bases_dedup_passed             Indicates number of deduplicated bases greater...
# genecov_qc_bases_dedup_mapped_passed      Indicates number of deduplicated bases aligned...
# genecov_qc_effective_coverage_passed      Indicates effective coverage greater than 0. f...
# genecov_qc_fraction_contamination_passed  Indicates contamination by DNA less than 0.06....
# genecov_qc_snps_passed                    Indicates number of variants covered by at lea...
# heterozygosity_proportion                 Estimated heterozygosity proportion across a s...
# pass_het_check                            Indicates heterozygosity proportion is less th...
# sample_qc_gp_pass_rate                    Proportion of genotypes with maximum GP greate...
# sample_qc_gp_pass_check                   Indicates proportion of GP greater than 0.9 is...
# genetic_sex                               Sex as determined by the percentage of read-al...
# chr_x_proportion                                percentage of reads aligned to chromosome X
# chr_y_proportion                                percentage of reads aligned to chromosome Y
# sample_qc_gender_match_check              Indicates inferred_gender and submitted_gender...
# variants_qc_parquet                                                  QC report for each SNP
# relatives                                 List of second and first degree relatives acco...
# relationship_king_tsv                     KING kinship coefficient matrix for pairs of p...
# relationship_ibs_txt                      PLINK IBS coefficient matrix for paris of part...
# chr_1_raw_bed                             Raw genotype calls (per chromosome) in binary ...
# chr_1_raw_fam                             PLINK sample information file accompanying a ....
# chr_1_raw_bim                             PLINK variant information file (per chromosome...
# chr_2_raw_bed                             Raw genotype calls (per chromosome) in binary ...
# chr_2_raw_fam                             PLINK sample information file accompanying a ....
# chr_2_raw_bim                             PLINK variant information file (per chromosome...
# chr_3_raw_bed                             Raw genotype calls (per chromosome) in binary ...
# chr_3_raw_fam                             PLINK sample information file accompanying a ....
# chr_3_raw_bim                             PLINK variant information file (per chromosome...
# chr_4_raw_bed                             Raw genotype calls (per chromosome) in binary ...
# chr_4_raw_fam                             PLINK sample information file accompanying a ....
# chr_4_raw_bim                             PLINK variant information file (per chromosome...
# chr_5_raw_bed                             Raw genotype calls (per chromosome) in binary ...
# chr_5_raw_fam                             PLINK sample information file accompanying a ....
# chr_5_raw_bim                             PLINK variant information file (per chromosome...
# chr_6_raw_bed                             Raw genotype calls (per chromosome) in binary ...
# chr_6_raw_fam                             PLINK sample information file accompanying a ....
# chr_6_raw_bim                             PLINK variant information file (per chromosome...
# chr_7_raw_bed                             Raw genotype calls (per chromosome) in binary ...
# chr_7_raw_fam                             PLINK sample information file accompanying a ....
# chr_7_raw_bim                             PLINK variant information file (per chromosome...
# chr_8_raw_bed                             Raw genotype calls (per chromosome) in binary ...
# chr_8_raw_fam                             PLINK sample information file accompanying a ....
# chr_8_raw_bim                             PLINK variant information file (per chromosome...
# chr_9_raw_bed                             Raw genotype calls (per chromosome) in binary ...
# chr_9_raw_fam                             PLINK sample information file accompanying a ....
# chr_9_raw_bim                             PLINK variant information file (per chromosome...
# chr_10_raw_bed                            Raw genotype calls (per chromosome) in binary ...
# chr_10_raw_fam                            PLINK sample information file accompanying a ....
# chr_10_raw_bim                            PLINK variant information file (per chromosome...
# chr_11_raw_bed                            Raw genotype calls (per chromosome) in binary ...
# chr_11_raw_fam                            PLINK sample information file accompanying a ....
# chr_11_raw_bim                            PLINK variant information file (per chromosome...
# chr_12_raw_bed                            Raw genotype calls (per chromosome) in binary ...
# chr_12_raw_fam                            PLINK sample information file accompanying a ....
# chr_12_raw_bim                            PLINK variant information file (per chromosome...
# chr_13_raw_bed                            Raw genotype calls (per chromosome) in binary ...
# chr_13_raw_fam                            PLINK sample information file accompanying a ....
# chr_13_raw_bim                            PLINK variant information file (per chromosome...
# chr_14_raw_bed                            Raw genotype calls (per chromosome) in binary ...
# chr_14_raw_fam                            PLINK sample information file accompanying a ....
# chr_14_raw_bim                            PLINK variant information file (per chromosome...
# chr_15_raw_bed                            Raw genotype calls (per chromosome) in binary ...
# chr_15_raw_fam                            PLINK sample information file accompanying a ....
# chr_15_raw_bim                            PLINK variant information file (per chromosome...
# chr_16_raw_bed                            Raw genotype calls (per chromosome) in binary ...
# chr_16_raw_fam                            PLINK sample information file accompanying a ....
# chr_16_raw_bim                            PLINK variant information file (per chromosome...
# chr_17_raw_bed                            Raw genotype calls (per chromosome) in binary ...
# chr_17_raw_fam                            PLINK sample information file accompanying a ....
# chr_17_raw_bim                            PLINK variant information file (per chromosome...
# chr_18_raw_bed                            Raw genotype calls (per chromosome) in binary ...
# chr_18_raw_fam                            PLINK sample information file accompanying a ....
# chr_18_raw_bim                            PLINK variant information file (per chromosome...
# chr_19_raw_bed                            Raw genotype calls (per chromosome) in binary ...
# chr_19_raw_fam                            PLINK sample information file accompanying a ....
# chr_19_raw_bim                            PLINK variant information file (per chromosome...
# chr_20_raw_bed                            Raw genotype calls (per chromosome) in binary ...
# chr_20_raw_fam                            PLINK sample information file accompanying a ....
# chr_20_raw_bim                            PLINK variant information file (per chromosome...
# chr_21_raw_bed                            Raw genotype calls (per chromosome) in binary ...
# chr_21_raw_fam                            PLINK sample information file accompanying a ....
# chr_21_raw_bim                            PLINK variant information file (per chromosome...
# chr_22_raw_bed                            Raw genotype calls (per chromosome) in binary ...
# chr_22_raw_fam                            PLINK sample information file accompanying a ....
# chr_22_raw_bim                            PLINK variant information file (per chromosome...
# chr_1_postqc_bed                          Raw genotype calls (per chromosome) in binary ...
# chr_1_postqc_fam                          PLINK sample information file accompanying a ....
# chr_1_postqc_bim                          PLINK variant information file (per chromosome...
# chr_2_postqc_bed                          Raw genotype calls (per chromosome) in binary ...
# chr_2_postqc_fam                          PLINK sample information file accompanying a ....
# chr_2_postqc_bim                          PLINK variant information file (per chromosome...
# chr_3_postqc_bed                          Raw genotype calls (per chromosome) in binary ...
# chr_3_postqc_fam                          PLINK sample information file accompanying a ....
# chr_3_postqc_bim                          PLINK variant information file (per chromosome...
# chr_4_postqc_bed                          Raw genotype calls (per chromosome) in binary ...
# chr_4_postqc_fam                          PLINK sample information file accompanying a ....
# chr_4_postqc_bim                          PLINK variant information file (per chromosome...
# chr_5_postqc_bed                          Raw genotype calls (per chromosome) in binary ...
# chr_5_postqc_fam                          PLINK sample information file accompanying a ....
# chr_5_postqc_bim                          PLINK variant information file (per chromosome...
# chr_6_postqc_bed                          Raw genotype calls (per chromosome) in binary ...
# chr_6_postqc_fam                          PLINK sample information file accompanying a ....
# chr_6_postqc_bim                          PLINK variant information file (per chromosome...
# chr_7_postqc_bed                          Raw genotype calls (per chromosome) in binary ...
# chr_7_postqc_fam                          PLINK sample information file accompanying a ....
# chr_7_postqc_bim                          PLINK variant information file (per chromosome...
# chr_8_postqc_bed                          Raw genotype calls (per chromosome) in binary ...
# chr_8_postqc_fam                          PLINK sample information file accompanying a ....
# chr_8_postqc_bim                          PLINK variant information file (per chromosome...
# chr_9_postqc_bed                          Raw genotype calls (per chromosome) in binary ...
# chr_9_postqc_fam                          PLINK sample information file accompanying a ....
# chr_9_postqc_bim                          PLINK variant information file (per chromosome...
# chr_10_postqc_bed                         Raw genotype calls (per chromosome) in binary ...
# chr_10_postqc_fam                         PLINK sample information file accompanying a ....
# chr_10_postqc_bim                         PLINK variant information file (per chromosome...
# chr_11_postqc_bed                         Raw genotype calls (per chromosome) in binary ...
# chr_11_postqc_fam                         PLINK sample information file accompanying a ....
# chr_11_postqc_bim                         PLINK variant information file (per chromosome...
# chr_12_postqc_bed                         Raw genotype calls (per chromosome) in binary ...
# chr_12_postqc_fam                         PLINK sample information file accompanying a ....
# chr_12_postqc_bim                         PLINK variant information file (per chromosome...
# chr_13_postqc_bed                         Raw genotype calls (per chromosome) in binary ...
# chr_13_postqc_fam                         PLINK sample information file accompanying a ....
# chr_13_postqc_bim                         PLINK variant information file (per chromosome...
# chr_14_postqc_bed                         Raw genotype calls (per chromosome) in binary ...
# chr_14_postqc_fam                         PLINK sample information file accompanying a ....
# chr_14_postqc_bim                         PLINK variant information file (per chromosome...
# chr_15_postqc_bed                         Raw genotype calls (per chromosome) in binary ...
# chr_15_postqc_fam                         PLINK sample information file accompanying a ....
# chr_15_postqc_bim                         PLINK variant information file (per chromosome...
# chr_16_postqc_bed                         Raw genotype calls (per chromosome) in binary ...
# chr_16_postqc_fam                         PLINK sample information file accompanying a ....
# chr_16_postqc_bim                         PLINK variant information file (per chromosome...
# chr_17_postqc_bed                         Raw genotype calls (per chromosome) in binary ...
# chr_17_postqc_fam                         PLINK sample information file accompanying a ....
# chr_17_postqc_bim                         PLINK variant information file (per chromosome...
# chr_18_postqc_bed                         Raw genotype calls (per chromosome) in binary ...
# chr_18_postqc_fam                         PLINK sample information file accompanying a ....
# chr_18_postqc_bim                         PLINK variant information file (per chromosome...
# chr_19_postqc_bed                         Raw genotype calls (per chromosome) in binary ...
# chr_19_postqc_fam                         PLINK sample information file accompanying a ....
# chr_19_postqc_bim                         PLINK variant information file (per chromosome...
# chr_20_postqc_bed                         Raw genotype calls (per chromosome) in binary ...
# chr_20_postqc_fam                         PLINK sample information file accompanying a ....
# chr_20_postqc_bim                         PLINK variant information file (per chromosome...
# chr_21_postqc_bed                         Raw genotype calls (per chromosome) in binary ...
# chr_21_postqc_fam                         PLINK sample information file accompanying a ....
# chr_21_postqc_bim                         PLINK variant information file (per chromosome...
# chr_22_postqc_bed                         Raw genotype calls (per chromosome) in binary ...
# chr_22_postqc_fam                         PLINK sample information file accompanying a ....
# chr_22_postqc_bim                         PLINK variant information file (per chromosome...
# pc1                                               Score for projected principal component 1
# ...
# chr_21_postqc_bim                           NaN             NaN
# chr_22_postqc_bed                           NaN             NaN
# chr_22_postqc_fam                           NaN             NaN
# chr_22_postqc_bim                           NaN             NaN
# pc1                                         NaN             NaN
# pc2                                         NaN             NaN
# pc3                                         NaN             NaN
# pc4                                         NaN             NaN
# pc5                                         NaN             NaN
# pc6                                         NaN             NaN
# pc7                                         NaN             NaN
# pc8                                         NaN             NaN
# pc9                                         NaN             NaN
# pc10                                        NaN             NaN
# pc11                                        NaN             NaN
# pc12                                        NaN             NaN
# pc13                                        NaN             NaN
# pc14                                        NaN             NaN
# pc15                                        NaN             NaN
# pc16                                        NaN             NaN
# pc17                                        NaN             NaN
# pc18                                        NaN             NaN
# pc19                                        NaN             NaN
# pc20                                        NaN             NaN
# used_in_pca_calculation                     NaN             NaN
# pca_loadings_tsv                            NaN             NaN
#
#                                             list_of_tags    pandas_dtype
# tabular_field_name
# collection_date                           Human Genetics  datetime64[ns]
# version                                   Human Genetics        category
# gencove_fastq_r1                          Human Genetics          string
# gencove_fastq_r2                          Human Genetics          string
# gencove_bam                               Human Genetics          string
# gencove_bai                               Human Genetics          string
# gencove_vcf                               Human Genetics          string
# genecov_qc_bases                          Human Genetics             int
# genecov_qc_bases_dedup                    Human Genetics             int
# gencove_qc_bases_dedup_mapped             Human Genetics             int
# genecov_qc_effective_coverage             Human Genetics           float
# genecov_qc_fraction_contamination         Human Genetics           float
# genecov_qc_snps                           Human Genetics             int
# genecov_qc_format_passed                  Human Genetics          object
# genecov_qc_r1_eq_r2_passed                Human Genetics          object
# genecov_qc_r1_r2_ids_match_passed         Human Genetics          object
# genecov_qc_bases_passed                   Human Genetics          object
# genecov_qc_bases_dedup_passed             Human Genetics          object
# genecov_qc_bases_dedup_mapped_passed      Human Genetics          object
# genecov_qc_effective_coverage_passed      Human Genetics          object
# genecov_qc_fraction_contamination_passed  Human Genetics          object
# genecov_qc_snps_passed                    Human Genetics          object
# heterozygosity_proportion                 Human Genetics           float
# pass_het_check                            Human Genetics            bool
# sample_qc_gp_pass_rate                    Human Genetics           float
# sample_qc_gp_pass_check                   Human Genetics            bool
# genetic_sex                               Human Genetics             int
# chr_x_proportion                          Human Genetics           float
# chr_y_proportion                          Human Genetics           float
# sample_qc_gender_match_check              Human Genetics            bool
# variants_qc_parquet                       Human Genetics        category
# relatives                                 Human Genetics          string
# relationship_king_tsv                     Human Genetics        category
# relationship_ibs_txt                      Human Genetics        category
# chr_1_raw_bed                             Human Genetics        category
# chr_1_raw_fam                             Human Genetics        category
# chr_1_raw_bim                             Human Genetics        category
# chr_2_raw_bed                             Human Genetics        category
# chr_2_raw_fam                             Human Genetics        category
# chr_2_raw_bim                             Human Genetics        category
# chr_3_raw_bed                             Human Genetics        category
# chr_3_raw_fam                             Human Genetics        category
# chr_3_raw_bim                             Human Genetics        category
# chr_4_raw_bed                             Human Genetics        category
# chr_4_raw_fam                             Human Genetics        category
# chr_4_raw_bim                             Human Genetics        category
# chr_5_raw_bed                             Human Genetics        category
# chr_5_raw_fam                             Human Genetics        category
# chr_5_raw_bim                             Human Genetics        category
# chr_6_raw_bed                             Human Genetics        category
# chr_6_raw_fam                             Human Genetics        category
# chr_6_raw_bim                             Human Genetics        category
# chr_7_raw_bed                             Human Genetics        category
# chr_7_raw_fam                             Human Genetics        category
# chr_7_raw_bim                             Human Genetics        category
# chr_8_raw_bed                             Human Genetics        category
# chr_8_raw_fam                             Human Genetics        category
# chr_8_raw_bim                             Human Genetics        category
# chr_9_raw_bed                             Human Genetics        category
# chr_9_raw_fam                             Human Genetics        category
# chr_9_raw_bim                             Human Genetics        category
# chr_10_raw_bed                            Human Genetics        category
# chr_10_raw_fam                            Human Genetics        category
# chr_10_raw_bim                            Human Genetics        category
# chr_11_raw_bed                            Human Genetics        category
# chr_11_raw_fam                            Human Genetics        category
# chr_11_raw_bim                            Human Genetics        category
# chr_12_raw_bed                            Human Genetics        category
# chr_12_raw_fam                            Human Genetics        category
# chr_12_raw_bim                            Human Genetics        category
# chr_13_raw_bed                            Human Genetics        category
# chr_13_raw_fam                            Human Genetics        category
# chr_13_raw_bim                            Human Genetics        category
# chr_14_raw_bed                            Human Genetics        category
# chr_14_raw_fam                            Human Genetics        category
# chr_14_raw_bim                            Human Genetics        category
# chr_15_raw_bed                            Human Genetics        category
# chr_15_raw_fam                            Human Genetics        category
# chr_15_raw_bim                            Human Genetics        category
# chr_16_raw_bed                            Human Genetics        category
# chr_16_raw_fam                            Human Genetics        category
# chr_16_raw_bim                            Human Genetics        category
# chr_17_raw_bed                            Human Genetics        category
# chr_17_raw_fam                            Human Genetics        category
# chr_17_raw_bim                            Human Genetics        category
# chr_18_raw_bed                            Human Genetics        category
# chr_18_raw_fam                            Human Genetics        category
# chr_18_raw_bim                            Human Genetics        category
# chr_19_raw_bed                            Human Genetics        category
# chr_19_raw_fam                            Human Genetics        category
# chr_19_raw_bim                            Human Genetics        category
# chr_20_raw_bed                            Human Genetics        category
# chr_20_raw_fam                            Human Genetics        category
# chr_20_raw_bim                            Human Genetics        category
# chr_21_raw_bed                            Human Genetics        category
# chr_21_raw_fam                            Human Genetics        category
# chr_21_raw_bim                            Human Genetics        category
# chr_22_raw_bed                            Human Genetics        category
# chr_22_raw_fam                            Human Genetics        category
# chr_22_raw_bim                            Human Genetics        category
# chr_1_postqc_bed                          Human Genetics        category
# chr_1_postqc_fam                          Human Genetics        category
# chr_1_postqc_bim                          Human Genetics        category
# chr_2_postqc_bed                          Human Genetics        category
# chr_2_postqc_fam                          Human Genetics        category
# chr_2_postqc_bim                          Human Genetics        category
# chr_3_postqc_bed                          Human Genetics        category
# chr_3_postqc_fam                          Human Genetics        category
# chr_3_postqc_bim                          Human Genetics        category
# chr_4_postqc_bed                          Human Genetics        category
# chr_4_postqc_fam                          Human Genetics        category
# chr_4_postqc_bim                          Human Genetics        category
# chr_5_postqc_bed                          Human Genetics        category
# chr_5_postqc_fam                          Human Genetics        category
# chr_5_postqc_bim                          Human Genetics        category
# chr_6_postqc_bed                          Human Genetics        category
# chr_6_postqc_fam                          Human Genetics        category
# chr_6_postqc_bim                          Human Genetics        category
# chr_7_postqc_bed                          Human Genetics        category
# chr_7_postqc_fam                          Human Genetics        category
# chr_7_postqc_bim                          Human Genetics        category
# chr_8_postqc_bed                          Human Genetics        category
# chr_8_postqc_fam                          Human Genetics        category
# chr_8_postqc_bim                          Human Genetics        category
# chr_9_postqc_bed                          Human Genetics        category
# chr_9_postqc_fam                          Human Genetics        category
# chr_9_postqc_bim                          Human Genetics        category
# chr_10_postqc_bed                         Human Genetics        category
# chr_10_postqc_fam                         Human Genetics        category
# chr_10_postqc_bim                         Human Genetics        category
# chr_11_postqc_bed                         Human Genetics        category
# chr_11_postqc_fam                         Human Genetics        category
# chr_11_postqc_bim                         Human Genetics        category
# chr_12_postqc_bed                         Human Genetics        category
# chr_12_postqc_fam                         Human Genetics        category
# chr_12_postqc_bim                         Human Genetics        category
# chr_13_postqc_bed                         Human Genetics        category
# chr_13_postqc_fam                         Human Genetics        category
# chr_13_postqc_bim                         Human Genetics        category
# chr_14_postqc_bed                         Human Genetics        category
# chr_14_postqc_fam                         Human Genetics        category
# chr_14_postqc_bim                         Human Genetics        category
# chr_15_postqc_bed                         Human Genetics        category
# chr_15_postqc_fam                         Human Genetics        category
# chr_15_postqc_bim                         Human Genetics        category
# chr_16_postqc_bed                         Human Genetics        category
# chr_16_postqc_fam                         Human Genetics        category
# chr_16_postqc_bim                         Human Genetics        category
# chr_17_postqc_bed                         Human Genetics        category
# chr_17_postqc_fam                         Human Genetics        category
# chr_17_postqc_bim                         Human Genetics        category
# chr_18_postqc_bed                         Human Genetics        category
# chr_18_postqc_fam                         Human Genetics        category
# chr_18_postqc_bim                         Human Genetics        category
# chr_19_postqc_bed                         Human Genetics        category
# chr_19_postqc_fam                         Human Genetics        category
# chr_19_postqc_bim                         Human Genetics        category
# chr_20_postqc_bed                         Human Genetics        category
# chr_20_postqc_fam                         Human Genetics        category
# chr_20_postqc_bim                         Human Genetics        category
# chr_21_postqc_bed                         Human Genetics        category
# chr_21_postqc_fam                         Human Genetics        category
# chr_21_postqc_bim                         Human Genetics        category
# chr_22_postqc_bed                         Human Genetics        category
# chr_22_postqc_fam                         Human Genetics        category
# chr_22_postqc_bim                         Human Genetics        category
# pc1                                       Human Genetics           float
# pc2                                       Human Genetics           float
# pc3                                       Human Genetics           float
# pc4                                       Human Genetics           float
# pc5                                       Human Genetics           float
# pc6                                       Human Genetics           float
# pc7                                       Human Genetics           float
# pc8                                       Human Genetics           float
# pc9                                       Human Genetics           float
# pc10                                      Human Genetics           float
# pc11                                      Human Genetics           float
# pc12                                      Human Genetics           float
# pc13                                      Human Genetics           float
# pc14                                      Human Genetics           float
# pc15                                      Human Genetics           float
# pc16                                      Human Genetics           float
# pc17                                      Human Genetics           float
# pc18                                      Human Genetics           float
# pc19                                      Human Genetics           float
# pc20                                      Human Genetics           float
# used_in_pca_calculation                   Human Genetics            bool
# pca_loadings_tsv                          Human Genetics        category
